# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import ensemble
from sklearn.model_selection import cross_val_score
# %matplotlib inline

# %%
y2015 = pd.read_csv(
    'https://www.dropbox.com/s/0so14yudedjmm5m/LoanStats3d.csv?dl=1',
    skipinitialspace=True,
    header=1
)
# Out:
# c:\users\nstow\appdata\local\programs\python\python37\lib\site-packages\IPython\core\interactiveshell.py:3044: DtypeWarning: Columns (0,19,55) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
categorical = y2015.select_dtypes(include=['object'])
for i in categorical:
    column = categorical[i]
    print(i)
    print(column.nunique())
# Out:
# id
# 421097
# term
# 2
# int_rate
# 110
# grade
# 7
# sub_grade
# 35
# emp_title
# 120812
# emp_length
# 11
# home_ownership
# 4
# verification_status
# 3
# issue_d
# 12
# loan_status
# 7
# pymnt_plan
# 1
# url
# 421095
# desc
# 34
# purpose
# 14
# title
# 27
# zip_code
# 914
# addr_state
# 49
# earliest_cr_line
# 668
# revol_util
# 1211
# initial_list_status
# 2
# last_pymnt_d
# 25
# next_pymnt_d
# 4
# last_credit_pull_d
# 26
# application_type
# 2
# verification_status_joint
# 3

# %%
# Convert ID and Interest Rate to numeric.
y2015['id'] = pd.to_numeric(y2015['id'], errors='coerce')
y2015['int_rate'] = pd.to_numeric(y2015['int_rate'].str.strip('%'), errors='coerce')

# Drop other columns with many unique variables
y2015.drop(['url', 'emp_title', 'zip_code', 'earliest_cr_line', 'revol_util',
            'sub_grade', 'addr_state', 'desc'], 1, inplace=True)

# %%
y2015 = y2015[:-2]

# %%
rfc = ensemble.RandomForestClassifier()
X = y2015.drop('loan_status', 1)
Y = y2015['loan_status']
X = pd.get_dummies(X)
X = X.dropna(axis=1)

cross_val_score(rfc, X, Y, cv=10)
# Out:
# c:\users\nstow\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# c:\users\nstow\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# c:\users\nstow\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# c:\users\nstow\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# c:\users\nstow\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# c:\users\nstow\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# c:\users\nstow\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# c:\users\nstow\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# c:\users\nstow\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# c:\users\nstow\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# array([0.97962528, 0.98067013, 0.98143003, 0.98185747, 0.96991213,
#        0.97876989, 0.92673775, 0.98071671, 0.98009832, 0.9802166 ])

# %% [markdown]
# ### Data Cleaning

# %%
## create a correlation matrix that is sorted
c = y2015.corr().abs()

s = c.unstack()
so = s.sort_values(kind="quicksort", ascending=False)

pd.set_option('display.max_rows', 5000)
print(so)
# Out:
# total_il_high_credit_limit      total_il_high_credit_limit        1.000000
# bc_util                         bc_util                           1.000000
# mths_since_recent_bc            mths_since_recent_bc              1.000000
# mort_acc                        mort_acc                          1.000000
# mo_sin_rcnt_tl                  mo_sin_rcnt_tl                    1.000000
# mo_sin_rcnt_rev_tl_op           mo_sin_rcnt_rev_tl_op             1.000000
# mo_sin_old_rev_tl_op            mo_sin_old_rev_tl_op              1.000000
# mo_sin_old_il_acct              mo_sin_old_il_acct                1.000000
# delinq_amnt                     delinq_amnt                       1.000000
# chargeoff_within_12_mths        chargeoff_within_12_mths          1.000000
# bc_open_to_buy                  bc_open_to_buy                    1.000000
# mths_since_recent_inq           mths_since_recent_inq             1.000000
# avg_cur_bal                     avg_cur_bal                       1.000000
# acc_open_past_24mths            acc_open_past_24mths              1.000000
# inq_last_12m                    inq_last_12m                      1.000000
# total_cu_tl                     total_cu_tl                       1.000000
# inq_fi                          inq_fi                            1.000000
# total_rev_hi_lim                total_rev_hi_lim                  1.000000
# all_util                        all_util                          1.000000
# max_bal_bc                      max_bal_bc                        1.000000
# mths_since_recent_bc_dlq        mths_since_recent_bc_dlq          1.000000
# mths_since_recent_revol_delinq  mths_since_recent_revol_delinq    1.000000
# open_rv_12m                     open_rv_12m                       1.000000
# num_tl_120dpd_2m                num_tl_120dpd_2m                  1.000000
# tot_hi_cred_lim                 tot_hi_cred_lim                   1.000000
# tax_liens                       tax_liens                         1.000000
# pub_rec_bankruptcies            pub_rec_bankruptcies              1.000000
# percent_bc_gt_75                percent_bc_gt_75                  1.000000
# pct_tl_nvr_dlq                  pct_tl_nvr_dlq                    1.000000
# num_tl_op_past_12m              num_tl_op_past_12m                1.000000
# num_tl_90g_dpd_24m              num_tl_90g_dpd_24m                1.000000
# num_tl_30dpd                    num_tl_30dpd                      1.000000
# num_sats                        num_sats                          1.000000
# num_accts_ever_120_pd           num_accts_ever_120_pd             1.000000
# num_rev_tl_bal_gt_0             num_rev_tl_bal_gt_0               1.000000
# num_rev_accts                   num_rev_accts                     1.000000
# num_op_rev_tl                   num_op_rev_tl                     1.000000
# num_il_tl                       num_il_tl                         1.000000
# num_bc_tl                       num_bc_tl                         1.000000
# num_bc_sats                     num_bc_sats                       1.000000
# num_actv_rev_tl                 num_actv_rev_tl                   1.000000
# num_actv_bc_tl                  num_actv_bc_tl                    1.000000
# open_rv_24m                     open_rv_24m                       1.000000
# il_util                         il_util                           1.000000
# total_bc_limit                  total_bc_limit                    1.000000
# dti                             dti                               1.000000
# total_acc                       total_acc                         1.000000
# revol_bal                       revol_bal                         1.000000
# pub_rec                         pub_rec                           1.000000
# open_acc                        open_acc                          1.000000
# mths_since_last_record          mths_since_last_record            1.000000
# mths_since_last_delinq          mths_since_last_delinq            1.000000
# inq_last_6mths                  inq_last_6mths                    1.000000
# delinq_2yrs                     delinq_2yrs                       1.000000
# annual_inc                      annual_inc                        1.000000
# out_prncp_inv                   out_prncp_inv                     1.000000
# installment                     installment                       1.000000
# int_rate                        int_rate                          1.000000
# funded_amnt_inv                 funded_amnt_inv                   1.000000
# funded_amnt                     funded_amnt                       1.000000
#                                 loan_amnt                         1.000000
# loan_amnt                       funded_amnt                       1.000000
#                                 loan_amnt                         1.000000
# member_id                       member_id                         1.000000
# out_prncp                       out_prncp                         1.000000
# total_pymnt                     total_pymnt                       1.000000
# total_bal_il                    total_bal_il                      1.000000
# dti_joint                       dti_joint                         1.000000
# mths_since_rcnt_il              mths_since_rcnt_il                1.000000
# open_il_24m                     open_il_24m                       1.000000
# open_il_12m                     open_il_12m                       1.000000
# open_il_6m                      open_il_6m                        1.000000
# open_acc_6m                     open_acc_6m                       1.000000
# tot_cur_bal                     tot_cur_bal                       1.000000
# tot_coll_amt                    tot_coll_amt                      1.000000
# acc_now_delinq                  acc_now_delinq                    1.000000
# annual_inc_joint                annual_inc_joint                  1.000000
# total_pymnt_inv                 total_pymnt_inv                   1.000000
# mths_since_last_major_derog     mths_since_last_major_derog       1.000000
# collections_12_mths_ex_med      collections_12_mths_ex_med        1.000000
# last_pymnt_amnt                 last_pymnt_amnt                   1.000000
# collection_recovery_fee         collection_recovery_fee           1.000000
# recoveries                      recoveries                        1.000000
# total_rec_late_fee              total_rec_late_fee                1.000000
# total_rec_int                   total_rec_int                     1.000000
# total_rec_prncp                 total_rec_prncp                   1.000000
# total_bal_ex_mort               total_bal_ex_mort                 1.000000
# id                              id                                1.000000
# out_prncp_inv                   out_prncp                         0.999997
# out_prncp                       out_prncp_inv                     0.999997
# total_pymnt                     total_pymnt_inv                   0.999997
# total_pymnt_inv                 total_pymnt                       0.999997
# funded_amnt_inv                 loan_amnt                         0.999994
# loan_amnt                       funded_amnt_inv                   0.999994
# funded_amnt                     funded_amnt_inv                   0.999994
# funded_amnt_inv                 funded_amnt                       0.999994
# open_acc                        num_sats                          0.998602
# num_sats                        open_acc                          0.998602
# id                              member_id                         0.997540
# member_id                       id                                0.997540
# num_actv_rev_tl                 num_rev_tl_bal_gt_0               0.980849
# num_rev_tl_bal_gt_0             num_actv_rev_tl                   0.980849
# tot_cur_bal                     tot_hi_cred_lim                   0.974943
# tot_hi_cred_lim                 tot_cur_bal                       0.974943
# recoveries                      collection_recovery_fee           0.973343
# collection_recovery_fee         recoveries                        0.973343
# total_pymnt_inv                 total_rec_prncp                   0.964892
# total_rec_prncp                 total_pymnt_inv                   0.964892
# total_pymnt                     total_rec_prncp                   0.964876
# total_rec_prncp                 total_pymnt                       0.964876
# total_il_high_credit_limit      total_bal_il                      0.958632
# total_bal_il                    total_il_high_credit_limit        0.958632
# installment                     loan_amnt                         0.941205
#                                 funded_amnt                       0.941205
# loan_amnt                       installment                       0.941205
# funded_amnt                     installment                       0.941205
# installment                     funded_amnt_inv                   0.941187
# funded_amnt_inv                 installment                       0.941187
# total_bal_ex_mort               total_bal_il                      0.904226
# total_bal_il                    total_bal_ex_mort                 0.904226
# mths_since_recent_bc_dlq        mths_since_recent_revol_delinq    0.891783
# mths_since_recent_revol_delinq  mths_since_recent_bc_dlq          0.891783
#                                 mths_since_last_delinq            0.864996
# mths_since_last_delinq          mths_since_recent_revol_delinq    0.864996
# total_bal_ex_mort               total_il_high_credit_limit        0.864517
# total_il_high_credit_limit      total_bal_ex_mort                 0.864517
# bc_util                         percent_bc_gt_75                  0.844485
# percent_bc_gt_75                bc_util                           0.844485
# acc_open_past_24mths            open_rv_24m                       0.842395
# open_rv_24m                     acc_open_past_24mths              0.842395
# num_bc_tl                       num_rev_accts                     0.839283
# num_rev_accts                   num_bc_tl                         0.839283
# num_actv_bc_tl                  num_bc_sats                       0.838795
# num_bc_sats                     num_actv_bc_tl                    0.838795
# tot_cur_bal                     avg_cur_bal                       0.834840
# avg_cur_bal                     tot_cur_bal                       0.834840
# revol_bal                       total_rev_hi_lim                  0.833423
# total_rev_hi_lim                revol_bal                         0.833423
# num_tl_op_past_12m              open_rv_12m                       0.832778
# open_rv_12m                     num_tl_op_past_12m                0.832778
# num_op_rev_tl                   open_acc                          0.829359
# open_acc                        num_op_rev_tl                     0.829359
# num_sats                        num_op_rev_tl                     0.828263
# num_op_rev_tl                   num_sats                          0.828263
# bc_open_to_buy                  total_bc_limit                    0.821647
# total_bc_limit                  bc_open_to_buy                    0.821647
# total_rec_prncp                 last_pymnt_amnt                   0.817310
# last_pymnt_amnt                 total_rec_prncp                   0.817310
# num_rev_tl_bal_gt_0             num_op_rev_tl                     0.811682
# num_op_rev_tl                   num_rev_tl_bal_gt_0               0.811682
#                                 num_actv_rev_tl                   0.806280
# num_actv_rev_tl                 num_op_rev_tl                     0.806280
#                                 num_actv_bc_tl                    0.805179
# num_actv_bc_tl                  num_actv_rev_tl                   0.805179
#                                 num_rev_tl_bal_gt_0               0.799656
# num_rev_tl_bal_gt_0             num_actv_bc_tl                    0.799656
# tot_hi_cred_lim                 avg_cur_bal                       0.797188
# avg_cur_bal                     tot_hi_cred_lim                   0.797188
# acc_now_delinq                  num_tl_30dpd                      0.793368
# num_tl_30dpd                    acc_now_delinq                    0.793368
# num_rev_accts                   num_op_rev_tl                     0.781827
# num_op_rev_tl                   num_rev_accts                     0.781827
# mths_since_recent_bc_dlq        mths_since_last_delinq            0.769685
# mths_since_last_delinq          mths_since_recent_bc_dlq          0.769685
# open_rv_24m                     open_rv_12m                       0.767262
# open_rv_12m                     open_rv_24m                       0.767262
# acc_open_past_24mths            num_tl_op_past_12m                0.762607
# num_tl_op_past_12m              acc_open_past_24mths              0.762607
# total_acc                       num_rev_accts                     0.761672
# num_rev_accts                   total_acc                         0.761672
# open_il_12m                     open_il_24m                       0.760552
# open_il_24m                     open_il_12m                       0.760552
# open_acc_6m                     num_tl_op_past_12m                0.748528
# num_tl_op_past_12m              open_acc_6m                       0.748528
# last_pymnt_amnt                 total_pymnt                       0.742504
# total_pymnt                     last_pymnt_amnt                   0.742504
# total_pymnt_inv                 last_pymnt_amnt                   0.742462
# last_pymnt_amnt                 total_pymnt_inv                   0.742462
# num_bc_sats                     num_op_rev_tl                     0.737117
# num_op_rev_tl                   num_bc_sats                       0.737117
# total_rec_int                   funded_amnt                       0.736585
# funded_amnt                     total_rec_int                     0.736585
# loan_amnt                       total_rec_int                     0.736585
# total_rec_int                   loan_amnt                         0.736585
#                                 funded_amnt_inv                   0.736483
# funded_amnt_inv                 total_rec_int                     0.736483
# total_pymnt                     installment                       0.732579
# installment                     total_pymnt                       0.732579
#                                 total_pymnt_inv                   0.732545
# total_pymnt_inv                 installment                       0.732545
# num_bc_tl                       num_bc_sats                       0.731209
# num_bc_sats                     num_bc_tl                         0.731209
# pub_rec                         tax_liens                         0.720037
# tax_liens                       pub_rec                           0.720037
# total_bc_limit                  total_rev_hi_lim                  0.711588
# total_rev_hi_lim                total_bc_limit                    0.711588
# annual_inc_joint                annual_inc                        0.711091
# annual_inc                      annual_inc_joint                  0.711091
# total_acc                       open_acc                          0.709499
# open_acc                        total_acc                         0.709499
# funded_amnt_inv                 total_pymnt                       0.706259
# total_pymnt                     funded_amnt_inv                   0.706259
# funded_amnt_inv                 total_pymnt_inv                   0.706239
# total_pymnt_inv                 funded_amnt_inv                   0.706239
# total_pymnt                     funded_amnt                       0.706184
# loan_amnt                       total_pymnt                       0.706184
# total_pymnt                     loan_amnt                         0.706184
# funded_amnt                     total_pymnt                       0.706184
# loan_amnt                       total_pymnt_inv                   0.706157
# total_pymnt_inv                 loan_amnt                         0.706157
#                                 funded_amnt                       0.706157
# funded_amnt                     total_pymnt_inv                   0.706157
# num_sats                        total_acc                         0.705166
# total_acc                       num_sats                          0.705166
# total_rec_int                   out_prncp                         0.684606
# out_prncp                       total_rec_int                     0.684606
# out_prncp_inv                   total_rec_int                     0.684557
# total_rec_int                   out_prncp_inv                     0.684557
# mths_since_last_delinq          mths_since_last_major_derog       0.681553
# mths_since_last_major_derog     mths_since_last_delinq            0.681553
# num_bc_sats                     num_actv_rev_tl                   0.677887
# num_actv_rev_tl                 num_bc_sats                       0.677887
# open_acc                        num_rev_tl_bal_gt_0               0.674676
# num_rev_tl_bal_gt_0             open_acc                          0.674676
# num_sats                        num_rev_tl_bal_gt_0               0.673746
# num_rev_tl_bal_gt_0             num_sats                          0.673746
# num_actv_rev_tl                 open_acc                          0.670931
# open_acc                        num_actv_rev_tl                   0.670931
# num_il_tl                       total_acc                         0.668232
# total_acc                       num_il_tl                         0.668232
# num_actv_rev_tl                 num_sats                          0.666629
# num_sats                        num_actv_rev_tl                   0.666629
# num_actv_bc_tl                  num_op_rev_tl                     0.665185
# num_op_rev_tl                   num_actv_bc_tl                    0.665185
# installment                     total_rec_int                     0.654990
# total_rec_int                   installment                       0.654990
# open_il_6m                      num_il_tl                         0.651989
# num_il_tl                       open_il_6m                        0.651989
# num_rev_tl_bal_gt_0             num_bc_sats                       0.651353
# num_bc_sats                     num_rev_tl_bal_gt_0               0.651353
# num_tl_90g_dpd_24m              delinq_2yrs                       0.649762
# delinq_2yrs                     num_tl_90g_dpd_24m                0.649762
# num_rev_accts                   open_acc                          0.649747
# open_acc                        num_rev_accts                     0.649747
# open_rv_24m                     num_tl_op_past_12m                0.648999
# num_tl_op_past_12m              open_rv_24m                       0.648999
# num_sats                        num_rev_accts                     0.643036
# num_rev_accts                   num_sats                          0.643036
# open_rv_12m                     acc_open_past_24mths              0.642637
# acc_open_past_24mths            open_rv_12m                       0.642637
# num_op_rev_tl                   num_bc_tl                         0.630135
# num_bc_tl                       num_op_rev_tl                     0.630135
# open_rv_12m                     open_acc_6m                       0.626833
# open_acc_6m                     open_rv_12m                       0.626833
# total_acc                       num_bc_tl                         0.625268
# num_bc_tl                       total_acc                         0.625268
# out_prncp_inv                   funded_amnt                       0.623961
#                                 loan_amnt                         0.623961
# loan_amnt                       out_prncp_inv                     0.623961
# funded_amnt                     out_prncp_inv                     0.623961
#                                 out_prncp                         0.623926
# loan_amnt                       out_prncp                         0.623926
# out_prncp                       loan_amnt                         0.623926
#                                 funded_amnt                       0.623926
# funded_amnt_inv                 out_prncp_inv                     0.623899
# out_prncp_inv                   funded_amnt_inv                   0.623899
# out_prncp                       funded_amnt_inv                   0.623858
# funded_amnt_inv                 out_prncp                         0.623858
# mo_sin_rcnt_tl                  mo_sin_rcnt_rev_tl_op             0.618613
# mo_sin_rcnt_rev_tl_op           mo_sin_rcnt_tl                    0.618613
# pub_rec                         pub_rec_bankruptcies              0.615794
# pub_rec_bankruptcies            pub_rec                           0.615794
# open_acc                        num_bc_sats                       0.613107
# num_bc_sats                     open_acc                          0.613107
# num_sats                        num_bc_sats                       0.608393
# num_bc_sats                     num_sats                          0.608393
# total_rec_prncp                 installment                       0.608280
# installment                     total_rec_prncp                   0.608280
# mo_sin_rcnt_rev_tl_op           mths_since_recent_bc              0.608235
# mths_since_recent_bc            mo_sin_rcnt_rev_tl_op             0.608235
# total_bal_il                    num_il_tl                         0.598984
# num_il_tl                       total_bal_il                      0.598984
# num_actv_bc_tl                  num_bc_tl                         0.594551
# num_bc_tl                       num_actv_bc_tl                    0.594551
# total_bc_limit                  max_bal_bc                        0.593642
# max_bal_bc                      total_bc_limit                    0.593642
# total_bc_limit                  num_bc_sats                       0.592517
# num_bc_sats                     total_bc_limit                    0.592517
# total_il_high_credit_limit      num_il_tl                         0.592311
# num_il_tl                       total_il_high_credit_limit        0.592311
# num_rev_accts                   num_actv_rev_tl                   0.586782
# num_actv_rev_tl                 num_rev_accts                     0.586782
# acc_open_past_24mths            open_il_24m                       0.586047
# open_il_24m                     acc_open_past_24mths              0.586047
# num_rev_accts                   num_bc_sats                       0.584828
# num_bc_sats                     num_rev_accts                     0.584828
# bc_util                         all_util                          0.582955
# all_util                        bc_util                           0.582955
# max_bal_bc                      revol_bal                         0.582009
# revol_bal                       max_bal_bc                        0.582009
# num_rev_tl_bal_gt_0             num_rev_accts                     0.580886
# num_rev_accts                   num_rev_tl_bal_gt_0               0.580886
# total_bal_il                    open_il_6m                        0.574424
# open_il_6m                      total_bal_il                      0.574424
# num_tl_op_past_12m              open_il_12m                       0.572495
# open_il_12m                     num_tl_op_past_12m                0.572495
# open_il_6m                      total_il_high_credit_limit        0.572296
# total_il_high_credit_limit      open_il_6m                        0.572296
# acc_open_past_24mths            open_acc_6m                       0.571151
# open_acc_6m                     acc_open_past_24mths              0.571151
# all_util                        il_util                           0.569126
# il_util                         all_util                          0.569126
# open_rv_24m                     num_op_rev_tl                     0.567877
# num_op_rev_tl                   open_rv_24m                       0.567877
# inq_last_12m                    inq_fi                            0.563795
# inq_fi                          inq_last_12m                      0.563795
# mths_since_last_major_derog     mths_since_recent_bc_dlq          0.563358
# mths_since_recent_bc_dlq        mths_since_last_major_derog       0.563358
# bc_open_to_buy                  total_rev_hi_lim                  0.562399
# total_rev_hi_lim                bc_open_to_buy                    0.562399
# total_acc                       num_op_rev_tl                     0.562151
# num_op_rev_tl                   total_acc                         0.562151
# funded_amnt_inv                 total_rec_prncp                   0.556377
# total_rec_prncp                 funded_amnt_inv                   0.556377
# funded_amnt                     total_rec_prncp                   0.556266
# loan_amnt                       total_rec_prncp                   0.556266
# total_rec_prncp                 loan_amnt                         0.556266
#                                 funded_amnt                       0.556266
# pct_tl_nvr_dlq                  num_accts_ever_120_pd             0.553769
# num_accts_ever_120_pd           pct_tl_nvr_dlq                    0.553769
# mths_since_last_delinq          delinq_2yrs                       0.553754
# delinq_2yrs                     mths_since_last_delinq            0.553754
# open_acc                        num_actv_bc_tl                    0.551822
# num_actv_bc_tl                  open_acc                          0.551822
#                                 num_sats                          0.550698
# num_sats                        num_actv_bc_tl                    0.550698
# inq_last_6mths                  mths_since_recent_inq             0.547384
# mths_since_recent_inq           inq_last_6mths                    0.547384
# mths_since_last_major_derog     mths_since_recent_revol_delinq    0.541628
# mths_since_recent_revol_delinq  mths_since_last_major_derog       0.541628
# bc_util                         bc_open_to_buy                    0.539107
# bc_open_to_buy                  bc_util                           0.539107
# annual_inc_joint                tot_hi_cred_lim                   0.530717
# tot_hi_cred_lim                 annual_inc_joint                  0.530717
#                                 mort_acc                          0.527594
# mort_acc                        tot_hi_cred_lim                   0.527594
# total_bal_ex_mort               tot_cur_bal                       0.526932
# tot_cur_bal                     total_bal_ex_mort                 0.526932
#                                 mort_acc                          0.524410
# mort_acc                        tot_cur_bal                       0.524410
# open_acc                        num_bc_tl                         0.519201
# num_bc_tl                       open_acc                          0.519201
# num_sats                        open_il_6m                        0.517672
# open_il_6m                      num_sats                          0.517672
# tot_cur_bal                     annual_inc_joint                  0.516695
# annual_inc_joint                tot_cur_bal                       0.516695
# open_il_6m                      open_acc                          0.515508
# open_acc                        open_il_6m                        0.515508
# total_bal_ex_mort               tot_hi_cred_lim                   0.515390
# tot_hi_cred_lim                 total_bal_ex_mort                 0.515390
# revol_bal                       total_bal_ex_mort                 0.514992
# total_bal_ex_mort               revol_bal                         0.514992
# num_sats                        num_bc_tl                         0.514561
# num_bc_tl                       num_sats                          0.514561
# inq_last_12m                    mths_since_recent_inq             0.508102
# mths_since_recent_inq           inq_last_12m                      0.508102
# installment                     out_prncp_inv                     0.506745
# out_prncp_inv                   installment                       0.506745
# installment                     out_prncp                         0.506732
# out_prncp                       installment                       0.506732
# num_il_tl                       total_bal_ex_mort                 0.505941
# total_bal_ex_mort               num_il_tl                         0.505941
# delinq_2yrs                     mths_since_recent_revol_delinq    0.505285
# mths_since_recent_revol_delinq  delinq_2yrs                       0.505285
# total_rec_int                   int_rate                          0.504617
# int_rate                        total_rec_int                     0.504617
# total_bc_limit                  revol_bal                         0.504089
# revol_bal                       total_bc_limit                    0.504089
# max_bal_bc                      total_rev_hi_lim                  0.502913
# total_rev_hi_lim                max_bal_bc                        0.502913
# total_bal_ex_mort               open_il_6m                        0.500373
# open_il_6m                      total_bal_ex_mort                 0.500373
# tot_hi_cred_lim                 total_rev_hi_lim                  0.493908
# total_rev_hi_lim                tot_hi_cred_lim                   0.493908
# num_actv_rev_tl                 num_bc_tl                         0.491451
# num_bc_tl                       num_actv_rev_tl                   0.491451
# mo_sin_rcnt_tl                  num_tl_op_past_12m                0.490789
# num_tl_op_past_12m              mo_sin_rcnt_tl                    0.490789
# inq_last_12m                    inq_last_6mths                    0.490561
# inq_last_6mths                  inq_last_12m                      0.490561
# percent_bc_gt_75                all_util                          0.490353
# all_util                        percent_bc_gt_75                  0.490353
# num_rev_tl_bal_gt_0             num_bc_tl                         0.487649
# num_bc_tl                       num_rev_tl_bal_gt_0               0.487649
# num_actv_bc_tl                  total_bc_limit                    0.487399
# total_bc_limit                  num_actv_bc_tl                    0.487399
# num_bc_tl                       total_bc_limit                    0.485230
# total_bc_limit                  num_bc_tl                         0.485230
# acc_open_past_24mths            open_acc                          0.484479
# open_acc                        acc_open_past_24mths              0.484479
# mths_since_rcnt_il              open_il_24m                       0.483421
# open_il_24m                     mths_since_rcnt_il                0.483421
# num_sats                        acc_open_past_24mths              0.482065
# acc_open_past_24mths            num_sats                          0.482065
# revol_bal                       tot_hi_cred_lim                   0.481402
# tot_hi_cred_lim                 revol_bal                         0.481402
# mths_since_recent_bc_dlq        delinq_2yrs                       0.480215
# delinq_2yrs                     mths_since_recent_bc_dlq          0.480215
# open_rv_24m                     open_acc_6m                       0.480090
# open_acc_6m                     open_rv_24m                       0.480090
# mo_sin_rcnt_rev_tl_op           open_rv_12m                       0.472118
# open_rv_12m                     mo_sin_rcnt_rev_tl_op             0.472118
# open_rv_24m                     num_rev_accts                     0.471077
# num_rev_accts                   open_rv_24m                       0.471077
# bc_open_to_buy                  all_util                          0.468038
# all_util                        bc_open_to_buy                    0.468038
# open_acc_6m                     mo_sin_rcnt_tl                    0.466575
# mo_sin_rcnt_tl                  open_acc_6m                       0.466575
# mo_sin_rcnt_rev_tl_op           open_rv_24m                       0.466446
# open_rv_24m                     mo_sin_rcnt_rev_tl_op             0.466446
# total_pymnt                     total_rec_int                     0.460466
# total_rec_int                   total_pymnt                       0.460466
# total_pymnt_inv                 total_rec_int                     0.460399
# total_rec_int                   total_pymnt_inv                   0.460399
# num_op_rev_tl                   acc_open_past_24mths              0.459725
# acc_open_past_24mths            num_op_rev_tl                     0.459725
# num_bc_sats                     bc_open_to_buy                    0.459137
# bc_open_to_buy                  num_bc_sats                       0.459137
# open_rv_24m                     open_acc                          0.458349
# open_acc                        open_rv_24m                       0.458349
# num_il_tl                       open_il_24m                       0.457890
# open_il_24m                     num_il_tl                         0.457890
# num_actv_bc_tl                  num_rev_accts                     0.457090
# num_rev_accts                   num_actv_bc_tl                    0.457090
# num_sats                        open_rv_24m                       0.456088
# open_rv_24m                     num_sats                          0.456088
# revol_bal                       tot_cur_bal                       0.455735
# tot_cur_bal                     revol_bal                         0.455735
# inq_last_12m                    num_tl_op_past_12m                0.453532
# num_tl_op_past_12m              inq_last_12m                      0.453532
# avg_cur_bal                     mort_acc                          0.452144
# mort_acc                        avg_cur_bal                       0.452144
# num_actv_rev_tl                 open_rv_24m                       0.451744
# open_rv_24m                     num_actv_rev_tl                   0.451744
# delinq_2yrs                     pct_tl_nvr_dlq                    0.451422
# pct_tl_nvr_dlq                  delinq_2yrs                       0.451422
# open_il_12m                     acc_open_past_24mths              0.450394
# acc_open_past_24mths            open_il_12m                       0.450394
# mths_since_last_major_derog     num_tl_90g_dpd_24m                0.448906
# num_tl_90g_dpd_24m              mths_since_last_major_derog       0.448906
# mo_sin_rcnt_tl                  acc_open_past_24mths              0.446766
# acc_open_past_24mths            mo_sin_rcnt_tl                    0.446766
# open_il_24m                     num_tl_op_past_12m                0.446085
# num_tl_op_past_12m              open_il_24m                       0.446085
# mths_since_rcnt_il              open_il_12m                       0.443401
# open_il_12m                     mths_since_rcnt_il                0.443401
# open_rv_24m                     num_rev_tl_bal_gt_0               0.441497
# num_rev_tl_bal_gt_0             open_rv_24m                       0.441497
# bc_open_to_buy                  percent_bc_gt_75                  0.439985
# percent_bc_gt_75                bc_open_to_buy                    0.439985
# annual_inc_joint                funded_amnt_inv                   0.439213
# funded_amnt_inv                 annual_inc_joint                  0.439213
# inq_last_6mths                  open_acc_6m                       0.439006
# open_acc_6m                     inq_last_6mths                    0.439006
# annual_inc_joint                funded_amnt                       0.438866
#                                 loan_amnt                         0.438866
# loan_amnt                       annual_inc_joint                  0.438866
# funded_amnt                     annual_inc_joint                  0.438866
# total_rev_hi_lim                total_bal_ex_mort                 0.437185
# total_bal_ex_mort               total_rev_hi_lim                  0.437185
# total_acc                       acc_open_past_24mths              0.435991
# acc_open_past_24mths            total_acc                         0.435991
# open_rv_12m                     num_op_rev_tl                     0.435435
# num_op_rev_tl                   open_rv_12m                       0.435435
# total_rev_hi_lim                num_bc_sats                       0.427742
# num_bc_sats                     total_rev_hi_lim                  0.427742
# total_bal_ex_mort               total_acc                         0.427075
# total_acc                       total_bal_ex_mort                 0.427075
# open_il_12m                     open_acc_6m                       0.422440
# open_acc_6m                     open_il_12m                       0.422440
# total_il_high_credit_limit      total_acc                         0.419243
# total_acc                       total_il_high_credit_limit        0.419243
# mths_since_last_major_derog     delinq_2yrs                       0.416555
# delinq_2yrs                     mths_since_last_major_derog       0.416555
# acc_open_past_24mths            mo_sin_rcnt_rev_tl_op             0.413834
# mo_sin_rcnt_rev_tl_op           acc_open_past_24mths              0.413834
# avg_cur_bal                     annual_inc_joint                  0.413761
# annual_inc_joint                avg_cur_bal                       0.413761
# num_op_rev_tl                   total_bc_limit                    0.413581
# total_bc_limit                  num_op_rev_tl                     0.413581
# bc_open_to_buy                  num_bc_tl                         0.412514
# num_bc_tl                       bc_open_to_buy                    0.412514
# funded_amnt_inv                 max_bal_bc                        0.412268
# max_bal_bc                      funded_amnt_inv                   0.412268
# loan_amnt                       max_bal_bc                        0.412165
# funded_amnt                     max_bal_bc                        0.412165
# max_bal_bc                      funded_amnt                       0.412165
#                                 loan_amnt                         0.412165
# mo_sin_rcnt_rev_tl_op           num_tl_op_past_12m                0.411336
# num_tl_op_past_12m              mo_sin_rcnt_rev_tl_op             0.411336
# total_rev_hi_lim                tot_cur_bal                       0.410690
# tot_cur_bal                     total_rev_hi_lim                  0.410690
# total_acc                       total_bal_il                      0.410463
# total_bal_il                    total_acc                         0.410463
# total_acc                       num_actv_rev_tl                   0.408414
# num_actv_rev_tl                 total_acc                         0.408414
# num_op_rev_tl                   total_rev_hi_lim                  0.407241
# total_rev_hi_lim                num_op_rev_tl                     0.407241
# num_rev_tl_bal_gt_0             total_acc                         0.406724
# total_acc                       num_rev_tl_bal_gt_0               0.406724
# annual_inc_joint                installment                       0.405141
# installment                     annual_inc_joint                  0.405141
# tot_hi_cred_lim                 total_bc_limit                    0.405070
# total_bc_limit                  tot_hi_cred_lim                   0.405070
# total_il_high_credit_limit      tot_cur_bal                       0.401982
# tot_cur_bal                     total_il_high_credit_limit        0.401982
# mths_since_recent_bc            open_rv_24m                       0.401618
# open_rv_24m                     mths_since_recent_bc              0.401618
# num_sats                        total_bal_ex_mort                 0.400886
# total_bal_ex_mort               num_sats                          0.400886
#                                 open_acc                          0.399890
# open_acc                        total_bal_ex_mort                 0.399890
# acc_open_past_24mths            inq_last_12m                      0.399875
# inq_last_12m                    acc_open_past_24mths              0.399875
# total_acc                       num_bc_sats                       0.397401
# num_bc_sats                     total_acc                         0.397401
# funded_amnt_inv                 total_bc_limit                    0.395973
# total_bc_limit                  funded_amnt_inv                   0.395973
# funded_amnt                     total_bc_limit                    0.395843
# total_bc_limit                  loan_amnt                         0.395843
#                                 funded_amnt                       0.395843
# loan_amnt                       total_bc_limit                    0.395843
# acc_open_past_24mths            num_rev_accts                     0.394277
# num_rev_accts                   acc_open_past_24mths              0.394277
# total_il_high_credit_limit      tot_hi_cred_lim                   0.394185
# tot_hi_cred_lim                 total_il_high_credit_limit        0.394185
# annual_inc                      tot_hi_cred_lim                   0.391129
# tot_hi_cred_lim                 annual_inc                        0.391129
# num_il_tl                       num_sats                          0.389742
# num_sats                        num_il_tl                         0.389742
# open_acc                        num_il_tl                         0.388601
# num_il_tl                       open_acc                          0.388601
# open_rv_24m                     num_bc_sats                       0.388025
# num_bc_sats                     open_rv_24m                       0.388025
# max_bal_bc                      installment                       0.385606
# installment                     max_bal_bc                        0.385606
# max_bal_bc                      tot_hi_cred_lim                   0.382977
# tot_hi_cred_lim                 max_bal_bc                        0.382977
# total_acc                       open_il_6m                        0.381588
# open_il_6m                      total_acc                         0.381588
# mo_sin_rcnt_tl                  open_rv_12m                       0.381179
# open_rv_12m                     mo_sin_rcnt_tl                    0.381179
# mo_sin_rcnt_tl                  mths_since_recent_bc              0.381143
# mths_since_recent_bc            mo_sin_rcnt_tl                    0.381143
# tot_cur_bal                     annual_inc                        0.379008
# annual_inc                      tot_cur_bal                       0.379008
# all_util                        open_il_6m                        0.374155
# open_il_6m                      all_util                          0.374155
# total_bal_il                    tot_cur_bal                       0.373898
# tot_cur_bal                     total_bal_il                      0.373898
# out_prncp_inv                   last_pymnt_amnt                   0.371058
# last_pymnt_amnt                 out_prncp_inv                     0.371058
# out_prncp                       last_pymnt_amnt                   0.371040
# last_pymnt_amnt                 out_prncp                         0.371040
# inq_last_6mths                  num_tl_op_past_12m                0.370187
# num_tl_op_past_12m              inq_last_6mths                    0.370187
# mo_sin_rcnt_tl                  mths_since_rcnt_il                0.368634
# mths_since_rcnt_il              mo_sin_rcnt_tl                    0.368634
# mths_since_recent_bc            open_rv_12m                       0.367274
# open_rv_12m                     mths_since_recent_bc              0.367274
# total_rev_hi_lim                num_bc_tl                         0.365439
# num_bc_tl                       total_rev_hi_lim                  0.365439
#                                 open_rv_24m                       0.364975
# open_rv_24m                     num_bc_tl                         0.364975
# mo_sin_rcnt_rev_tl_op           open_acc_6m                       0.362280
# open_acc_6m                     mo_sin_rcnt_rev_tl_op             0.362280
# open_il_24m                     open_il_6m                        0.361892
# open_il_6m                      open_il_24m                       0.361892
# num_rev_accts                   open_rv_12m                       0.361472
# open_rv_12m                     num_rev_accts                     0.361472
# num_tl_op_past_12m              open_acc                          0.361077
# open_acc                        num_tl_op_past_12m                0.361077
# total_il_high_credit_limit      num_sats                          0.360230
# num_sats                        total_il_high_credit_limit        0.360230
# tot_cur_bal                     max_bal_bc                        0.359861
# max_bal_bc                      tot_cur_bal                       0.359861
# mo_sin_old_rev_tl_op            num_rev_accts                     0.359234
# num_rev_accts                   mo_sin_old_rev_tl_op              0.359234
# open_acc                        total_il_high_credit_limit        0.359085
# total_il_high_credit_limit      open_acc                          0.359085
# total_bc_limit                  installment                       0.358718
# installment                     total_bc_limit                    0.358718
# total_il_high_credit_limit      open_il_24m                       0.358619
# open_il_24m                     total_il_high_credit_limit        0.358619
# dti_joint                       total_il_high_credit_limit        0.358091
# total_il_high_credit_limit      dti_joint                         0.358091
# num_sats                        num_tl_op_past_12m                0.358021
# num_tl_op_past_12m              num_sats                          0.358021
# total_rev_hi_lim                num_rev_accts                     0.357123
# num_rev_accts                   total_rev_hi_lim                  0.357123
# inq_last_6mths                  open_rv_12m                       0.356947
# open_rv_12m                     inq_last_6mths                    0.356947
# num_op_rev_tl                   bc_open_to_buy                    0.356520
# bc_open_to_buy                  num_op_rev_tl                     0.356520
# total_acc                       mort_acc                          0.356387
# mort_acc                        total_acc                         0.356387
# total_bal_ex_mort               dti_joint                         0.356333
# dti_joint                       total_bal_ex_mort                 0.356333
# num_sats                        total_bc_limit                    0.355557
# total_bc_limit                  num_sats                          0.355557
#                                 num_rev_accts                     0.354540
# num_rev_accts                   total_bc_limit                    0.354540
# acc_now_delinq                  num_tl_120dpd_2m                  0.354200
# num_tl_120dpd_2m                acc_now_delinq                    0.354200
# open_acc                        total_bc_limit                    0.354028
# total_bc_limit                  open_acc                          0.354028
# total_bal_il                    open_il_24m                       0.353834
# open_il_24m                     total_bal_il                      0.353834
# num_actv_rev_tl                 acc_open_past_24mths              0.353799
# acc_open_past_24mths            num_actv_rev_tl                   0.353799
# total_rev_hi_lim                open_acc                          0.353095
# open_acc                        total_rev_hi_lim                  0.353095
# total_rev_hi_lim                num_sats                          0.352837
# num_sats                        total_rev_hi_lim                  0.352837
# open_rv_12m                     num_actv_rev_tl                   0.352630
# num_actv_rev_tl                 open_rv_12m                       0.352630
# acc_open_past_24mths            mths_since_recent_bc              0.347586
# mths_since_recent_bc            acc_open_past_24mths              0.347586
# funded_amnt_inv                 tot_hi_cred_lim                   0.347355
# tot_hi_cred_lim                 funded_amnt_inv                   0.347355
# funded_amnt                     tot_hi_cred_lim                   0.347289
# tot_hi_cred_lim                 loan_amnt                         0.347289
#                                 funded_amnt                       0.347289
# loan_amnt                       tot_hi_cred_lim                   0.347289
# total_rev_hi_lim                num_actv_bc_tl                    0.347138
# num_actv_bc_tl                  total_rev_hi_lim                  0.347138
# open_acc                        open_rv_12m                       0.345658
# open_rv_12m                     open_acc                          0.345658
# open_rv_24m                     mo_sin_rcnt_tl                    0.345050
# mo_sin_rcnt_tl                  open_rv_24m                       0.345050
# ...
# chargeoff_within_12_mths        num_tl_30dpd                      0.000220
# mths_since_last_delinq          dti                               0.000219
# dti                             mths_since_last_delinq            0.000219
# total_rec_late_fee              mort_acc                          0.000210
# mort_acc                        total_rec_late_fee                0.000210
# mo_sin_rcnt_rev_tl_op           total_rec_late_fee                0.000203
# total_rec_late_fee              mo_sin_rcnt_rev_tl_op             0.000203
# inq_last_12m                    total_rev_hi_lim                  0.000173
# total_rev_hi_lim                inq_last_12m                      0.000173
# pub_rec                         total_rec_late_fee                0.000146
# total_rec_late_fee              pub_rec                           0.000146
#                                 mths_since_recent_bc              0.000137
# mths_since_recent_bc            total_rec_late_fee                0.000137
# open_il_12m                     installment                       0.000136
# installment                     open_il_12m                       0.000136
# total_bc_limit                  recoveries                        0.000129
# recoveries                      total_bc_limit                    0.000129
# delinq_amnt                     num_il_tl                         0.000105
# num_il_tl                       delinq_amnt                       0.000105
# total_rec_late_fee              num_tl_120dpd_2m                  0.000098
# num_tl_120dpd_2m                total_rec_late_fee                0.000098
# acc_now_delinq                  mo_sin_rcnt_tl                    0.000093
# mo_sin_rcnt_tl                  acc_now_delinq                    0.000093
# id                              mo_sin_old_il_acct                0.000088
# mo_sin_old_il_acct              id                                0.000088
# all_util                        num_tl_120dpd_2m                  0.000036
# num_tl_120dpd_2m                all_util                          0.000036
# total_rev_hi_lim                delinq_amnt                       0.000032
# delinq_amnt                     total_rev_hi_lim                  0.000032
# total_rev_hi_lim                collection_recovery_fee           0.000030
# collection_recovery_fee         total_rev_hi_lim                  0.000030
# open_rv_12m                     total_cu_tl                       0.000015
# total_cu_tl                     open_rv_12m                       0.000015
# member_id                       mo_sin_old_il_acct                0.000009
# mo_sin_old_il_acct              member_id                         0.000009
# id                              policy_code                            NaN
# member_id                       policy_code                            NaN
# loan_amnt                       policy_code                            NaN
# funded_amnt                     policy_code                            NaN
# funded_amnt_inv                 policy_code                            NaN
# int_rate                        policy_code                            NaN
# installment                     policy_code                            NaN
# annual_inc                      policy_code                            NaN
# dti                             policy_code                            NaN
# delinq_2yrs                     policy_code                            NaN
# inq_last_6mths                  policy_code                            NaN
# mths_since_last_delinq          policy_code                            NaN
# mths_since_last_record          policy_code                            NaN
# open_acc                        policy_code                            NaN
# pub_rec                         policy_code                            NaN
# revol_bal                       policy_code                            NaN
# total_acc                       policy_code                            NaN
# out_prncp                       policy_code                            NaN
# out_prncp_inv                   policy_code                            NaN
# total_pymnt                     policy_code                            NaN
# total_pymnt_inv                 policy_code                            NaN
# total_rec_prncp                 policy_code                            NaN
# total_rec_int                   policy_code                            NaN
# total_rec_late_fee              policy_code                            NaN
# recoveries                      policy_code                            NaN
# collection_recovery_fee         policy_code                            NaN
# last_pymnt_amnt                 policy_code                            NaN
# collections_12_mths_ex_med      policy_code                            NaN
# mths_since_last_major_derog     policy_code                            NaN
# policy_code                     id                                     NaN
#                                 member_id                              NaN
#                                 loan_amnt                              NaN
#                                 funded_amnt                            NaN
#                                 funded_amnt_inv                        NaN
#                                 int_rate                               NaN
#                                 installment                            NaN
#                                 annual_inc                             NaN
#                                 dti                                    NaN
#                                 delinq_2yrs                            NaN
#                                 inq_last_6mths                         NaN
#                                 mths_since_last_delinq                 NaN
#                                 mths_since_last_record                 NaN
#                                 open_acc                               NaN
#                                 pub_rec                                NaN
#                                 revol_bal                              NaN
#                                 total_acc                              NaN
#                                 out_prncp                              NaN
#                                 out_prncp_inv                          NaN
#                                 total_pymnt                            NaN
#                                 total_pymnt_inv                        NaN
#                                 total_rec_prncp                        NaN
#                                 total_rec_int                          NaN
#                                 total_rec_late_fee                     NaN
#                                 recoveries                             NaN
#                                 collection_recovery_fee                NaN
#                                 last_pymnt_amnt                        NaN
#                                 collections_12_mths_ex_med             NaN
#                                 mths_since_last_major_derog            NaN
#                                 policy_code                            NaN
#                                 annual_inc_joint                       NaN
#                                 dti_joint                              NaN
#                                 acc_now_delinq                         NaN
#                                 tot_coll_amt                           NaN
#                                 tot_cur_bal                            NaN
#                                 open_acc_6m                            NaN
#                                 open_il_6m                             NaN
#                                 open_il_12m                            NaN
#                                 open_il_24m                            NaN
#                                 mths_since_rcnt_il                     NaN
#                                 total_bal_il                           NaN
#                                 il_util                                NaN
#                                 open_rv_12m                            NaN
#                                 open_rv_24m                            NaN
#                                 max_bal_bc                             NaN
#                                 all_util                               NaN
#                                 total_rev_hi_lim                       NaN
#                                 inq_fi                                 NaN
#                                 total_cu_tl                            NaN
#                                 inq_last_12m                           NaN
#                                 acc_open_past_24mths                   NaN
#                                 avg_cur_bal                            NaN
#                                 bc_open_to_buy                         NaN
#                                 bc_util                                NaN
#                                 chargeoff_within_12_mths               NaN
#                                 delinq_amnt                            NaN
#                                 mo_sin_old_il_acct                     NaN
#                                 mo_sin_old_rev_tl_op                   NaN
#                                 mo_sin_rcnt_rev_tl_op                  NaN
#                                 mo_sin_rcnt_tl                         NaN
#                                 mort_acc                               NaN
#                                 mths_since_recent_bc                   NaN
#                                 mths_since_recent_bc_dlq               NaN
#                                 mths_since_recent_inq                  NaN
#                                 mths_since_recent_revol_delinq         NaN
#                                 num_accts_ever_120_pd                  NaN
#                                 num_actv_bc_tl                         NaN
#                                 num_actv_rev_tl                        NaN
#                                 num_bc_sats                            NaN
#                                 num_bc_tl                              NaN
#                                 num_il_tl                              NaN
#                                 num_op_rev_tl                          NaN
#                                 num_rev_accts                          NaN
#                                 num_rev_tl_bal_gt_0                    NaN
#                                 num_sats                               NaN
#                                 num_tl_120dpd_2m                       NaN
#                                 num_tl_30dpd                           NaN
#                                 num_tl_90g_dpd_24m                     NaN
#                                 num_tl_op_past_12m                     NaN
#                                 pct_tl_nvr_dlq                         NaN
#                                 percent_bc_gt_75                       NaN
#                                 pub_rec_bankruptcies                   NaN
#                                 tax_liens                              NaN
#                                 tot_hi_cred_lim                        NaN
#                                 total_bal_ex_mort                      NaN
#                                 total_bc_limit                         NaN
#                                 total_il_high_credit_limit             NaN
# annual_inc_joint                policy_code                            NaN
#                                 num_tl_120dpd_2m                       NaN
# dti_joint                       policy_code                            NaN
#                                 num_tl_120dpd_2m                       NaN
# acc_now_delinq                  policy_code                            NaN
# tot_coll_amt                    policy_code                            NaN
# tot_cur_bal                     policy_code                            NaN
# open_acc_6m                     policy_code                            NaN
# open_il_6m                      policy_code                            NaN
# open_il_12m                     policy_code                            NaN
# open_il_24m                     policy_code                            NaN
# mths_since_rcnt_il              policy_code                            NaN
# total_bal_il                    policy_code                            NaN
# il_util                         policy_code                            NaN
# open_rv_12m                     policy_code                            NaN
# open_rv_24m                     policy_code                            NaN
# max_bal_bc                      policy_code                            NaN
# all_util                        policy_code                            NaN
# total_rev_hi_lim                policy_code                            NaN
# inq_fi                          policy_code                            NaN
# total_cu_tl                     policy_code                            NaN
# inq_last_12m                    policy_code                            NaN
# acc_open_past_24mths            policy_code                            NaN
# avg_cur_bal                     policy_code                            NaN
# bc_open_to_buy                  policy_code                            NaN
# bc_util                         policy_code                            NaN
# chargeoff_within_12_mths        policy_code                            NaN
# delinq_amnt                     policy_code                            NaN
# mo_sin_old_il_acct              policy_code                            NaN
# mo_sin_old_rev_tl_op            policy_code                            NaN
# mo_sin_rcnt_rev_tl_op           policy_code                            NaN
# mo_sin_rcnt_tl                  policy_code                            NaN
# mort_acc                        policy_code                            NaN
# mths_since_recent_bc            policy_code                            NaN
# mths_since_recent_bc_dlq        policy_code                            NaN
# mths_since_recent_inq           policy_code                            NaN
# mths_since_recent_revol_delinq  policy_code                            NaN
# num_accts_ever_120_pd           policy_code                            NaN
# num_actv_bc_tl                  policy_code                            NaN
# num_actv_rev_tl                 policy_code                            NaN
# num_bc_sats                     policy_code                            NaN
# num_bc_tl                       policy_code                            NaN
# num_il_tl                       policy_code                            NaN
# num_op_rev_tl                   policy_code                            NaN
# num_rev_accts                   policy_code                            NaN
# num_rev_tl_bal_gt_0             policy_code                            NaN
# num_sats                        policy_code                            NaN
# num_tl_120dpd_2m                policy_code                            NaN
#                                 annual_inc_joint                       NaN
#                                 dti_joint                              NaN
# num_tl_30dpd                    policy_code                            NaN
# num_tl_90g_dpd_24m              policy_code                            NaN
# num_tl_op_past_12m              policy_code                            NaN
# pct_tl_nvr_dlq                  policy_code                            NaN
# percent_bc_gt_75                policy_code                            NaN
# pub_rec_bankruptcies            policy_code                            NaN
# tax_liens                       policy_code                            NaN
# tot_hi_cred_lim                 policy_code                            NaN
# total_bal_ex_mort               policy_code                            NaN
# total_bc_limit                  policy_code                            NaN
# total_il_high_credit_limit      policy_code                            NaN
# Length: 7569, dtype: float64

# %%
## remove highly correlated values
y2015 = y2015.drop(columns = ['out_prncp_inv','total_pymnt', 'funded_amnt_inv', 'num_sats', 'member_id', 'num_rev_tl_bal_gt_0',\
                    'tot_hi_cred_lim', 'collection_recovery_fee', 'total_rec_prncp', 'total_bal_il', 'installment', \
                    'mths_since_recent_bc_dlq', 'total_bal_ex_mort', 'percent_bc_gt_75', 'open_rv_24m', 'num_rev_accts',\
                    'num_bc_sats', 'avg_cur_bal', 'total_rev_hi_lim', 'open_rv_12m', 'num_op_rev_tl', 'total_bc_limit',\
                    'last_pymnt_amnt'])

# %%
## recreate sorted correlation matrix
c1 = y2015.corr().abs()

s1 = c1.unstack()
so1 = s1.sort_values(kind="quicksort", ascending=False)

pd.set_option('display.max_rows', 5000)
print(so1)
# Out:
# total_il_high_credit_limit      total_il_high_credit_limit        1.000000
# mo_sin_rcnt_tl                  mo_sin_rcnt_tl                    1.000000
# max_bal_bc                      max_bal_bc                        1.000000
# all_util                        all_util                          1.000000
# inq_fi                          inq_fi                            1.000000
# total_cu_tl                     total_cu_tl                       1.000000
# inq_last_12m                    inq_last_12m                      1.000000
# acc_open_past_24mths            acc_open_past_24mths              1.000000
# bc_open_to_buy                  bc_open_to_buy                    1.000000
# bc_util                         bc_util                           1.000000
# chargeoff_within_12_mths        chargeoff_within_12_mths          1.000000
# delinq_amnt                     delinq_amnt                       1.000000
# mo_sin_old_il_acct              mo_sin_old_il_acct                1.000000
# mo_sin_old_rev_tl_op            mo_sin_old_rev_tl_op              1.000000
# mo_sin_rcnt_rev_tl_op           mo_sin_rcnt_rev_tl_op             1.000000
# mort_acc                        mort_acc                          1.000000
# open_il_24m                     open_il_24m                       1.000000
# mths_since_recent_bc            mths_since_recent_bc              1.000000
# mths_since_recent_inq           mths_since_recent_inq             1.000000
# mths_since_recent_revol_delinq  mths_since_recent_revol_delinq    1.000000
# num_accts_ever_120_pd           num_accts_ever_120_pd             1.000000
# num_actv_bc_tl                  num_actv_bc_tl                    1.000000
# num_actv_rev_tl                 num_actv_rev_tl                   1.000000
# num_bc_tl                       num_bc_tl                         1.000000
# num_il_tl                       num_il_tl                         1.000000
# num_tl_120dpd_2m                num_tl_120dpd_2m                  1.000000
# num_tl_30dpd                    num_tl_30dpd                      1.000000
# num_tl_90g_dpd_24m              num_tl_90g_dpd_24m                1.000000
# num_tl_op_past_12m              num_tl_op_past_12m                1.000000
# pct_tl_nvr_dlq                  pct_tl_nvr_dlq                    1.000000
# mths_since_rcnt_il              mths_since_rcnt_il                1.000000
# open_il_12m                     open_il_12m                       1.000000
# tax_liens                       tax_liens                         1.000000
# revol_bal                       revol_bal                         1.000000
# loan_amnt                       loan_amnt                         1.000000
#                                 funded_amnt                       1.000000
# funded_amnt                     loan_amnt                         1.000000
#                                 funded_amnt                       1.000000
# int_rate                        int_rate                          1.000000
# annual_inc                      annual_inc                        1.000000
# dti                             dti                               1.000000
# delinq_2yrs                     delinq_2yrs                       1.000000
# inq_last_6mths                  inq_last_6mths                    1.000000
# mths_since_last_delinq          mths_since_last_delinq            1.000000
# mths_since_last_record          mths_since_last_record            1.000000
# open_acc                        open_acc                          1.000000
# pub_rec                         pub_rec                           1.000000
# total_acc                       total_acc                         1.000000
# open_il_6m                      open_il_6m                        1.000000
# out_prncp                       out_prncp                         1.000000
# total_pymnt_inv                 total_pymnt_inv                   1.000000
# total_rec_int                   total_rec_int                     1.000000
# total_rec_late_fee              total_rec_late_fee                1.000000
# recoveries                      recoveries                        1.000000
# collections_12_mths_ex_med      collections_12_mths_ex_med        1.000000
# mths_since_last_major_derog     mths_since_last_major_derog       1.000000
# annual_inc_joint                annual_inc_joint                  1.000000
# dti_joint                       dti_joint                         1.000000
# acc_now_delinq                  acc_now_delinq                    1.000000
# tot_coll_amt                    tot_coll_amt                      1.000000
# tot_cur_bal                     tot_cur_bal                       1.000000
# open_acc_6m                     open_acc_6m                       1.000000
# pub_rec_bankruptcies            pub_rec_bankruptcies              1.000000
# il_util                         il_util                           1.000000
# id                              id                                1.000000
# mths_since_recent_revol_delinq  mths_since_last_delinq            0.864996
# mths_since_last_delinq          mths_since_recent_revol_delinq    0.864996
# num_actv_rev_tl                 num_actv_bc_tl                    0.805179
# num_actv_bc_tl                  num_actv_rev_tl                   0.805179
# acc_now_delinq                  num_tl_30dpd                      0.793368
# num_tl_30dpd                    acc_now_delinq                    0.793368
# num_tl_op_past_12m              acc_open_past_24mths              0.762607
# acc_open_past_24mths            num_tl_op_past_12m                0.762607
# open_il_12m                     open_il_24m                       0.760552
# open_il_24m                     open_il_12m                       0.760552
# open_acc_6m                     num_tl_op_past_12m                0.748528
# num_tl_op_past_12m              open_acc_6m                       0.748528
# funded_amnt                     total_rec_int                     0.736585
# loan_amnt                       total_rec_int                     0.736585
# total_rec_int                   funded_amnt                       0.736585
#                                 loan_amnt                         0.736585
# tax_liens                       pub_rec                           0.720037
# pub_rec                         tax_liens                         0.720037
# annual_inc_joint                annual_inc                        0.711091
# annual_inc                      annual_inc_joint                  0.711091
# open_acc                        total_acc                         0.709499
# total_acc                       open_acc                          0.709499
# total_pymnt_inv                 loan_amnt                         0.706157
# loan_amnt                       total_pymnt_inv                   0.706157
# funded_amnt                     total_pymnt_inv                   0.706157
# total_pymnt_inv                 funded_amnt                       0.706157
# out_prncp                       total_rec_int                     0.684606
# total_rec_int                   out_prncp                         0.684606
# mths_since_last_major_derog     mths_since_last_delinq            0.681553
# mths_since_last_delinq          mths_since_last_major_derog       0.681553
# num_actv_rev_tl                 open_acc                          0.670931
# open_acc                        num_actv_rev_tl                   0.670931
# total_acc                       num_il_tl                         0.668232
# num_il_tl                       total_acc                         0.668232
#                                 open_il_6m                        0.651989
# open_il_6m                      num_il_tl                         0.651989
# num_tl_90g_dpd_24m              delinq_2yrs                       0.649762
# delinq_2yrs                     num_tl_90g_dpd_24m                0.649762
# total_acc                       num_bc_tl                         0.625268
# num_bc_tl                       total_acc                         0.625268
# funded_amnt                     out_prncp                         0.623926
# out_prncp                       funded_amnt                       0.623926
# loan_amnt                       out_prncp                         0.623926
# out_prncp                       loan_amnt                         0.623926
# mo_sin_rcnt_tl                  mo_sin_rcnt_rev_tl_op             0.618613
# mo_sin_rcnt_rev_tl_op           mo_sin_rcnt_tl                    0.618613
# pub_rec_bankruptcies            pub_rec                           0.615794
# pub_rec                         pub_rec_bankruptcies              0.615794
# mo_sin_rcnt_rev_tl_op           mths_since_recent_bc              0.608235
# mths_since_recent_bc            mo_sin_rcnt_rev_tl_op             0.608235
# num_bc_tl                       num_actv_bc_tl                    0.594551
# num_actv_bc_tl                  num_bc_tl                         0.594551
# num_il_tl                       total_il_high_credit_limit        0.592311
# total_il_high_credit_limit      num_il_tl                         0.592311
# acc_open_past_24mths            open_il_24m                       0.586047
# open_il_24m                     acc_open_past_24mths              0.586047
# bc_util                         all_util                          0.582955
# all_util                        bc_util                           0.582955
# max_bal_bc                      revol_bal                         0.582009
# revol_bal                       max_bal_bc                        0.582009
# open_il_12m                     num_tl_op_past_12m                0.572495
# num_tl_op_past_12m              open_il_12m                       0.572495
# total_il_high_credit_limit      open_il_6m                        0.572296
# open_il_6m                      total_il_high_credit_limit        0.572296
# acc_open_past_24mths            open_acc_6m                       0.571151
# open_acc_6m                     acc_open_past_24mths              0.571151
# all_util                        il_util                           0.569126
# il_util                         all_util                          0.569126
# inq_fi                          inq_last_12m                      0.563795
# inq_last_12m                    inq_fi                            0.563795
# pct_tl_nvr_dlq                  num_accts_ever_120_pd             0.553769
# num_accts_ever_120_pd           pct_tl_nvr_dlq                    0.553769
# delinq_2yrs                     mths_since_last_delinq            0.553754
# mths_since_last_delinq          delinq_2yrs                       0.553754
# num_actv_bc_tl                  open_acc                          0.551822
# open_acc                        num_actv_bc_tl                    0.551822
# inq_last_6mths                  mths_since_recent_inq             0.547384
# mths_since_recent_inq           inq_last_6mths                    0.547384
# mths_since_last_major_derog     mths_since_recent_revol_delinq    0.541628
# mths_since_recent_revol_delinq  mths_since_last_major_derog       0.541628
# bc_util                         bc_open_to_buy                    0.539107
# bc_open_to_buy                  bc_util                           0.539107
# tot_cur_bal                     mort_acc                          0.524410
# mort_acc                        tot_cur_bal                       0.524410
# open_acc                        num_bc_tl                         0.519201
# num_bc_tl                       open_acc                          0.519201
# tot_cur_bal                     annual_inc_joint                  0.516695
# annual_inc_joint                tot_cur_bal                       0.516695
# open_acc                        open_il_6m                        0.515508
# open_il_6m                      open_acc                          0.515508
# inq_last_12m                    mths_since_recent_inq             0.508102
# mths_since_recent_inq           inq_last_12m                      0.508102
# delinq_2yrs                     mths_since_recent_revol_delinq    0.505285
# mths_since_recent_revol_delinq  delinq_2yrs                       0.505285
# total_rec_int                   int_rate                          0.504617
# int_rate                        total_rec_int                     0.504617
# num_bc_tl                       num_actv_rev_tl                   0.491451
# num_actv_rev_tl                 num_bc_tl                         0.491451
# mo_sin_rcnt_tl                  num_tl_op_past_12m                0.490789
# num_tl_op_past_12m              mo_sin_rcnt_tl                    0.490789
# inq_last_6mths                  inq_last_12m                      0.490561
# inq_last_12m                    inq_last_6mths                    0.490561
# acc_open_past_24mths            open_acc                          0.484479
# open_acc                        acc_open_past_24mths              0.484479
# mths_since_rcnt_il              open_il_24m                       0.483421
# open_il_24m                     mths_since_rcnt_il                0.483421
# bc_open_to_buy                  all_util                          0.468038
# all_util                        bc_open_to_buy                    0.468038
# mo_sin_rcnt_tl                  open_acc_6m                       0.466575
# open_acc_6m                     mo_sin_rcnt_tl                    0.466575
# total_rec_int                   total_pymnt_inv                   0.460399
# total_pymnt_inv                 total_rec_int                     0.460399
# num_il_tl                       open_il_24m                       0.457890
# open_il_24m                     num_il_tl                         0.457890
# revol_bal                       tot_cur_bal                       0.455735
# tot_cur_bal                     revol_bal                         0.455735
# num_tl_op_past_12m              inq_last_12m                      0.453532
# inq_last_12m                    num_tl_op_past_12m                0.453532
# delinq_2yrs                     pct_tl_nvr_dlq                    0.451422
# pct_tl_nvr_dlq                  delinq_2yrs                       0.451422
# open_il_12m                     acc_open_past_24mths              0.450394
# acc_open_past_24mths            open_il_12m                       0.450394
# mths_since_last_major_derog     num_tl_90g_dpd_24m                0.448906
# num_tl_90g_dpd_24m              mths_since_last_major_derog       0.448906
# acc_open_past_24mths            mo_sin_rcnt_tl                    0.446766
# mo_sin_rcnt_tl                  acc_open_past_24mths              0.446766
# open_il_24m                     num_tl_op_past_12m                0.446085
# num_tl_op_past_12m              open_il_24m                       0.446085
# mths_since_rcnt_il              open_il_12m                       0.443401
# open_il_12m                     mths_since_rcnt_il                0.443401
# open_acc_6m                     inq_last_6mths                    0.439006
# inq_last_6mths                  open_acc_6m                       0.439006
# annual_inc_joint                loan_amnt                         0.438866
#                                 funded_amnt                       0.438866
# funded_amnt                     annual_inc_joint                  0.438866
# loan_amnt                       annual_inc_joint                  0.438866
# total_acc                       acc_open_past_24mths              0.435991
# acc_open_past_24mths            total_acc                         0.435991
# open_il_12m                     open_acc_6m                       0.422440
# open_acc_6m                     open_il_12m                       0.422440
# total_il_high_credit_limit      total_acc                         0.419243
# total_acc                       total_il_high_credit_limit        0.419243
# mths_since_last_major_derog     delinq_2yrs                       0.416555
# delinq_2yrs                     mths_since_last_major_derog       0.416555
# acc_open_past_24mths            mo_sin_rcnt_rev_tl_op             0.413834
# mo_sin_rcnt_rev_tl_op           acc_open_past_24mths              0.413834
# bc_open_to_buy                  num_bc_tl                         0.412514
# num_bc_tl                       bc_open_to_buy                    0.412514
# loan_amnt                       max_bal_bc                        0.412165
# max_bal_bc                      loan_amnt                         0.412165
#                                 funded_amnt                       0.412165
# funded_amnt                     max_bal_bc                        0.412165
# mo_sin_rcnt_rev_tl_op           num_tl_op_past_12m                0.411336
# num_tl_op_past_12m              mo_sin_rcnt_rev_tl_op             0.411336
# total_acc                       num_actv_rev_tl                   0.408414
# num_actv_rev_tl                 total_acc                         0.408414
# total_il_high_credit_limit      tot_cur_bal                       0.401982
# tot_cur_bal                     total_il_high_credit_limit        0.401982
# inq_last_12m                    acc_open_past_24mths              0.399875
# acc_open_past_24mths            inq_last_12m                      0.399875
# open_acc                        num_il_tl                         0.388601
# num_il_tl                       open_acc                          0.388601
# open_il_6m                      total_acc                         0.381588
# total_acc                       open_il_6m                        0.381588
# mths_since_recent_bc            mo_sin_rcnt_tl                    0.381143
# mo_sin_rcnt_tl                  mths_since_recent_bc              0.381143
# tot_cur_bal                     annual_inc                        0.379008
# annual_inc                      tot_cur_bal                       0.379008
# all_util                        open_il_6m                        0.374155
# open_il_6m                      all_util                          0.374155
# inq_last_6mths                  num_tl_op_past_12m                0.370187
# num_tl_op_past_12m              inq_last_6mths                    0.370187
# mths_since_rcnt_il              mo_sin_rcnt_tl                    0.368634
# mo_sin_rcnt_tl                  mths_since_rcnt_il                0.368634
# open_acc_6m                     mo_sin_rcnt_rev_tl_op             0.362280
# mo_sin_rcnt_rev_tl_op           open_acc_6m                       0.362280
# open_il_24m                     open_il_6m                        0.361892
# open_il_6m                      open_il_24m                       0.361892
# num_tl_op_past_12m              open_acc                          0.361077
# open_acc                        num_tl_op_past_12m                0.361077
# max_bal_bc                      tot_cur_bal                       0.359861
# tot_cur_bal                     max_bal_bc                        0.359861
# open_acc                        total_il_high_credit_limit        0.359085
# total_il_high_credit_limit      open_acc                          0.359085
#                                 open_il_24m                       0.358619
# open_il_24m                     total_il_high_credit_limit        0.358619
# total_il_high_credit_limit      dti_joint                         0.358091
# dti_joint                       total_il_high_credit_limit        0.358091
# total_acc                       mort_acc                          0.356387
# mort_acc                        total_acc                         0.356387
# num_tl_120dpd_2m                acc_now_delinq                    0.354200
# acc_now_delinq                  num_tl_120dpd_2m                  0.354200
# acc_open_past_24mths            num_actv_rev_tl                   0.353799
# num_actv_rev_tl                 acc_open_past_24mths              0.353799
# acc_open_past_24mths            mths_since_recent_bc              0.347586
# mths_since_recent_bc            acc_open_past_24mths              0.347586
# open_il_24m                     inq_fi                            0.343567
# inq_fi                          open_il_24m                       0.343567
# il_util                         mths_since_rcnt_il                0.339755
# mths_since_rcnt_il              il_util                           0.339755
# il_util                         open_il_12m                       0.335348
# open_il_12m                     il_util                           0.335348
# total_acc                       num_tl_op_past_12m                0.335309
# num_tl_op_past_12m              total_acc                         0.335309
# revol_bal                       funded_amnt                       0.334656
# loan_amnt                       revol_bal                         0.334656
# revol_bal                       loan_amnt                         0.334656
# funded_amnt                     revol_bal                         0.334656
# open_acc_6m                     open_il_24m                       0.334135
# open_il_24m                     open_acc_6m                       0.334135
# num_il_tl                       open_il_12m                       0.330264
# open_il_12m                     num_il_tl                         0.330264
# open_il_24m                     total_acc                         0.327416
# total_acc                       open_il_24m                       0.327416
# tot_cur_bal                     funded_amnt                       0.325352
# loan_amnt                       tot_cur_bal                       0.325352
# tot_cur_bal                     loan_amnt                         0.325352
# funded_amnt                     tot_cur_bal                       0.325352
# total_acc                       mo_sin_old_il_acct                0.324681
# mo_sin_old_il_acct              total_acc                         0.324681
# max_bal_bc                      annual_inc                        0.323838
# annual_inc                      max_bal_bc                        0.323838
# open_il_12m                     inq_last_12m                      0.320455
# inq_last_12m                    open_il_12m                       0.320455
# num_bc_tl                       mo_sin_old_rev_tl_op              0.318972
# mo_sin_old_rev_tl_op            num_bc_tl                         0.318972
# mo_sin_old_il_acct              num_il_tl                         0.318158
# num_il_tl                       mo_sin_old_il_acct                0.318158
# inq_last_12m                    open_acc_6m                       0.316823
# open_acc_6m                     inq_last_12m                      0.316823
# open_il_24m                     il_util                           0.313991
# il_util                         open_il_24m                       0.313991
# acc_open_past_24mths            inq_last_6mths                    0.313472
# inq_last_6mths                  acc_open_past_24mths              0.313472
# num_actv_bc_tl                  revol_bal                         0.313037
# revol_bal                       num_actv_bc_tl                    0.313037
# mths_since_recent_bc            num_tl_op_past_12m                0.311198
# num_tl_op_past_12m              mths_since_recent_bc              0.311198
# funded_amnt                     annual_inc                        0.305734
# annual_inc                      funded_amnt                       0.305734
#                                 loan_amnt                         0.305734
# loan_amnt                       annual_inc                        0.305734
# total_acc                       tot_cur_bal                       0.305456
# tot_cur_bal                     total_acc                         0.305456
# num_actv_rev_tl                 revol_bal                         0.303062
# revol_bal                       num_actv_rev_tl                   0.303062
# open_il_6m                      il_util                           0.302547
# il_util                         open_il_6m                        0.302547
# num_actv_bc_tl                  total_acc                         0.298630
# total_acc                       num_actv_bc_tl                    0.298630
# acc_open_past_24mths            mths_since_rcnt_il                0.297660
# mths_since_rcnt_il              acc_open_past_24mths              0.297660
# out_prncp                       max_bal_bc                        0.296159
# max_bal_bc                      out_prncp                         0.296159
# annual_inc_joint                out_prncp                         0.294799
# out_prncp                       annual_inc_joint                  0.294799
# mths_since_recent_inq           num_tl_op_past_12m                0.293933
# num_tl_op_past_12m              mths_since_recent_inq             0.293933
# inq_fi                          acc_open_past_24mths              0.293872
# acc_open_past_24mths            inq_fi                            0.293872
# int_rate                        bc_open_to_buy                    0.293227
# bc_open_to_buy                  int_rate                          0.293227
# revol_bal                       annual_inc_joint                  0.292057
# annual_inc_joint                revol_bal                         0.292057
# open_acc                        bc_open_to_buy                    0.291677
# bc_open_to_buy                  open_acc                          0.291677
# mo_sin_old_rev_tl_op            mort_acc                          0.291468
# mort_acc                        mo_sin_old_rev_tl_op              0.291468
# open_acc_6m                     mths_since_recent_inq             0.290239
# mths_since_recent_inq           open_acc_6m                       0.290239
# num_bc_tl                       acc_open_past_24mths              0.290163
# acc_open_past_24mths            num_bc_tl                         0.290163
# open_il_12m                     mo_sin_rcnt_tl                    0.290154
# mo_sin_rcnt_tl                  open_il_12m                       0.290154
# num_accts_ever_120_pd           num_tl_90g_dpd_24m                0.289009
# num_tl_90g_dpd_24m              num_accts_ever_120_pd             0.289009
# mort_acc                        annual_inc_joint                  0.288563
# annual_inc_joint                mort_acc                          0.288563
# int_rate                        all_util                          0.287799
# all_util                        int_rate                          0.287799
# dti_joint                       int_rate                          0.287345
# int_rate                        dti_joint                         0.287345
# max_bal_bc                      bc_util                           0.285585
# bc_util                         max_bal_bc                        0.285585
# dti_joint                       all_util                          0.283800
# all_util                        dti_joint                         0.283800
# total_il_high_credit_limit      mths_since_rcnt_il                0.279007
# mths_since_rcnt_il              total_il_high_credit_limit        0.279007
# num_il_tl                       all_util                          0.276826
# all_util                        num_il_tl                         0.276826
# pct_tl_nvr_dlq                  num_tl_90g_dpd_24m                0.275400
# num_tl_90g_dpd_24m              pct_tl_nvr_dlq                    0.275400
# mo_sin_old_rev_tl_op            total_acc                         0.272853
# total_acc                       mo_sin_old_rev_tl_op              0.272853
# num_tl_op_past_12m              num_actv_rev_tl                   0.272512
# num_actv_rev_tl                 num_tl_op_past_12m                0.272512
# mths_since_last_record          tax_liens                         0.272167
# tax_liens                       mths_since_last_record            0.272167
# open_acc                        open_acc_6m                       0.272024
# open_acc_6m                     open_acc                          0.272024
# total_cu_tl                     open_il_24m                       0.271978
# open_il_24m                     total_cu_tl                       0.271978
# total_cu_tl                     num_il_tl                         0.271690
# num_il_tl                       total_cu_tl                       0.271690
# total_rec_int                   annual_inc_joint                  0.271435
# annual_inc_joint                total_rec_int                     0.271435
# revol_bal                       annual_inc                        0.270174
# annual_inc                      revol_bal                         0.270174
# inq_fi                          open_il_12m                       0.269379
# open_il_12m                     inq_fi                            0.269379
# open_il_24m                     mo_sin_rcnt_tl                    0.269002
# mo_sin_rcnt_tl                  open_il_24m                       0.269002
# annual_inc_joint                total_il_high_credit_limit        0.267373
# total_il_high_credit_limit      annual_inc_joint                  0.267373
#                                 open_il_12m                       0.267005
# open_il_12m                     total_il_high_credit_limit        0.267005
# total_pymnt_inv                 max_bal_bc                        0.266137
# max_bal_bc                      total_pymnt_inv                   0.266137
# mths_since_rcnt_il              num_tl_op_past_12m                0.265792
# num_tl_op_past_12m              mths_since_rcnt_il                0.265792
# mths_since_last_record          pub_rec                           0.265775
# pub_rec                         mths_since_last_record            0.265775
# open_il_12m                     open_il_6m                        0.264868
# open_il_6m                      open_il_12m                       0.264868
# total_cu_tl                     total_acc                         0.264322
# total_acc                       total_cu_tl                       0.264322
# open_acc_6m                     mths_since_recent_bc              0.264169
# mths_since_recent_bc            open_acc_6m                       0.264169
# dti_joint                       open_il_24m                       0.263564
# open_il_24m                     dti_joint                         0.263564
#                                 inq_last_12m                      0.262772
# inq_last_12m                    open_il_24m                       0.262772
# total_pymnt_inv                 annual_inc_joint                  0.262040
# annual_inc_joint                total_pymnt_inv                   0.262040
#                                 dti_joint                         0.260920
# dti_joint                       annual_inc_joint                  0.260920
#                                 num_il_tl                         0.257909
# num_il_tl                       dti_joint                         0.257909
# dti_joint                       open_il_6m                        0.257454
# open_il_6m                      dti_joint                         0.257454
# inq_last_12m                    int_rate                          0.257077
# int_rate                        inq_last_12m                      0.257077
# num_tl_op_past_12m              int_rate                          0.256831
# int_rate                        num_tl_op_past_12m                0.256831
# tot_cur_bal                     total_pymnt_inv                   0.256324
# total_pymnt_inv                 tot_cur_bal                       0.256324
# open_acc_6m                     total_acc                         0.255894
# total_acc                       open_acc_6m                       0.255894
# num_actv_bc_tl                  bc_open_to_buy                    0.254651
# bc_open_to_buy                  num_actv_bc_tl                    0.254651
# mths_since_recent_inq           mo_sin_rcnt_tl                    0.254345
# mo_sin_rcnt_tl                  mths_since_recent_inq             0.254345
# mths_since_rcnt_il              num_il_tl                         0.254214
# num_il_tl                       mths_since_rcnt_il                0.254214
# mths_since_recent_bc            num_actv_bc_tl                    0.253040
# num_actv_bc_tl                  mths_since_recent_bc              0.253040
# num_il_tl                       il_util                           0.252761
# il_util                         num_il_tl                         0.252761
# all_util                        total_il_high_credit_limit        0.252285
# total_il_high_credit_limit      all_util                          0.252285
# num_il_tl                       acc_open_past_24mths              0.250266
# acc_open_past_24mths            num_il_tl                         0.250266
# open_acc                        dti_joint                         0.248634
# dti_joint                       open_acc                          0.248634
# tot_cur_bal                     open_acc                          0.245249
# open_acc                        tot_cur_bal                       0.245249
# int_rate                        open_il_12m                       0.245028
# open_il_12m                     int_rate                          0.245028
# annual_inc                      total_il_high_credit_limit        0.242637
# total_il_high_credit_limit      annual_inc                        0.242637
# mths_since_rcnt_il              open_il_6m                        0.239308
# open_il_6m                      mths_since_rcnt_il                0.239308
# total_rec_int                   max_bal_bc                        0.238917
# max_bal_bc                      total_rec_int                     0.238917
# inq_last_12m                    mo_sin_rcnt_tl                    0.238692
# mo_sin_rcnt_tl                  inq_last_12m                      0.238692
# mo_sin_rcnt_rev_tl_op           open_acc                          0.237177
# open_acc                        mo_sin_rcnt_rev_tl_op             0.237177
# num_tl_120dpd_2m                delinq_amnt                       0.235801
# delinq_amnt                     num_tl_120dpd_2m                  0.235801
# annual_inc                      total_pymnt_inv                   0.233854
# total_pymnt_inv                 annual_inc                        0.233854
# mo_sin_rcnt_rev_tl_op           num_actv_rev_tl                   0.233198
# num_actv_rev_tl                 mo_sin_rcnt_rev_tl_op             0.233198
# max_bal_bc                      mo_sin_old_rev_tl_op              0.232998
# mo_sin_old_rev_tl_op            max_bal_bc                        0.232998
# total_pymnt_inv                 revol_bal                         0.232882
# revol_bal                       total_pymnt_inv                   0.232882
# num_tl_op_past_12m              inq_fi                            0.232548
# inq_fi                          num_tl_op_past_12m                0.232548
# mths_since_recent_bc            num_bc_tl                         0.232140
# num_bc_tl                       mths_since_recent_bc              0.232140
# mo_sin_rcnt_tl                  inq_last_6mths                    0.231653
# inq_last_6mths                  mo_sin_rcnt_tl                    0.231653
# num_tl_op_past_12m              num_bc_tl                         0.231639
# num_bc_tl                       num_tl_op_past_12m                0.231639
# mort_acc                        loan_amnt                         0.231574
# funded_amnt                     mort_acc                          0.231574
# mort_acc                        funded_amnt                       0.231574
# loan_amnt                       mort_acc                          0.231574
# int_rate                        inq_last_6mths                    0.231139
# inq_last_6mths                  int_rate                          0.231139
# total_acc                       open_il_12m                       0.229534
# open_il_12m                     total_acc                         0.229534
# mo_sin_old_rev_tl_op            revol_bal                         0.229251
# revol_bal                       mo_sin_old_rev_tl_op              0.229251
# acc_open_past_24mths            int_rate                          0.228782
# int_rate                        acc_open_past_24mths              0.228782
# dti_joint                       total_acc                         0.228740
# total_acc                       dti_joint                         0.228740
# all_util                        open_il_24m                       0.228108
# open_il_24m                     all_util                          0.228108
# bc_util                         int_rate                          0.226620
# int_rate                        bc_util                           0.226620
# num_bc_tl                       all_util                          0.226541
# all_util                        num_bc_tl                         0.226541
# revol_bal                       num_bc_tl                         0.226247
# num_bc_tl                       revol_bal                         0.226247
# open_acc                        mo_sin_rcnt_tl                    0.226008
# mo_sin_rcnt_tl                  open_acc                          0.226008
# open_acc_6m                     int_rate                          0.225983
# int_rate                        open_acc_6m                       0.225983
# max_bal_bc                      mort_acc                          0.225561
# mort_acc                        max_bal_bc                        0.225561
# dti_joint                       num_actv_rev_tl                   0.223716
# num_actv_rev_tl                 dti_joint                         0.223716
# open_acc                        revol_bal                         0.222987
# revol_bal                       open_acc                          0.222987
# bc_open_to_buy                  total_acc                         0.222279
# total_acc                       bc_open_to_buy                    0.222279
# open_acc                        open_il_24m                       0.222188
# open_il_24m                     open_acc                          0.222188
# acc_open_past_24mths            num_actv_bc_tl                    0.221338
# num_actv_bc_tl                  acc_open_past_24mths              0.221338
# il_util                         num_tl_op_past_12m                0.221101
# num_tl_op_past_12m              il_util                           0.221101
# mths_since_last_delinq          num_tl_90g_dpd_24m                0.220551
# num_tl_90g_dpd_24m              mths_since_last_delinq            0.220551
# total_pymnt_inv                 id                                0.220078
# id                              total_pymnt_inv                   0.220078
# num_tl_90g_dpd_24m              chargeoff_within_12_mths          0.219341
# chargeoff_within_12_mths        num_tl_90g_dpd_24m                0.219341
# annual_inc_joint                total_acc                         0.218706
# total_acc                       annual_inc_joint                  0.218706
# pct_tl_nvr_dlq                  mths_since_last_record            0.217565
# mths_since_last_record          pct_tl_nvr_dlq                    0.217565
# mths_since_recent_inq           acc_open_past_24mths              0.217455
# acc_open_past_24mths            mths_since_recent_inq             0.217455
# mths_since_recent_inq           inq_fi                            0.217058
# inq_fi                          mths_since_recent_inq             0.217058
# revol_bal                       out_prncp                         0.216746
# out_prncp                       revol_bal                         0.216746
# mths_since_rcnt_il              open_acc_6m                       0.213904
# open_acc_6m                     mths_since_rcnt_il                0.213904
# loan_amnt                       num_actv_bc_tl                    0.212990
# funded_amnt                     num_actv_bc_tl                    0.212990
# num_actv_bc_tl                  funded_amnt                       0.212990
#                                 loan_amnt                         0.212990
# inq_last_6mths                  mo_sin_rcnt_rev_tl_op             0.212791
# mo_sin_rcnt_rev_tl_op           inq_last_6mths                    0.212791
# annual_inc_joint                open_acc                          0.212462
# open_acc                        annual_inc_joint                  0.212462
# total_acc                       mo_sin_rcnt_tl                    0.212142
# mo_sin_rcnt_tl                  total_acc                         0.212142
# acc_open_past_24mths            il_util                           0.211992
# il_util                         acc_open_past_24mths              0.211992
# max_bal_bc                      num_actv_bc_tl                    0.210655
# num_actv_bc_tl                  max_bal_bc                        0.210655
# mo_sin_old_rev_tl_op            mo_sin_old_il_acct                0.209846
# mo_sin_old_il_acct              mo_sin_old_rev_tl_op              0.209846
# dti_joint                       revol_bal                         0.209837
# revol_bal                       dti_joint                         0.209837
# mths_since_recent_bc            open_acc                          0.209754
# open_acc                        mths_since_recent_bc              0.209754
# annual_inc                      mort_acc                          0.209046
# mort_acc                        annual_inc                        0.209046
# num_actv_rev_tl                 mths_since_recent_bc              0.208867
# mths_since_recent_bc            num_actv_rev_tl                   0.208867
# loan_amnt                       total_acc                         0.208430
# total_acc                       funded_amnt                       0.208430
#                                 loan_amnt                         0.208430
# funded_amnt                     total_acc                         0.208430
# inq_last_6mths                  inq_fi                            0.206920
# inq_fi                          inq_last_6mths                    0.206920
# all_util                        open_il_12m                       0.206718
# open_il_12m                     all_util                          0.206718
# il_util                         mo_sin_rcnt_tl                    0.206114
# mo_sin_rcnt_tl                  il_util                           0.206114
# pub_rec_bankruptcies            mths_since_last_record            0.205201
# mths_since_last_record          pub_rec_bankruptcies              0.205201
# num_bc_tl                       loan_amnt                         0.203509
# loan_amnt                       num_bc_tl                         0.203509
# num_bc_tl                       funded_amnt                       0.203509
# funded_amnt                     num_bc_tl                         0.203509
# loan_amnt                       total_il_high_credit_limit        0.203093
# total_il_high_credit_limit      funded_amnt                       0.203093
#                                 loan_amnt                         0.203093
# funded_amnt                     total_il_high_credit_limit        0.203093
# bc_open_to_buy                  loan_amnt                         0.202669
# funded_amnt                     bc_open_to_buy                    0.202669
# bc_open_to_buy                  funded_amnt                       0.202669
# loan_amnt                       bc_open_to_buy                    0.202669
# delinq_2yrs                     num_accts_ever_120_pd             0.202065
# num_accts_ever_120_pd           delinq_2yrs                       0.202065
# revol_bal                       mort_acc                          0.200702
# mort_acc                        revol_bal                         0.200702
# total_acc                       inq_last_12m                      0.200231
# inq_last_12m                    total_acc                         0.200231
# int_rate                        open_il_24m                       0.199403
# open_il_24m                     int_rate                          0.199403
# total_il_high_credit_limit      mo_sin_old_il_acct                0.198404
# mo_sin_old_il_acct              total_il_high_credit_limit        0.198404
# revol_bal                       total_rec_int                     0.196740
# total_rec_int                   revol_bal                         0.196740
# mort_acc                        total_pymnt_inv                   0.195691
# total_pymnt_inv                 mort_acc                          0.195691
# num_actv_rev_tl                 open_acc_6m                       0.194478
# open_acc_6m                     num_actv_rev_tl                   0.194478
# total_il_high_credit_limit      il_util                           0.192893
# il_util                         total_il_high_credit_limit        0.192893
# tot_cur_bal                     num_il_tl                         0.192672
# num_il_tl                       tot_cur_bal                       0.192672
# out_prncp                       id                                0.192187
# id                              out_prncp                         0.192187
# mths_since_rcnt_il              inq_fi                            0.190816
# inq_fi                          mths_since_rcnt_il                0.190816
# mths_since_last_major_derog     chargeoff_within_12_mths          0.190762
# chargeoff_within_12_mths        mths_since_last_major_derog       0.190762
# num_bc_tl                       bc_util                           0.190620
# bc_util                         num_bc_tl                         0.190620
# open_il_12m                     dti_joint                         0.189623
# dti_joint                       open_il_12m                       0.189623
# mo_sin_old_rev_tl_op            bc_open_to_buy                    0.189489
# bc_open_to_buy                  mo_sin_old_rev_tl_op              0.189489
# inq_last_12m                    mths_since_rcnt_il                0.188328
# mths_since_rcnt_il              inq_last_12m                      0.188328
# num_bc_tl                       mort_acc                          0.188328
# mort_acc                        num_bc_tl                         0.188328
# open_acc                        funded_amnt                       0.188214
# funded_amnt                     open_acc                          0.188214
# loan_amnt                       open_acc                          0.188214
# open_acc                        loan_amnt                         0.188214
# total_cu_tl                     open_il_12m                       0.188198
# open_il_12m                     total_cu_tl                       0.188198
# max_bal_bc                      bc_open_to_buy                    0.187992
# bc_open_to_buy                  max_bal_bc                        0.187992
# num_il_tl                       num_tl_op_past_12m                0.187427
# num_tl_op_past_12m              num_il_tl                         0.187427
# mort_acc                        mo_sin_old_il_acct                0.185704
# mo_sin_old_il_acct              mort_acc                          0.185704
# mths_since_last_delinq          pct_tl_nvr_dlq                    0.185657
# pct_tl_nvr_dlq                  mths_since_last_delinq            0.185657
# out_prncp                       tot_cur_bal                       0.185158
# tot_cur_bal                     out_prncp                         0.185158
# open_acc_6m                     il_util                           0.184878
# il_util                         open_acc_6m                       0.184878
# annual_inc_joint                max_bal_bc                        0.184765
# max_bal_bc                      annual_inc_joint                  0.184765
# mths_since_recent_inq           int_rate                          0.184545
# int_rate                        mths_since_recent_inq             0.184545
# loan_amnt                       mo_sin_old_rev_tl_op              0.183754
# mo_sin_old_rev_tl_op            funded_amnt                       0.183754
#                                 loan_amnt                         0.183754
# funded_amnt                     mo_sin_old_rev_tl_op              0.183754
# int_rate                        il_util                           0.183550
# il_util                         int_rate                          0.183550
# mo_sin_rcnt_rev_tl_op           num_bc_tl                         0.182871
# num_bc_tl                       mo_sin_rcnt_rev_tl_op             0.182871
# tot_cur_bal                     mo_sin_old_rev_tl_op              0.181803
# mo_sin_old_rev_tl_op            tot_cur_bal                       0.181803
# total_acc                       mths_since_rcnt_il                0.181232
# mths_since_rcnt_il              total_acc                         0.181232
# dti_joint                       acc_open_past_24mths              0.180794
# acc_open_past_24mths            dti_joint                         0.180794
# revol_bal                       total_acc                         0.180191
# ...
# mo_sin_rcnt_rev_tl_op           tax_liens                         0.000762
# tax_liens                       mo_sin_rcnt_rev_tl_op             0.000762
#                                 recoveries                        0.000758
# recoveries                      tax_liens                         0.000758
# num_il_tl                       mths_since_recent_revol_delinq    0.000722
# mths_since_recent_revol_delinq  num_il_tl                         0.000722
# mths_since_recent_bc            tax_liens                         0.000695
# tax_liens                       mths_since_recent_bc              0.000695
# num_actv_rev_tl                 num_tl_30dpd                      0.000679
# num_tl_30dpd                    num_actv_rev_tl                   0.000679
# num_il_tl                       id                                0.000665
# id                              num_il_tl                         0.000665
# inq_last_6mths                  id                                0.000660
# id                              inq_last_6mths                    0.000660
# acc_now_delinq                  loan_amnt                         0.000645
# funded_amnt                     acc_now_delinq                    0.000645
# loan_amnt                       acc_now_delinq                    0.000645
# acc_now_delinq                  funded_amnt                       0.000645
# mths_since_recent_inq           acc_now_delinq                    0.000626
# acc_now_delinq                  mths_since_recent_inq             0.000626
# id                              num_tl_90g_dpd_24m                0.000612
# num_tl_90g_dpd_24m              id                                0.000612
# acc_now_delinq                  dti                               0.000583
# dti                             acc_now_delinq                    0.000583
# collections_12_mths_ex_med      num_tl_30dpd                      0.000566
# num_tl_30dpd                    collections_12_mths_ex_med        0.000566
# inq_last_6mths                  acc_now_delinq                    0.000563
# acc_now_delinq                  inq_last_6mths                    0.000563
# max_bal_bc                      id                                0.000543
# id                              max_bal_bc                        0.000543
# tax_liens                       num_tl_90g_dpd_24m                0.000522
# num_tl_90g_dpd_24m              tax_liens                         0.000522
# delinq_amnt                     acc_open_past_24mths              0.000521
# acc_open_past_24mths            delinq_amnt                       0.000521
# tot_coll_amt                    annual_inc                        0.000509
# annual_inc                      tot_coll_amt                      0.000509
# num_tl_30dpd                    id                                0.000488
# id                              num_tl_30dpd                      0.000488
# mo_sin_rcnt_tl                  num_tl_30dpd                      0.000443
# num_tl_30dpd                    mo_sin_rcnt_tl                    0.000443
# max_bal_bc                      num_il_tl                         0.000410
# num_il_tl                       max_bal_bc                        0.000410
# all_util                        id                                0.000399
# id                              all_util                          0.000399
# total_pymnt_inv                 num_tl_120dpd_2m                  0.000378
# num_tl_120dpd_2m                total_pymnt_inv                   0.000378
# total_cu_tl                     chargeoff_within_12_mths          0.000372
# chargeoff_within_12_mths        total_cu_tl                       0.000372
# out_prncp                       num_tl_30dpd                      0.000368
# num_tl_30dpd                    out_prncp                         0.000368
# tot_coll_amt                    recoveries                        0.000342
# recoveries                      tot_coll_amt                      0.000342
# num_actv_rev_tl                 delinq_amnt                       0.000339
# delinq_amnt                     num_actv_rev_tl                   0.000339
# tot_coll_amt                    total_rec_late_fee                0.000320
# total_rec_late_fee              tot_coll_amt                      0.000320
# num_actv_rev_tl                 chargeoff_within_12_mths          0.000267
# chargeoff_within_12_mths        num_actv_rev_tl                   0.000267
# delinq_amnt                     total_il_high_credit_limit        0.000250
# total_il_high_credit_limit      delinq_amnt                       0.000250
# num_tl_30dpd                    chargeoff_within_12_mths          0.000220
# chargeoff_within_12_mths        num_tl_30dpd                      0.000220
# dti                             mths_since_last_delinq            0.000219
# mths_since_last_delinq          dti                               0.000219
# mort_acc                        total_rec_late_fee                0.000210
# total_rec_late_fee              mort_acc                          0.000210
# mo_sin_rcnt_rev_tl_op           total_rec_late_fee                0.000203
# total_rec_late_fee              mo_sin_rcnt_rev_tl_op             0.000203
#                                 pub_rec                           0.000146
# pub_rec                         total_rec_late_fee                0.000146
# total_rec_late_fee              mths_since_recent_bc              0.000137
# mths_since_recent_bc            total_rec_late_fee                0.000137
# num_il_tl                       delinq_amnt                       0.000105
# delinq_amnt                     num_il_tl                         0.000105
# total_rec_late_fee              num_tl_120dpd_2m                  0.000098
# num_tl_120dpd_2m                total_rec_late_fee                0.000098
# acc_now_delinq                  mo_sin_rcnt_tl                    0.000093
# mo_sin_rcnt_tl                  acc_now_delinq                    0.000093
# mo_sin_old_il_acct              id                                0.000088
# id                              mo_sin_old_il_acct                0.000088
# num_tl_120dpd_2m                all_util                          0.000036
# all_util                        num_tl_120dpd_2m                  0.000036
# id                              policy_code                            NaN
# loan_amnt                       policy_code                            NaN
# funded_amnt                     policy_code                            NaN
# int_rate                        policy_code                            NaN
# annual_inc                      policy_code                            NaN
# dti                             policy_code                            NaN
# delinq_2yrs                     policy_code                            NaN
# inq_last_6mths                  policy_code                            NaN
# mths_since_last_delinq          policy_code                            NaN
# mths_since_last_record          policy_code                            NaN
# open_acc                        policy_code                            NaN
# pub_rec                         policy_code                            NaN
# revol_bal                       policy_code                            NaN
# total_acc                       policy_code                            NaN
# out_prncp                       policy_code                            NaN
# total_pymnt_inv                 policy_code                            NaN
# total_rec_int                   policy_code                            NaN
# total_rec_late_fee              policy_code                            NaN
# recoveries                      policy_code                            NaN
# collections_12_mths_ex_med      policy_code                            NaN
# mths_since_last_major_derog     policy_code                            NaN
# policy_code                     id                                     NaN
#                                 loan_amnt                              NaN
#                                 funded_amnt                            NaN
#                                 int_rate                               NaN
#                                 annual_inc                             NaN
#                                 dti                                    NaN
#                                 delinq_2yrs                            NaN
#                                 inq_last_6mths                         NaN
#                                 mths_since_last_delinq                 NaN
#                                 mths_since_last_record                 NaN
#                                 open_acc                               NaN
#                                 pub_rec                                NaN
#                                 revol_bal                              NaN
#                                 total_acc                              NaN
#                                 out_prncp                              NaN
#                                 total_pymnt_inv                        NaN
#                                 total_rec_int                          NaN
#                                 total_rec_late_fee                     NaN
#                                 recoveries                             NaN
#                                 collections_12_mths_ex_med             NaN
#                                 mths_since_last_major_derog            NaN
#                                 policy_code                            NaN
#                                 annual_inc_joint                       NaN
#                                 dti_joint                              NaN
#                                 acc_now_delinq                         NaN
#                                 tot_coll_amt                           NaN
#                                 tot_cur_bal                            NaN
#                                 open_acc_6m                            NaN
#                                 open_il_6m                             NaN
#                                 open_il_12m                            NaN
#                                 open_il_24m                            NaN
#                                 mths_since_rcnt_il                     NaN
#                                 il_util                                NaN
#                                 max_bal_bc                             NaN
#                                 all_util                               NaN
#                                 inq_fi                                 NaN
#                                 total_cu_tl                            NaN
#                                 inq_last_12m                           NaN
#                                 acc_open_past_24mths                   NaN
#                                 bc_open_to_buy                         NaN
#                                 bc_util                                NaN
#                                 chargeoff_within_12_mths               NaN
#                                 delinq_amnt                            NaN
#                                 mo_sin_old_il_acct                     NaN
#                                 mo_sin_old_rev_tl_op                   NaN
#                                 mo_sin_rcnt_rev_tl_op                  NaN
#                                 mo_sin_rcnt_tl                         NaN
#                                 mort_acc                               NaN
#                                 mths_since_recent_bc                   NaN
#                                 mths_since_recent_inq                  NaN
#                                 mths_since_recent_revol_delinq         NaN
#                                 num_accts_ever_120_pd                  NaN
#                                 num_actv_bc_tl                         NaN
#                                 num_actv_rev_tl                        NaN
#                                 num_bc_tl                              NaN
#                                 num_il_tl                              NaN
#                                 num_tl_120dpd_2m                       NaN
#                                 num_tl_30dpd                           NaN
#                                 num_tl_90g_dpd_24m                     NaN
#                                 num_tl_op_past_12m                     NaN
#                                 pct_tl_nvr_dlq                         NaN
#                                 pub_rec_bankruptcies                   NaN
#                                 tax_liens                              NaN
#                                 total_il_high_credit_limit             NaN
# annual_inc_joint                policy_code                            NaN
#                                 num_tl_120dpd_2m                       NaN
# dti_joint                       policy_code                            NaN
#                                 num_tl_120dpd_2m                       NaN
# acc_now_delinq                  policy_code                            NaN
# tot_coll_amt                    policy_code                            NaN
# tot_cur_bal                     policy_code                            NaN
# open_acc_6m                     policy_code                            NaN
# open_il_6m                      policy_code                            NaN
# open_il_12m                     policy_code                            NaN
# open_il_24m                     policy_code                            NaN
# mths_since_rcnt_il              policy_code                            NaN
# il_util                         policy_code                            NaN
# max_bal_bc                      policy_code                            NaN
# all_util                        policy_code                            NaN
# inq_fi                          policy_code                            NaN
# total_cu_tl                     policy_code                            NaN
# inq_last_12m                    policy_code                            NaN
# acc_open_past_24mths            policy_code                            NaN
# bc_open_to_buy                  policy_code                            NaN
# bc_util                         policy_code                            NaN
# chargeoff_within_12_mths        policy_code                            NaN
# delinq_amnt                     policy_code                            NaN
# mo_sin_old_il_acct              policy_code                            NaN
# mo_sin_old_rev_tl_op            policy_code                            NaN
# mo_sin_rcnt_rev_tl_op           policy_code                            NaN
# mo_sin_rcnt_tl                  policy_code                            NaN
# mort_acc                        policy_code                            NaN
# mths_since_recent_bc            policy_code                            NaN
# mths_since_recent_inq           policy_code                            NaN
# mths_since_recent_revol_delinq  policy_code                            NaN
# num_accts_ever_120_pd           policy_code                            NaN
# num_actv_bc_tl                  policy_code                            NaN
# num_actv_rev_tl                 policy_code                            NaN
# num_bc_tl                       policy_code                            NaN
# num_il_tl                       policy_code                            NaN
# num_tl_120dpd_2m                policy_code                            NaN
#                                 annual_inc_joint                       NaN
#                                 dti_joint                              NaN
# num_tl_30dpd                    policy_code                            NaN
# num_tl_90g_dpd_24m              policy_code                            NaN
# num_tl_op_past_12m              policy_code                            NaN
# pct_tl_nvr_dlq                  policy_code                            NaN
# pub_rec_bankruptcies            policy_code                            NaN
# tax_liens                       policy_code                            NaN
# total_il_high_credit_limit      policy_code                            NaN
# dtype: float64

# %%
## remove more columns
y2015 = y2015.drop(columns = ['mths_since_last_delinq', 'num_actv_bc_tl', 'num_tl_30dpd', 'acc_open_past_24mths',\
                             'open_il_24m', 'open_acc_6m', 'total_rec_int', 'total_rec_int', 'tax_liens', 'annual_inc',\
                             'total_acc'])

# %%
## recreate sorted correlation matrix
c2 = y2015.corr().abs()

s2 = c2.unstack()
so2 = s2.sort_values(kind="quicksort", ascending=False)

pd.set_option('display.max_rows', 5000)
print(so2)
# Out:
# total_il_high_credit_limit      total_il_high_credit_limit        1.000000
# mths_since_rcnt_il              mths_since_rcnt_il                1.000000
# all_util                        all_util                          1.000000
# inq_fi                          inq_fi                            1.000000
# total_cu_tl                     total_cu_tl                       1.000000
# inq_last_12m                    inq_last_12m                      1.000000
# bc_open_to_buy                  bc_open_to_buy                    1.000000
# bc_util                         bc_util                           1.000000
# chargeoff_within_12_mths        chargeoff_within_12_mths          1.000000
# delinq_amnt                     delinq_amnt                       1.000000
# mo_sin_old_il_acct              mo_sin_old_il_acct                1.000000
# mo_sin_old_rev_tl_op            mo_sin_old_rev_tl_op              1.000000
# mo_sin_rcnt_rev_tl_op           mo_sin_rcnt_rev_tl_op             1.000000
# mo_sin_rcnt_tl                  mo_sin_rcnt_tl                    1.000000
# mort_acc                        mort_acc                          1.000000
# mths_since_recent_bc            mths_since_recent_bc              1.000000
# mths_since_recent_inq           mths_since_recent_inq             1.000000
# mths_since_recent_revol_delinq  mths_since_recent_revol_delinq    1.000000
# num_accts_ever_120_pd           num_accts_ever_120_pd             1.000000
# num_actv_rev_tl                 num_actv_rev_tl                   1.000000
# num_bc_tl                       num_bc_tl                         1.000000
# num_il_tl                       num_il_tl                         1.000000
# num_tl_120dpd_2m                num_tl_120dpd_2m                  1.000000
# num_tl_90g_dpd_24m              num_tl_90g_dpd_24m                1.000000
# num_tl_op_past_12m              num_tl_op_past_12m                1.000000
# il_util                         il_util                           1.000000
# open_il_12m                     open_il_12m                       1.000000
# pub_rec_bankruptcies            pub_rec_bankruptcies              1.000000
# open_il_6m                      open_il_6m                        1.000000
# loan_amnt                       loan_amnt                         1.000000
#                                 funded_amnt                       1.000000
# funded_amnt                     loan_amnt                         1.000000
#                                 funded_amnt                       1.000000
# int_rate                        int_rate                          1.000000
# dti                             dti                               1.000000
# delinq_2yrs                     delinq_2yrs                       1.000000
# inq_last_6mths                  inq_last_6mths                    1.000000
# mths_since_last_record          mths_since_last_record            1.000000
# open_acc                        open_acc                          1.000000
# pub_rec                         pub_rec                           1.000000
# revol_bal                       revol_bal                         1.000000
# out_prncp                       out_prncp                         1.000000
# total_pymnt_inv                 total_pymnt_inv                   1.000000
# total_rec_late_fee              total_rec_late_fee                1.000000
# recoveries                      recoveries                        1.000000
# collections_12_mths_ex_med      collections_12_mths_ex_med        1.000000
# mths_since_last_major_derog     mths_since_last_major_derog       1.000000
# annual_inc_joint                annual_inc_joint                  1.000000
# dti_joint                       dti_joint                         1.000000
# acc_now_delinq                  acc_now_delinq                    1.000000
# tot_coll_amt                    tot_coll_amt                      1.000000
# tot_cur_bal                     tot_cur_bal                       1.000000
# pct_tl_nvr_dlq                  pct_tl_nvr_dlq                    1.000000
# max_bal_bc                      max_bal_bc                        1.000000
# id                              id                                1.000000
# loan_amnt                       total_pymnt_inv                   0.706157
# total_pymnt_inv                 funded_amnt                       0.706157
#                                 loan_amnt                         0.706157
# funded_amnt                     total_pymnt_inv                   0.706157
# open_acc                        num_actv_rev_tl                   0.670931
# num_actv_rev_tl                 open_acc                          0.670931
# num_il_tl                       open_il_6m                        0.651989
# open_il_6m                      num_il_tl                         0.651989
# num_tl_90g_dpd_24m              delinq_2yrs                       0.649762
# delinq_2yrs                     num_tl_90g_dpd_24m                0.649762
# funded_amnt                     out_prncp                         0.623926
# loan_amnt                       out_prncp                         0.623926
# out_prncp                       loan_amnt                         0.623926
#                                 funded_amnt                       0.623926
# mo_sin_rcnt_tl                  mo_sin_rcnt_rev_tl_op             0.618613
# mo_sin_rcnt_rev_tl_op           mo_sin_rcnt_tl                    0.618613
# pub_rec_bankruptcies            pub_rec                           0.615794
# pub_rec                         pub_rec_bankruptcies              0.615794
# mths_since_recent_bc            mo_sin_rcnt_rev_tl_op             0.608235
# mo_sin_rcnt_rev_tl_op           mths_since_recent_bc              0.608235
# total_il_high_credit_limit      num_il_tl                         0.592311
# num_il_tl                       total_il_high_credit_limit        0.592311
# bc_util                         all_util                          0.582955
# all_util                        bc_util                           0.582955
# max_bal_bc                      revol_bal                         0.582009
# revol_bal                       max_bal_bc                        0.582009
# open_il_12m                     num_tl_op_past_12m                0.572495
# num_tl_op_past_12m              open_il_12m                       0.572495
# open_il_6m                      total_il_high_credit_limit        0.572296
# total_il_high_credit_limit      open_il_6m                        0.572296
# all_util                        il_util                           0.569126
# il_util                         all_util                          0.569126
# inq_fi                          inq_last_12m                      0.563795
# inq_last_12m                    inq_fi                            0.563795
# pct_tl_nvr_dlq                  num_accts_ever_120_pd             0.553769
# num_accts_ever_120_pd           pct_tl_nvr_dlq                    0.553769
# mths_since_recent_inq           inq_last_6mths                    0.547384
# inq_last_6mths                  mths_since_recent_inq             0.547384
# mths_since_last_major_derog     mths_since_recent_revol_delinq    0.541628
# mths_since_recent_revol_delinq  mths_since_last_major_derog       0.541628
# bc_util                         bc_open_to_buy                    0.539107
# bc_open_to_buy                  bc_util                           0.539107
# mort_acc                        tot_cur_bal                       0.524410
# tot_cur_bal                     mort_acc                          0.524410
# open_acc                        num_bc_tl                         0.519201
# num_bc_tl                       open_acc                          0.519201
# tot_cur_bal                     annual_inc_joint                  0.516695
# annual_inc_joint                tot_cur_bal                       0.516695
# open_acc                        open_il_6m                        0.515508
# open_il_6m                      open_acc                          0.515508
# inq_last_12m                    mths_since_recent_inq             0.508102
# mths_since_recent_inq           inq_last_12m                      0.508102
# mths_since_recent_revol_delinq  delinq_2yrs                       0.505285
# delinq_2yrs                     mths_since_recent_revol_delinq    0.505285
# num_actv_rev_tl                 num_bc_tl                         0.491451
# num_bc_tl                       num_actv_rev_tl                   0.491451
# num_tl_op_past_12m              mo_sin_rcnt_tl                    0.490789
# mo_sin_rcnt_tl                  num_tl_op_past_12m                0.490789
# inq_last_12m                    inq_last_6mths                    0.490561
# inq_last_6mths                  inq_last_12m                      0.490561
# all_util                        bc_open_to_buy                    0.468038
# bc_open_to_buy                  all_util                          0.468038
# tot_cur_bal                     revol_bal                         0.455735
# revol_bal                       tot_cur_bal                       0.455735
# inq_last_12m                    num_tl_op_past_12m                0.453532
# num_tl_op_past_12m              inq_last_12m                      0.453532
# delinq_2yrs                     pct_tl_nvr_dlq                    0.451422
# pct_tl_nvr_dlq                  delinq_2yrs                       0.451422
# num_tl_90g_dpd_24m              mths_since_last_major_derog       0.448906
# mths_since_last_major_derog     num_tl_90g_dpd_24m                0.448906
# open_il_12m                     mths_since_rcnt_il                0.443401
# mths_since_rcnt_il              open_il_12m                       0.443401
# funded_amnt                     annual_inc_joint                  0.438866
# annual_inc_joint                funded_amnt                       0.438866
#                                 loan_amnt                         0.438866
# loan_amnt                       annual_inc_joint                  0.438866
# delinq_2yrs                     mths_since_last_major_derog       0.416555
# mths_since_last_major_derog     delinq_2yrs                       0.416555
# num_bc_tl                       bc_open_to_buy                    0.412514
# bc_open_to_buy                  num_bc_tl                         0.412514
# max_bal_bc                      loan_amnt                         0.412165
# loan_amnt                       max_bal_bc                        0.412165
# max_bal_bc                      funded_amnt                       0.412165
# funded_amnt                     max_bal_bc                        0.412165
# mo_sin_rcnt_rev_tl_op           num_tl_op_past_12m                0.411336
# num_tl_op_past_12m              mo_sin_rcnt_rev_tl_op             0.411336
# tot_cur_bal                     total_il_high_credit_limit        0.401982
# total_il_high_credit_limit      tot_cur_bal                       0.401982
# num_il_tl                       open_acc                          0.388601
# open_acc                        num_il_tl                         0.388601
# mths_since_recent_bc            mo_sin_rcnt_tl                    0.381143
# mo_sin_rcnt_tl                  mths_since_recent_bc              0.381143
# open_il_6m                      all_util                          0.374155
# all_util                        open_il_6m                        0.374155
# inq_last_6mths                  num_tl_op_past_12m                0.370187
# num_tl_op_past_12m              inq_last_6mths                    0.370187
# mo_sin_rcnt_tl                  mths_since_rcnt_il                0.368634
# mths_since_rcnt_il              mo_sin_rcnt_tl                    0.368634
# num_tl_op_past_12m              open_acc                          0.361077
# open_acc                        num_tl_op_past_12m                0.361077
# max_bal_bc                      tot_cur_bal                       0.359861
# tot_cur_bal                     max_bal_bc                        0.359861
# total_il_high_credit_limit      open_acc                          0.359085
# open_acc                        total_il_high_credit_limit        0.359085
# dti_joint                       total_il_high_credit_limit        0.358091
# total_il_high_credit_limit      dti_joint                         0.358091
# num_tl_120dpd_2m                acc_now_delinq                    0.354200
# acc_now_delinq                  num_tl_120dpd_2m                  0.354200
# mths_since_rcnt_il              il_util                           0.339755
# il_util                         mths_since_rcnt_il                0.339755
# open_il_12m                     il_util                           0.335348
# il_util                         open_il_12m                       0.335348
# revol_bal                       funded_amnt                       0.334656
# funded_amnt                     revol_bal                         0.334656
# loan_amnt                       revol_bal                         0.334656
# revol_bal                       loan_amnt                         0.334656
# num_il_tl                       open_il_12m                       0.330264
# open_il_12m                     num_il_tl                         0.330264
# loan_amnt                       tot_cur_bal                       0.325352
# funded_amnt                     tot_cur_bal                       0.325352
# tot_cur_bal                     loan_amnt                         0.325352
#                                 funded_amnt                       0.325352
# open_il_12m                     inq_last_12m                      0.320455
# inq_last_12m                    open_il_12m                       0.320455
# mo_sin_old_rev_tl_op            num_bc_tl                         0.318972
# num_bc_tl                       mo_sin_old_rev_tl_op              0.318972
# mo_sin_old_il_acct              num_il_tl                         0.318158
# num_il_tl                       mo_sin_old_il_acct                0.318158
# num_tl_op_past_12m              mths_since_recent_bc              0.311198
# mths_since_recent_bc            num_tl_op_past_12m                0.311198
# num_actv_rev_tl                 revol_bal                         0.303062
# revol_bal                       num_actv_rev_tl                   0.303062
# il_util                         open_il_6m                        0.302547
# open_il_6m                      il_util                           0.302547
# max_bal_bc                      out_prncp                         0.296159
# out_prncp                       max_bal_bc                        0.296159
#                                 annual_inc_joint                  0.294799
# annual_inc_joint                out_prncp                         0.294799
# mths_since_recent_inq           num_tl_op_past_12m                0.293933
# num_tl_op_past_12m              mths_since_recent_inq             0.293933
# bc_open_to_buy                  int_rate                          0.293227
# int_rate                        bc_open_to_buy                    0.293227
# annual_inc_joint                revol_bal                         0.292057
# revol_bal                       annual_inc_joint                  0.292057
# open_acc                        bc_open_to_buy                    0.291677
# bc_open_to_buy                  open_acc                          0.291677
# mort_acc                        mo_sin_old_rev_tl_op              0.291468
# mo_sin_old_rev_tl_op            mort_acc                          0.291468
# mo_sin_rcnt_tl                  open_il_12m                       0.290154
# open_il_12m                     mo_sin_rcnt_tl                    0.290154
# num_tl_90g_dpd_24m              num_accts_ever_120_pd             0.289009
# num_accts_ever_120_pd           num_tl_90g_dpd_24m                0.289009
# annual_inc_joint                mort_acc                          0.288563
# mort_acc                        annual_inc_joint                  0.288563
# int_rate                        all_util                          0.287799
# all_util                        int_rate                          0.287799
# dti_joint                       int_rate                          0.287345
# int_rate                        dti_joint                         0.287345
# max_bal_bc                      bc_util                           0.285585
# bc_util                         max_bal_bc                        0.285585
# dti_joint                       all_util                          0.283800
# all_util                        dti_joint                         0.283800
# total_il_high_credit_limit      mths_since_rcnt_il                0.279007
# mths_since_rcnt_il              total_il_high_credit_limit        0.279007
# all_util                        num_il_tl                         0.276826
# num_il_tl                       all_util                          0.276826
# num_tl_90g_dpd_24m              pct_tl_nvr_dlq                    0.275400
# pct_tl_nvr_dlq                  num_tl_90g_dpd_24m                0.275400
# num_actv_rev_tl                 num_tl_op_past_12m                0.272512
# num_tl_op_past_12m              num_actv_rev_tl                   0.272512
# num_il_tl                       total_cu_tl                       0.271690
# total_cu_tl                     num_il_tl                         0.271690
# inq_fi                          open_il_12m                       0.269379
# open_il_12m                     inq_fi                            0.269379
# annual_inc_joint                total_il_high_credit_limit        0.267373
# total_il_high_credit_limit      annual_inc_joint                  0.267373
#                                 open_il_12m                       0.267005
# open_il_12m                     total_il_high_credit_limit        0.267005
# max_bal_bc                      total_pymnt_inv                   0.266137
# total_pymnt_inv                 max_bal_bc                        0.266137
# num_tl_op_past_12m              mths_since_rcnt_il                0.265792
# mths_since_rcnt_il              num_tl_op_past_12m                0.265792
# pub_rec                         mths_since_last_record            0.265775
# mths_since_last_record          pub_rec                           0.265775
# open_il_12m                     open_il_6m                        0.264868
# open_il_6m                      open_il_12m                       0.264868
# annual_inc_joint                total_pymnt_inv                   0.262040
# total_pymnt_inv                 annual_inc_joint                  0.262040
# dti_joint                       annual_inc_joint                  0.260920
# annual_inc_joint                dti_joint                         0.260920
# num_il_tl                       dti_joint                         0.257909
# dti_joint                       num_il_tl                         0.257909
# open_il_6m                      dti_joint                         0.257454
# dti_joint                       open_il_6m                        0.257454
# int_rate                        inq_last_12m                      0.257077
# inq_last_12m                    int_rate                          0.257077
# num_tl_op_past_12m              int_rate                          0.256831
# int_rate                        num_tl_op_past_12m                0.256831
# tot_cur_bal                     total_pymnt_inv                   0.256324
# total_pymnt_inv                 tot_cur_bal                       0.256324
# mo_sin_rcnt_tl                  mths_since_recent_inq             0.254345
# mths_since_recent_inq           mo_sin_rcnt_tl                    0.254345
# num_il_tl                       mths_since_rcnt_il                0.254214
# mths_since_rcnt_il              num_il_tl                         0.254214
# num_il_tl                       il_util                           0.252761
# il_util                         num_il_tl                         0.252761
# total_il_high_credit_limit      all_util                          0.252285
# all_util                        total_il_high_credit_limit        0.252285
# open_acc                        dti_joint                         0.248634
# dti_joint                       open_acc                          0.248634
# open_acc                        tot_cur_bal                       0.245249
# tot_cur_bal                     open_acc                          0.245249
# open_il_12m                     int_rate                          0.245028
# int_rate                        open_il_12m                       0.245028
# open_il_6m                      mths_since_rcnt_il                0.239308
# mths_since_rcnt_il              open_il_6m                        0.239308
# mo_sin_rcnt_tl                  inq_last_12m                      0.238692
# inq_last_12m                    mo_sin_rcnt_tl                    0.238692
# mo_sin_rcnt_rev_tl_op           open_acc                          0.237177
# open_acc                        mo_sin_rcnt_rev_tl_op             0.237177
# delinq_amnt                     num_tl_120dpd_2m                  0.235801
# num_tl_120dpd_2m                delinq_amnt                       0.235801
# num_actv_rev_tl                 mo_sin_rcnt_rev_tl_op             0.233198
# mo_sin_rcnt_rev_tl_op           num_actv_rev_tl                   0.233198
# max_bal_bc                      mo_sin_old_rev_tl_op              0.232998
# mo_sin_old_rev_tl_op            max_bal_bc                        0.232998
# revol_bal                       total_pymnt_inv                   0.232882
# total_pymnt_inv                 revol_bal                         0.232882
# num_tl_op_past_12m              inq_fi                            0.232548
# inq_fi                          num_tl_op_past_12m                0.232548
# num_bc_tl                       mths_since_recent_bc              0.232140
# mths_since_recent_bc            num_bc_tl                         0.232140
# mo_sin_rcnt_tl                  inq_last_6mths                    0.231653
# inq_last_6mths                  mo_sin_rcnt_tl                    0.231653
# num_tl_op_past_12m              num_bc_tl                         0.231639
# num_bc_tl                       num_tl_op_past_12m                0.231639
# loan_amnt                       mort_acc                          0.231574
# funded_amnt                     mort_acc                          0.231574
# mort_acc                        funded_amnt                       0.231574
#                                 loan_amnt                         0.231574
# inq_last_6mths                  int_rate                          0.231139
# int_rate                        inq_last_6mths                    0.231139
# mo_sin_old_rev_tl_op            revol_bal                         0.229251
# revol_bal                       mo_sin_old_rev_tl_op              0.229251
# bc_util                         int_rate                          0.226620
# int_rate                        bc_util                           0.226620
# num_bc_tl                       all_util                          0.226541
# all_util                        num_bc_tl                         0.226541
# revol_bal                       num_bc_tl                         0.226247
# num_bc_tl                       revol_bal                         0.226247
# mo_sin_rcnt_tl                  open_acc                          0.226008
# open_acc                        mo_sin_rcnt_tl                    0.226008
# max_bal_bc                      mort_acc                          0.225561
# mort_acc                        max_bal_bc                        0.225561
# num_actv_rev_tl                 dti_joint                         0.223716
# dti_joint                       num_actv_rev_tl                   0.223716
# open_acc                        revol_bal                         0.222987
# revol_bal                       open_acc                          0.222987
# num_tl_op_past_12m              il_util                           0.221101
# il_util                         num_tl_op_past_12m                0.221101
# id                              total_pymnt_inv                   0.220078
# total_pymnt_inv                 id                                0.220078
# num_tl_90g_dpd_24m              chargeoff_within_12_mths          0.219341
# chargeoff_within_12_mths        num_tl_90g_dpd_24m                0.219341
# pct_tl_nvr_dlq                  mths_since_last_record            0.217565
# mths_since_last_record          pct_tl_nvr_dlq                    0.217565
# mths_since_recent_inq           inq_fi                            0.217058
# inq_fi                          mths_since_recent_inq             0.217058
# out_prncp                       revol_bal                         0.216746
# revol_bal                       out_prncp                         0.216746
# inq_last_6mths                  mo_sin_rcnt_rev_tl_op             0.212791
# mo_sin_rcnt_rev_tl_op           inq_last_6mths                    0.212791
# annual_inc_joint                open_acc                          0.212462
# open_acc                        annual_inc_joint                  0.212462
# mo_sin_old_rev_tl_op            mo_sin_old_il_acct                0.209846
# mo_sin_old_il_acct              mo_sin_old_rev_tl_op              0.209846
# dti_joint                       revol_bal                         0.209837
# revol_bal                       dti_joint                         0.209837
# mths_since_recent_bc            open_acc                          0.209754
# open_acc                        mths_since_recent_bc              0.209754
# mths_since_recent_bc            num_actv_rev_tl                   0.208867
# num_actv_rev_tl                 mths_since_recent_bc              0.208867
# inq_fi                          inq_last_6mths                    0.206920
# inq_last_6mths                  inq_fi                            0.206920
# open_il_12m                     all_util                          0.206718
# all_util                        open_il_12m                       0.206718
# mo_sin_rcnt_tl                  il_util                           0.206114
# il_util                         mo_sin_rcnt_tl                    0.206114
# pub_rec_bankruptcies            mths_since_last_record            0.205201
# mths_since_last_record          pub_rec_bankruptcies              0.205201
# num_bc_tl                       loan_amnt                         0.203509
#                                 funded_amnt                       0.203509
# funded_amnt                     num_bc_tl                         0.203509
# loan_amnt                       num_bc_tl                         0.203509
# total_il_high_credit_limit      funded_amnt                       0.203093
#                                 loan_amnt                         0.203093
# loan_amnt                       total_il_high_credit_limit        0.203093
# funded_amnt                     total_il_high_credit_limit        0.203093
# loan_amnt                       bc_open_to_buy                    0.202669
# bc_open_to_buy                  loan_amnt                         0.202669
#                                 funded_amnt                       0.202669
# funded_amnt                     bc_open_to_buy                    0.202669
# num_accts_ever_120_pd           delinq_2yrs                       0.202065
# delinq_2yrs                     num_accts_ever_120_pd             0.202065
# mort_acc                        revol_bal                         0.200702
# revol_bal                       mort_acc                          0.200702
# total_il_high_credit_limit      mo_sin_old_il_acct                0.198404
# mo_sin_old_il_acct              total_il_high_credit_limit        0.198404
# total_pymnt_inv                 mort_acc                          0.195691
# mort_acc                        total_pymnt_inv                   0.195691
# total_il_high_credit_limit      il_util                           0.192893
# il_util                         total_il_high_credit_limit        0.192893
# num_il_tl                       tot_cur_bal                       0.192672
# tot_cur_bal                     num_il_tl                         0.192672
# out_prncp                       id                                0.192187
# id                              out_prncp                         0.192187
# mths_since_rcnt_il              inq_fi                            0.190816
# inq_fi                          mths_since_rcnt_il                0.190816
# chargeoff_within_12_mths        mths_since_last_major_derog       0.190762
# mths_since_last_major_derog     chargeoff_within_12_mths          0.190762
# bc_util                         num_bc_tl                         0.190620
# num_bc_tl                       bc_util                           0.190620
# open_il_12m                     dti_joint                         0.189623
# dti_joint                       open_il_12m                       0.189623
# mo_sin_old_rev_tl_op            bc_open_to_buy                    0.189489
# bc_open_to_buy                  mo_sin_old_rev_tl_op              0.189489
# inq_last_12m                    mths_since_rcnt_il                0.188328
# mths_since_rcnt_il              inq_last_12m                      0.188328
# mort_acc                        num_bc_tl                         0.188328
# num_bc_tl                       mort_acc                          0.188328
# open_acc                        loan_amnt                         0.188214
# loan_amnt                       open_acc                          0.188214
# funded_amnt                     open_acc                          0.188214
# open_acc                        funded_amnt                       0.188214
# total_cu_tl                     open_il_12m                       0.188198
# open_il_12m                     total_cu_tl                       0.188198
# bc_open_to_buy                  max_bal_bc                        0.187992
# max_bal_bc                      bc_open_to_buy                    0.187992
# num_il_tl                       num_tl_op_past_12m                0.187427
# num_tl_op_past_12m              num_il_tl                         0.187427
# mo_sin_old_il_acct              mort_acc                          0.185704
# mort_acc                        mo_sin_old_il_acct                0.185704
# out_prncp                       tot_cur_bal                       0.185158
# tot_cur_bal                     out_prncp                         0.185158
# max_bal_bc                      annual_inc_joint                  0.184765
# annual_inc_joint                max_bal_bc                        0.184765
# mths_since_recent_inq           int_rate                          0.184545
# int_rate                        mths_since_recent_inq             0.184545
# funded_amnt                     mo_sin_old_rev_tl_op              0.183754
# mo_sin_old_rev_tl_op            funded_amnt                       0.183754
# loan_amnt                       mo_sin_old_rev_tl_op              0.183754
# mo_sin_old_rev_tl_op            loan_amnt                         0.183754
# il_util                         int_rate                          0.183550
# int_rate                        il_util                           0.183550
# num_bc_tl                       mo_sin_rcnt_rev_tl_op             0.182871
# mo_sin_rcnt_rev_tl_op           num_bc_tl                         0.182871
# mo_sin_old_rev_tl_op            tot_cur_bal                       0.181803
# tot_cur_bal                     mo_sin_old_rev_tl_op              0.181803
# mo_sin_rcnt_rev_tl_op           inq_last_12m                      0.179508
# inq_last_12m                    mo_sin_rcnt_rev_tl_op             0.179508
# revol_bal                       bc_open_to_buy                    0.178413
# bc_open_to_buy                  revol_bal                         0.178413
# num_bc_tl                       max_bal_bc                        0.177423
# max_bal_bc                      num_bc_tl                         0.177423
# bc_util                         num_tl_op_past_12m                0.174605
# num_tl_op_past_12m              bc_util                           0.174605
# int_rate                        inq_fi                            0.170973
# inq_fi                          int_rate                          0.170973
# num_actv_rev_tl                 mo_sin_old_rev_tl_op              0.170584
# mo_sin_old_rev_tl_op            num_actv_rev_tl                   0.170584
# mo_sin_old_il_acct              tot_cur_bal                       0.170101
# tot_cur_bal                     mo_sin_old_il_acct                0.170101
# mort_acc                        total_cu_tl                       0.169887
# total_cu_tl                     mort_acc                          0.169887
# bc_util                         dti_joint                         0.169820
# dti_joint                       bc_util                           0.169820
# num_il_tl                       inq_fi                            0.169657
# inq_fi                          num_il_tl                         0.169657
# pub_rec_bankruptcies            max_bal_bc                        0.167210
# max_bal_bc                      pub_rec_bankruptcies              0.167210
# bc_open_to_buy                  total_pymnt_inv                   0.167077
# total_pymnt_inv                 bc_open_to_buy                    0.167077
# pct_tl_nvr_dlq                  max_bal_bc                        0.166550
# max_bal_bc                      pct_tl_nvr_dlq                    0.166550
# annual_inc_joint                all_util                          0.166212
# all_util                        annual_inc_joint                  0.166212
# num_bc_tl                       total_pymnt_inv                   0.166191
# total_pymnt_inv                 num_bc_tl                         0.166191
# mths_since_recent_revol_delinq  pub_rec_bankruptcies              0.164847
# pub_rec_bankruptcies            mths_since_recent_revol_delinq    0.164847
# num_accts_ever_120_pd           mths_since_recent_revol_delinq    0.164582
# mths_since_recent_revol_delinq  num_accts_ever_120_pd             0.164582
# funded_amnt                     num_actv_rev_tl                   0.164565
# loan_amnt                       num_actv_rev_tl                   0.164565
# num_actv_rev_tl                 loan_amnt                         0.164565
#                                 funded_amnt                       0.164565
# inq_last_12m                    open_acc                          0.163774
# open_acc                        inq_last_12m                      0.163774
# bc_open_to_buy                  tot_cur_bal                       0.163424
# tot_cur_bal                     bc_open_to_buy                    0.163424
# mo_sin_rcnt_rev_tl_op           mths_since_recent_inq             0.163163
# mths_since_recent_inq           mo_sin_rcnt_rev_tl_op             0.163163
# bc_open_to_buy                  pct_tl_nvr_dlq                    0.162892
# pct_tl_nvr_dlq                  bc_open_to_buy                    0.162892
# mo_sin_old_rev_tl_op            int_rate                          0.160134
# int_rate                        mo_sin_old_rev_tl_op              0.160134
# inq_last_6mths                  num_actv_rev_tl                   0.159185
# num_actv_rev_tl                 inq_last_6mths                    0.159185
# open_acc                        inq_last_6mths                    0.159144
# inq_last_6mths                  open_acc                          0.159144
# num_bc_tl                       mths_since_last_record            0.157830
# mths_since_last_record          num_bc_tl                         0.157830
# open_il_12m                     mths_since_recent_inq             0.157380
# mths_since_recent_inq           open_il_12m                       0.157380
# tot_cur_bal                     open_il_6m                        0.156413
# open_il_6m                      tot_cur_bal                       0.156413
# bc_util                         revol_bal                         0.154151
# revol_bal                       bc_util                           0.154151
# all_util                        mths_since_rcnt_il                0.154030
# mths_since_rcnt_il              all_util                          0.154030
# inq_last_12m                    il_util                           0.153825
# il_util                         inq_last_12m                      0.153825
# mo_sin_rcnt_tl                  num_actv_rev_tl                   0.153668
# num_actv_rev_tl                 mo_sin_rcnt_tl                    0.153668
# mths_since_rcnt_il              open_acc                          0.153199
# open_acc                        mths_since_rcnt_il                0.153199
# inq_last_6mths                  mths_since_recent_bc              0.152971
# mths_since_recent_bc            inq_last_6mths                    0.152971
#                                 bc_util                           0.151931
# bc_util                         mths_since_recent_bc              0.151931
# max_bal_bc                      pub_rec                           0.151474
# pub_rec                         max_bal_bc                        0.151474
# annual_inc_joint                bc_open_to_buy                    0.150660
# bc_open_to_buy                  annual_inc_joint                  0.150660
# int_rate                        mo_sin_rcnt_tl                    0.150179
# mo_sin_rcnt_tl                  int_rate                          0.150179
# inq_last_6mths                  open_il_12m                       0.149877
# open_il_12m                     inq_last_6mths                    0.149877
# num_accts_ever_120_pd           mths_since_last_record            0.149832
# mths_since_last_record          num_accts_ever_120_pd             0.149832
# annual_inc_joint                num_bc_tl                         0.147784
# num_bc_tl                       annual_inc_joint                  0.147784
# tot_coll_amt                    num_accts_ever_120_pd             0.145754
# num_accts_ever_120_pd           tot_coll_amt                      0.145754
# inq_fi                          total_il_high_credit_limit        0.145450
# total_il_high_credit_limit      inq_fi                            0.145450
# il_util                         inq_fi                            0.145342
# inq_fi                          il_util                           0.145342
# delinq_2yrs                     chargeoff_within_12_mths          0.144239
# chargeoff_within_12_mths        delinq_2yrs                       0.144239
# open_acc                        open_il_12m                       0.142777
# open_il_12m                     open_acc                          0.142777
# num_bc_tl                       tot_cur_bal                       0.142479
# tot_cur_bal                     num_bc_tl                         0.142479
# mths_since_recent_revol_delinq  num_tl_90g_dpd_24m                0.141736
# num_tl_90g_dpd_24m              mths_since_recent_revol_delinq    0.141736
# inq_last_12m                    mths_since_recent_bc              0.141577
# mths_since_recent_bc            inq_last_12m                      0.141577
# num_il_tl                       inq_last_12m                      0.141528
# inq_last_12m                    num_il_tl                         0.141528
# funded_amnt                     int_rate                          0.140572
# int_rate                        funded_amnt                       0.140572
# loan_amnt                       int_rate                          0.140572
# int_rate                        loan_amnt                         0.140572
# mths_since_rcnt_il              total_cu_tl                       0.138082
# total_cu_tl                     mths_since_rcnt_il                0.138082
# loan_amnt                       mo_sin_old_il_acct                0.137114
# mo_sin_old_il_acct              funded_amnt                       0.137114
# funded_amnt                     mo_sin_old_il_acct                0.137114
# mo_sin_old_il_acct              loan_amnt                         0.137114
# total_il_high_credit_limit      max_bal_bc                        0.137002
# max_bal_bc                      total_il_high_credit_limit        0.137002
# num_bc_tl                       inq_last_6mths                    0.136091
# inq_last_6mths                  num_bc_tl                         0.136091
# out_prncp                       mo_sin_old_rev_tl_op              0.136083
# mo_sin_old_rev_tl_op            out_prncp                         0.136083
# mo_sin_rcnt_tl                  inq_fi                            0.135433
# inq_fi                          mo_sin_rcnt_tl                    0.135433
# mo_sin_old_rev_tl_op            open_acc                          0.135201
# open_acc                        mo_sin_old_rev_tl_op              0.135201
# out_prncp                       total_il_high_credit_limit        0.134439
# total_il_high_credit_limit      out_prncp                         0.134439
# dti_joint                       max_bal_bc                        0.134070
# max_bal_bc                      dti_joint                         0.134070
# total_pymnt_inv                 total_il_high_credit_limit        0.133848
# total_il_high_credit_limit      total_pymnt_inv                   0.133848
# acc_now_delinq                  delinq_2yrs                       0.132685
# delinq_2yrs                     acc_now_delinq                    0.132685
# revol_bal                       pub_rec_bankruptcies              0.132012
# pub_rec_bankruptcies            revol_bal                         0.132012
# bc_util                         mo_sin_rcnt_rev_tl_op             0.131450
# mo_sin_rcnt_rev_tl_op           bc_util                           0.131450
# pub_rec_bankruptcies            mths_since_last_major_derog       0.131395
# mths_since_last_major_derog     pub_rec_bankruptcies              0.131395
# num_tl_op_past_12m              total_il_high_credit_limit        0.130805
# total_il_high_credit_limit      num_tl_op_past_12m                0.130805
# out_prncp                       num_actv_rev_tl                   0.130760
# num_actv_rev_tl                 out_prncp                         0.130760
# inq_last_12m                    total_il_high_credit_limit        0.130535
# total_il_high_credit_limit      inq_last_12m                      0.130535
# inq_last_12m                    pub_rec_bankruptcies              0.130482
# pub_rec_bankruptcies            inq_last_12m                      0.130482
# num_tl_op_past_12m              max_bal_bc                        0.130009
# max_bal_bc                      num_tl_op_past_12m                0.130009
# mo_sin_rcnt_tl                  num_bc_tl                         0.129605
# num_bc_tl                       mo_sin_rcnt_tl                    0.129605
# annual_inc_joint                mo_sin_old_rev_tl_op              0.129117
# mo_sin_old_rev_tl_op            annual_inc_joint                  0.129117
# open_acc                        mo_sin_old_il_acct                0.128910
# mo_sin_old_il_acct              open_acc                          0.128910
# mths_since_rcnt_il              int_rate                          0.128435
# int_rate                        mths_since_rcnt_il                0.128435
# revol_bal                       pct_tl_nvr_dlq                    0.128087
# pct_tl_nvr_dlq                  revol_bal                         0.128087
# dti_joint                       pub_rec                           0.127954
# pub_rec                         dti_joint                         0.127954
# open_acc                        pct_tl_nvr_dlq                    0.127752
# pct_tl_nvr_dlq                  open_acc                          0.127752
# recoveries                      out_prncp                         0.127724
# out_prncp                       recoveries                        0.127724
# delinq_amnt                     acc_now_delinq                    0.127571
# acc_now_delinq                  delinq_amnt                       0.127571
# max_bal_bc                      mo_sin_rcnt_rev_tl_op             0.127563
# mo_sin_rcnt_rev_tl_op           max_bal_bc                        0.127563
# num_il_tl                       mo_sin_rcnt_tl                    0.127561
# mo_sin_rcnt_tl                  num_il_tl                         0.127561
# collections_12_mths_ex_med      mths_since_last_major_derog       0.127003
# mths_since_last_major_derog     collections_12_mths_ex_med        0.127003
# pub_rec                         mths_since_recent_revol_delinq    0.126948
# mths_since_recent_revol_delinq  pub_rec                           0.126948
# all_util                        mo_sin_rcnt_rev_tl_op             0.126885
# mo_sin_rcnt_rev_tl_op           all_util                          0.126885
# pub_rec_bankruptcies            num_tl_op_past_12m                0.126741
# num_tl_op_past_12m              pub_rec_bankruptcies              0.126741
# num_accts_ever_120_pd           chargeoff_within_12_mths          0.126719
# chargeoff_within_12_mths        num_accts_ever_120_pd             0.126719
# max_bal_bc                      il_util                           0.126547
# il_util                         max_bal_bc                        0.126547
# open_acc                        il_util                           0.126190
# il_util                         open_acc                          0.126190
# mort_acc                        bc_open_to_buy                    0.125294
# bc_open_to_buy                  mort_acc                          0.125294
# funded_amnt                     pub_rec_bankruptcies              0.124430
# loan_amnt                       pub_rec_bankruptcies              0.124430
# pub_rec_bankruptcies            loan_amnt                         0.124430
#                                 funded_amnt                       0.124430
# bc_util                         mo_sin_rcnt_tl                    0.124193
# mo_sin_rcnt_tl                  bc_util                           0.124193
# open_acc                        total_pymnt_inv                   0.123737
# total_pymnt_inv                 open_acc                          0.123737
# acc_now_delinq                  mths_since_recent_revol_delinq    0.123189
# mths_since_recent_revol_delinq  acc_now_delinq                    0.123189
# mort_acc                        out_prncp                         0.123181
# out_prncp                       mort_acc                          0.123181
# total_cu_tl                     total_il_high_credit_limit        0.122955
# total_il_high_credit_limit      total_cu_tl                       0.122955
# int_rate                        mo_sin_rcnt_rev_tl_op             0.122028
# mo_sin_rcnt_rev_tl_op           int_rate                          0.122028
# all_util                        max_bal_bc                        0.121486
# max_bal_bc                      all_util                          0.121486
# mths_since_last_record          mo_sin_old_rev_tl_op              0.121044
# mo_sin_old_rev_tl_op            mths_since_last_record            0.121044
# inq_last_6mths                  pub_rec_bankruptcies              0.120260
# pub_rec_bankruptcies            inq_last_6mths                    0.120260
# max_bal_bc                      num_accts_ever_120_pd             0.120136
# num_accts_ever_120_pd           max_bal_bc                        0.120136
# collections_12_mths_ex_med      num_tl_90g_dpd_24m                0.120101
# num_tl_90g_dpd_24m              collections_12_mths_ex_med        0.120101
# out_prncp                       open_acc                          0.119976
# open_acc                        out_prncp                         0.119976
# int_rate                        recoveries                        0.119825
# recoveries                      int_rate                          0.119825
# max_bal_bc                      mo_sin_old_il_acct                0.119804
# mo_sin_old_il_acct              max_bal_bc                        0.119804
# mo_sin_old_rev_tl_op            total_pymnt_inv                   0.119130
# total_pymnt_inv                 mo_sin_old_rev_tl_op              0.119130
# mths_since_recent_revol_delinq  num_tl_op_past_12m                0.118200
# num_tl_op_past_12m              mths_since_recent_revol_delinq    0.118200
#                                 open_il_6m                        0.117489
# open_il_6m                      num_tl_op_past_12m                0.117489
# open_acc                        mort_acc                          0.117382
# mort_acc                        open_acc                          0.117382
# mths_since_recent_bc            mo_sin_old_rev_tl_op              0.116124
# mo_sin_old_rev_tl_op            mths_since_recent_bc              0.116124
# int_rate                        num_bc_tl                         0.115968
# ...
# dti                             total_rec_late_fee                0.001150
# total_rec_late_fee              dti                               0.001150
# revol_bal                       delinq_amnt                       0.001126
# delinq_amnt                     revol_bal                         0.001126
# dti                             mths_since_recent_bc              0.001114
# mths_since_recent_bc            dti                               0.001114
# collections_12_mths_ex_med      open_il_6m                        0.001082
# open_il_6m                      collections_12_mths_ex_med        0.001082
# delinq_amnt                     recoveries                        0.001075
# recoveries                      delinq_amnt                       0.001075
# id                              chargeoff_within_12_mths          0.001075
# chargeoff_within_12_mths        id                                0.001075
# num_tl_120dpd_2m                pub_rec                           0.001069
# pub_rec                         num_tl_120dpd_2m                  0.001069
# mo_sin_rcnt_rev_tl_op           delinq_amnt                       0.001056
# delinq_amnt                     mo_sin_rcnt_rev_tl_op             0.001056
# bc_open_to_buy                  delinq_amnt                       0.001050
# delinq_amnt                     bc_open_to_buy                    0.001050
# acc_now_delinq                  out_prncp                         0.001027
# out_prncp                       acc_now_delinq                    0.001027
# recoveries                      tot_cur_bal                       0.001026
# tot_cur_bal                     recoveries                        0.001026
# tot_coll_amt                    open_il_6m                        0.001023
# open_il_6m                      tot_coll_amt                      0.001023
# delinq_amnt                     mths_since_recent_revol_delinq    0.001022
# mths_since_recent_revol_delinq  delinq_amnt                       0.001022
# open_il_6m                      acc_now_delinq                    0.000992
# acc_now_delinq                  open_il_6m                        0.000992
# out_prncp                       delinq_2yrs                       0.000939
# delinq_2yrs                     out_prncp                         0.000939
# total_rec_late_fee              open_il_6m                        0.000922
# open_il_6m                      total_rec_late_fee                0.000922
# total_cu_tl                     id                                0.000914
# id                              total_cu_tl                       0.000914
# loan_amnt                       num_tl_120dpd_2m                  0.000905
# num_tl_120dpd_2m                loan_amnt                         0.000905
# funded_amnt                     num_tl_120dpd_2m                  0.000905
# num_tl_120dpd_2m                funded_amnt                       0.000905
#                                 collections_12_mths_ex_med        0.000860
# collections_12_mths_ex_med      num_tl_120dpd_2m                  0.000860
# total_cu_tl                     mths_since_recent_revol_delinq    0.000860
# mths_since_recent_revol_delinq  total_cu_tl                       0.000860
# total_rec_late_fee              delinq_amnt                       0.000787
# delinq_amnt                     total_rec_late_fee                0.000787
# tot_coll_amt                    delinq_2yrs                       0.000762
# delinq_2yrs                     tot_coll_amt                      0.000762
# num_il_tl                       mths_since_recent_revol_delinq    0.000722
# mths_since_recent_revol_delinq  num_il_tl                         0.000722
# num_il_tl                       id                                0.000665
# id                              num_il_tl                         0.000665
#                                 inq_last_6mths                    0.000660
# inq_last_6mths                  id                                0.000660
# funded_amnt                     acc_now_delinq                    0.000645
# acc_now_delinq                  loan_amnt                         0.000645
# loan_amnt                       acc_now_delinq                    0.000645
# acc_now_delinq                  funded_amnt                       0.000645
# mths_since_recent_inq           acc_now_delinq                    0.000626
# acc_now_delinq                  mths_since_recent_inq             0.000626
# id                              num_tl_90g_dpd_24m                0.000612
# num_tl_90g_dpd_24m              id                                0.000612
# dti                             acc_now_delinq                    0.000583
# acc_now_delinq                  dti                               0.000583
# inq_last_6mths                  acc_now_delinq                    0.000563
# acc_now_delinq                  inq_last_6mths                    0.000563
# max_bal_bc                      id                                0.000543
# id                              max_bal_bc                        0.000543
# max_bal_bc                      num_il_tl                         0.000410
# num_il_tl                       max_bal_bc                        0.000410
# id                              all_util                          0.000399
# all_util                        id                                0.000399
# total_pymnt_inv                 num_tl_120dpd_2m                  0.000378
# num_tl_120dpd_2m                total_pymnt_inv                   0.000378
# total_cu_tl                     chargeoff_within_12_mths          0.000372
# chargeoff_within_12_mths        total_cu_tl                       0.000372
# tot_coll_amt                    recoveries                        0.000342
# recoveries                      tot_coll_amt                      0.000342
# delinq_amnt                     num_actv_rev_tl                   0.000339
# num_actv_rev_tl                 delinq_amnt                       0.000339
# tot_coll_amt                    total_rec_late_fee                0.000320
# total_rec_late_fee              tot_coll_amt                      0.000320
# num_actv_rev_tl                 chargeoff_within_12_mths          0.000267
# chargeoff_within_12_mths        num_actv_rev_tl                   0.000267
# delinq_amnt                     total_il_high_credit_limit        0.000250
# total_il_high_credit_limit      delinq_amnt                       0.000250
# total_rec_late_fee              mort_acc                          0.000210
# mort_acc                        total_rec_late_fee                0.000210
# mo_sin_rcnt_rev_tl_op           total_rec_late_fee                0.000203
# total_rec_late_fee              mo_sin_rcnt_rev_tl_op             0.000203
# pub_rec                         total_rec_late_fee                0.000146
# total_rec_late_fee              pub_rec                           0.000146
# mths_since_recent_bc            total_rec_late_fee                0.000137
# total_rec_late_fee              mths_since_recent_bc              0.000137
# delinq_amnt                     num_il_tl                         0.000105
# num_il_tl                       delinq_amnt                       0.000105
# num_tl_120dpd_2m                total_rec_late_fee                0.000098
# total_rec_late_fee              num_tl_120dpd_2m                  0.000098
# mo_sin_rcnt_tl                  acc_now_delinq                    0.000093
# acc_now_delinq                  mo_sin_rcnt_tl                    0.000093
# id                              mo_sin_old_il_acct                0.000088
# mo_sin_old_il_acct              id                                0.000088
# all_util                        num_tl_120dpd_2m                  0.000036
# num_tl_120dpd_2m                all_util                          0.000036
# id                              policy_code                            NaN
# loan_amnt                       policy_code                            NaN
# funded_amnt                     policy_code                            NaN
# int_rate                        policy_code                            NaN
# dti                             policy_code                            NaN
# delinq_2yrs                     policy_code                            NaN
# inq_last_6mths                  policy_code                            NaN
# mths_since_last_record          policy_code                            NaN
# open_acc                        policy_code                            NaN
# pub_rec                         policy_code                            NaN
# revol_bal                       policy_code                            NaN
# out_prncp                       policy_code                            NaN
# total_pymnt_inv                 policy_code                            NaN
# total_rec_late_fee              policy_code                            NaN
# recoveries                      policy_code                            NaN
# collections_12_mths_ex_med      policy_code                            NaN
# mths_since_last_major_derog     policy_code                            NaN
# policy_code                     id                                     NaN
#                                 loan_amnt                              NaN
#                                 funded_amnt                            NaN
#                                 int_rate                               NaN
#                                 dti                                    NaN
#                                 delinq_2yrs                            NaN
#                                 inq_last_6mths                         NaN
#                                 mths_since_last_record                 NaN
#                                 open_acc                               NaN
#                                 pub_rec                                NaN
#                                 revol_bal                              NaN
#                                 out_prncp                              NaN
#                                 total_pymnt_inv                        NaN
#                                 total_rec_late_fee                     NaN
#                                 recoveries                             NaN
#                                 collections_12_mths_ex_med             NaN
#                                 mths_since_last_major_derog            NaN
#                                 policy_code                            NaN
#                                 annual_inc_joint                       NaN
#                                 dti_joint                              NaN
#                                 acc_now_delinq                         NaN
#                                 tot_coll_amt                           NaN
#                                 tot_cur_bal                            NaN
#                                 open_il_6m                             NaN
#                                 open_il_12m                            NaN
#                                 mths_since_rcnt_il                     NaN
#                                 il_util                                NaN
#                                 max_bal_bc                             NaN
#                                 all_util                               NaN
#                                 inq_fi                                 NaN
#                                 total_cu_tl                            NaN
#                                 inq_last_12m                           NaN
#                                 bc_open_to_buy                         NaN
#                                 bc_util                                NaN
#                                 chargeoff_within_12_mths               NaN
#                                 delinq_amnt                            NaN
#                                 mo_sin_old_il_acct                     NaN
#                                 mo_sin_old_rev_tl_op                   NaN
#                                 mo_sin_rcnt_rev_tl_op                  NaN
#                                 mo_sin_rcnt_tl                         NaN
#                                 mort_acc                               NaN
#                                 mths_since_recent_bc                   NaN
#                                 mths_since_recent_inq                  NaN
#                                 mths_since_recent_revol_delinq         NaN
#                                 num_accts_ever_120_pd                  NaN
#                                 num_actv_rev_tl                        NaN
#                                 num_bc_tl                              NaN
#                                 num_il_tl                              NaN
#                                 num_tl_120dpd_2m                       NaN
#                                 num_tl_90g_dpd_24m                     NaN
#                                 num_tl_op_past_12m                     NaN
#                                 pct_tl_nvr_dlq                         NaN
#                                 pub_rec_bankruptcies                   NaN
#                                 total_il_high_credit_limit             NaN
# annual_inc_joint                policy_code                            NaN
#                                 num_tl_120dpd_2m                       NaN
# dti_joint                       policy_code                            NaN
#                                 num_tl_120dpd_2m                       NaN
# acc_now_delinq                  policy_code                            NaN
# tot_coll_amt                    policy_code                            NaN
# tot_cur_bal                     policy_code                            NaN
# open_il_6m                      policy_code                            NaN
# open_il_12m                     policy_code                            NaN
# mths_since_rcnt_il              policy_code                            NaN
# il_util                         policy_code                            NaN
# max_bal_bc                      policy_code                            NaN
# all_util                        policy_code                            NaN
# inq_fi                          policy_code                            NaN
# total_cu_tl                     policy_code                            NaN
# inq_last_12m                    policy_code                            NaN
# bc_open_to_buy                  policy_code                            NaN
# bc_util                         policy_code                            NaN
# chargeoff_within_12_mths        policy_code                            NaN
# delinq_amnt                     policy_code                            NaN
# mo_sin_old_il_acct              policy_code                            NaN
# mo_sin_old_rev_tl_op            policy_code                            NaN
# mo_sin_rcnt_rev_tl_op           policy_code                            NaN
# mo_sin_rcnt_tl                  policy_code                            NaN
# mort_acc                        policy_code                            NaN
# mths_since_recent_bc            policy_code                            NaN
# mths_since_recent_inq           policy_code                            NaN
# mths_since_recent_revol_delinq  policy_code                            NaN
# num_accts_ever_120_pd           policy_code                            NaN
# num_actv_rev_tl                 policy_code                            NaN
# num_bc_tl                       policy_code                            NaN
# num_il_tl                       policy_code                            NaN
# num_tl_120dpd_2m                policy_code                            NaN
#                                 annual_inc_joint                       NaN
#                                 dti_joint                              NaN
# num_tl_90g_dpd_24m              policy_code                            NaN
# num_tl_op_past_12m              policy_code                            NaN
# pct_tl_nvr_dlq                  policy_code                            NaN
# pub_rec_bankruptcies            policy_code                            NaN
# total_il_high_credit_limit      policy_code                            NaN
# dtype: float64

# %%
## remove more columns
y2015 = y2015.drop(columns = ['total_pymnt_inv', 'funded_amnt', 'num_actv_rev_tl', 'open_il_6m', 'delinq_2yrs', 'out_prncp',\
                             'mo_sin_rcnt_rev_tl_op', 'pub_rec_bankruptcies', 'mths_since_recent_bc'])

# %%
## Run Random Forest with cleaned data
rfc1 = ensemble.RandomForestClassifier()
X1 = y2015.drop('loan_status', 1)
Y1 = y2015['loan_status']
X1 = pd.get_dummies(X1)
X1 = X1.dropna(axis=1)

cross_val_score(rfc1, X1, Y1, cv=10)
# Out:
# c:\users\nstow\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# c:\users\nstow\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# c:\users\nstow\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# c:\users\nstow\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# c:\users\nstow\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# c:\users\nstow\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# c:\users\nstow\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# c:\users\nstow\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# c:\users\nstow\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# c:\users\nstow\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# array([0.92196813, 0.93585999, 0.92959084, 0.9232742 , 0.90949893,
#        0.92348611, 0.90833314, 0.94264884, 0.92880044, 0.94694343])

# %%
## recreate sorted correlation matrix
c3 = y2015.corr().abs()

s3 = c3.unstack()
so3 = s3.sort_values(kind="quicksort", ascending=False)

pd.set_option('display.max_rows', 5000)
print(so3)
# Out:
# total_il_high_credit_limit      total_il_high_credit_limit        1.000000
# mo_sin_old_rev_tl_op            mo_sin_old_rev_tl_op              1.000000
# inq_fi                          inq_fi                            1.000000
# total_cu_tl                     total_cu_tl                       1.000000
# inq_last_12m                    inq_last_12m                      1.000000
# bc_open_to_buy                  bc_open_to_buy                    1.000000
# bc_util                         bc_util                           1.000000
# chargeoff_within_12_mths        chargeoff_within_12_mths          1.000000
# delinq_amnt                     delinq_amnt                       1.000000
# mo_sin_old_il_acct              mo_sin_old_il_acct                1.000000
# mo_sin_rcnt_tl                  mo_sin_rcnt_tl                    1.000000
# max_bal_bc                      max_bal_bc                        1.000000
# mort_acc                        mort_acc                          1.000000
# mths_since_recent_inq           mths_since_recent_inq             1.000000
# mths_since_recent_revol_delinq  mths_since_recent_revol_delinq    1.000000
# num_accts_ever_120_pd           num_accts_ever_120_pd             1.000000
# num_bc_tl                       num_bc_tl                         1.000000
# num_il_tl                       num_il_tl                         1.000000
# num_tl_120dpd_2m                num_tl_120dpd_2m                  1.000000
# num_tl_90g_dpd_24m              num_tl_90g_dpd_24m                1.000000
# all_util                        all_util                          1.000000
# il_util                         il_util                           1.000000
# pct_tl_nvr_dlq                  pct_tl_nvr_dlq                    1.000000
# total_rec_late_fee              total_rec_late_fee                1.000000
# loan_amnt                       loan_amnt                         1.000000
# int_rate                        int_rate                          1.000000
# dti                             dti                               1.000000
# inq_last_6mths                  inq_last_6mths                    1.000000
# mths_since_last_record          mths_since_last_record            1.000000
# open_acc                        open_acc                          1.000000
# pub_rec                         pub_rec                           1.000000
# revol_bal                       revol_bal                         1.000000
# recoveries                      recoveries                        1.000000
# mths_since_rcnt_il              mths_since_rcnt_il                1.000000
# collections_12_mths_ex_med      collections_12_mths_ex_med        1.000000
# mths_since_last_major_derog     mths_since_last_major_derog       1.000000
# annual_inc_joint                annual_inc_joint                  1.000000
# dti_joint                       dti_joint                         1.000000
# acc_now_delinq                  acc_now_delinq                    1.000000
# tot_coll_amt                    tot_coll_amt                      1.000000
# tot_cur_bal                     tot_cur_bal                       1.000000
# open_il_12m                     open_il_12m                       1.000000
# num_tl_op_past_12m              num_tl_op_past_12m                1.000000
# id                              id                                1.000000
# total_il_high_credit_limit      num_il_tl                         0.592311
# num_il_tl                       total_il_high_credit_limit        0.592311
# all_util                        bc_util                           0.582955
# bc_util                         all_util                          0.582955
# revol_bal                       max_bal_bc                        0.582009
# max_bal_bc                      revol_bal                         0.582009
# open_il_12m                     num_tl_op_past_12m                0.572495
# num_tl_op_past_12m              open_il_12m                       0.572495
# il_util                         all_util                          0.569126
# all_util                        il_util                           0.569126
# inq_fi                          inq_last_12m                      0.563795
# inq_last_12m                    inq_fi                            0.563795
# pct_tl_nvr_dlq                  num_accts_ever_120_pd             0.553769
# num_accts_ever_120_pd           pct_tl_nvr_dlq                    0.553769
# inq_last_6mths                  mths_since_recent_inq             0.547384
# mths_since_recent_inq           inq_last_6mths                    0.547384
# mths_since_recent_revol_delinq  mths_since_last_major_derog       0.541628
# mths_since_last_major_derog     mths_since_recent_revol_delinq    0.541628
# bc_open_to_buy                  bc_util                           0.539107
# bc_util                         bc_open_to_buy                    0.539107
# mort_acc                        tot_cur_bal                       0.524410
# tot_cur_bal                     mort_acc                          0.524410
# num_bc_tl                       open_acc                          0.519201
# open_acc                        num_bc_tl                         0.519201
# tot_cur_bal                     annual_inc_joint                  0.516695
# annual_inc_joint                tot_cur_bal                       0.516695
# mths_since_recent_inq           inq_last_12m                      0.508102
# inq_last_12m                    mths_since_recent_inq             0.508102
# num_tl_op_past_12m              mo_sin_rcnt_tl                    0.490789
# mo_sin_rcnt_tl                  num_tl_op_past_12m                0.490789
# inq_last_6mths                  inq_last_12m                      0.490561
# inq_last_12m                    inq_last_6mths                    0.490561
# bc_open_to_buy                  all_util                          0.468038
# all_util                        bc_open_to_buy                    0.468038
# tot_cur_bal                     revol_bal                         0.455735
# revol_bal                       tot_cur_bal                       0.455735
# inq_last_12m                    num_tl_op_past_12m                0.453532
# num_tl_op_past_12m              inq_last_12m                      0.453532
# num_tl_90g_dpd_24m              mths_since_last_major_derog       0.448906
# mths_since_last_major_derog     num_tl_90g_dpd_24m                0.448906
# open_il_12m                     mths_since_rcnt_il                0.443401
# mths_since_rcnt_il              open_il_12m                       0.443401
# annual_inc_joint                loan_amnt                         0.438866
# loan_amnt                       annual_inc_joint                  0.438866
# num_bc_tl                       bc_open_to_buy                    0.412514
# bc_open_to_buy                  num_bc_tl                         0.412514
# loan_amnt                       max_bal_bc                        0.412165
# max_bal_bc                      loan_amnt                         0.412165
# tot_cur_bal                     total_il_high_credit_limit        0.401982
# total_il_high_credit_limit      tot_cur_bal                       0.401982
# open_acc                        num_il_tl                         0.388601
# num_il_tl                       open_acc                          0.388601
# inq_last_6mths                  num_tl_op_past_12m                0.370187
# num_tl_op_past_12m              inq_last_6mths                    0.370187
# mths_since_rcnt_il              mo_sin_rcnt_tl                    0.368634
# mo_sin_rcnt_tl                  mths_since_rcnt_il                0.368634
# open_acc                        num_tl_op_past_12m                0.361077
# num_tl_op_past_12m              open_acc                          0.361077
# tot_cur_bal                     max_bal_bc                        0.359861
# max_bal_bc                      tot_cur_bal                       0.359861
# open_acc                        total_il_high_credit_limit        0.359085
# total_il_high_credit_limit      open_acc                          0.359085
#                                 dti_joint                         0.358091
# dti_joint                       total_il_high_credit_limit        0.358091
# num_tl_120dpd_2m                acc_now_delinq                    0.354200
# acc_now_delinq                  num_tl_120dpd_2m                  0.354200
# mths_since_rcnt_il              il_util                           0.339755
# il_util                         mths_since_rcnt_il                0.339755
# open_il_12m                     il_util                           0.335348
# il_util                         open_il_12m                       0.335348
# revol_bal                       loan_amnt                         0.334656
# loan_amnt                       revol_bal                         0.334656
# num_il_tl                       open_il_12m                       0.330264
# open_il_12m                     num_il_tl                         0.330264
# tot_cur_bal                     loan_amnt                         0.325352
# loan_amnt                       tot_cur_bal                       0.325352
# inq_last_12m                    open_il_12m                       0.320455
# open_il_12m                     inq_last_12m                      0.320455
# mo_sin_old_rev_tl_op            num_bc_tl                         0.318972
# num_bc_tl                       mo_sin_old_rev_tl_op              0.318972
# num_il_tl                       mo_sin_old_il_acct                0.318158
# mo_sin_old_il_acct              num_il_tl                         0.318158
# mths_since_recent_inq           num_tl_op_past_12m                0.293933
# num_tl_op_past_12m              mths_since_recent_inq             0.293933
# bc_open_to_buy                  int_rate                          0.293227
# int_rate                        bc_open_to_buy                    0.293227
# annual_inc_joint                revol_bal                         0.292057
# revol_bal                       annual_inc_joint                  0.292057
# bc_open_to_buy                  open_acc                          0.291677
# open_acc                        bc_open_to_buy                    0.291677
# mort_acc                        mo_sin_old_rev_tl_op              0.291468
# mo_sin_old_rev_tl_op            mort_acc                          0.291468
# mo_sin_rcnt_tl                  open_il_12m                       0.290154
# open_il_12m                     mo_sin_rcnt_tl                    0.290154
# num_accts_ever_120_pd           num_tl_90g_dpd_24m                0.289009
# num_tl_90g_dpd_24m              num_accts_ever_120_pd             0.289009
# mort_acc                        annual_inc_joint                  0.288563
# annual_inc_joint                mort_acc                          0.288563
# int_rate                        all_util                          0.287799
# all_util                        int_rate                          0.287799
# dti_joint                       int_rate                          0.287345
# int_rate                        dti_joint                         0.287345
# bc_util                         max_bal_bc                        0.285585
# max_bal_bc                      bc_util                           0.285585
# all_util                        dti_joint                         0.283800
# dti_joint                       all_util                          0.283800
# mths_since_rcnt_il              total_il_high_credit_limit        0.279007
# total_il_high_credit_limit      mths_since_rcnt_il                0.279007
# all_util                        num_il_tl                         0.276826
# num_il_tl                       all_util                          0.276826
# num_tl_90g_dpd_24m              pct_tl_nvr_dlq                    0.275400
# pct_tl_nvr_dlq                  num_tl_90g_dpd_24m                0.275400
# total_cu_tl                     num_il_tl                         0.271690
# num_il_tl                       total_cu_tl                       0.271690
# open_il_12m                     inq_fi                            0.269379
# inq_fi                          open_il_12m                       0.269379
# annual_inc_joint                total_il_high_credit_limit        0.267373
# total_il_high_credit_limit      annual_inc_joint                  0.267373
# open_il_12m                     total_il_high_credit_limit        0.267005
# total_il_high_credit_limit      open_il_12m                       0.267005
# num_tl_op_past_12m              mths_since_rcnt_il                0.265792
# mths_since_rcnt_il              num_tl_op_past_12m                0.265792
# pub_rec                         mths_since_last_record            0.265775
# mths_since_last_record          pub_rec                           0.265775
# dti_joint                       annual_inc_joint                  0.260920
# annual_inc_joint                dti_joint                         0.260920
# num_il_tl                       dti_joint                         0.257909
# dti_joint                       num_il_tl                         0.257909
# inq_last_12m                    int_rate                          0.257077
# int_rate                        inq_last_12m                      0.257077
#                                 num_tl_op_past_12m                0.256831
# num_tl_op_past_12m              int_rate                          0.256831
# mths_since_recent_inq           mo_sin_rcnt_tl                    0.254345
# mo_sin_rcnt_tl                  mths_since_recent_inq             0.254345
# mths_since_rcnt_il              num_il_tl                         0.254214
# num_il_tl                       mths_since_rcnt_il                0.254214
#                                 il_util                           0.252761
# il_util                         num_il_tl                         0.252761
# all_util                        total_il_high_credit_limit        0.252285
# total_il_high_credit_limit      all_util                          0.252285
# open_acc                        dti_joint                         0.248634
# dti_joint                       open_acc                          0.248634
# tot_cur_bal                     open_acc                          0.245249
# open_acc                        tot_cur_bal                       0.245249
# int_rate                        open_il_12m                       0.245028
# open_il_12m                     int_rate                          0.245028
# mo_sin_rcnt_tl                  inq_last_12m                      0.238692
# inq_last_12m                    mo_sin_rcnt_tl                    0.238692
# num_tl_120dpd_2m                delinq_amnt                       0.235801
# delinq_amnt                     num_tl_120dpd_2m                  0.235801
# max_bal_bc                      mo_sin_old_rev_tl_op              0.232998
# mo_sin_old_rev_tl_op            max_bal_bc                        0.232998
# num_tl_op_past_12m              inq_fi                            0.232548
# inq_fi                          num_tl_op_past_12m                0.232548
# inq_last_6mths                  mo_sin_rcnt_tl                    0.231653
# mo_sin_rcnt_tl                  inq_last_6mths                    0.231653
# num_tl_op_past_12m              num_bc_tl                         0.231639
# num_bc_tl                       num_tl_op_past_12m                0.231639
# loan_amnt                       mort_acc                          0.231574
# mort_acc                        loan_amnt                         0.231574
# int_rate                        inq_last_6mths                    0.231139
# inq_last_6mths                  int_rate                          0.231139
# mo_sin_old_rev_tl_op            revol_bal                         0.229251
# revol_bal                       mo_sin_old_rev_tl_op              0.229251
# int_rate                        bc_util                           0.226620
# bc_util                         int_rate                          0.226620
# all_util                        num_bc_tl                         0.226541
# num_bc_tl                       all_util                          0.226541
#                                 revol_bal                         0.226247
# revol_bal                       num_bc_tl                         0.226247
# open_acc                        mo_sin_rcnt_tl                    0.226008
# mo_sin_rcnt_tl                  open_acc                          0.226008
# max_bal_bc                      mort_acc                          0.225561
# mort_acc                        max_bal_bc                        0.225561
# revol_bal                       open_acc                          0.222987
# open_acc                        revol_bal                         0.222987
# num_tl_op_past_12m              il_util                           0.221101
# il_util                         num_tl_op_past_12m                0.221101
# chargeoff_within_12_mths        num_tl_90g_dpd_24m                0.219341
# num_tl_90g_dpd_24m              chargeoff_within_12_mths          0.219341
# mths_since_last_record          pct_tl_nvr_dlq                    0.217565
# pct_tl_nvr_dlq                  mths_since_last_record            0.217565
# mths_since_recent_inq           inq_fi                            0.217058
# inq_fi                          mths_since_recent_inq             0.217058
# annual_inc_joint                open_acc                          0.212462
# open_acc                        annual_inc_joint                  0.212462
# mo_sin_old_il_acct              mo_sin_old_rev_tl_op              0.209846
# mo_sin_old_rev_tl_op            mo_sin_old_il_acct                0.209846
# revol_bal                       dti_joint                         0.209837
# dti_joint                       revol_bal                         0.209837
# inq_last_6mths                  inq_fi                            0.206920
# inq_fi                          inq_last_6mths                    0.206920
# all_util                        open_il_12m                       0.206718
# open_il_12m                     all_util                          0.206718
# mo_sin_rcnt_tl                  il_util                           0.206114
# il_util                         mo_sin_rcnt_tl                    0.206114
# loan_amnt                       num_bc_tl                         0.203509
# num_bc_tl                       loan_amnt                         0.203509
# loan_amnt                       total_il_high_credit_limit        0.203093
# total_il_high_credit_limit      loan_amnt                         0.203093
# bc_open_to_buy                  loan_amnt                         0.202669
# loan_amnt                       bc_open_to_buy                    0.202669
# mort_acc                        revol_bal                         0.200702
# revol_bal                       mort_acc                          0.200702
# mo_sin_old_il_acct              total_il_high_credit_limit        0.198404
# total_il_high_credit_limit      mo_sin_old_il_acct                0.198404
#                                 il_util                           0.192893
# il_util                         total_il_high_credit_limit        0.192893
# tot_cur_bal                     num_il_tl                         0.192672
# num_il_tl                       tot_cur_bal                       0.192672
# inq_fi                          mths_since_rcnt_il                0.190816
# mths_since_rcnt_il              inq_fi                            0.190816
# chargeoff_within_12_mths        mths_since_last_major_derog       0.190762
# mths_since_last_major_derog     chargeoff_within_12_mths          0.190762
# num_bc_tl                       bc_util                           0.190620
# bc_util                         num_bc_tl                         0.190620
# dti_joint                       open_il_12m                       0.189623
# open_il_12m                     dti_joint                         0.189623
# bc_open_to_buy                  mo_sin_old_rev_tl_op              0.189489
# mo_sin_old_rev_tl_op            bc_open_to_buy                    0.189489
# inq_last_12m                    mths_since_rcnt_il                0.188328
# mths_since_rcnt_il              inq_last_12m                      0.188328
# num_bc_tl                       mort_acc                          0.188328
# mort_acc                        num_bc_tl                         0.188328
# loan_amnt                       open_acc                          0.188214
# open_acc                        loan_amnt                         0.188214
# total_cu_tl                     open_il_12m                       0.188198
# open_il_12m                     total_cu_tl                       0.188198
# max_bal_bc                      bc_open_to_buy                    0.187992
# bc_open_to_buy                  max_bal_bc                        0.187992
# num_tl_op_past_12m              num_il_tl                         0.187427
# num_il_tl                       num_tl_op_past_12m                0.187427
# mo_sin_old_il_acct              mort_acc                          0.185704
# mort_acc                        mo_sin_old_il_acct                0.185704
# annual_inc_joint                max_bal_bc                        0.184765
# max_bal_bc                      annual_inc_joint                  0.184765
# int_rate                        mths_since_recent_inq             0.184545
# mths_since_recent_inq           int_rate                          0.184545
# mo_sin_old_rev_tl_op            loan_amnt                         0.183754
# loan_amnt                       mo_sin_old_rev_tl_op              0.183754
# int_rate                        il_util                           0.183550
# il_util                         int_rate                          0.183550
# tot_cur_bal                     mo_sin_old_rev_tl_op              0.181803
# mo_sin_old_rev_tl_op            tot_cur_bal                       0.181803
# bc_open_to_buy                  revol_bal                         0.178413
# revol_bal                       bc_open_to_buy                    0.178413
# num_bc_tl                       max_bal_bc                        0.177423
# max_bal_bc                      num_bc_tl                         0.177423
# num_tl_op_past_12m              bc_util                           0.174605
# bc_util                         num_tl_op_past_12m                0.174605
# int_rate                        inq_fi                            0.170973
# inq_fi                          int_rate                          0.170973
# tot_cur_bal                     mo_sin_old_il_acct                0.170101
# mo_sin_old_il_acct              tot_cur_bal                       0.170101
# mort_acc                        total_cu_tl                       0.169887
# total_cu_tl                     mort_acc                          0.169887
# bc_util                         dti_joint                         0.169820
# dti_joint                       bc_util                           0.169820
# inq_fi                          num_il_tl                         0.169657
# num_il_tl                       inq_fi                            0.169657
# pct_tl_nvr_dlq                  max_bal_bc                        0.166550
# max_bal_bc                      pct_tl_nvr_dlq                    0.166550
# annual_inc_joint                all_util                          0.166212
# all_util                        annual_inc_joint                  0.166212
# num_accts_ever_120_pd           mths_since_recent_revol_delinq    0.164582
# mths_since_recent_revol_delinq  num_accts_ever_120_pd             0.164582
# inq_last_12m                    open_acc                          0.163774
# open_acc                        inq_last_12m                      0.163774
# bc_open_to_buy                  tot_cur_bal                       0.163424
# tot_cur_bal                     bc_open_to_buy                    0.163424
# pct_tl_nvr_dlq                  bc_open_to_buy                    0.162892
# bc_open_to_buy                  pct_tl_nvr_dlq                    0.162892
# mo_sin_old_rev_tl_op            int_rate                          0.160134
# int_rate                        mo_sin_old_rev_tl_op              0.160134
# inq_last_6mths                  open_acc                          0.159144
# open_acc                        inq_last_6mths                    0.159144
# num_bc_tl                       mths_since_last_record            0.157830
# mths_since_last_record          num_bc_tl                         0.157830
# mths_since_recent_inq           open_il_12m                       0.157380
# open_il_12m                     mths_since_recent_inq             0.157380
# revol_bal                       bc_util                           0.154151
# bc_util                         revol_bal                         0.154151
# all_util                        mths_since_rcnt_il                0.154030
# mths_since_rcnt_il              all_util                          0.154030
# inq_last_12m                    il_util                           0.153825
# il_util                         inq_last_12m                      0.153825
# open_acc                        mths_since_rcnt_il                0.153199
# mths_since_rcnt_il              open_acc                          0.153199
# max_bal_bc                      pub_rec                           0.151474
# pub_rec                         max_bal_bc                        0.151474
# annual_inc_joint                bc_open_to_buy                    0.150660
# bc_open_to_buy                  annual_inc_joint                  0.150660
# mo_sin_rcnt_tl                  int_rate                          0.150179
# int_rate                        mo_sin_rcnt_tl                    0.150179
# open_il_12m                     inq_last_6mths                    0.149877
# inq_last_6mths                  open_il_12m                       0.149877
# mths_since_last_record          num_accts_ever_120_pd             0.149832
# num_accts_ever_120_pd           mths_since_last_record            0.149832
# annual_inc_joint                num_bc_tl                         0.147784
# num_bc_tl                       annual_inc_joint                  0.147784
# num_accts_ever_120_pd           tot_coll_amt                      0.145754
# tot_coll_amt                    num_accts_ever_120_pd             0.145754
# inq_fi                          total_il_high_credit_limit        0.145450
# total_il_high_credit_limit      inq_fi                            0.145450
# inq_fi                          il_util                           0.145342
# il_util                         inq_fi                            0.145342
# open_acc                        open_il_12m                       0.142777
# open_il_12m                     open_acc                          0.142777
# num_bc_tl                       tot_cur_bal                       0.142479
# tot_cur_bal                     num_bc_tl                         0.142479
# num_tl_90g_dpd_24m              mths_since_recent_revol_delinq    0.141736
# mths_since_recent_revol_delinq  num_tl_90g_dpd_24m                0.141736
# inq_last_12m                    num_il_tl                         0.141528
# num_il_tl                       inq_last_12m                      0.141528
# loan_amnt                       int_rate                          0.140572
# int_rate                        loan_amnt                         0.140572
# total_cu_tl                     mths_since_rcnt_il                0.138082
# mths_since_rcnt_il              total_cu_tl                       0.138082
# mo_sin_old_il_acct              loan_amnt                         0.137114
# loan_amnt                       mo_sin_old_il_acct                0.137114
# total_il_high_credit_limit      max_bal_bc                        0.137002
# max_bal_bc                      total_il_high_credit_limit        0.137002
# inq_last_6mths                  num_bc_tl                         0.136091
# num_bc_tl                       inq_last_6mths                    0.136091
# inq_fi                          mo_sin_rcnt_tl                    0.135433
# mo_sin_rcnt_tl                  inq_fi                            0.135433
# mo_sin_old_rev_tl_op            open_acc                          0.135201
# open_acc                        mo_sin_old_rev_tl_op              0.135201
# dti_joint                       max_bal_bc                        0.134070
# max_bal_bc                      dti_joint                         0.134070
# num_tl_op_past_12m              total_il_high_credit_limit        0.130805
# total_il_high_credit_limit      num_tl_op_past_12m                0.130805
# inq_last_12m                    total_il_high_credit_limit        0.130535
# total_il_high_credit_limit      inq_last_12m                      0.130535
# max_bal_bc                      num_tl_op_past_12m                0.130009
# num_tl_op_past_12m              max_bal_bc                        0.130009
# mo_sin_rcnt_tl                  num_bc_tl                         0.129605
# num_bc_tl                       mo_sin_rcnt_tl                    0.129605
# mo_sin_old_rev_tl_op            annual_inc_joint                  0.129117
# annual_inc_joint                mo_sin_old_rev_tl_op              0.129117
# open_acc                        mo_sin_old_il_acct                0.128910
# mo_sin_old_il_acct              open_acc                          0.128910
# mths_since_rcnt_il              int_rate                          0.128435
# int_rate                        mths_since_rcnt_il                0.128435
# revol_bal                       pct_tl_nvr_dlq                    0.128087
# pct_tl_nvr_dlq                  revol_bal                         0.128087
# dti_joint                       pub_rec                           0.127954
# pub_rec                         dti_joint                         0.127954
# pct_tl_nvr_dlq                  open_acc                          0.127752
# open_acc                        pct_tl_nvr_dlq                    0.127752
# delinq_amnt                     acc_now_delinq                    0.127571
# acc_now_delinq                  delinq_amnt                       0.127571
# num_il_tl                       mo_sin_rcnt_tl                    0.127561
# mo_sin_rcnt_tl                  num_il_tl                         0.127561
# mths_since_last_major_derog     collections_12_mths_ex_med        0.127003
# collections_12_mths_ex_med      mths_since_last_major_derog       0.127003
# mths_since_recent_revol_delinq  pub_rec                           0.126948
# pub_rec                         mths_since_recent_revol_delinq    0.126948
# chargeoff_within_12_mths        num_accts_ever_120_pd             0.126719
# num_accts_ever_120_pd           chargeoff_within_12_mths          0.126719
# max_bal_bc                      il_util                           0.126547
# il_util                         max_bal_bc                        0.126547
# open_acc                        il_util                           0.126190
# il_util                         open_acc                          0.126190
# bc_open_to_buy                  mort_acc                          0.125294
# mort_acc                        bc_open_to_buy                    0.125294
# mo_sin_rcnt_tl                  bc_util                           0.124193
# bc_util                         mo_sin_rcnt_tl                    0.124193
# acc_now_delinq                  mths_since_recent_revol_delinq    0.123189
# mths_since_recent_revol_delinq  acc_now_delinq                    0.123189
# total_il_high_credit_limit      total_cu_tl                       0.122955
# total_cu_tl                     total_il_high_credit_limit        0.122955
# all_util                        max_bal_bc                        0.121486
# max_bal_bc                      all_util                          0.121486
# mths_since_last_record          mo_sin_old_rev_tl_op              0.121044
# mo_sin_old_rev_tl_op            mths_since_last_record            0.121044
# max_bal_bc                      num_accts_ever_120_pd             0.120136
# num_accts_ever_120_pd           max_bal_bc                        0.120136
# collections_12_mths_ex_med      num_tl_90g_dpd_24m                0.120101
# num_tl_90g_dpd_24m              collections_12_mths_ex_med        0.120101
# int_rate                        recoveries                        0.119825
# recoveries                      int_rate                          0.119825
# max_bal_bc                      mo_sin_old_il_acct                0.119804
# mo_sin_old_il_acct              max_bal_bc                        0.119804
# num_tl_op_past_12m              mths_since_recent_revol_delinq    0.118200
# mths_since_recent_revol_delinq  num_tl_op_past_12m                0.118200
# mort_acc                        open_acc                          0.117382
# open_acc                        mort_acc                          0.117382
# num_bc_tl                       int_rate                          0.115968
# int_rate                        num_bc_tl                         0.115968
# revol_bal                       il_util                           0.115711
# il_util                         revol_bal                         0.115711
# num_accts_ever_120_pd           num_il_tl                         0.115446
# num_il_tl                       num_accts_ever_120_pd             0.115446
# num_bc_tl                       mo_sin_old_il_acct                0.114920
# mo_sin_old_il_acct              num_bc_tl                         0.114920
# total_il_high_credit_limit      dti                               0.113685
# dti                             total_il_high_credit_limit        0.113685
# total_il_high_credit_limit      mo_sin_rcnt_tl                    0.113229
# mo_sin_rcnt_tl                  total_il_high_credit_limit        0.113229
# annual_inc_joint                open_il_12m                       0.113061
# open_il_12m                     annual_inc_joint                  0.113061
# bc_util                         open_acc                          0.112724
# open_acc                        bc_util                           0.112724
# pub_rec                         mths_since_last_major_derog       0.109844
# mths_since_last_major_derog     pub_rec                           0.109844
#                                 acc_now_delinq                    0.109642
# acc_now_delinq                  mths_since_last_major_derog       0.109642
# total_il_high_credit_limit      revol_bal                         0.109299
# revol_bal                       total_il_high_credit_limit        0.109299
# num_tl_op_past_12m              dti_joint                         0.109118
# dti_joint                       num_tl_op_past_12m                0.109118
# tot_cur_bal                     inq_last_12m                      0.108578
# inq_last_12m                    tot_cur_bal                       0.108578
# mths_since_last_record          mort_acc                          0.108039
# mort_acc                        mths_since_last_record            0.108039
# mths_since_last_major_derog     pct_tl_nvr_dlq                    0.107929
# pct_tl_nvr_dlq                  mths_since_last_major_derog       0.107929
# il_util                         loan_amnt                         0.107324
# loan_amnt                       il_util                           0.107324
# annual_inc_joint                mths_since_recent_inq             0.106858
# mths_since_recent_inq           annual_inc_joint                  0.106858
# num_tl_op_past_12m              total_cu_tl                       0.106768
# total_cu_tl                     num_tl_op_past_12m                0.106768
# pub_rec                         revol_bal                         0.106714
# revol_bal                       pub_rec                           0.106714
# pub_rec                         inq_last_12m                      0.106224
# inq_last_12m                    pub_rec                           0.106224
# open_acc                        mths_since_recent_inq             0.105660
# mths_since_recent_inq           open_acc                          0.105660
# num_tl_op_past_12m              pub_rec                           0.105336
# pub_rec                         num_tl_op_past_12m                0.105336
# mo_sin_rcnt_tl                  max_bal_bc                        0.105131
# max_bal_bc                      mo_sin_rcnt_tl                    0.105131
# pct_tl_nvr_dlq                  loan_amnt                         0.105056
# loan_amnt                       pct_tl_nvr_dlq                    0.105056
# il_util                         annual_inc_joint                  0.105042
# annual_inc_joint                il_util                           0.105042
# int_rate                        max_bal_bc                        0.104685
# max_bal_bc                      int_rate                          0.104685
# num_bc_tl                       inq_last_12m                      0.104675
# inq_last_12m                    num_bc_tl                         0.104675
# revol_bal                       all_util                          0.104449
# all_util                        revol_bal                         0.104449
# open_acc                        dti                               0.104364
# dti                             open_acc                          0.104364
# total_cu_tl                     dti_joint                         0.103740
# dti_joint                       total_cu_tl                       0.103740
# tot_cur_bal                     mths_since_rcnt_il                0.103207
# mths_since_rcnt_il              tot_cur_bal                       0.103207
# all_util                        mo_sin_old_rev_tl_op              0.103039
# mo_sin_old_rev_tl_op            all_util                          0.103039
#                                 il_util                           0.102888
# il_util                         mo_sin_old_rev_tl_op              0.102888
# mo_sin_old_il_acct              num_accts_ever_120_pd             0.101918
# num_accts_ever_120_pd           mo_sin_old_il_acct                0.101918
# open_acc                        max_bal_bc                        0.101191
# max_bal_bc                      open_acc                          0.101191
# pct_tl_nvr_dlq                  mo_sin_old_il_acct                0.099719
# mo_sin_old_il_acct              pct_tl_nvr_dlq                    0.099719
# annual_inc_joint                int_rate                          0.099026
# int_rate                        annual_inc_joint                  0.099026
# all_util                        tot_cur_bal                       0.098923
# tot_cur_bal                     all_util                          0.098923
# mort_acc                        total_il_high_credit_limit        0.097536
# total_il_high_credit_limit      mort_acc                          0.097536
# pub_rec                         inq_last_6mths                    0.097382
# inq_last_6mths                  pub_rec                           0.097382
# num_tl_120dpd_2m                mths_since_last_major_derog       0.097230
# mths_since_last_major_derog     num_tl_120dpd_2m                  0.097230
# mo_sin_old_il_acct              total_cu_tl                       0.096620
# total_cu_tl                     mo_sin_old_il_acct                0.096620
# dti_joint                       bc_open_to_buy                    0.096073
# bc_open_to_buy                  dti_joint                         0.096073
# num_accts_ever_120_pd           mths_since_last_major_derog       0.095995
# mths_since_last_major_derog     num_accts_ever_120_pd             0.095995
# inq_fi                          all_util                          0.095073
# all_util                        inq_fi                            0.095073
# chargeoff_within_12_mths        pct_tl_nvr_dlq                    0.094867
# pct_tl_nvr_dlq                  chargeoff_within_12_mths          0.094867
# total_cu_tl                     tot_cur_bal                       0.094735
# tot_cur_bal                     total_cu_tl                       0.094735
# num_il_tl                       annual_inc_joint                  0.094272
# annual_inc_joint                num_il_tl                         0.094272
# revol_bal                       mo_sin_old_il_acct                0.094032
# mo_sin_old_il_acct              revol_bal                         0.094032
# open_acc                        inq_fi                            0.093534
# inq_fi                          open_acc                          0.093534
# mo_sin_old_il_acct              dti_joint                         0.093306
# dti_joint                       mo_sin_old_il_acct                0.093306
# total_cu_tl                     open_acc                          0.093138
# open_acc                        total_cu_tl                       0.093138
# pct_tl_nvr_dlq                  mo_sin_old_rev_tl_op              0.092974
# mo_sin_old_rev_tl_op            pct_tl_nvr_dlq                    0.092974
# dti_joint                       id                                0.092846
# id                              dti_joint                         0.092846
# total_cu_tl                     inq_fi                            0.092703
# inq_fi                          total_cu_tl                       0.092703
# num_tl_op_past_12m              mths_since_last_major_derog       0.091598
# mths_since_last_major_derog     num_tl_op_past_12m                0.091598
# inq_last_12m                    max_bal_bc                        0.090661
# max_bal_bc                      inq_last_12m                      0.090661
#                                 inq_fi                            0.090170
# inq_fi                          max_bal_bc                        0.090170
# mths_since_last_record          num_tl_90g_dpd_24m                0.089774
# num_tl_90g_dpd_24m              mths_since_last_record            0.089774
# bc_util                         inq_last_12m                      0.088955
# inq_last_12m                    bc_util                           0.088955
#                                 mort_acc                          0.088937
# mort_acc                        inq_last_12m                      0.088937
# loan_amnt                       pub_rec                           0.088899
# pub_rec                         loan_amnt                         0.088899
# il_util                         num_accts_ever_120_pd             0.088093
# num_accts_ever_120_pd           il_util                           0.088093
# tot_cur_bal                     int_rate                          0.087011
# int_rate                        tot_cur_bal                       0.087011
# tot_cur_bal                     inq_fi                            0.086877
# inq_fi                          tot_cur_bal                       0.086877
# bc_open_to_buy                  pub_rec                           0.085906
# pub_rec                         bc_open_to_buy                    0.085906
# revol_bal                       num_accts_ever_120_pd             0.085905
# num_accts_ever_120_pd           revol_bal                         0.085905
# dti_joint                       pct_tl_nvr_dlq                    0.085603
# pct_tl_nvr_dlq                  dti_joint                         0.085603
# mths_since_recent_revol_delinq  pct_tl_nvr_dlq                    0.085372
# pct_tl_nvr_dlq                  mths_since_recent_revol_delinq    0.085372
# mo_sin_rcnt_tl                  total_cu_tl                       0.085295
# total_cu_tl                     mo_sin_rcnt_tl                    0.085295
# mo_sin_rcnt_tl                  mths_since_last_major_derog       0.085145
# mths_since_last_major_derog     mo_sin_rcnt_tl                    0.085145
# mo_sin_old_il_acct              annual_inc_joint                  0.084972
# annual_inc_joint                mo_sin_old_il_acct                0.084972
# num_accts_ever_120_pd           mort_acc                          0.084609
# mort_acc                        num_accts_ever_120_pd             0.084609
# open_il_12m                     max_bal_bc                        0.084379
# max_bal_bc                      open_il_12m                       0.084379
# num_accts_ever_120_pd           num_tl_op_past_12m                0.083971
# num_tl_op_past_12m              num_accts_ever_120_pd             0.083971
# mths_since_last_record          dti                               0.083465
# dti                             mths_since_last_record            0.083465
# bc_open_to_buy                  num_accts_ever_120_pd             0.083308
# num_accts_ever_120_pd           bc_open_to_buy                    0.083308
#                                 inq_last_12m                      0.083016
# inq_last_12m                    num_accts_ever_120_pd             0.083016
# mths_since_recent_inq           mths_since_rcnt_il                0.082158
# mths_since_rcnt_il              mths_since_recent_inq             0.082158
# mths_since_recent_inq           num_bc_tl                         0.081775
# num_bc_tl                       mths_since_recent_inq             0.081775
# num_il_tl                       dti                               0.081730
# dti                             num_il_tl                         0.081730
# mo_sin_old_il_acct              int_rate                          0.080956
# int_rate                        mo_sin_old_il_acct                0.080956
# mo_sin_old_rev_tl_op            mths_since_rcnt_il                0.080442
# mths_since_rcnt_il              mo_sin_old_rev_tl_op              0.080442
# mths_since_recent_inq           il_util                           0.080198
# il_util                         mths_since_recent_inq             0.080198
# num_tl_120dpd_2m                num_tl_90g_dpd_24m                0.080164
# num_tl_90g_dpd_24m              num_tl_120dpd_2m                  0.080164
# dti_joint                       il_util                           0.079700
# il_util                         dti_joint                         0.079700
# inq_last_6mths                  mths_since_rcnt_il                0.079560
# mths_since_rcnt_il              inq_last_6mths                    0.079560
# num_accts_ever_120_pd           mo_sin_old_rev_tl_op              0.078439
# mo_sin_old_rev_tl_op            num_accts_ever_120_pd             0.078439
# annual_inc_joint                inq_fi                            0.078332
# inq_fi                          annual_inc_joint                  0.078332
# num_accts_ever_120_pd           num_bc_tl                         0.078175
# num_bc_tl                       num_accts_ever_120_pd             0.078175
# dti                             int_rate                          0.077932
# int_rate                        dti                               0.077932
# mths_since_rcnt_il              mo_sin_old_il_acct                0.077925
# mo_sin_old_il_acct              mths_since_rcnt_il                0.077925
# recoveries                      loan_amnt                         0.077870
# loan_amnt                       recoveries                        0.077870
# mths_since_recent_revol_delinq  mo_sin_rcnt_tl                    0.077252
# mo_sin_rcnt_tl                  mths_since_recent_revol_delinq    0.077252
# pub_rec                         tot_cur_bal                       0.077184
# tot_cur_bal                     pub_rec                           0.077184
# inq_last_6mths                  bc_util                           0.076651
# bc_util                         inq_last_6mths                    0.076651
# int_rate                        mort_acc                          0.076131
# mort_acc                        int_rate                          0.076131
# il_util                         inq_last_6mths                    0.075468
# inq_last_6mths                  il_util                           0.075468
# inq_fi                          mort_acc                          0.075278
# mort_acc                        inq_fi                            0.075278
# num_il_tl                       loan_amnt                         0.074857
# loan_amnt                       num_il_tl                         0.074857
# bc_open_to_buy                  num_tl_op_past_12m                0.074575
# num_tl_op_past_12m              bc_open_to_buy                    0.074575
# num_accts_ever_120_pd           dti_joint                         0.074170
# dti_joint                       num_accts_ever_120_pd             0.074170
# il_util                         mort_acc                          0.073663
# mort_acc                        il_util                           0.073663
# tot_cur_bal                     open_il_12m                       0.073339
# open_il_12m                     tot_cur_bal                       0.073339
# ...
# total_cu_tl                     num_tl_120dpd_2m                  0.002029
# num_tl_120dpd_2m                total_cu_tl                       0.002029
# pub_rec                         chargeoff_within_12_mths          0.001974
# chargeoff_within_12_mths        pub_rec                           0.001974
# delinq_amnt                     id                                0.001961
# id                              delinq_amnt                       0.001961
# pub_rec                         recoveries                        0.001952
# recoveries                      pub_rec                           0.001952
# num_bc_tl                       delinq_amnt                       0.001911
# delinq_amnt                     num_bc_tl                         0.001911
# num_tl_120dpd_2m                inq_last_6mths                    0.001884
# inq_last_6mths                  num_tl_120dpd_2m                  0.001884
# open_acc                        delinq_amnt                       0.001843
# delinq_amnt                     open_acc                          0.001843
# tot_coll_amt                    acc_now_delinq                    0.001841
# acc_now_delinq                  tot_coll_amt                      0.001841
# bc_open_to_buy                  inq_last_12m                      0.001841
# inq_last_12m                    bc_open_to_buy                    0.001841
# bc_open_to_buy                  num_tl_120dpd_2m                  0.001794
# num_tl_120dpd_2m                bc_open_to_buy                    0.001794
# bc_open_to_buy                  mths_since_rcnt_il                0.001788
# mths_since_rcnt_il              bc_open_to_buy                    0.001788
# num_tl_120dpd_2m                il_util                           0.001763
# il_util                         num_tl_120dpd_2m                  0.001763
# dti                             annual_inc_joint                  0.001654
# annual_inc_joint                dti                               0.001654
# int_rate                        mths_since_last_major_derog       0.001652
# mths_since_last_major_derog     int_rate                          0.001652
# num_accts_ever_120_pd           mths_since_rcnt_il                0.001630
# mths_since_rcnt_il              num_accts_ever_120_pd             0.001630
# num_tl_120dpd_2m                mths_since_recent_inq             0.001598
# mths_since_recent_inq           num_tl_120dpd_2m                  0.001598
# num_tl_90g_dpd_24m              recoveries                        0.001556
# recoveries                      num_tl_90g_dpd_24m                0.001556
#                                 num_accts_ever_120_pd             0.001521
# num_accts_ever_120_pd           recoveries                        0.001521
# inq_last_12m                    dti                               0.001416
# dti                             inq_last_12m                      0.001416
# id                              inq_last_12m                      0.001412
# inq_last_12m                    id                                0.001412
# mths_since_recent_inq           dti                               0.001369
# dti                             mths_since_recent_inq             0.001369
# dti_joint                       num_tl_90g_dpd_24m                0.001323
# num_tl_90g_dpd_24m              dti_joint                         0.001323
# open_il_12m                     delinq_amnt                       0.001277
# delinq_amnt                     open_il_12m                       0.001277
# mths_since_recent_revol_delinq  id                                0.001272
# id                              mths_since_recent_revol_delinq    0.001272
# chargeoff_within_12_mths        open_il_12m                       0.001270
# open_il_12m                     chargeoff_within_12_mths          0.001270
# total_rec_late_fee              dti                               0.001150
# dti                             total_rec_late_fee                0.001150
# revol_bal                       delinq_amnt                       0.001126
# delinq_amnt                     revol_bal                         0.001126
#                                 recoveries                        0.001075
# recoveries                      delinq_amnt                       0.001075
# id                              chargeoff_within_12_mths          0.001075
# chargeoff_within_12_mths        id                                0.001075
# num_tl_120dpd_2m                pub_rec                           0.001069
# pub_rec                         num_tl_120dpd_2m                  0.001069
# bc_open_to_buy                  delinq_amnt                       0.001050
# delinq_amnt                     bc_open_to_buy                    0.001050
# recoveries                      tot_cur_bal                       0.001026
# tot_cur_bal                     recoveries                        0.001026
# mths_since_recent_revol_delinq  delinq_amnt                       0.001022
# delinq_amnt                     mths_since_recent_revol_delinq    0.001022
# total_cu_tl                     id                                0.000914
# id                              total_cu_tl                       0.000914
# loan_amnt                       num_tl_120dpd_2m                  0.000905
# num_tl_120dpd_2m                loan_amnt                         0.000905
#                                 collections_12_mths_ex_med        0.000860
# collections_12_mths_ex_med      num_tl_120dpd_2m                  0.000860
# total_cu_tl                     mths_since_recent_revol_delinq    0.000860
# mths_since_recent_revol_delinq  total_cu_tl                       0.000860
# delinq_amnt                     total_rec_late_fee                0.000787
# total_rec_late_fee              delinq_amnt                       0.000787
# mths_since_recent_revol_delinq  num_il_tl                         0.000722
# num_il_tl                       mths_since_recent_revol_delinq    0.000722
# id                              num_il_tl                         0.000665
# num_il_tl                       id                                0.000665
# inq_last_6mths                  id                                0.000660
# id                              inq_last_6mths                    0.000660
# acc_now_delinq                  loan_amnt                         0.000645
# loan_amnt                       acc_now_delinq                    0.000645
# mths_since_recent_inq           acc_now_delinq                    0.000626
# acc_now_delinq                  mths_since_recent_inq             0.000626
# num_tl_90g_dpd_24m              id                                0.000612
# id                              num_tl_90g_dpd_24m                0.000612
# dti                             acc_now_delinq                    0.000583
# acc_now_delinq                  dti                               0.000583
# inq_last_6mths                  acc_now_delinq                    0.000563
# acc_now_delinq                  inq_last_6mths                    0.000563
# max_bal_bc                      id                                0.000543
# id                              max_bal_bc                        0.000543
# max_bal_bc                      num_il_tl                         0.000410
# num_il_tl                       max_bal_bc                        0.000410
# all_util                        id                                0.000399
# id                              all_util                          0.000399
# total_cu_tl                     chargeoff_within_12_mths          0.000372
# chargeoff_within_12_mths        total_cu_tl                       0.000372
# tot_coll_amt                    recoveries                        0.000342
# recoveries                      tot_coll_amt                      0.000342
# tot_coll_amt                    total_rec_late_fee                0.000320
# total_rec_late_fee              tot_coll_amt                      0.000320
# delinq_amnt                     total_il_high_credit_limit        0.000250
# total_il_high_credit_limit      delinq_amnt                       0.000250
# total_rec_late_fee              mort_acc                          0.000210
# mort_acc                        total_rec_late_fee                0.000210
# pub_rec                         total_rec_late_fee                0.000146
# total_rec_late_fee              pub_rec                           0.000146
# delinq_amnt                     num_il_tl                         0.000105
# num_il_tl                       delinq_amnt                       0.000105
# num_tl_120dpd_2m                total_rec_late_fee                0.000098
# total_rec_late_fee              num_tl_120dpd_2m                  0.000098
# acc_now_delinq                  mo_sin_rcnt_tl                    0.000093
# mo_sin_rcnt_tl                  acc_now_delinq                    0.000093
# mo_sin_old_il_acct              id                                0.000088
# id                              mo_sin_old_il_acct                0.000088
# num_tl_120dpd_2m                all_util                          0.000036
# all_util                        num_tl_120dpd_2m                  0.000036
# id                              policy_code                            NaN
# loan_amnt                       policy_code                            NaN
# int_rate                        policy_code                            NaN
# dti                             policy_code                            NaN
# inq_last_6mths                  policy_code                            NaN
# mths_since_last_record          policy_code                            NaN
# open_acc                        policy_code                            NaN
# pub_rec                         policy_code                            NaN
# revol_bal                       policy_code                            NaN
# total_rec_late_fee              policy_code                            NaN
# recoveries                      policy_code                            NaN
# collections_12_mths_ex_med      policy_code                            NaN
# mths_since_last_major_derog     policy_code                            NaN
# policy_code                     id                                     NaN
#                                 loan_amnt                              NaN
#                                 int_rate                               NaN
#                                 dti                                    NaN
#                                 inq_last_6mths                         NaN
#                                 mths_since_last_record                 NaN
#                                 open_acc                               NaN
#                                 pub_rec                                NaN
#                                 revol_bal                              NaN
#                                 total_rec_late_fee                     NaN
#                                 recoveries                             NaN
#                                 collections_12_mths_ex_med             NaN
#                                 mths_since_last_major_derog            NaN
#                                 policy_code                            NaN
#                                 annual_inc_joint                       NaN
#                                 dti_joint                              NaN
#                                 acc_now_delinq                         NaN
#                                 tot_coll_amt                           NaN
#                                 tot_cur_bal                            NaN
#                                 open_il_12m                            NaN
#                                 mths_since_rcnt_il                     NaN
#                                 il_util                                NaN
#                                 max_bal_bc                             NaN
#                                 all_util                               NaN
#                                 inq_fi                                 NaN
#                                 total_cu_tl                            NaN
#                                 inq_last_12m                           NaN
#                                 bc_open_to_buy                         NaN
#                                 bc_util                                NaN
#                                 chargeoff_within_12_mths               NaN
#                                 delinq_amnt                            NaN
#                                 mo_sin_old_il_acct                     NaN
#                                 mo_sin_old_rev_tl_op                   NaN
#                                 mo_sin_rcnt_tl                         NaN
#                                 mort_acc                               NaN
#                                 mths_since_recent_inq                  NaN
#                                 mths_since_recent_revol_delinq         NaN
#                                 num_accts_ever_120_pd                  NaN
#                                 num_bc_tl                              NaN
#                                 num_il_tl                              NaN
#                                 num_tl_120dpd_2m                       NaN
#                                 num_tl_90g_dpd_24m                     NaN
#                                 num_tl_op_past_12m                     NaN
#                                 pct_tl_nvr_dlq                         NaN
#                                 total_il_high_credit_limit             NaN
# annual_inc_joint                policy_code                            NaN
#                                 num_tl_120dpd_2m                       NaN
# dti_joint                       policy_code                            NaN
#                                 num_tl_120dpd_2m                       NaN
# acc_now_delinq                  policy_code                            NaN
# tot_coll_amt                    policy_code                            NaN
# tot_cur_bal                     policy_code                            NaN
# open_il_12m                     policy_code                            NaN
# mths_since_rcnt_il              policy_code                            NaN
# il_util                         policy_code                            NaN
# max_bal_bc                      policy_code                            NaN
# all_util                        policy_code                            NaN
# inq_fi                          policy_code                            NaN
# total_cu_tl                     policy_code                            NaN
# inq_last_12m                    policy_code                            NaN
# bc_open_to_buy                  policy_code                            NaN
# bc_util                         policy_code                            NaN
# chargeoff_within_12_mths        policy_code                            NaN
# delinq_amnt                     policy_code                            NaN
# mo_sin_old_il_acct              policy_code                            NaN
# mo_sin_old_rev_tl_op            policy_code                            NaN
# mo_sin_rcnt_tl                  policy_code                            NaN
# mort_acc                        policy_code                            NaN
# mths_since_recent_inq           policy_code                            NaN
# mths_since_recent_revol_delinq  policy_code                            NaN
# num_accts_ever_120_pd           policy_code                            NaN
# num_bc_tl                       policy_code                            NaN
# num_il_tl                       policy_code                            NaN
# num_tl_120dpd_2m                policy_code                            NaN
#                                 annual_inc_joint                       NaN
#                                 dti_joint                              NaN
# num_tl_90g_dpd_24m              policy_code                            NaN
# num_tl_op_past_12m              policy_code                            NaN
# pct_tl_nvr_dlq                  policy_code                            NaN
# total_il_high_credit_limit      policy_code                            NaN
# dtype: float64

# %%
y2015 = y2015.drop(columns = ['num_il_tl', 'bc_util', 'max_bal_bc', 'num_tl_op_past_12m', 'all_util', 'inq_last_12m',\
                              'num_accts_ever_120_pd', 'mths_since_recent_inq', 'mths_since_last_major_derog', 'open_acc', \
                              'annual_inc_joint'])

# %%
## Run Random Forest with cleaned data
rfc2 = ensemble.RandomForestClassifier()
X2 = y2015.drop('loan_status', 1)
Y2 = y2015['loan_status']
X2 = pd.get_dummies(X2)
X2 = X2.dropna(axis=1)

cross_val_score(rfc2, X2, Y2, cv=10)
# Out:
# c:\users\nstow\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# c:\users\nstow\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# c:\users\nstow\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# c:\users\nstow\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# c:\users\nstow\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# c:\users\nstow\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# c:\users\nstow\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# c:\users\nstow\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# c:\users\nstow\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# c:\users\nstow\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# array([0.93227423, 0.93543255, 0.92203937, 0.93353281, 0.90301591,
#        0.92652577, 0.90607709, 0.94447743, 0.94219488, 0.92993873])

# %%
## recreate sorted correlation matrix
c4 = y2015.corr().abs()

s4 = c4.unstack()
so4 = s4.sort_values(kind="quicksort", ascending=False)

pd.set_option('display.max_rows', 5000)
print(so4)
# Out:
# total_il_high_credit_limit      total_il_high_credit_limit        1.000000
# open_il_12m                     open_il_12m                       1.000000
# num_tl_120dpd_2m                num_tl_120dpd_2m                  1.000000
# num_bc_tl                       num_bc_tl                         1.000000
# mths_since_recent_revol_delinq  mths_since_recent_revol_delinq    1.000000
# mort_acc                        mort_acc                          1.000000
# mo_sin_rcnt_tl                  mo_sin_rcnt_tl                    1.000000
# mo_sin_old_rev_tl_op            mo_sin_old_rev_tl_op              1.000000
# mo_sin_old_il_acct              mo_sin_old_il_acct                1.000000
# delinq_amnt                     delinq_amnt                       1.000000
# chargeoff_within_12_mths        chargeoff_within_12_mths          1.000000
# bc_open_to_buy                  bc_open_to_buy                    1.000000
# total_cu_tl                     total_cu_tl                       1.000000
# inq_fi                          inq_fi                            1.000000
# il_util                         il_util                           1.000000
# tot_cur_bal                     tot_cur_bal                       1.000000
# pct_tl_nvr_dlq                  pct_tl_nvr_dlq                    1.000000
# tot_coll_amt                    tot_coll_amt                      1.000000
# acc_now_delinq                  acc_now_delinq                    1.000000
# dti_joint                       dti_joint                         1.000000
# collections_12_mths_ex_med      collections_12_mths_ex_med        1.000000
# recoveries                      recoveries                        1.000000
# total_rec_late_fee              total_rec_late_fee                1.000000
# revol_bal                       revol_bal                         1.000000
# pub_rec                         pub_rec                           1.000000
# mths_since_last_record          mths_since_last_record            1.000000
# inq_last_6mths                  inq_last_6mths                    1.000000
# dti                             dti                               1.000000
# int_rate                        int_rate                          1.000000
# loan_amnt                       loan_amnt                         1.000000
# num_tl_90g_dpd_24m              num_tl_90g_dpd_24m                1.000000
# mths_since_rcnt_il              mths_since_rcnt_il                1.000000
# id                              id                                1.000000
# mort_acc                        tot_cur_bal                       0.524410
# tot_cur_bal                     mort_acc                          0.524410
# revol_bal                       tot_cur_bal                       0.455735
# tot_cur_bal                     revol_bal                         0.455735
# mths_since_rcnt_il              open_il_12m                       0.443401
# open_il_12m                     mths_since_rcnt_il                0.443401
# num_bc_tl                       bc_open_to_buy                    0.412514
# bc_open_to_buy                  num_bc_tl                         0.412514
# tot_cur_bal                     total_il_high_credit_limit        0.401982
# total_il_high_credit_limit      tot_cur_bal                       0.401982
# mths_since_rcnt_il              mo_sin_rcnt_tl                    0.368634
# mo_sin_rcnt_tl                  mths_since_rcnt_il                0.368634
# dti_joint                       total_il_high_credit_limit        0.358091
# total_il_high_credit_limit      dti_joint                         0.358091
# acc_now_delinq                  num_tl_120dpd_2m                  0.354200
# num_tl_120dpd_2m                acc_now_delinq                    0.354200
# mths_since_rcnt_il              il_util                           0.339755
# il_util                         mths_since_rcnt_il                0.339755
# open_il_12m                     il_util                           0.335348
# il_util                         open_il_12m                       0.335348
# revol_bal                       loan_amnt                         0.334656
# loan_amnt                       revol_bal                         0.334656
# tot_cur_bal                     loan_amnt                         0.325352
# loan_amnt                       tot_cur_bal                       0.325352
# num_bc_tl                       mo_sin_old_rev_tl_op              0.318972
# mo_sin_old_rev_tl_op            num_bc_tl                         0.318972
# bc_open_to_buy                  int_rate                          0.293227
# int_rate                        bc_open_to_buy                    0.293227
# mort_acc                        mo_sin_old_rev_tl_op              0.291468
# mo_sin_old_rev_tl_op            mort_acc                          0.291468
# mo_sin_rcnt_tl                  open_il_12m                       0.290154
# open_il_12m                     mo_sin_rcnt_tl                    0.290154
# int_rate                        dti_joint                         0.287345
# dti_joint                       int_rate                          0.287345
# mths_since_rcnt_il              total_il_high_credit_limit        0.279007
# total_il_high_credit_limit      mths_since_rcnt_il                0.279007
# pct_tl_nvr_dlq                  num_tl_90g_dpd_24m                0.275400
# num_tl_90g_dpd_24m              pct_tl_nvr_dlq                    0.275400
# inq_fi                          open_il_12m                       0.269379
# open_il_12m                     inq_fi                            0.269379
#                                 total_il_high_credit_limit        0.267005
# total_il_high_credit_limit      open_il_12m                       0.267005
# pub_rec                         mths_since_last_record            0.265775
# mths_since_last_record          pub_rec                           0.265775
# int_rate                        open_il_12m                       0.245028
# open_il_12m                     int_rate                          0.245028
# delinq_amnt                     num_tl_120dpd_2m                  0.235801
# num_tl_120dpd_2m                delinq_amnt                       0.235801
# mo_sin_rcnt_tl                  inq_last_6mths                    0.231653
# inq_last_6mths                  mo_sin_rcnt_tl                    0.231653
# loan_amnt                       mort_acc                          0.231574
# mort_acc                        loan_amnt                         0.231574
# inq_last_6mths                  int_rate                          0.231139
# int_rate                        inq_last_6mths                    0.231139
# mo_sin_old_rev_tl_op            revol_bal                         0.229251
# revol_bal                       mo_sin_old_rev_tl_op              0.229251
#                                 num_bc_tl                         0.226247
# num_bc_tl                       revol_bal                         0.226247
# num_tl_90g_dpd_24m              chargeoff_within_12_mths          0.219341
# chargeoff_within_12_mths        num_tl_90g_dpd_24m                0.219341
# mths_since_last_record          pct_tl_nvr_dlq                    0.217565
# pct_tl_nvr_dlq                  mths_since_last_record            0.217565
# mo_sin_old_rev_tl_op            mo_sin_old_il_acct                0.209846
# mo_sin_old_il_acct              mo_sin_old_rev_tl_op              0.209846
# revol_bal                       dti_joint                         0.209837
# dti_joint                       revol_bal                         0.209837
# inq_last_6mths                  inq_fi                            0.206920
# inq_fi                          inq_last_6mths                    0.206920
# mo_sin_rcnt_tl                  il_util                           0.206114
# il_util                         mo_sin_rcnt_tl                    0.206114
# num_bc_tl                       loan_amnt                         0.203509
# loan_amnt                       num_bc_tl                         0.203509
# total_il_high_credit_limit      loan_amnt                         0.203093
# loan_amnt                       total_il_high_credit_limit        0.203093
#                                 bc_open_to_buy                    0.202669
# bc_open_to_buy                  loan_amnt                         0.202669
# mort_acc                        revol_bal                         0.200702
# revol_bal                       mort_acc                          0.200702
# mo_sin_old_il_acct              total_il_high_credit_limit        0.198404
# total_il_high_credit_limit      mo_sin_old_il_acct                0.198404
#                                 il_util                           0.192893
# il_util                         total_il_high_credit_limit        0.192893
# mths_since_rcnt_il              inq_fi                            0.190816
# inq_fi                          mths_since_rcnt_il                0.190816
# open_il_12m                     dti_joint                         0.189623
# dti_joint                       open_il_12m                       0.189623
# mo_sin_old_rev_tl_op            bc_open_to_buy                    0.189489
# bc_open_to_buy                  mo_sin_old_rev_tl_op              0.189489
# mort_acc                        num_bc_tl                         0.188328
# num_bc_tl                       mort_acc                          0.188328
# total_cu_tl                     open_il_12m                       0.188198
# open_il_12m                     total_cu_tl                       0.188198
# mo_sin_old_il_acct              mort_acc                          0.185704
# mort_acc                        mo_sin_old_il_acct                0.185704
# mo_sin_old_rev_tl_op            loan_amnt                         0.183754
# loan_amnt                       mo_sin_old_rev_tl_op              0.183754
# int_rate                        il_util                           0.183550
# il_util                         int_rate                          0.183550
# mo_sin_old_rev_tl_op            tot_cur_bal                       0.181803
# tot_cur_bal                     mo_sin_old_rev_tl_op              0.181803
# revol_bal                       bc_open_to_buy                    0.178413
# bc_open_to_buy                  revol_bal                         0.178413
# int_rate                        inq_fi                            0.170973
# inq_fi                          int_rate                          0.170973
# mo_sin_old_il_acct              tot_cur_bal                       0.170101
# tot_cur_bal                     mo_sin_old_il_acct                0.170101
# mort_acc                        total_cu_tl                       0.169887
# total_cu_tl                     mort_acc                          0.169887
# tot_cur_bal                     bc_open_to_buy                    0.163424
# bc_open_to_buy                  tot_cur_bal                       0.163424
#                                 pct_tl_nvr_dlq                    0.162892
# pct_tl_nvr_dlq                  bc_open_to_buy                    0.162892
# mo_sin_old_rev_tl_op            int_rate                          0.160134
# int_rate                        mo_sin_old_rev_tl_op              0.160134
# num_bc_tl                       mths_since_last_record            0.157830
# mths_since_last_record          num_bc_tl                         0.157830
# int_rate                        mo_sin_rcnt_tl                    0.150179
# mo_sin_rcnt_tl                  int_rate                          0.150179
# inq_last_6mths                  open_il_12m                       0.149877
# open_il_12m                     inq_last_6mths                    0.149877
# total_il_high_credit_limit      inq_fi                            0.145450
# inq_fi                          total_il_high_credit_limit        0.145450
# il_util                         inq_fi                            0.145342
# inq_fi                          il_util                           0.145342
# tot_cur_bal                     num_bc_tl                         0.142479
# num_bc_tl                       tot_cur_bal                       0.142479
# num_tl_90g_dpd_24m              mths_since_recent_revol_delinq    0.141736
# mths_since_recent_revol_delinq  num_tl_90g_dpd_24m                0.141736
# int_rate                        loan_amnt                         0.140572
# loan_amnt                       int_rate                          0.140572
# total_cu_tl                     mths_since_rcnt_il                0.138082
# mths_since_rcnt_il              total_cu_tl                       0.138082
# loan_amnt                       mo_sin_old_il_acct                0.137114
# mo_sin_old_il_acct              loan_amnt                         0.137114
# num_bc_tl                       inq_last_6mths                    0.136091
# inq_last_6mths                  num_bc_tl                         0.136091
# inq_fi                          mo_sin_rcnt_tl                    0.135433
# mo_sin_rcnt_tl                  inq_fi                            0.135433
#                                 num_bc_tl                         0.129605
# num_bc_tl                       mo_sin_rcnt_tl                    0.129605
# mths_since_rcnt_il              int_rate                          0.128435
# int_rate                        mths_since_rcnt_il                0.128435
# revol_bal                       pct_tl_nvr_dlq                    0.128087
# pct_tl_nvr_dlq                  revol_bal                         0.128087
# pub_rec                         dti_joint                         0.127954
# dti_joint                       pub_rec                           0.127954
# acc_now_delinq                  delinq_amnt                       0.127571
# delinq_amnt                     acc_now_delinq                    0.127571
# pub_rec                         mths_since_recent_revol_delinq    0.126948
# mths_since_recent_revol_delinq  pub_rec                           0.126948
# mort_acc                        bc_open_to_buy                    0.125294
# bc_open_to_buy                  mort_acc                          0.125294
# acc_now_delinq                  mths_since_recent_revol_delinq    0.123189
# mths_since_recent_revol_delinq  acc_now_delinq                    0.123189
# total_cu_tl                     total_il_high_credit_limit        0.122955
# total_il_high_credit_limit      total_cu_tl                       0.122955
# mo_sin_old_rev_tl_op            mths_since_last_record            0.121044
# mths_since_last_record          mo_sin_old_rev_tl_op              0.121044
# num_tl_90g_dpd_24m              collections_12_mths_ex_med        0.120101
# collections_12_mths_ex_med      num_tl_90g_dpd_24m                0.120101
# int_rate                        recoveries                        0.119825
# recoveries                      int_rate                          0.119825
# num_bc_tl                       int_rate                          0.115968
# int_rate                        num_bc_tl                         0.115968
# revol_bal                       il_util                           0.115711
# il_util                         revol_bal                         0.115711
# num_bc_tl                       mo_sin_old_il_acct                0.114920
# mo_sin_old_il_acct              num_bc_tl                         0.114920
# dti                             total_il_high_credit_limit        0.113685
# total_il_high_credit_limit      dti                               0.113685
# mo_sin_rcnt_tl                  total_il_high_credit_limit        0.113229
# total_il_high_credit_limit      mo_sin_rcnt_tl                    0.113229
#                                 revol_bal                         0.109299
# revol_bal                       total_il_high_credit_limit        0.109299
# mths_since_last_record          mort_acc                          0.108039
# mort_acc                        mths_since_last_record            0.108039
# il_util                         loan_amnt                         0.107324
# loan_amnt                       il_util                           0.107324
# revol_bal                       pub_rec                           0.106714
# pub_rec                         revol_bal                         0.106714
# loan_amnt                       pct_tl_nvr_dlq                    0.105056
# pct_tl_nvr_dlq                  loan_amnt                         0.105056
# total_cu_tl                     dti_joint                         0.103740
# dti_joint                       total_cu_tl                       0.103740
# mths_since_rcnt_il              tot_cur_bal                       0.103207
# tot_cur_bal                     mths_since_rcnt_il                0.103207
# mo_sin_old_rev_tl_op            il_util                           0.102888
# il_util                         mo_sin_old_rev_tl_op              0.102888
# pct_tl_nvr_dlq                  mo_sin_old_il_acct                0.099719
# mo_sin_old_il_acct              pct_tl_nvr_dlq                    0.099719
# total_il_high_credit_limit      mort_acc                          0.097536
# mort_acc                        total_il_high_credit_limit        0.097536
# pub_rec                         inq_last_6mths                    0.097382
# inq_last_6mths                  pub_rec                           0.097382
# total_cu_tl                     mo_sin_old_il_acct                0.096620
# mo_sin_old_il_acct              total_cu_tl                       0.096620
# bc_open_to_buy                  dti_joint                         0.096073
# dti_joint                       bc_open_to_buy                    0.096073
# pct_tl_nvr_dlq                  chargeoff_within_12_mths          0.094867
# chargeoff_within_12_mths        pct_tl_nvr_dlq                    0.094867
# tot_cur_bal                     total_cu_tl                       0.094735
# total_cu_tl                     tot_cur_bal                       0.094735
# revol_bal                       mo_sin_old_il_acct                0.094032
# mo_sin_old_il_acct              revol_bal                         0.094032
# dti_joint                       mo_sin_old_il_acct                0.093306
# mo_sin_old_il_acct              dti_joint                         0.093306
# pct_tl_nvr_dlq                  mo_sin_old_rev_tl_op              0.092974
# mo_sin_old_rev_tl_op            pct_tl_nvr_dlq                    0.092974
# id                              dti_joint                         0.092846
# dti_joint                       id                                0.092846
# inq_fi                          total_cu_tl                       0.092703
# total_cu_tl                     inq_fi                            0.092703
# num_tl_90g_dpd_24m              mths_since_last_record            0.089774
# mths_since_last_record          num_tl_90g_dpd_24m                0.089774
# loan_amnt                       pub_rec                           0.088899
# pub_rec                         loan_amnt                         0.088899
# tot_cur_bal                     int_rate                          0.087011
# int_rate                        tot_cur_bal                       0.087011
# tot_cur_bal                     inq_fi                            0.086877
# inq_fi                          tot_cur_bal                       0.086877
# pub_rec                         bc_open_to_buy                    0.085906
# bc_open_to_buy                  pub_rec                           0.085906
# dti_joint                       pct_tl_nvr_dlq                    0.085603
# pct_tl_nvr_dlq                  dti_joint                         0.085603
# mths_since_recent_revol_delinq  pct_tl_nvr_dlq                    0.085372
# pct_tl_nvr_dlq                  mths_since_recent_revol_delinq    0.085372
# mo_sin_rcnt_tl                  total_cu_tl                       0.085295
# total_cu_tl                     mo_sin_rcnt_tl                    0.085295
# dti                             mths_since_last_record            0.083465
# mths_since_last_record          dti                               0.083465
# mo_sin_old_il_acct              int_rate                          0.080956
# int_rate                        mo_sin_old_il_acct                0.080956
# mo_sin_old_rev_tl_op            mths_since_rcnt_il                0.080442
# mths_since_rcnt_il              mo_sin_old_rev_tl_op              0.080442
# num_tl_90g_dpd_24m              num_tl_120dpd_2m                  0.080164
# num_tl_120dpd_2m                num_tl_90g_dpd_24m                0.080164
# il_util                         dti_joint                         0.079700
# dti_joint                       il_util                           0.079700
# inq_last_6mths                  mths_since_rcnt_il                0.079560
# mths_since_rcnt_il              inq_last_6mths                    0.079560
# int_rate                        dti                               0.077932
# dti                             int_rate                          0.077932
# mths_since_rcnt_il              mo_sin_old_il_acct                0.077925
# mo_sin_old_il_acct              mths_since_rcnt_il                0.077925
# recoveries                      loan_amnt                         0.077870
# loan_amnt                       recoveries                        0.077870
# mo_sin_rcnt_tl                  mths_since_recent_revol_delinq    0.077252
# mths_since_recent_revol_delinq  mo_sin_rcnt_tl                    0.077252
# tot_cur_bal                     pub_rec                           0.077184
# pub_rec                         tot_cur_bal                       0.077184
# int_rate                        mort_acc                          0.076131
# mort_acc                        int_rate                          0.076131
# il_util                         inq_last_6mths                    0.075468
# inq_last_6mths                  il_util                           0.075468
# inq_fi                          mort_acc                          0.075278
# mort_acc                        inq_fi                            0.075278
# il_util                         mort_acc                          0.073663
# mort_acc                        il_util                           0.073663
# tot_cur_bal                     open_il_12m                       0.073339
# open_il_12m                     tot_cur_bal                       0.073339
# dti_joint                       tot_coll_amt                      0.071590
# tot_coll_amt                    dti_joint                         0.071590
# total_cu_tl                     loan_amnt                         0.071500
# loan_amnt                       total_cu_tl                       0.071500
# recoveries                      dti_joint                         0.070967
# dti_joint                       recoveries                        0.070967
# mths_since_last_record          inq_last_6mths                    0.070857
# inq_last_6mths                  mths_since_last_record            0.070857
# id                              recoveries                        0.070027
# recoveries                      id                                0.070027
# bc_open_to_buy                  mths_since_recent_revol_delinq    0.069615
# mths_since_recent_revol_delinq  bc_open_to_buy                    0.069615
# num_bc_tl                       dti_joint                         0.069130
# dti_joint                       num_bc_tl                         0.069130
# mths_since_recent_revol_delinq  tot_coll_amt                      0.069065
# tot_coll_amt                    mths_since_recent_revol_delinq    0.069065
# pct_tl_nvr_dlq                  tot_coll_amt                      0.068542
# tot_coll_amt                    pct_tl_nvr_dlq                    0.068542
# total_rec_late_fee              recoveries                        0.065903
# recoveries                      total_rec_late_fee                0.065903
# mths_since_recent_revol_delinq  il_util                           0.065826
# il_util                         mths_since_recent_revol_delinq    0.065826
# pub_rec                         mo_sin_rcnt_tl                    0.065738
# mo_sin_rcnt_tl                  pub_rec                           0.065738
# acc_now_delinq                  num_tl_90g_dpd_24m                0.065097
# num_tl_90g_dpd_24m              acc_now_delinq                    0.065097
# mths_since_recent_revol_delinq  tot_cur_bal                       0.064337
# tot_cur_bal                     mths_since_recent_revol_delinq    0.064337
# int_rate                        total_rec_late_fee                0.063685
# total_rec_late_fee              int_rate                          0.063685
# dti_joint                       tot_cur_bal                       0.063018
# tot_cur_bal                     dti_joint                         0.063018
# il_util                         num_bc_tl                         0.062322
# num_bc_tl                       il_util                           0.062322
# mo_sin_old_rev_tl_op            inq_fi                            0.062211
# inq_fi                          mo_sin_old_rev_tl_op              0.062211
# pct_tl_nvr_dlq                  int_rate                          0.061652
# int_rate                        pct_tl_nvr_dlq                    0.061652
# mths_since_recent_revol_delinq  open_il_12m                       0.060292
# open_il_12m                     mths_since_recent_revol_delinq    0.060292
# pub_rec                         inq_fi                            0.060046
# inq_fi                          pub_rec                           0.060046
# pub_rec                         pct_tl_nvr_dlq                    0.059723
# pct_tl_nvr_dlq                  pub_rec                           0.059723
# mo_sin_old_rev_tl_op            total_cu_tl                       0.058459
# total_cu_tl                     mo_sin_old_rev_tl_op              0.058459
# pct_tl_nvr_dlq                  inq_last_6mths                    0.058290
# inq_last_6mths                  pct_tl_nvr_dlq                    0.058290
# int_rate                        pub_rec                           0.058231
# pub_rec                         int_rate                          0.058231
# revol_bal                       int_rate                          0.057412
# int_rate                        revol_bal                         0.057412
# mo_sin_rcnt_tl                  dti_joint                         0.056705
# dti_joint                       mo_sin_rcnt_tl                    0.056705
# mo_sin_rcnt_tl                  tot_cur_bal                       0.055598
# tot_cur_bal                     mo_sin_rcnt_tl                    0.055598
# dti_joint                       total_rec_late_fee                0.054897
# total_rec_late_fee              dti_joint                         0.054897
# chargeoff_within_12_mths        mths_since_recent_revol_delinq    0.053455
# mths_since_recent_revol_delinq  chargeoff_within_12_mths          0.053455
# id                              int_rate                          0.053402
# int_rate                        id                                0.053402
# mo_sin_old_il_acct              mths_since_last_record            0.053113
# mths_since_last_record          mo_sin_old_il_acct                0.053113
# pub_rec                         open_il_12m                       0.052021
# open_il_12m                     pub_rec                           0.052021
# loan_amnt                       total_rec_late_fee                0.051888
# total_rec_late_fee              loan_amnt                         0.051888
# pct_tl_nvr_dlq                  mths_since_rcnt_il                0.051598
# mths_since_rcnt_il              pct_tl_nvr_dlq                    0.051598
# revol_bal                       open_il_12m                       0.051477
# open_il_12m                     revol_bal                         0.051477
# collections_12_mths_ex_med      acc_now_delinq                    0.051278
# acc_now_delinq                  collections_12_mths_ex_med        0.051278
# pct_tl_nvr_dlq                  collections_12_mths_ex_med        0.051073
# collections_12_mths_ex_med      pct_tl_nvr_dlq                    0.051073
# mths_since_recent_revol_delinq  revol_bal                         0.050308
# revol_bal                       mths_since_recent_revol_delinq    0.050308
# num_tl_90g_dpd_24m              mo_sin_old_il_acct                0.050211
# mo_sin_old_il_acct              num_tl_90g_dpd_24m                0.050211
# mths_since_recent_revol_delinq  loan_amnt                         0.049828
# loan_amnt                       mths_since_recent_revol_delinq    0.049828
# num_tl_90g_dpd_24m              inq_last_6mths                    0.049446
# inq_last_6mths                  num_tl_90g_dpd_24m                0.049446
# mo_sin_old_rev_tl_op            pub_rec                           0.049367
# pub_rec                         mo_sin_old_rev_tl_op              0.049367
# acc_now_delinq                  pct_tl_nvr_dlq                    0.049099
# pct_tl_nvr_dlq                  acc_now_delinq                    0.049099
# dti_joint                       mths_since_rcnt_il                0.049040
# mths_since_rcnt_il              dti_joint                         0.049040
# num_bc_tl                       total_il_high_credit_limit        0.048957
# total_il_high_credit_limit      num_bc_tl                         0.048957
# mo_sin_rcnt_tl                  mort_acc                          0.048839
# mort_acc                        mo_sin_rcnt_tl                    0.048839
# mths_since_last_record          tot_coll_amt                      0.048726
# tot_coll_amt                    mths_since_last_record            0.048726
# pct_tl_nvr_dlq                  mort_acc                          0.048490
# mort_acc                        pct_tl_nvr_dlq                    0.048490
# dti                             revol_bal                         0.048135
# revol_bal                       dti                               0.048135
#                                 inq_fi                            0.047681
# inq_fi                          revol_bal                         0.047681
# total_il_high_credit_limit      bc_open_to_buy                    0.047631
# bc_open_to_buy                  total_il_high_credit_limit        0.047631
# mths_since_recent_revol_delinq  inq_last_6mths                    0.047287
# inq_last_6mths                  mths_since_recent_revol_delinq    0.047287
# collections_12_mths_ex_med      tot_coll_amt                      0.046012
# tot_coll_amt                    collections_12_mths_ex_med        0.046012
# mo_sin_rcnt_tl                  mo_sin_old_rev_tl_op              0.045998
# mo_sin_old_rev_tl_op            mo_sin_rcnt_tl                    0.045998
# il_util                         bc_open_to_buy                    0.045875
# bc_open_to_buy                  il_util                           0.045875
# mo_sin_old_il_acct              pub_rec                           0.044982
# pub_rec                         mo_sin_old_il_acct                0.044982
# mths_since_rcnt_il              mort_acc                          0.044964
# mort_acc                        mths_since_rcnt_il                0.044964
# num_tl_90g_dpd_24m              bc_open_to_buy                    0.044056
# bc_open_to_buy                  num_tl_90g_dpd_24m                0.044056
# chargeoff_within_12_mths        mths_since_last_record            0.043150
# mths_since_last_record          chargeoff_within_12_mths          0.043150
# mo_sin_rcnt_tl                  bc_open_to_buy                    0.042936
# bc_open_to_buy                  mo_sin_rcnt_tl                    0.042936
# num_bc_tl                       pct_tl_nvr_dlq                    0.042177
# pct_tl_nvr_dlq                  num_bc_tl                         0.042177
# chargeoff_within_12_mths        collections_12_mths_ex_med        0.042027
# collections_12_mths_ex_med      chargeoff_within_12_mths          0.042027
# pct_tl_nvr_dlq                  dti                               0.042020
# dti                             pct_tl_nvr_dlq                    0.042020
# mo_sin_rcnt_tl                  loan_amnt                         0.041686
# loan_amnt                       mo_sin_rcnt_tl                    0.041686
# revol_bal                       num_tl_90g_dpd_24m                0.040672
# num_tl_90g_dpd_24m              revol_bal                         0.040672
# delinq_amnt                     num_tl_90g_dpd_24m                0.040582
# num_tl_90g_dpd_24m              delinq_amnt                       0.040582
# pct_tl_nvr_dlq                  total_cu_tl                       0.040010
# total_cu_tl                     pct_tl_nvr_dlq                    0.040010
# inq_last_6mths                  total_il_high_credit_limit        0.039506
# total_il_high_credit_limit      inq_last_6mths                    0.039506
# recoveries                      inq_last_6mths                    0.039129
# inq_last_6mths                  recoveries                        0.039129
#                                 loan_amnt                         0.039040
# loan_amnt                       inq_last_6mths                    0.039040
# bc_open_to_buy                  mths_since_last_record            0.038786
# mths_since_last_record          bc_open_to_buy                    0.038786
# mths_since_recent_revol_delinq  mths_since_last_record            0.038435
# mths_since_last_record          mths_since_recent_revol_delinq    0.038435
#                                 mths_since_rcnt_il                0.038229
# mths_since_rcnt_il              mths_since_last_record            0.038229
# open_il_12m                     mort_acc                          0.038035
# mort_acc                        open_il_12m                       0.038035
# mo_sin_rcnt_tl                  revol_bal                         0.037997
# revol_bal                       mo_sin_rcnt_tl                    0.037997
# num_tl_120dpd_2m                chargeoff_within_12_mths          0.037937
# chargeoff_within_12_mths        num_tl_120dpd_2m                  0.037937
# dti                             mo_sin_rcnt_tl                    0.037806
# mo_sin_rcnt_tl                  dti                               0.037806
# num_bc_tl                       mths_since_recent_revol_delinq    0.037502
# mths_since_recent_revol_delinq  num_bc_tl                         0.037502
# mths_since_last_record          id                                0.037319
# id                              mths_since_last_record            0.037319
# dti                             mths_since_rcnt_il                0.036447
# mths_since_rcnt_il              dti                               0.036447
# mths_since_recent_revol_delinq  num_tl_120dpd_2m                  0.036336
# num_tl_120dpd_2m                mths_since_recent_revol_delinq    0.036336
# mort_acc                        num_tl_90g_dpd_24m                0.036336
# num_tl_90g_dpd_24m              mort_acc                          0.036336
# tot_coll_amt                    pub_rec                           0.035377
# pub_rec                         tot_coll_amt                      0.035377
# open_il_12m                     mo_sin_old_rev_tl_op              0.034594
# mo_sin_old_rev_tl_op            open_il_12m                       0.034594
#                                 chargeoff_within_12_mths          0.034235
# chargeoff_within_12_mths        mo_sin_old_rev_tl_op              0.034235
#                                 acc_now_delinq                    0.034094
# acc_now_delinq                  chargeoff_within_12_mths          0.034094
# mths_since_last_record          il_util                           0.033809
# il_util                         mths_since_last_record            0.033809
# mort_acc                        chargeoff_within_12_mths          0.033692
# chargeoff_within_12_mths        mort_acc                          0.033692
# tot_coll_amt                    mo_sin_old_rev_tl_op              0.033676
# mo_sin_old_rev_tl_op            tot_coll_amt                      0.033676
# num_tl_90g_dpd_24m              mo_sin_old_rev_tl_op              0.033258
# mo_sin_old_rev_tl_op            num_tl_90g_dpd_24m                0.033258
# inq_fi                          dti_joint                         0.032828
# dti_joint                       inq_fi                            0.032828
# inq_last_6mths                  total_cu_tl                       0.032530
# total_cu_tl                     inq_last_6mths                    0.032530
# mths_since_rcnt_il              revol_bal                         0.032370
# revol_bal                       mths_since_rcnt_il                0.032370
# chargeoff_within_12_mths        num_bc_tl                         0.032293
# num_bc_tl                       chargeoff_within_12_mths          0.032293
# bc_open_to_buy                  mo_sin_old_il_acct                0.032111
# mo_sin_old_il_acct              bc_open_to_buy                    0.032111
# total_rec_late_fee              mths_since_recent_revol_delinq    0.031637
# mths_since_recent_revol_delinq  total_rec_late_fee                0.031637
# num_tl_90g_dpd_24m              int_rate                          0.031344
# int_rate                        num_tl_90g_dpd_24m                0.031344
# num_tl_90g_dpd_24m              loan_amnt                         0.031334
# loan_amnt                       num_tl_90g_dpd_24m                0.031334
# open_il_12m                     mths_since_last_record            0.031312
# mths_since_last_record          open_il_12m                       0.031312
# revol_bal                       tot_coll_amt                      0.030903
# tot_coll_amt                    revol_bal                         0.030903
# inq_fi                          mths_since_last_record            0.030853
# mths_since_last_record          inq_fi                            0.030853
# num_bc_tl                       inq_fi                            0.030827
# inq_fi                          num_bc_tl                         0.030827
# total_il_high_credit_limit      mths_since_recent_revol_delinq    0.030632
# mths_since_recent_revol_delinq  total_il_high_credit_limit        0.030632
# revol_bal                       collections_12_mths_ex_med        0.029719
# collections_12_mths_ex_med      revol_bal                         0.029719
# dti                             bc_open_to_buy                    0.029073
# bc_open_to_buy                  dti                               0.029073
# il_util                         mo_sin_old_il_acct                0.028591
# mo_sin_old_il_acct              il_util                           0.028591
# open_il_12m                     recoveries                        0.028576
# recoveries                      open_il_12m                       0.028576
# num_bc_tl                       id                                0.028205
# id                              num_bc_tl                         0.028205
# dti                             num_bc_tl                         0.028171
# num_bc_tl                       dti                               0.028171
# num_tl_90g_dpd_24m              total_il_high_credit_limit        0.027985
# total_il_high_credit_limit      num_tl_90g_dpd_24m                0.027985
# acc_now_delinq                  dti_joint                         0.027877
# dti_joint                       acc_now_delinq                    0.027877
# delinq_amnt                     dti_joint                         0.027877
# dti_joint                       delinq_amnt                       0.027877
# inq_fi                          recoveries                        0.027693
# recoveries                      inq_fi                            0.027693
# acc_now_delinq                  int_rate                          0.027495
# int_rate                        acc_now_delinq                    0.027495
# collections_12_mths_ex_med      loan_amnt                         0.027454
# loan_amnt                       collections_12_mths_ex_med        0.027454
# open_il_12m                     bc_open_to_buy                    0.027200
# bc_open_to_buy                  open_il_12m                       0.027200
# pct_tl_nvr_dlq                  inq_fi                            0.026616
# inq_fi                          pct_tl_nvr_dlq                    0.026616
# bc_open_to_buy                  inq_fi                            0.026612
# inq_fi                          bc_open_to_buy                    0.026612
# total_rec_late_fee              pct_tl_nvr_dlq                    0.026287
# pct_tl_nvr_dlq                  total_rec_late_fee                0.026287
# pub_rec                         total_il_high_credit_limit        0.026032
# total_il_high_credit_limit      pub_rec                           0.026032
# inq_last_6mths                  collections_12_mths_ex_med        0.025801
# collections_12_mths_ex_med      inq_last_6mths                    0.025801
# pct_tl_nvr_dlq                  total_il_high_credit_limit        0.025657
# total_il_high_credit_limit      pct_tl_nvr_dlq                    0.025657
# mths_since_recent_revol_delinq  mths_since_rcnt_il                0.025012
# mths_since_rcnt_il              mths_since_recent_revol_delinq    0.025012
# tot_cur_bal                     mths_since_last_record            0.024939
# mths_since_last_record          tot_cur_bal                       0.024939
# tot_coll_amt                    inq_fi                            0.024884
# inq_fi                          tot_coll_amt                      0.024884
# mo_sin_rcnt_tl                  recoveries                        0.024589
# recoveries                      mo_sin_rcnt_tl                    0.024589
# acc_now_delinq                  mo_sin_old_rev_tl_op              0.024103
# mo_sin_old_rev_tl_op            acc_now_delinq                    0.024103
# total_cu_tl                     revol_bal                         0.023853
# revol_bal                       total_cu_tl                       0.023853
# num_bc_tl                       tot_coll_amt                      0.023352
# tot_coll_amt                    num_bc_tl                         0.023352
# dti                             pub_rec                           0.023200
# pub_rec                         dti                               0.023200
# tot_cur_bal                     acc_now_delinq                    0.023160
# acc_now_delinq                  tot_cur_bal                       0.023160
# mort_acc                        acc_now_delinq                    0.022914
# acc_now_delinq                  mort_acc                          0.022914
# tot_cur_bal                     il_util                           0.022896
# il_util                         tot_cur_bal                       0.022896
#                                 num_tl_90g_dpd_24m                0.022781
# num_tl_90g_dpd_24m              il_util                           0.022781
# id                              bc_open_to_buy                    0.022195
# bc_open_to_buy                  id                                0.022195
# mths_since_last_record          revol_bal                         0.022070
# revol_bal                       mths_since_last_record            0.022070
# total_cu_tl                     mths_since_last_record            0.021990
# mths_since_last_record          total_cu_tl                       0.021990
# inq_last_6mths                  mort_acc                          0.021717
# mort_acc                        inq_last_6mths                    0.021717
# tot_cur_bal                     total_rec_late_fee                0.021698
# total_rec_late_fee              tot_cur_bal                       0.021698
# tot_coll_amt                    loan_amnt                         0.021437
# loan_amnt                       tot_coll_amt                      0.021437
# il_util                         pub_rec                           0.021355
# pub_rec                         il_util                           0.021355
# total_rec_late_fee              mths_since_last_record            0.021311
# mths_since_last_record          total_rec_late_fee                0.021311
# chargeoff_within_12_mths        dti_joint                         0.021140
# dti_joint                       chargeoff_within_12_mths          0.021140
# num_tl_120dpd_2m                pct_tl_nvr_dlq                    0.021027
# pct_tl_nvr_dlq                  num_tl_120dpd_2m                  0.021027
# num_bc_tl                       num_tl_90g_dpd_24m                0.020871
# num_tl_90g_dpd_24m              num_bc_tl                         0.020871
# id                              total_il_high_credit_limit        0.020870
# total_il_high_credit_limit      id                                0.020870
# inq_last_6mths                  tot_coll_amt                      0.020749
# tot_coll_amt                    inq_last_6mths                    0.020749
# open_il_12m                     total_rec_late_fee                0.020737
# total_rec_late_fee              open_il_12m                       0.020737
# total_cu_tl                     int_rate                          0.020685
# int_rate                        total_cu_tl                       0.020685
# dti                             open_il_12m                       0.020348
# open_il_12m                     dti                               0.020348
# total_rec_late_fee              total_il_high_credit_limit        0.020241
# total_il_high_credit_limit      total_rec_late_fee                0.020241
# chargeoff_within_12_mths        inq_last_6mths                    0.020136
# inq_last_6mths                  chargeoff_within_12_mths          0.020136
# dti                             mort_acc                          0.020044
# mort_acc                        dti                               0.020044
# inq_fi                          mths_since_recent_revol_delinq    0.019561
# mths_since_recent_revol_delinq  inq_fi                            0.019561
# chargeoff_within_12_mths        mo_sin_old_il_acct                0.019460
# mo_sin_old_il_acct              chargeoff_within_12_mths          0.019460
# tot_coll_amt                    il_util                           0.019390
# il_util                         tot_coll_amt                      0.019390
# total_rec_late_fee              inq_last_6mths                    0.019330
# inq_last_6mths                  total_rec_late_fee                0.019330
# collections_12_mths_ex_med      int_rate                          0.019234
# int_rate                        collections_12_mths_ex_med        0.019234
# il_util                         chargeoff_within_12_mths          0.019124
# chargeoff_within_12_mths        il_util                           0.019124
# loan_amnt                       dti_joint                         0.018769
# dti_joint                       loan_amnt                         0.018769
# mths_since_recent_revol_delinq  mort_acc                          0.018656
# mort_acc                        mths_since_recent_revol_delinq    0.018656
# open_il_12m                     pct_tl_nvr_dlq                    0.018381
# pct_tl_nvr_dlq                  open_il_12m                       0.018381
#                                 tot_cur_bal                       0.018303
# tot_cur_bal                     pct_tl_nvr_dlq                    0.018303
# dti                             mo_sin_old_rev_tl_op              0.018276
# mo_sin_old_rev_tl_op            dti                               0.018276
# open_il_12m                     mo_sin_old_il_acct                0.018267
# mo_sin_old_il_acct              open_il_12m                       0.018267
#                                 tot_coll_amt                      0.018129
# tot_coll_amt                    mo_sin_old_il_acct                0.018129
# recoveries                      total_il_high_credit_limit        0.018024
# total_il_high_credit_limit      recoveries                        0.018024
# acc_now_delinq                  total_cu_tl                       0.017527
# total_cu_tl                     acc_now_delinq                    0.017527
# recoveries                      mths_since_rcnt_il                0.017375
# mths_since_rcnt_il              recoveries                        0.017375
# delinq_amnt                     tot_cur_bal                       0.017337
# tot_cur_bal                     delinq_amnt                       0.017337
# mo_sin_rcnt_tl                  mo_sin_old_il_acct                0.017177
# mo_sin_old_il_acct              mo_sin_rcnt_tl                    0.017177
# pub_rec                         collections_12_mths_ex_med        0.016719
# collections_12_mths_ex_med      pub_rec                           0.016719
# acc_now_delinq                  total_il_high_credit_limit        0.016714
# ...
# total_il_high_credit_limit      num_tl_120dpd_2m                  0.003570
# num_tl_120dpd_2m                total_il_high_credit_limit        0.003570
# pub_rec                         id                                0.003501
# id                              pub_rec                           0.003501
# mths_since_last_record          delinq_amnt                       0.003392
# delinq_amnt                     mths_since_last_record            0.003392
# mths_since_recent_revol_delinq  dti                               0.003353
# dti                             mths_since_recent_revol_delinq    0.003353
# total_cu_tl                     pub_rec                           0.003349
# pub_rec                         total_cu_tl                       0.003349
# num_tl_120dpd_2m                mo_sin_rcnt_tl                    0.003288
# mo_sin_rcnt_tl                  num_tl_120dpd_2m                  0.003288
# dti                             inq_last_6mths                    0.003277
# inq_last_6mths                  dti                               0.003277
# delinq_amnt                     pub_rec                           0.003200
# pub_rec                         delinq_amnt                       0.003200
# inq_last_6mths                  mo_sin_old_rev_tl_op              0.003108
# mo_sin_old_rev_tl_op            inq_last_6mths                    0.003108
# chargeoff_within_12_mths        total_il_high_credit_limit        0.003073
# total_il_high_credit_limit      chargeoff_within_12_mths          0.003073
# acc_now_delinq                  revol_bal                         0.003011
# revol_bal                       acc_now_delinq                    0.003011
# recoveries                      chargeoff_within_12_mths          0.002795
# chargeoff_within_12_mths        recoveries                        0.002795
# open_il_12m                     num_tl_120dpd_2m                  0.002767
# num_tl_120dpd_2m                open_il_12m                       0.002767
# recoveries                      num_tl_120dpd_2m                  0.002738
# num_tl_120dpd_2m                recoveries                        0.002738
# delinq_amnt                     dti                               0.002667
# dti                             delinq_amnt                       0.002667
# recoveries                      mort_acc                          0.002563
# mort_acc                        recoveries                        0.002563
# acc_now_delinq                  pub_rec                           0.002458
# pub_rec                         acc_now_delinq                    0.002458
# mths_since_rcnt_il              tot_coll_amt                      0.002451
# tot_coll_amt                    mths_since_rcnt_il                0.002451
# total_cu_tl                     num_bc_tl                         0.002413
# num_bc_tl                       total_cu_tl                       0.002413
# total_rec_late_fee              mo_sin_old_il_acct                0.002383
# mo_sin_old_il_acct              total_rec_late_fee                0.002383
# chargeoff_within_12_mths        dti                               0.002340
# dti                             chargeoff_within_12_mths          0.002340
# tot_coll_amt                    id                                0.002312
# id                              tot_coll_amt                      0.002312
#                                 mths_since_rcnt_il                0.002310
# mths_since_rcnt_il              id                                0.002310
# num_tl_120dpd_2m                dti                               0.002251
# dti                             num_tl_120dpd_2m                  0.002251
# mo_sin_rcnt_tl                  delinq_amnt                       0.002235
# delinq_amnt                     mo_sin_rcnt_tl                    0.002235
# il_util                         collections_12_mths_ex_med        0.002178
# collections_12_mths_ex_med      il_util                           0.002178
# tot_coll_amt                    delinq_amnt                       0.002142
# delinq_amnt                     tot_coll_amt                      0.002142
# loan_amnt                       delinq_amnt                       0.002096
# delinq_amnt                     loan_amnt                         0.002096
# mths_since_last_record          mo_sin_rcnt_tl                    0.002069
# mo_sin_rcnt_tl                  mths_since_last_record            0.002069
# mths_since_recent_revol_delinq  recoveries                        0.002057
# recoveries                      mths_since_recent_revol_delinq    0.002057
# num_tl_120dpd_2m                total_cu_tl                       0.002029
# total_cu_tl                     num_tl_120dpd_2m                  0.002029
# chargeoff_within_12_mths        pub_rec                           0.001974
# pub_rec                         chargeoff_within_12_mths          0.001974
# id                              delinq_amnt                       0.001961
# delinq_amnt                     id                                0.001961
# pub_rec                         recoveries                        0.001952
# recoveries                      pub_rec                           0.001952
# delinq_amnt                     num_bc_tl                         0.001911
# num_bc_tl                       delinq_amnt                       0.001911
# num_tl_120dpd_2m                inq_last_6mths                    0.001884
# inq_last_6mths                  num_tl_120dpd_2m                  0.001884
# tot_coll_amt                    acc_now_delinq                    0.001841
# acc_now_delinq                  tot_coll_amt                      0.001841
# bc_open_to_buy                  num_tl_120dpd_2m                  0.001794
# num_tl_120dpd_2m                bc_open_to_buy                    0.001794
# bc_open_to_buy                  mths_since_rcnt_il                0.001788
# mths_since_rcnt_il              bc_open_to_buy                    0.001788
# il_util                         num_tl_120dpd_2m                  0.001763
# num_tl_120dpd_2m                il_util                           0.001763
# num_tl_90g_dpd_24m              recoveries                        0.001556
# recoveries                      num_tl_90g_dpd_24m                0.001556
# num_tl_90g_dpd_24m              dti_joint                         0.001323
# dti_joint                       num_tl_90g_dpd_24m                0.001323
# delinq_amnt                     open_il_12m                       0.001277
# open_il_12m                     delinq_amnt                       0.001277
# id                              mths_since_recent_revol_delinq    0.001272
# mths_since_recent_revol_delinq  id                                0.001272
# chargeoff_within_12_mths        open_il_12m                       0.001270
# open_il_12m                     chargeoff_within_12_mths          0.001270
# total_rec_late_fee              dti                               0.001150
# dti                             total_rec_late_fee                0.001150
# delinq_amnt                     revol_bal                         0.001126
# revol_bal                       delinq_amnt                       0.001126
# recoveries                      delinq_amnt                       0.001075
# delinq_amnt                     recoveries                        0.001075
# id                              chargeoff_within_12_mths          0.001075
# chargeoff_within_12_mths        id                                0.001075
# pub_rec                         num_tl_120dpd_2m                  0.001069
# num_tl_120dpd_2m                pub_rec                           0.001069
# delinq_amnt                     bc_open_to_buy                    0.001050
# bc_open_to_buy                  delinq_amnt                       0.001050
# tot_cur_bal                     recoveries                        0.001026
# recoveries                      tot_cur_bal                       0.001026
# delinq_amnt                     mths_since_recent_revol_delinq    0.001022
# mths_since_recent_revol_delinq  delinq_amnt                       0.001022
# total_cu_tl                     id                                0.000914
# id                              total_cu_tl                       0.000914
# num_tl_120dpd_2m                loan_amnt                         0.000905
# loan_amnt                       num_tl_120dpd_2m                  0.000905
# num_tl_120dpd_2m                collections_12_mths_ex_med        0.000860
# collections_12_mths_ex_med      num_tl_120dpd_2m                  0.000860
# total_cu_tl                     mths_since_recent_revol_delinq    0.000860
# mths_since_recent_revol_delinq  total_cu_tl                       0.000860
# total_rec_late_fee              delinq_amnt                       0.000787
# delinq_amnt                     total_rec_late_fee                0.000787
# id                              inq_last_6mths                    0.000660
# inq_last_6mths                  id                                0.000660
# acc_now_delinq                  loan_amnt                         0.000645
# loan_amnt                       acc_now_delinq                    0.000645
# num_tl_90g_dpd_24m              id                                0.000612
# id                              num_tl_90g_dpd_24m                0.000612
# dti                             acc_now_delinq                    0.000583
# acc_now_delinq                  dti                               0.000583
#                                 inq_last_6mths                    0.000563
# inq_last_6mths                  acc_now_delinq                    0.000563
# total_cu_tl                     chargeoff_within_12_mths          0.000372
# chargeoff_within_12_mths        total_cu_tl                       0.000372
# recoveries                      tot_coll_amt                      0.000342
# tot_coll_amt                    recoveries                        0.000342
# total_rec_late_fee              tot_coll_amt                      0.000320
# tot_coll_amt                    total_rec_late_fee                0.000320
# total_il_high_credit_limit      delinq_amnt                       0.000250
# delinq_amnt                     total_il_high_credit_limit        0.000250
# mort_acc                        total_rec_late_fee                0.000210
# total_rec_late_fee              mort_acc                          0.000210
#                                 pub_rec                           0.000146
# pub_rec                         total_rec_late_fee                0.000146
# num_tl_120dpd_2m                total_rec_late_fee                0.000098
# total_rec_late_fee              num_tl_120dpd_2m                  0.000098
# mo_sin_rcnt_tl                  acc_now_delinq                    0.000093
# acc_now_delinq                  mo_sin_rcnt_tl                    0.000093
# id                              mo_sin_old_il_acct                0.000088
# mo_sin_old_il_acct              id                                0.000088
# id                              policy_code                            NaN
# loan_amnt                       policy_code                            NaN
# int_rate                        policy_code                            NaN
# dti                             policy_code                            NaN
# inq_last_6mths                  policy_code                            NaN
# mths_since_last_record          policy_code                            NaN
# pub_rec                         policy_code                            NaN
# revol_bal                       policy_code                            NaN
# total_rec_late_fee              policy_code                            NaN
# recoveries                      policy_code                            NaN
# collections_12_mths_ex_med      policy_code                            NaN
# policy_code                     id                                     NaN
#                                 loan_amnt                              NaN
#                                 int_rate                               NaN
#                                 dti                                    NaN
#                                 inq_last_6mths                         NaN
#                                 mths_since_last_record                 NaN
#                                 pub_rec                                NaN
#                                 revol_bal                              NaN
#                                 total_rec_late_fee                     NaN
#                                 recoveries                             NaN
#                                 collections_12_mths_ex_med             NaN
#                                 policy_code                            NaN
#                                 dti_joint                              NaN
#                                 acc_now_delinq                         NaN
#                                 tot_coll_amt                           NaN
#                                 tot_cur_bal                            NaN
#                                 open_il_12m                            NaN
#                                 mths_since_rcnt_il                     NaN
#                                 il_util                                NaN
#                                 inq_fi                                 NaN
#                                 total_cu_tl                            NaN
#                                 bc_open_to_buy                         NaN
#                                 chargeoff_within_12_mths               NaN
#                                 delinq_amnt                            NaN
#                                 mo_sin_old_il_acct                     NaN
#                                 mo_sin_old_rev_tl_op                   NaN
#                                 mo_sin_rcnt_tl                         NaN
#                                 mort_acc                               NaN
#                                 mths_since_recent_revol_delinq         NaN
#                                 num_bc_tl                              NaN
#                                 num_tl_120dpd_2m                       NaN
#                                 num_tl_90g_dpd_24m                     NaN
#                                 pct_tl_nvr_dlq                         NaN
#                                 total_il_high_credit_limit             NaN
# dti_joint                       policy_code                            NaN
#                                 num_tl_120dpd_2m                       NaN
# acc_now_delinq                  policy_code                            NaN
# tot_coll_amt                    policy_code                            NaN
# tot_cur_bal                     policy_code                            NaN
# open_il_12m                     policy_code                            NaN
# mths_since_rcnt_il              policy_code                            NaN
# il_util                         policy_code                            NaN
# inq_fi                          policy_code                            NaN
# total_cu_tl                     policy_code                            NaN
# bc_open_to_buy                  policy_code                            NaN
# chargeoff_within_12_mths        policy_code                            NaN
# delinq_amnt                     policy_code                            NaN
# mo_sin_old_il_acct              policy_code                            NaN
# mo_sin_old_rev_tl_op            policy_code                            NaN
# mo_sin_rcnt_tl                  policy_code                            NaN
# mort_acc                        policy_code                            NaN
# mths_since_recent_revol_delinq  policy_code                            NaN
# num_bc_tl                       policy_code                            NaN
# num_tl_120dpd_2m                policy_code                            NaN
#                                 dti_joint                              NaN
# num_tl_90g_dpd_24m              policy_code                            NaN
# pct_tl_nvr_dlq                  policy_code                            NaN
# total_il_high_credit_limit      policy_code                            NaN
# dtype: float64

# %%
y2015 = y2015.drop(columns = ['tot_cur_bal', 'open_il_12m', 'bc_open_to_buy', 'total_il_high_credit_limit'])

# %%
## Run Random Forest with cleaned data
rfc3 = ensemble.RandomForestClassifier()
X3 = y2015.drop('loan_status', 1)
Y3 = y2015['loan_status']
X3 = pd.get_dummies(X3)
X3 = X3.dropna(axis=1)

cross_val_score(rfc3, X3, Y3, cv=10)
# Out:
# c:\users\nstow\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# c:\users\nstow\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# c:\users\nstow\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# c:\users\nstow\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# c:\users\nstow\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# c:\users\nstow\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# c:\users\nstow\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# c:\users\nstow\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# c:\users\nstow\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# c:\users\nstow\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# array([0.92823728, 0.93020826, 0.92792857, 0.92417658, 0.90676799,
#        0.93006412, 0.92260562, 0.94013156, 0.93839504, 0.93435615])

# %%
## recreate sorted correlation matrix
c5 = y2015.corr().abs()

s5 = c5.unstack()
so5 = s5.sort_values(kind="quicksort", ascending=False)

pd.set_option('display.max_rows', 5000)
print(so5)
# Out:
# pct_tl_nvr_dlq                  pct_tl_nvr_dlq                    1.000000
# tot_coll_amt                    tot_coll_amt                      1.000000
# num_bc_tl                       num_bc_tl                         1.000000
# mths_since_recent_revol_delinq  mths_since_recent_revol_delinq    1.000000
# mort_acc                        mort_acc                          1.000000
# mo_sin_rcnt_tl                  mo_sin_rcnt_tl                    1.000000
# mo_sin_old_rev_tl_op            mo_sin_old_rev_tl_op              1.000000
# mo_sin_old_il_acct              mo_sin_old_il_acct                1.000000
# delinq_amnt                     delinq_amnt                       1.000000
# chargeoff_within_12_mths        chargeoff_within_12_mths          1.000000
# total_cu_tl                     total_cu_tl                       1.000000
# inq_fi                          inq_fi                            1.000000
# il_util                         il_util                           1.000000
# acc_now_delinq                  acc_now_delinq                    1.000000
# num_tl_90g_dpd_24m              num_tl_90g_dpd_24m                1.000000
# dti_joint                       dti_joint                         1.000000
# collections_12_mths_ex_med      collections_12_mths_ex_med        1.000000
# recoveries                      recoveries                        1.000000
# total_rec_late_fee              total_rec_late_fee                1.000000
# revol_bal                       revol_bal                         1.000000
# pub_rec                         pub_rec                           1.000000
# mths_since_last_record          mths_since_last_record            1.000000
# inq_last_6mths                  inq_last_6mths                    1.000000
# dti                             dti                               1.000000
# int_rate                        int_rate                          1.000000
# loan_amnt                       loan_amnt                         1.000000
# num_tl_120dpd_2m                num_tl_120dpd_2m                  1.000000
# mths_since_rcnt_il              mths_since_rcnt_il                1.000000
# id                              id                                1.000000
# mths_since_rcnt_il              mo_sin_rcnt_tl                    0.368634
# mo_sin_rcnt_tl                  mths_since_rcnt_il                0.368634
# num_tl_120dpd_2m                acc_now_delinq                    0.354200
# acc_now_delinq                  num_tl_120dpd_2m                  0.354200
# il_util                         mths_since_rcnt_il                0.339755
# mths_since_rcnt_il              il_util                           0.339755
# loan_amnt                       revol_bal                         0.334656
# revol_bal                       loan_amnt                         0.334656
# mo_sin_old_rev_tl_op            num_bc_tl                         0.318972
# num_bc_tl                       mo_sin_old_rev_tl_op              0.318972
# mort_acc                        mo_sin_old_rev_tl_op              0.291468
# mo_sin_old_rev_tl_op            mort_acc                          0.291468
# int_rate                        dti_joint                         0.287345
# dti_joint                       int_rate                          0.287345
# pct_tl_nvr_dlq                  num_tl_90g_dpd_24m                0.275400
# num_tl_90g_dpd_24m              pct_tl_nvr_dlq                    0.275400
# mths_since_last_record          pub_rec                           0.265775
# pub_rec                         mths_since_last_record            0.265775
# delinq_amnt                     num_tl_120dpd_2m                  0.235801
# num_tl_120dpd_2m                delinq_amnt                       0.235801
# mo_sin_rcnt_tl                  inq_last_6mths                    0.231653
# inq_last_6mths                  mo_sin_rcnt_tl                    0.231653
# loan_amnt                       mort_acc                          0.231574
# mort_acc                        loan_amnt                         0.231574
# inq_last_6mths                  int_rate                          0.231139
# int_rate                        inq_last_6mths                    0.231139
# revol_bal                       mo_sin_old_rev_tl_op              0.229251
# mo_sin_old_rev_tl_op            revol_bal                         0.229251
# revol_bal                       num_bc_tl                         0.226247
# num_bc_tl                       revol_bal                         0.226247
# num_tl_90g_dpd_24m              chargeoff_within_12_mths          0.219341
# chargeoff_within_12_mths        num_tl_90g_dpd_24m                0.219341
# pct_tl_nvr_dlq                  mths_since_last_record            0.217565
# mths_since_last_record          pct_tl_nvr_dlq                    0.217565
# mo_sin_old_il_acct              mo_sin_old_rev_tl_op              0.209846
# mo_sin_old_rev_tl_op            mo_sin_old_il_acct                0.209846
# dti_joint                       revol_bal                         0.209837
# revol_bal                       dti_joint                         0.209837
# inq_last_6mths                  inq_fi                            0.206920
# inq_fi                          inq_last_6mths                    0.206920
# mo_sin_rcnt_tl                  il_util                           0.206114
# il_util                         mo_sin_rcnt_tl                    0.206114
# num_bc_tl                       loan_amnt                         0.203509
# loan_amnt                       num_bc_tl                         0.203509
# revol_bal                       mort_acc                          0.200702
# mort_acc                        revol_bal                         0.200702
# mths_since_rcnt_il              inq_fi                            0.190816
# inq_fi                          mths_since_rcnt_il                0.190816
# mort_acc                        num_bc_tl                         0.188328
# num_bc_tl                       mort_acc                          0.188328
# mort_acc                        mo_sin_old_il_acct                0.185704
# mo_sin_old_il_acct              mort_acc                          0.185704
# loan_amnt                       mo_sin_old_rev_tl_op              0.183754
# mo_sin_old_rev_tl_op            loan_amnt                         0.183754
# int_rate                        il_util                           0.183550
# il_util                         int_rate                          0.183550
# inq_fi                          int_rate                          0.170973
# int_rate                        inq_fi                            0.170973
# mort_acc                        total_cu_tl                       0.169887
# total_cu_tl                     mort_acc                          0.169887
# mo_sin_old_rev_tl_op            int_rate                          0.160134
# int_rate                        mo_sin_old_rev_tl_op              0.160134
# mths_since_last_record          num_bc_tl                         0.157830
# num_bc_tl                       mths_since_last_record            0.157830
# int_rate                        mo_sin_rcnt_tl                    0.150179
# mo_sin_rcnt_tl                  int_rate                          0.150179
# il_util                         inq_fi                            0.145342
# inq_fi                          il_util                           0.145342
# num_tl_90g_dpd_24m              mths_since_recent_revol_delinq    0.141736
# mths_since_recent_revol_delinq  num_tl_90g_dpd_24m                0.141736
# loan_amnt                       int_rate                          0.140572
# int_rate                        loan_amnt                         0.140572
# total_cu_tl                     mths_since_rcnt_il                0.138082
# mths_since_rcnt_il              total_cu_tl                       0.138082
# mo_sin_old_il_acct              loan_amnt                         0.137114
# loan_amnt                       mo_sin_old_il_acct                0.137114
# num_bc_tl                       inq_last_6mths                    0.136091
# inq_last_6mths                  num_bc_tl                         0.136091
# mo_sin_rcnt_tl                  inq_fi                            0.135433
# inq_fi                          mo_sin_rcnt_tl                    0.135433
# mo_sin_rcnt_tl                  num_bc_tl                         0.129605
# num_bc_tl                       mo_sin_rcnt_tl                    0.129605
# int_rate                        mths_since_rcnt_il                0.128435
# mths_since_rcnt_il              int_rate                          0.128435
# pct_tl_nvr_dlq                  revol_bal                         0.128087
# revol_bal                       pct_tl_nvr_dlq                    0.128087
# dti_joint                       pub_rec                           0.127954
# pub_rec                         dti_joint                         0.127954
# acc_now_delinq                  delinq_amnt                       0.127571
# delinq_amnt                     acc_now_delinq                    0.127571
# pub_rec                         mths_since_recent_revol_delinq    0.126948
# mths_since_recent_revol_delinq  pub_rec                           0.126948
# acc_now_delinq                  mths_since_recent_revol_delinq    0.123189
# mths_since_recent_revol_delinq  acc_now_delinq                    0.123189
# mo_sin_old_rev_tl_op            mths_since_last_record            0.121044
# mths_since_last_record          mo_sin_old_rev_tl_op              0.121044
# collections_12_mths_ex_med      num_tl_90g_dpd_24m                0.120101
# num_tl_90g_dpd_24m              collections_12_mths_ex_med        0.120101
# recoveries                      int_rate                          0.119825
# int_rate                        recoveries                        0.119825
#                                 num_bc_tl                         0.115968
# num_bc_tl                       int_rate                          0.115968
# revol_bal                       il_util                           0.115711
# il_util                         revol_bal                         0.115711
# mo_sin_old_il_acct              num_bc_tl                         0.114920
# num_bc_tl                       mo_sin_old_il_acct                0.114920
# mort_acc                        mths_since_last_record            0.108039
# mths_since_last_record          mort_acc                          0.108039
# loan_amnt                       il_util                           0.107324
# il_util                         loan_amnt                         0.107324
# revol_bal                       pub_rec                           0.106714
# pub_rec                         revol_bal                         0.106714
# loan_amnt                       pct_tl_nvr_dlq                    0.105056
# pct_tl_nvr_dlq                  loan_amnt                         0.105056
# total_cu_tl                     dti_joint                         0.103740
# dti_joint                       total_cu_tl                       0.103740
# mo_sin_old_rev_tl_op            il_util                           0.102888
# il_util                         mo_sin_old_rev_tl_op              0.102888
# mo_sin_old_il_acct              pct_tl_nvr_dlq                    0.099719
# pct_tl_nvr_dlq                  mo_sin_old_il_acct                0.099719
# pub_rec                         inq_last_6mths                    0.097382
# inq_last_6mths                  pub_rec                           0.097382
# mo_sin_old_il_acct              total_cu_tl                       0.096620
# total_cu_tl                     mo_sin_old_il_acct                0.096620
# chargeoff_within_12_mths        pct_tl_nvr_dlq                    0.094867
# pct_tl_nvr_dlq                  chargeoff_within_12_mths          0.094867
# mo_sin_old_il_acct              revol_bal                         0.094032
# revol_bal                       mo_sin_old_il_acct                0.094032
# dti_joint                       mo_sin_old_il_acct                0.093306
# mo_sin_old_il_acct              dti_joint                         0.093306
# mo_sin_old_rev_tl_op            pct_tl_nvr_dlq                    0.092974
# pct_tl_nvr_dlq                  mo_sin_old_rev_tl_op              0.092974
# id                              dti_joint                         0.092846
# dti_joint                       id                                0.092846
# inq_fi                          total_cu_tl                       0.092703
# total_cu_tl                     inq_fi                            0.092703
# mths_since_last_record          num_tl_90g_dpd_24m                0.089774
# num_tl_90g_dpd_24m              mths_since_last_record            0.089774
# loan_amnt                       pub_rec                           0.088899
# pub_rec                         loan_amnt                         0.088899
# pct_tl_nvr_dlq                  dti_joint                         0.085603
# dti_joint                       pct_tl_nvr_dlq                    0.085603
# mths_since_recent_revol_delinq  pct_tl_nvr_dlq                    0.085372
# pct_tl_nvr_dlq                  mths_since_recent_revol_delinq    0.085372
# total_cu_tl                     mo_sin_rcnt_tl                    0.085295
# mo_sin_rcnt_tl                  total_cu_tl                       0.085295
# dti                             mths_since_last_record            0.083465
# mths_since_last_record          dti                               0.083465
# int_rate                        mo_sin_old_il_acct                0.080956
# mo_sin_old_il_acct              int_rate                          0.080956
# mo_sin_old_rev_tl_op            mths_since_rcnt_il                0.080442
# mths_since_rcnt_il              mo_sin_old_rev_tl_op              0.080442
# num_tl_90g_dpd_24m              num_tl_120dpd_2m                  0.080164
# num_tl_120dpd_2m                num_tl_90g_dpd_24m                0.080164
# dti_joint                       il_util                           0.079700
# il_util                         dti_joint                         0.079700
# inq_last_6mths                  mths_since_rcnt_il                0.079560
# mths_since_rcnt_il              inq_last_6mths                    0.079560
# int_rate                        dti                               0.077932
# dti                             int_rate                          0.077932
# mths_since_rcnt_il              mo_sin_old_il_acct                0.077925
# mo_sin_old_il_acct              mths_since_rcnt_il                0.077925
# loan_amnt                       recoveries                        0.077870
# recoveries                      loan_amnt                         0.077870
# mths_since_recent_revol_delinq  mo_sin_rcnt_tl                    0.077252
# mo_sin_rcnt_tl                  mths_since_recent_revol_delinq    0.077252
# mort_acc                        int_rate                          0.076131
# int_rate                        mort_acc                          0.076131
# inq_last_6mths                  il_util                           0.075468
# il_util                         inq_last_6mths                    0.075468
# inq_fi                          mort_acc                          0.075278
# mort_acc                        inq_fi                            0.075278
#                                 il_util                           0.073663
# il_util                         mort_acc                          0.073663
# tot_coll_amt                    dti_joint                         0.071590
# dti_joint                       tot_coll_amt                      0.071590
# total_cu_tl                     loan_amnt                         0.071500
# loan_amnt                       total_cu_tl                       0.071500
# dti_joint                       recoveries                        0.070967
# recoveries                      dti_joint                         0.070967
# inq_last_6mths                  mths_since_last_record            0.070857
# mths_since_last_record          inq_last_6mths                    0.070857
# recoveries                      id                                0.070027
# id                              recoveries                        0.070027
# dti_joint                       num_bc_tl                         0.069130
# num_bc_tl                       dti_joint                         0.069130
# mths_since_recent_revol_delinq  tot_coll_amt                      0.069065
# tot_coll_amt                    mths_since_recent_revol_delinq    0.069065
#                                 pct_tl_nvr_dlq                    0.068542
# pct_tl_nvr_dlq                  tot_coll_amt                      0.068542
# total_rec_late_fee              recoveries                        0.065903
# recoveries                      total_rec_late_fee                0.065903
# mths_since_recent_revol_delinq  il_util                           0.065826
# il_util                         mths_since_recent_revol_delinq    0.065826
# mo_sin_rcnt_tl                  pub_rec                           0.065738
# pub_rec                         mo_sin_rcnt_tl                    0.065738
# acc_now_delinq                  num_tl_90g_dpd_24m                0.065097
# num_tl_90g_dpd_24m              acc_now_delinq                    0.065097
# int_rate                        total_rec_late_fee                0.063685
# total_rec_late_fee              int_rate                          0.063685
# il_util                         num_bc_tl                         0.062322
# num_bc_tl                       il_util                           0.062322
# inq_fi                          mo_sin_old_rev_tl_op              0.062211
# mo_sin_old_rev_tl_op            inq_fi                            0.062211
# int_rate                        pct_tl_nvr_dlq                    0.061652
# pct_tl_nvr_dlq                  int_rate                          0.061652
# pub_rec                         inq_fi                            0.060046
# inq_fi                          pub_rec                           0.060046
# pct_tl_nvr_dlq                  pub_rec                           0.059723
# pub_rec                         pct_tl_nvr_dlq                    0.059723
# total_cu_tl                     mo_sin_old_rev_tl_op              0.058459
# mo_sin_old_rev_tl_op            total_cu_tl                       0.058459
# pct_tl_nvr_dlq                  inq_last_6mths                    0.058290
# inq_last_6mths                  pct_tl_nvr_dlq                    0.058290
# int_rate                        pub_rec                           0.058231
# pub_rec                         int_rate                          0.058231
# revol_bal                       int_rate                          0.057412
# int_rate                        revol_bal                         0.057412
# mo_sin_rcnt_tl                  dti_joint                         0.056705
# dti_joint                       mo_sin_rcnt_tl                    0.056705
# total_rec_late_fee              dti_joint                         0.054897
# dti_joint                       total_rec_late_fee                0.054897
# chargeoff_within_12_mths        mths_since_recent_revol_delinq    0.053455
# mths_since_recent_revol_delinq  chargeoff_within_12_mths          0.053455
# int_rate                        id                                0.053402
# id                              int_rate                          0.053402
# mo_sin_old_il_acct              mths_since_last_record            0.053113
# mths_since_last_record          mo_sin_old_il_acct                0.053113
# loan_amnt                       total_rec_late_fee                0.051888
# total_rec_late_fee              loan_amnt                         0.051888
# mths_since_rcnt_il              pct_tl_nvr_dlq                    0.051598
# pct_tl_nvr_dlq                  mths_since_rcnt_il                0.051598
# collections_12_mths_ex_med      acc_now_delinq                    0.051278
# acc_now_delinq                  collections_12_mths_ex_med        0.051278
# pct_tl_nvr_dlq                  collections_12_mths_ex_med        0.051073
# collections_12_mths_ex_med      pct_tl_nvr_dlq                    0.051073
# revol_bal                       mths_since_recent_revol_delinq    0.050308
# mths_since_recent_revol_delinq  revol_bal                         0.050308
# num_tl_90g_dpd_24m              mo_sin_old_il_acct                0.050211
# mo_sin_old_il_acct              num_tl_90g_dpd_24m                0.050211
# mths_since_recent_revol_delinq  loan_amnt                         0.049828
# loan_amnt                       mths_since_recent_revol_delinq    0.049828
# num_tl_90g_dpd_24m              inq_last_6mths                    0.049446
# inq_last_6mths                  num_tl_90g_dpd_24m                0.049446
# mo_sin_old_rev_tl_op            pub_rec                           0.049367
# pub_rec                         mo_sin_old_rev_tl_op              0.049367
# pct_tl_nvr_dlq                  acc_now_delinq                    0.049099
# acc_now_delinq                  pct_tl_nvr_dlq                    0.049099
# mths_since_rcnt_il              dti_joint                         0.049040
# dti_joint                       mths_since_rcnt_il                0.049040
# mort_acc                        mo_sin_rcnt_tl                    0.048839
# mo_sin_rcnt_tl                  mort_acc                          0.048839
# mths_since_last_record          tot_coll_amt                      0.048726
# tot_coll_amt                    mths_since_last_record            0.048726
# mort_acc                        pct_tl_nvr_dlq                    0.048490
# pct_tl_nvr_dlq                  mort_acc                          0.048490
# revol_bal                       dti                               0.048135
# dti                             revol_bal                         0.048135
# revol_bal                       inq_fi                            0.047681
# inq_fi                          revol_bal                         0.047681
# mths_since_recent_revol_delinq  inq_last_6mths                    0.047287
# inq_last_6mths                  mths_since_recent_revol_delinq    0.047287
# tot_coll_amt                    collections_12_mths_ex_med        0.046012
# collections_12_mths_ex_med      tot_coll_amt                      0.046012
# mo_sin_old_rev_tl_op            mo_sin_rcnt_tl                    0.045998
# mo_sin_rcnt_tl                  mo_sin_old_rev_tl_op              0.045998
# pub_rec                         mo_sin_old_il_acct                0.044982
# mo_sin_old_il_acct              pub_rec                           0.044982
# mort_acc                        mths_since_rcnt_il                0.044964
# mths_since_rcnt_il              mort_acc                          0.044964
# mths_since_last_record          chargeoff_within_12_mths          0.043150
# chargeoff_within_12_mths        mths_since_last_record            0.043150
# num_bc_tl                       pct_tl_nvr_dlq                    0.042177
# pct_tl_nvr_dlq                  num_bc_tl                         0.042177
# collections_12_mths_ex_med      chargeoff_within_12_mths          0.042027
# chargeoff_within_12_mths        collections_12_mths_ex_med        0.042027
# pct_tl_nvr_dlq                  dti                               0.042020
# dti                             pct_tl_nvr_dlq                    0.042020
# loan_amnt                       mo_sin_rcnt_tl                    0.041686
# mo_sin_rcnt_tl                  loan_amnt                         0.041686
# revol_bal                       num_tl_90g_dpd_24m                0.040672
# num_tl_90g_dpd_24m              revol_bal                         0.040672
# delinq_amnt                     num_tl_90g_dpd_24m                0.040582
# num_tl_90g_dpd_24m              delinq_amnt                       0.040582
# pct_tl_nvr_dlq                  total_cu_tl                       0.040010
# total_cu_tl                     pct_tl_nvr_dlq                    0.040010
# recoveries                      inq_last_6mths                    0.039129
# inq_last_6mths                  recoveries                        0.039129
# loan_amnt                       inq_last_6mths                    0.039040
# inq_last_6mths                  loan_amnt                         0.039040
# mths_since_recent_revol_delinq  mths_since_last_record            0.038435
# mths_since_last_record          mths_since_recent_revol_delinq    0.038435
#                                 mths_since_rcnt_il                0.038229
# mths_since_rcnt_il              mths_since_last_record            0.038229
# mo_sin_rcnt_tl                  revol_bal                         0.037997
# revol_bal                       mo_sin_rcnt_tl                    0.037997
# chargeoff_within_12_mths        num_tl_120dpd_2m                  0.037937
# num_tl_120dpd_2m                chargeoff_within_12_mths          0.037937
# dti                             mo_sin_rcnt_tl                    0.037806
# mo_sin_rcnt_tl                  dti                               0.037806
# mths_since_recent_revol_delinq  num_bc_tl                         0.037502
# num_bc_tl                       mths_since_recent_revol_delinq    0.037502
# id                              mths_since_last_record            0.037319
# mths_since_last_record          id                                0.037319
# dti                             mths_since_rcnt_il                0.036447
# mths_since_rcnt_il              dti                               0.036447
# mths_since_recent_revol_delinq  num_tl_120dpd_2m                  0.036336
# num_tl_120dpd_2m                mths_since_recent_revol_delinq    0.036336
# num_tl_90g_dpd_24m              mort_acc                          0.036336
# mort_acc                        num_tl_90g_dpd_24m                0.036336
# tot_coll_amt                    pub_rec                           0.035377
# pub_rec                         tot_coll_amt                      0.035377
# mo_sin_old_rev_tl_op            chargeoff_within_12_mths          0.034235
# chargeoff_within_12_mths        mo_sin_old_rev_tl_op              0.034235
# acc_now_delinq                  chargeoff_within_12_mths          0.034094
# chargeoff_within_12_mths        acc_now_delinq                    0.034094
# mths_since_last_record          il_util                           0.033809
# il_util                         mths_since_last_record            0.033809
# mort_acc                        chargeoff_within_12_mths          0.033692
# chargeoff_within_12_mths        mort_acc                          0.033692
# mo_sin_old_rev_tl_op            tot_coll_amt                      0.033676
# tot_coll_amt                    mo_sin_old_rev_tl_op              0.033676
# mo_sin_old_rev_tl_op            num_tl_90g_dpd_24m                0.033258
# num_tl_90g_dpd_24m              mo_sin_old_rev_tl_op              0.033258
# inq_fi                          dti_joint                         0.032828
# dti_joint                       inq_fi                            0.032828
# inq_last_6mths                  total_cu_tl                       0.032530
# total_cu_tl                     inq_last_6mths                    0.032530
# mths_since_rcnt_il              revol_bal                         0.032370
# revol_bal                       mths_since_rcnt_il                0.032370
# num_bc_tl                       chargeoff_within_12_mths          0.032293
# chargeoff_within_12_mths        num_bc_tl                         0.032293
# total_rec_late_fee              mths_since_recent_revol_delinq    0.031637
# mths_since_recent_revol_delinq  total_rec_late_fee                0.031637
# num_tl_90g_dpd_24m              int_rate                          0.031344
# int_rate                        num_tl_90g_dpd_24m                0.031344
# num_tl_90g_dpd_24m              loan_amnt                         0.031334
# loan_amnt                       num_tl_90g_dpd_24m                0.031334
# revol_bal                       tot_coll_amt                      0.030903
# tot_coll_amt                    revol_bal                         0.030903
# mths_since_last_record          inq_fi                            0.030853
# inq_fi                          mths_since_last_record            0.030853
# num_bc_tl                       inq_fi                            0.030827
# inq_fi                          num_bc_tl                         0.030827
# collections_12_mths_ex_med      revol_bal                         0.029719
# revol_bal                       collections_12_mths_ex_med        0.029719
# mo_sin_old_il_acct              il_util                           0.028591
# il_util                         mo_sin_old_il_acct                0.028591
# id                              num_bc_tl                         0.028205
# num_bc_tl                       id                                0.028205
# dti                             num_bc_tl                         0.028171
# num_bc_tl                       dti                               0.028171
# dti_joint                       acc_now_delinq                    0.027877
# acc_now_delinq                  dti_joint                         0.027877
# delinq_amnt                     dti_joint                         0.027877
# dti_joint                       delinq_amnt                       0.027877
# recoveries                      inq_fi                            0.027693
# inq_fi                          recoveries                        0.027693
# acc_now_delinq                  int_rate                          0.027495
# int_rate                        acc_now_delinq                    0.027495
# collections_12_mths_ex_med      loan_amnt                         0.027454
# loan_amnt                       collections_12_mths_ex_med        0.027454
# inq_fi                          pct_tl_nvr_dlq                    0.026616
# pct_tl_nvr_dlq                  inq_fi                            0.026616
# total_rec_late_fee              pct_tl_nvr_dlq                    0.026287
# pct_tl_nvr_dlq                  total_rec_late_fee                0.026287
# collections_12_mths_ex_med      inq_last_6mths                    0.025801
# inq_last_6mths                  collections_12_mths_ex_med        0.025801
# mths_since_recent_revol_delinq  mths_since_rcnt_il                0.025012
# mths_since_rcnt_il              mths_since_recent_revol_delinq    0.025012
# inq_fi                          tot_coll_amt                      0.024884
# tot_coll_amt                    inq_fi                            0.024884
# recoveries                      mo_sin_rcnt_tl                    0.024589
# mo_sin_rcnt_tl                  recoveries                        0.024589
# mo_sin_old_rev_tl_op            acc_now_delinq                    0.024103
# acc_now_delinq                  mo_sin_old_rev_tl_op              0.024103
# revol_bal                       total_cu_tl                       0.023853
# total_cu_tl                     revol_bal                         0.023853
# num_bc_tl                       tot_coll_amt                      0.023352
# tot_coll_amt                    num_bc_tl                         0.023352
# pub_rec                         dti                               0.023200
# dti                             pub_rec                           0.023200
# acc_now_delinq                  mort_acc                          0.022914
# mort_acc                        acc_now_delinq                    0.022914
# num_tl_90g_dpd_24m              il_util                           0.022781
# il_util                         num_tl_90g_dpd_24m                0.022781
# revol_bal                       mths_since_last_record            0.022070
# mths_since_last_record          revol_bal                         0.022070
# total_cu_tl                     mths_since_last_record            0.021990
# mths_since_last_record          total_cu_tl                       0.021990
# mort_acc                        inq_last_6mths                    0.021717
# inq_last_6mths                  mort_acc                          0.021717
# tot_coll_amt                    loan_amnt                         0.021437
# loan_amnt                       tot_coll_amt                      0.021437
# il_util                         pub_rec                           0.021355
# pub_rec                         il_util                           0.021355
# total_rec_late_fee              mths_since_last_record            0.021311
# mths_since_last_record          total_rec_late_fee                0.021311
# dti_joint                       chargeoff_within_12_mths          0.021140
# chargeoff_within_12_mths        dti_joint                         0.021140
# num_tl_120dpd_2m                pct_tl_nvr_dlq                    0.021027
# pct_tl_nvr_dlq                  num_tl_120dpd_2m                  0.021027
# num_bc_tl                       num_tl_90g_dpd_24m                0.020871
# num_tl_90g_dpd_24m              num_bc_tl                         0.020871
# tot_coll_amt                    inq_last_6mths                    0.020749
# inq_last_6mths                  tot_coll_amt                      0.020749
# total_cu_tl                     int_rate                          0.020685
# int_rate                        total_cu_tl                       0.020685
# chargeoff_within_12_mths        inq_last_6mths                    0.020136
# inq_last_6mths                  chargeoff_within_12_mths          0.020136
# dti                             mort_acc                          0.020044
# mort_acc                        dti                               0.020044
# inq_fi                          mths_since_recent_revol_delinq    0.019561
# mths_since_recent_revol_delinq  inq_fi                            0.019561
# chargeoff_within_12_mths        mo_sin_old_il_acct                0.019460
# mo_sin_old_il_acct              chargeoff_within_12_mths          0.019460
# il_util                         tot_coll_amt                      0.019390
# tot_coll_amt                    il_util                           0.019390
# total_rec_late_fee              inq_last_6mths                    0.019330
# inq_last_6mths                  total_rec_late_fee                0.019330
# collections_12_mths_ex_med      int_rate                          0.019234
# int_rate                        collections_12_mths_ex_med        0.019234
# il_util                         chargeoff_within_12_mths          0.019124
# chargeoff_within_12_mths        il_util                           0.019124
# loan_amnt                       dti_joint                         0.018769
# dti_joint                       loan_amnt                         0.018769
# mort_acc                        mths_since_recent_revol_delinq    0.018656
# mths_since_recent_revol_delinq  mort_acc                          0.018656
# mo_sin_old_rev_tl_op            dti                               0.018276
# dti                             mo_sin_old_rev_tl_op              0.018276
# mo_sin_old_il_acct              tot_coll_amt                      0.018129
# tot_coll_amt                    mo_sin_old_il_acct                0.018129
# acc_now_delinq                  total_cu_tl                       0.017527
# total_cu_tl                     acc_now_delinq                    0.017527
# recoveries                      mths_since_rcnt_il                0.017375
# mths_since_rcnt_il              recoveries                        0.017375
# mo_sin_rcnt_tl                  mo_sin_old_il_acct                0.017177
# mo_sin_old_il_acct              mo_sin_rcnt_tl                    0.017177
# collections_12_mths_ex_med      pub_rec                           0.016719
# pub_rec                         collections_12_mths_ex_med        0.016719
# total_rec_late_fee              mths_since_rcnt_il                0.016417
# mths_since_rcnt_il              total_rec_late_fee                0.016417
# dti_joint                       inq_last_6mths                    0.016370
# inq_last_6mths                  dti_joint                         0.016370
# il_util                         delinq_amnt                       0.016289
# delinq_amnt                     il_util                           0.016289
# tot_coll_amt                    mort_acc                          0.016086
# mort_acc                        tot_coll_amt                      0.016086
# pct_tl_nvr_dlq                  delinq_amnt                       0.016077
# delinq_amnt                     pct_tl_nvr_dlq                    0.016077
# dti_joint                       collections_12_mths_ex_med        0.015914
# collections_12_mths_ex_med      dti_joint                         0.015914
# id                              total_rec_late_fee                0.015779
# total_rec_late_fee              id                                0.015779
# mo_sin_old_il_acct              acc_now_delinq                    0.015769
# acc_now_delinq                  mo_sin_old_il_acct                0.015769
# mort_acc                        delinq_amnt                       0.015543
# delinq_amnt                     mort_acc                          0.015543
# mths_since_recent_revol_delinq  dti_joint                         0.015510
# dti_joint                       mths_since_recent_revol_delinq    0.015510
# collections_12_mths_ex_med      mths_since_last_record            0.015383
# mths_since_last_record          collections_12_mths_ex_med        0.015383
# chargeoff_within_12_mths        revol_bal                         0.014793
# revol_bal                       chargeoff_within_12_mths          0.014793
# collections_12_mths_ex_med      total_cu_tl                       0.014588
# total_cu_tl                     collections_12_mths_ex_med        0.014588
# mo_sin_rcnt_tl                  pct_tl_nvr_dlq                    0.014469
# pct_tl_nvr_dlq                  mo_sin_rcnt_tl                    0.014469
# inq_fi                          num_tl_90g_dpd_24m                0.014341
# num_tl_90g_dpd_24m              inq_fi                            0.014341
# mths_since_rcnt_il              pub_rec                           0.014308
# pub_rec                         mths_since_rcnt_il                0.014308
# acc_now_delinq                  total_rec_late_fee                0.014186
# total_rec_late_fee              acc_now_delinq                    0.014186
# mths_since_last_record          loan_amnt                         0.014108
# loan_amnt                       mths_since_last_record            0.014108
# inq_last_6mths                  mo_sin_old_il_acct                0.014022
# mo_sin_old_il_acct              inq_last_6mths                    0.014022
# mo_sin_old_rev_tl_op            recoveries                        0.014001
# recoveries                      mo_sin_old_rev_tl_op              0.014001
# pct_tl_nvr_dlq                  il_util                           0.013843
# il_util                         pct_tl_nvr_dlq                    0.013843
# mths_since_recent_revol_delinq  int_rate                          0.013657
# int_rate                        mths_since_recent_revol_delinq    0.013657
# inq_fi                          id                                0.013579
# id                              inq_fi                            0.013579
# total_rec_late_fee              total_cu_tl                       0.013268
# total_cu_tl                     total_rec_late_fee                0.013268
# chargeoff_within_12_mths        tot_coll_amt                      0.013216
# tot_coll_amt                    chargeoff_within_12_mths          0.013216
# id                              mort_acc                          0.013036
# mort_acc                        id                                0.013036
# mths_since_recent_revol_delinq  mo_sin_old_rev_tl_op              0.012916
# mo_sin_old_rev_tl_op            mths_since_recent_revol_delinq    0.012916
# mo_sin_old_il_acct              dti                               0.012866
# dti                             mo_sin_old_il_acct                0.012866
# mths_since_last_record          acc_now_delinq                    0.012845
# acc_now_delinq                  mths_since_last_record            0.012845
# num_tl_120dpd_2m                inq_fi                            0.012796
# inq_fi                          num_tl_120dpd_2m                  0.012796
# tot_coll_amt                    mo_sin_rcnt_tl                    0.012672
# mo_sin_rcnt_tl                  tot_coll_amt                      0.012672
# revol_bal                       inq_last_6mths                    0.012303
# inq_last_6mths                  revol_bal                         0.012303
# total_cu_tl                     recoveries                        0.012112
# recoveries                      total_cu_tl                       0.012112
# num_tl_90g_dpd_24m              pub_rec                           0.011977
# pub_rec                         num_tl_90g_dpd_24m                0.011977
# collections_12_mths_ex_med      id                                0.011953
# id                              collections_12_mths_ex_med        0.011953
# int_rate                        chargeoff_within_12_mths          0.011913
# chargeoff_within_12_mths        int_rate                          0.011913
# dti                             total_cu_tl                       0.011851
# total_cu_tl                     dti                               0.011851
# recoveries                      num_bc_tl                         0.011549
# num_bc_tl                       recoveries                        0.011549
# mort_acc                        num_tl_120dpd_2m                  0.011498
# num_tl_120dpd_2m                mort_acc                          0.011498
# total_rec_late_fee              num_bc_tl                         0.011243
# num_bc_tl                       total_rec_late_fee                0.011243
#                                 pub_rec                           0.011189
# pub_rec                         num_bc_tl                         0.011189
# num_bc_tl                       collections_12_mths_ex_med        0.011185
# collections_12_mths_ex_med      num_bc_tl                         0.011185
# inq_fi                          dti                               0.011065
# dti                             inq_fi                            0.011065
# mths_since_rcnt_il              loan_amnt                         0.010985
# loan_amnt                       mths_since_rcnt_il                0.010985
# mths_since_rcnt_il              num_bc_tl                         0.010854
# num_bc_tl                       mths_since_rcnt_il                0.010854
# collections_12_mths_ex_med      mo_sin_rcnt_tl                    0.010853
# mo_sin_rcnt_tl                  collections_12_mths_ex_med        0.010853
# total_rec_late_fee              inq_fi                            0.010681
# inq_fi                          total_rec_late_fee                0.010681
#                                 collections_12_mths_ex_med        0.010622
# collections_12_mths_ex_med      inq_fi                            0.010622
# id                              pct_tl_nvr_dlq                    0.010366
# pct_tl_nvr_dlq                  id                                0.010366
# recoveries                      il_util                           0.010266
# il_util                         recoveries                        0.010266
# num_bc_tl                       acc_now_delinq                    0.010240
# acc_now_delinq                  num_bc_tl                         0.010240
# collections_12_mths_ex_med      mo_sin_old_il_acct                0.010227
# mo_sin_old_il_acct              collections_12_mths_ex_med        0.010227
# mort_acc                        collections_12_mths_ex_med        0.010133
# collections_12_mths_ex_med      mort_acc                          0.010133
# int_rate                        num_tl_120dpd_2m                  0.010100
# num_tl_120dpd_2m                int_rate                          0.010100
# collections_12_mths_ex_med      mths_since_recent_revol_delinq    0.010015
# mths_since_recent_revol_delinq  collections_12_mths_ex_med        0.010015
# num_tl_120dpd_2m                mths_since_rcnt_il                0.009793
# mths_since_rcnt_il              num_tl_120dpd_2m                  0.009793
# mo_sin_rcnt_tl                  total_rec_late_fee                0.009785
# total_rec_late_fee              mo_sin_rcnt_tl                    0.009785
# int_rate                        tot_coll_amt                      0.009697
# tot_coll_amt                    int_rate                          0.009697
# total_rec_late_fee              revol_bal                         0.009657
# revol_bal                       total_rec_late_fee                0.009657
# int_rate                        delinq_amnt                       0.009647
# delinq_amnt                     int_rate                          0.009647
#                                 mths_since_rcnt_il                0.009642
# mths_since_rcnt_il              delinq_amnt                       0.009642
# total_cu_tl                     il_util                           0.009640
# il_util                         total_cu_tl                       0.009640
# loan_amnt                       inq_fi                            0.009638
# inq_fi                          loan_amnt                         0.009638
# dti_joint                       mths_since_last_record            0.009629
# mths_since_last_record          dti_joint                         0.009629
# il_util                         id                                0.009614
# id                              il_util                           0.009614
# dti                             recoveries                        0.009553
# recoveries                      dti                               0.009553
# total_rec_late_fee              num_tl_90g_dpd_24m                0.009493
# num_tl_90g_dpd_24m              total_rec_late_fee                0.009493
# int_rate                        mths_since_last_record            0.009398
# mths_since_last_record          int_rate                          0.009398
# num_tl_120dpd_2m                mths_since_last_record            0.009131
# mths_since_last_record          num_tl_120dpd_2m                  0.009131
# il_util                         acc_now_delinq                    0.008960
# acc_now_delinq                  il_util                           0.008960
# mths_since_rcnt_il              collections_12_mths_ex_med        0.008475
# collections_12_mths_ex_med      mths_since_rcnt_il                0.008475
# delinq_amnt                     inq_last_6mths                    0.008457
# inq_last_6mths                  delinq_amnt                       0.008457
# revol_bal                       recoveries                        0.008373
# recoveries                      revol_bal                         0.008373
# id                              loan_amnt                         0.008288
# loan_amnt                       id                                0.008288
# num_tl_90g_dpd_24m              mths_since_rcnt_il                0.008253
# mths_since_rcnt_il              num_tl_90g_dpd_24m                0.008253
#                                 chargeoff_within_12_mths          0.008249
# chargeoff_within_12_mths        mths_since_rcnt_il                0.008249
# delinq_amnt                     collections_12_mths_ex_med        0.008177
# collections_12_mths_ex_med      delinq_amnt                       0.008177
# recoveries                      pct_tl_nvr_dlq                    0.007896
# pct_tl_nvr_dlq                  recoveries                        0.007896
# dti                             tot_coll_amt                      0.007619
# tot_coll_amt                    dti                               0.007619
# mort_acc                        pub_rec                           0.007400
# pub_rec                         mort_acc                          0.007400
# mo_sin_old_rev_tl_op            total_rec_late_fee                0.007191
# total_rec_late_fee              mo_sin_old_rev_tl_op              0.007191
# delinq_amnt                     chargeoff_within_12_mths          0.007182
# chargeoff_within_12_mths        delinq_amnt                       0.007182
# mo_sin_old_il_acct              recoveries                        0.007012
# recoveries                      mo_sin_old_il_acct                0.007012
# mths_since_rcnt_il              acc_now_delinq                    0.006952
# acc_now_delinq                  mths_since_rcnt_il                0.006952
# mo_sin_old_rev_tl_op            delinq_amnt                       0.006876
# delinq_amnt                     mo_sin_old_rev_tl_op              0.006876
# num_tl_90g_dpd_24m              tot_coll_amt                      0.006871
# ...
# recoveries                      collections_12_mths_ex_med        0.004269
# collections_12_mths_ex_med      recoveries                        0.004269
# dti                             il_util                           0.004219
# il_util                         dti                               0.004219
# chargeoff_within_12_mths        total_rec_late_fee                0.004216
# total_rec_late_fee              chargeoff_within_12_mths          0.004216
# inq_fi                          acc_now_delinq                    0.004188
# acc_now_delinq                  inq_fi                            0.004188
# total_rec_late_fee              collections_12_mths_ex_med        0.004134
# collections_12_mths_ex_med      total_rec_late_fee                0.004134
# acc_now_delinq                  recoveries                        0.004052
# recoveries                      acc_now_delinq                    0.004052
# mths_since_last_record          recoveries                        0.004039
# recoveries                      mths_since_last_record            0.004039
# chargeoff_within_12_mths        inq_fi                            0.003950
# inq_fi                          chargeoff_within_12_mths          0.003950
# mths_since_recent_revol_delinq  mo_sin_old_il_acct                0.003847
# mo_sin_old_il_acct              mths_since_recent_revol_delinq    0.003847
# inq_fi                          delinq_amnt                       0.003818
# delinq_amnt                     inq_fi                            0.003818
# id                              revol_bal                         0.003774
# revol_bal                       id                                0.003774
# mo_sin_old_il_acct              delinq_amnt                       0.003759
# delinq_amnt                     mo_sin_old_il_acct                0.003759
# dti_joint                       mort_acc                          0.003638
# mort_acc                        dti_joint                         0.003638
# dti                             collections_12_mths_ex_med        0.003588
# collections_12_mths_ex_med      dti                               0.003588
# id                              pub_rec                           0.003501
# pub_rec                         id                                0.003501
# mths_since_last_record          delinq_amnt                       0.003392
# delinq_amnt                     mths_since_last_record            0.003392
# mths_since_recent_revol_delinq  dti                               0.003353
# dti                             mths_since_recent_revol_delinq    0.003353
# total_cu_tl                     pub_rec                           0.003349
# pub_rec                         total_cu_tl                       0.003349
# mo_sin_rcnt_tl                  num_tl_120dpd_2m                  0.003288
# num_tl_120dpd_2m                mo_sin_rcnt_tl                    0.003288
# dti                             inq_last_6mths                    0.003277
# inq_last_6mths                  dti                               0.003277
# pub_rec                         delinq_amnt                       0.003200
# delinq_amnt                     pub_rec                           0.003200
# mo_sin_old_rev_tl_op            inq_last_6mths                    0.003108
# inq_last_6mths                  mo_sin_old_rev_tl_op              0.003108
# acc_now_delinq                  revol_bal                         0.003011
# revol_bal                       acc_now_delinq                    0.003011
# chargeoff_within_12_mths        recoveries                        0.002795
# recoveries                      chargeoff_within_12_mths          0.002795
# num_tl_120dpd_2m                recoveries                        0.002738
# recoveries                      num_tl_120dpd_2m                  0.002738
# dti                             delinq_amnt                       0.002667
# delinq_amnt                     dti                               0.002667
# mort_acc                        recoveries                        0.002563
# recoveries                      mort_acc                          0.002563
# pub_rec                         acc_now_delinq                    0.002458
# acc_now_delinq                  pub_rec                           0.002458
# mths_since_rcnt_il              tot_coll_amt                      0.002451
# tot_coll_amt                    mths_since_rcnt_il                0.002451
# total_cu_tl                     num_bc_tl                         0.002413
# num_bc_tl                       total_cu_tl                       0.002413
# mo_sin_old_il_acct              total_rec_late_fee                0.002383
# total_rec_late_fee              mo_sin_old_il_acct                0.002383
# dti                             chargeoff_within_12_mths          0.002340
# chargeoff_within_12_mths        dti                               0.002340
# id                              tot_coll_amt                      0.002312
# tot_coll_amt                    id                                0.002312
# id                              mths_since_rcnt_il                0.002310
# mths_since_rcnt_il              id                                0.002310
# num_tl_120dpd_2m                dti                               0.002251
# dti                             num_tl_120dpd_2m                  0.002251
# delinq_amnt                     mo_sin_rcnt_tl                    0.002235
# mo_sin_rcnt_tl                  delinq_amnt                       0.002235
# il_util                         collections_12_mths_ex_med        0.002178
# collections_12_mths_ex_med      il_util                           0.002178
# delinq_amnt                     tot_coll_amt                      0.002142
# tot_coll_amt                    delinq_amnt                       0.002142
# loan_amnt                       delinq_amnt                       0.002096
# delinq_amnt                     loan_amnt                         0.002096
# mths_since_last_record          mo_sin_rcnt_tl                    0.002069
# mo_sin_rcnt_tl                  mths_since_last_record            0.002069
# recoveries                      mths_since_recent_revol_delinq    0.002057
# mths_since_recent_revol_delinq  recoveries                        0.002057
# total_cu_tl                     num_tl_120dpd_2m                  0.002029
# num_tl_120dpd_2m                total_cu_tl                       0.002029
# pub_rec                         chargeoff_within_12_mths          0.001974
# chargeoff_within_12_mths        pub_rec                           0.001974
# delinq_amnt                     id                                0.001961
# id                              delinq_amnt                       0.001961
# pub_rec                         recoveries                        0.001952
# recoveries                      pub_rec                           0.001952
# delinq_amnt                     num_bc_tl                         0.001911
# num_bc_tl                       delinq_amnt                       0.001911
# inq_last_6mths                  num_tl_120dpd_2m                  0.001884
# num_tl_120dpd_2m                inq_last_6mths                    0.001884
# acc_now_delinq                  tot_coll_amt                      0.001841
# tot_coll_amt                    acc_now_delinq                    0.001841
# il_util                         num_tl_120dpd_2m                  0.001763
# num_tl_120dpd_2m                il_util                           0.001763
# num_tl_90g_dpd_24m              recoveries                        0.001556
# recoveries                      num_tl_90g_dpd_24m                0.001556
# dti_joint                       num_tl_90g_dpd_24m                0.001323
# num_tl_90g_dpd_24m              dti_joint                         0.001323
# mths_since_recent_revol_delinq  id                                0.001272
# id                              mths_since_recent_revol_delinq    0.001272
# dti                             total_rec_late_fee                0.001150
# total_rec_late_fee              dti                               0.001150
# revol_bal                       delinq_amnt                       0.001126
# delinq_amnt                     revol_bal                         0.001126
#                                 recoveries                        0.001075
# recoveries                      delinq_amnt                       0.001075
# id                              chargeoff_within_12_mths          0.001075
# chargeoff_within_12_mths        id                                0.001075
# pub_rec                         num_tl_120dpd_2m                  0.001069
# num_tl_120dpd_2m                pub_rec                           0.001069
# mths_since_recent_revol_delinq  delinq_amnt                       0.001022
# delinq_amnt                     mths_since_recent_revol_delinq    0.001022
# total_cu_tl                     id                                0.000914
# id                              total_cu_tl                       0.000914
# loan_amnt                       num_tl_120dpd_2m                  0.000905
# num_tl_120dpd_2m                loan_amnt                         0.000905
# collections_12_mths_ex_med      num_tl_120dpd_2m                  0.000860
# num_tl_120dpd_2m                collections_12_mths_ex_med        0.000860
# total_cu_tl                     mths_since_recent_revol_delinq    0.000860
# mths_since_recent_revol_delinq  total_cu_tl                       0.000860
# delinq_amnt                     total_rec_late_fee                0.000787
# total_rec_late_fee              delinq_amnt                       0.000787
# id                              inq_last_6mths                    0.000660
# inq_last_6mths                  id                                0.000660
# loan_amnt                       acc_now_delinq                    0.000645
# acc_now_delinq                  loan_amnt                         0.000645
# id                              num_tl_90g_dpd_24m                0.000612
# num_tl_90g_dpd_24m              id                                0.000612
# acc_now_delinq                  dti                               0.000583
# dti                             acc_now_delinq                    0.000583
# inq_last_6mths                  acc_now_delinq                    0.000563
# acc_now_delinq                  inq_last_6mths                    0.000563
# chargeoff_within_12_mths        total_cu_tl                       0.000372
# total_cu_tl                     chargeoff_within_12_mths          0.000372
# recoveries                      tot_coll_amt                      0.000342
# tot_coll_amt                    recoveries                        0.000342
# total_rec_late_fee              tot_coll_amt                      0.000320
# tot_coll_amt                    total_rec_late_fee                0.000320
# total_rec_late_fee              mort_acc                          0.000210
# mort_acc                        total_rec_late_fee                0.000210
# total_rec_late_fee              pub_rec                           0.000146
# pub_rec                         total_rec_late_fee                0.000146
# total_rec_late_fee              num_tl_120dpd_2m                  0.000098
# num_tl_120dpd_2m                total_rec_late_fee                0.000098
# mo_sin_rcnt_tl                  acc_now_delinq                    0.000093
# acc_now_delinq                  mo_sin_rcnt_tl                    0.000093
# id                              mo_sin_old_il_acct                0.000088
# mo_sin_old_il_acct              id                                0.000088
# id                              policy_code                            NaN
# loan_amnt                       policy_code                            NaN
# int_rate                        policy_code                            NaN
# dti                             policy_code                            NaN
# inq_last_6mths                  policy_code                            NaN
# mths_since_last_record          policy_code                            NaN
# pub_rec                         policy_code                            NaN
# revol_bal                       policy_code                            NaN
# total_rec_late_fee              policy_code                            NaN
# recoveries                      policy_code                            NaN
# collections_12_mths_ex_med      policy_code                            NaN
# policy_code                     id                                     NaN
#                                 loan_amnt                              NaN
#                                 int_rate                               NaN
#                                 dti                                    NaN
#                                 inq_last_6mths                         NaN
#                                 mths_since_last_record                 NaN
#                                 pub_rec                                NaN
#                                 revol_bal                              NaN
#                                 total_rec_late_fee                     NaN
#                                 recoveries                             NaN
#                                 collections_12_mths_ex_med             NaN
#                                 policy_code                            NaN
#                                 dti_joint                              NaN
#                                 acc_now_delinq                         NaN
#                                 tot_coll_amt                           NaN
#                                 mths_since_rcnt_il                     NaN
#                                 il_util                                NaN
#                                 inq_fi                                 NaN
#                                 total_cu_tl                            NaN
#                                 chargeoff_within_12_mths               NaN
#                                 delinq_amnt                            NaN
#                                 mo_sin_old_il_acct                     NaN
#                                 mo_sin_old_rev_tl_op                   NaN
#                                 mo_sin_rcnt_tl                         NaN
#                                 mort_acc                               NaN
#                                 mths_since_recent_revol_delinq         NaN
#                                 num_bc_tl                              NaN
#                                 num_tl_120dpd_2m                       NaN
#                                 num_tl_90g_dpd_24m                     NaN
#                                 pct_tl_nvr_dlq                         NaN
# dti_joint                       policy_code                            NaN
#                                 num_tl_120dpd_2m                       NaN
# acc_now_delinq                  policy_code                            NaN
# tot_coll_amt                    policy_code                            NaN
# mths_since_rcnt_il              policy_code                            NaN
# il_util                         policy_code                            NaN
# inq_fi                          policy_code                            NaN
# total_cu_tl                     policy_code                            NaN
# chargeoff_within_12_mths        policy_code                            NaN
# delinq_amnt                     policy_code                            NaN
# mo_sin_old_il_acct              policy_code                            NaN
# mo_sin_old_rev_tl_op            policy_code                            NaN
# mo_sin_rcnt_tl                  policy_code                            NaN
# mort_acc                        policy_code                            NaN
# mths_since_recent_revol_delinq  policy_code                            NaN
# num_bc_tl                       policy_code                            NaN
# num_tl_120dpd_2m                policy_code                            NaN
#                                 dti_joint                              NaN
# num_tl_90g_dpd_24m              policy_code                            NaN
# pct_tl_nvr_dlq                  policy_code                            NaN
# dtype: float64

# %%
y2015 = y2015.drop(columns = ['mths_since_rcnt_il', 'acc_now_delinq', 'mths_since_rcnt_il', 'revol_bal',\
                              'mo_sin_old_rev_tl_op'])

# %%
## Run Random Forest with cleaned data
rfc4 = ensemble.RandomForestClassifier()
X4 = y2015.drop('loan_status', 1)
Y4 = y2015['loan_status']
X4 = pd.get_dummies(X4)
X4 = X4.dropna(axis=1)

cross_val_score(rfc4, X4, Y4, cv=10)
# Out:
# c:\users\nstow\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# c:\users\nstow\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# c:\users\nstow\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# c:\users\nstow\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# c:\users\nstow\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# c:\users\nstow\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# c:\users\nstow\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# c:\users\nstow\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# c:\users\nstow\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# c:\users\nstow\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# array([0.92059082, 0.93574126, 0.91598395, 0.92099451, 0.91840418,
#        0.92429352, 0.90477095, 0.93825548, 0.92549932, 0.88077709])

# %%
## recreate sorted correlation matrix
c6 = y2015.corr().abs()

s6 = c6.unstack()
so6 = s6.sort_values(kind="quicksort", ascending=False)

print(so6)
# Out:
# pct_tl_nvr_dlq                  pct_tl_nvr_dlq                    1.000000
# tot_coll_amt                    tot_coll_amt                      1.000000
# num_bc_tl                       num_bc_tl                         1.000000
# mths_since_recent_revol_delinq  mths_since_recent_revol_delinq    1.000000
# mort_acc                        mort_acc                          1.000000
# mo_sin_rcnt_tl                  mo_sin_rcnt_tl                    1.000000
# mo_sin_old_il_acct              mo_sin_old_il_acct                1.000000
# delinq_amnt                     delinq_amnt                       1.000000
# chargeoff_within_12_mths        chargeoff_within_12_mths          1.000000
# total_cu_tl                     total_cu_tl                       1.000000
# inq_fi                          inq_fi                            1.000000
# dti_joint                       dti_joint                         1.000000
# num_tl_90g_dpd_24m              num_tl_90g_dpd_24m                1.000000
# collections_12_mths_ex_med      collections_12_mths_ex_med        1.000000
# recoveries                      recoveries                        1.000000
# total_rec_late_fee              total_rec_late_fee                1.000000
# pub_rec                         pub_rec                           1.000000
# mths_since_last_record          mths_since_last_record            1.000000
# inq_last_6mths                  inq_last_6mths                    1.000000
# dti                             dti                               1.000000
# int_rate                        int_rate                          1.000000
# loan_amnt                       loan_amnt                         1.000000
# num_tl_120dpd_2m                num_tl_120dpd_2m                  1.000000
# il_util                         il_util                           1.000000
# id                              id                                1.000000
# int_rate                        dti_joint                         0.287345
# dti_joint                       int_rate                          0.287345
# num_tl_90g_dpd_24m              pct_tl_nvr_dlq                    0.275400
# pct_tl_nvr_dlq                  num_tl_90g_dpd_24m                0.275400
# mths_since_last_record          pub_rec                           0.265775
# pub_rec                         mths_since_last_record            0.265775
# delinq_amnt                     num_tl_120dpd_2m                  0.235801
# num_tl_120dpd_2m                delinq_amnt                       0.235801
# mo_sin_rcnt_tl                  inq_last_6mths                    0.231653
# inq_last_6mths                  mo_sin_rcnt_tl                    0.231653
# mort_acc                        loan_amnt                         0.231574
# loan_amnt                       mort_acc                          0.231574
# inq_last_6mths                  int_rate                          0.231139
# int_rate                        inq_last_6mths                    0.231139
# chargeoff_within_12_mths        num_tl_90g_dpd_24m                0.219341
# num_tl_90g_dpd_24m              chargeoff_within_12_mths          0.219341
# pct_tl_nvr_dlq                  mths_since_last_record            0.217565
# mths_since_last_record          pct_tl_nvr_dlq                    0.217565
# inq_fi                          inq_last_6mths                    0.206920
# inq_last_6mths                  inq_fi                            0.206920
# il_util                         mo_sin_rcnt_tl                    0.206114
# mo_sin_rcnt_tl                  il_util                           0.206114
# loan_amnt                       num_bc_tl                         0.203509
# num_bc_tl                       loan_amnt                         0.203509
# mort_acc                        num_bc_tl                         0.188328
# num_bc_tl                       mort_acc                          0.188328
# mort_acc                        mo_sin_old_il_acct                0.185704
# mo_sin_old_il_acct              mort_acc                          0.185704
# int_rate                        il_util                           0.183550
# il_util                         int_rate                          0.183550
# inq_fi                          int_rate                          0.170973
# int_rate                        inq_fi                            0.170973
# mort_acc                        total_cu_tl                       0.169887
# total_cu_tl                     mort_acc                          0.169887
# num_bc_tl                       mths_since_last_record            0.157830
# mths_since_last_record          num_bc_tl                         0.157830
# mo_sin_rcnt_tl                  int_rate                          0.150179
# int_rate                        mo_sin_rcnt_tl                    0.150179
# inq_fi                          il_util                           0.145342
# il_util                         inq_fi                            0.145342
# num_tl_90g_dpd_24m              mths_since_recent_revol_delinq    0.141736
# mths_since_recent_revol_delinq  num_tl_90g_dpd_24m                0.141736
# int_rate                        loan_amnt                         0.140572
# loan_amnt                       int_rate                          0.140572
#                                 mo_sin_old_il_acct                0.137114
# mo_sin_old_il_acct              loan_amnt                         0.137114
# inq_last_6mths                  num_bc_tl                         0.136091
# num_bc_tl                       inq_last_6mths                    0.136091
# inq_fi                          mo_sin_rcnt_tl                    0.135433
# mo_sin_rcnt_tl                  inq_fi                            0.135433
#                                 num_bc_tl                         0.129605
# num_bc_tl                       mo_sin_rcnt_tl                    0.129605
# dti_joint                       pub_rec                           0.127954
# pub_rec                         dti_joint                         0.127954
# mths_since_recent_revol_delinq  pub_rec                           0.126948
# pub_rec                         mths_since_recent_revol_delinq    0.126948
# num_tl_90g_dpd_24m              collections_12_mths_ex_med        0.120101
# collections_12_mths_ex_med      num_tl_90g_dpd_24m                0.120101
# recoveries                      int_rate                          0.119825
# int_rate                        recoveries                        0.119825
# num_bc_tl                       int_rate                          0.115968
# int_rate                        num_bc_tl                         0.115968
# num_bc_tl                       mo_sin_old_il_acct                0.114920
# mo_sin_old_il_acct              num_bc_tl                         0.114920
# mths_since_last_record          mort_acc                          0.108039
# mort_acc                        mths_since_last_record            0.108039
# loan_amnt                       il_util                           0.107324
# il_util                         loan_amnt                         0.107324
# loan_amnt                       pct_tl_nvr_dlq                    0.105056
# pct_tl_nvr_dlq                  loan_amnt                         0.105056
# dti_joint                       total_cu_tl                       0.103740
# total_cu_tl                     dti_joint                         0.103740
# mo_sin_old_il_acct              pct_tl_nvr_dlq                    0.099719
# pct_tl_nvr_dlq                  mo_sin_old_il_acct                0.099719
# inq_last_6mths                  pub_rec                           0.097382
# pub_rec                         inq_last_6mths                    0.097382
# mo_sin_old_il_acct              total_cu_tl                       0.096620
# total_cu_tl                     mo_sin_old_il_acct                0.096620
# pct_tl_nvr_dlq                  chargeoff_within_12_mths          0.094867
# chargeoff_within_12_mths        pct_tl_nvr_dlq                    0.094867
# mo_sin_old_il_acct              dti_joint                         0.093306
# dti_joint                       mo_sin_old_il_acct                0.093306
#                                 id                                0.092846
# id                              dti_joint                         0.092846
# total_cu_tl                     inq_fi                            0.092703
# inq_fi                          total_cu_tl                       0.092703
# num_tl_90g_dpd_24m              mths_since_last_record            0.089774
# mths_since_last_record          num_tl_90g_dpd_24m                0.089774
# pub_rec                         loan_amnt                         0.088899
# loan_amnt                       pub_rec                           0.088899
# pct_tl_nvr_dlq                  dti_joint                         0.085603
# dti_joint                       pct_tl_nvr_dlq                    0.085603
# mths_since_recent_revol_delinq  pct_tl_nvr_dlq                    0.085372
# pct_tl_nvr_dlq                  mths_since_recent_revol_delinq    0.085372
# mo_sin_rcnt_tl                  total_cu_tl                       0.085295
# total_cu_tl                     mo_sin_rcnt_tl                    0.085295
# mths_since_last_record          dti                               0.083465
# dti                             mths_since_last_record            0.083465
# mo_sin_old_il_acct              int_rate                          0.080956
# int_rate                        mo_sin_old_il_acct                0.080956
# num_tl_90g_dpd_24m              num_tl_120dpd_2m                  0.080164
# num_tl_120dpd_2m                num_tl_90g_dpd_24m                0.080164
# il_util                         dti_joint                         0.079700
# dti_joint                       il_util                           0.079700
# int_rate                        dti                               0.077932
# dti                             int_rate                          0.077932
# loan_amnt                       recoveries                        0.077870
# recoveries                      loan_amnt                         0.077870
# mo_sin_rcnt_tl                  mths_since_recent_revol_delinq    0.077252
# mths_since_recent_revol_delinq  mo_sin_rcnt_tl                    0.077252
# mort_acc                        int_rate                          0.076131
# int_rate                        mort_acc                          0.076131
# inq_last_6mths                  il_util                           0.075468
# il_util                         inq_last_6mths                    0.075468
# inq_fi                          mort_acc                          0.075278
# mort_acc                        inq_fi                            0.075278
# il_util                         mort_acc                          0.073663
# mort_acc                        il_util                           0.073663
# tot_coll_amt                    dti_joint                         0.071590
# dti_joint                       tot_coll_amt                      0.071590
# total_cu_tl                     loan_amnt                         0.071500
# loan_amnt                       total_cu_tl                       0.071500
# dti_joint                       recoveries                        0.070967
# recoveries                      dti_joint                         0.070967
# mths_since_last_record          inq_last_6mths                    0.070857
# inq_last_6mths                  mths_since_last_record            0.070857
# id                              recoveries                        0.070027
# recoveries                      id                                0.070027
# num_bc_tl                       dti_joint                         0.069130
# dti_joint                       num_bc_tl                         0.069130
# tot_coll_amt                    mths_since_recent_revol_delinq    0.069065
# mths_since_recent_revol_delinq  tot_coll_amt                      0.069065
# tot_coll_amt                    pct_tl_nvr_dlq                    0.068542
# pct_tl_nvr_dlq                  tot_coll_amt                      0.068542
# total_rec_late_fee              recoveries                        0.065903
# recoveries                      total_rec_late_fee                0.065903
# mths_since_recent_revol_delinq  il_util                           0.065826
# il_util                         mths_since_recent_revol_delinq    0.065826
# mo_sin_rcnt_tl                  pub_rec                           0.065738
# pub_rec                         mo_sin_rcnt_tl                    0.065738
# total_rec_late_fee              int_rate                          0.063685
# int_rate                        total_rec_late_fee                0.063685
# il_util                         num_bc_tl                         0.062322
# num_bc_tl                       il_util                           0.062322
# int_rate                        pct_tl_nvr_dlq                    0.061652
# pct_tl_nvr_dlq                  int_rate                          0.061652
# inq_fi                          pub_rec                           0.060046
# pub_rec                         inq_fi                            0.060046
# pct_tl_nvr_dlq                  pub_rec                           0.059723
# pub_rec                         pct_tl_nvr_dlq                    0.059723
# inq_last_6mths                  pct_tl_nvr_dlq                    0.058290
# pct_tl_nvr_dlq                  inq_last_6mths                    0.058290
# int_rate                        pub_rec                           0.058231
# pub_rec                         int_rate                          0.058231
# mo_sin_rcnt_tl                  dti_joint                         0.056705
# dti_joint                       mo_sin_rcnt_tl                    0.056705
# total_rec_late_fee              dti_joint                         0.054897
# dti_joint                       total_rec_late_fee                0.054897
# mths_since_recent_revol_delinq  chargeoff_within_12_mths          0.053455
# chargeoff_within_12_mths        mths_since_recent_revol_delinq    0.053455
# int_rate                        id                                0.053402
# id                              int_rate                          0.053402
# mo_sin_old_il_acct              mths_since_last_record            0.053113
# mths_since_last_record          mo_sin_old_il_acct                0.053113
# loan_amnt                       total_rec_late_fee                0.051888
# total_rec_late_fee              loan_amnt                         0.051888
# collections_12_mths_ex_med      pct_tl_nvr_dlq                    0.051073
# pct_tl_nvr_dlq                  collections_12_mths_ex_med        0.051073
# mo_sin_old_il_acct              num_tl_90g_dpd_24m                0.050211
# num_tl_90g_dpd_24m              mo_sin_old_il_acct                0.050211
# loan_amnt                       mths_since_recent_revol_delinq    0.049828
# mths_since_recent_revol_delinq  loan_amnt                         0.049828
# num_tl_90g_dpd_24m              inq_last_6mths                    0.049446
# inq_last_6mths                  num_tl_90g_dpd_24m                0.049446
# mort_acc                        mo_sin_rcnt_tl                    0.048839
# mo_sin_rcnt_tl                  mort_acc                          0.048839
# tot_coll_amt                    mths_since_last_record            0.048726
# mths_since_last_record          tot_coll_amt                      0.048726
# mort_acc                        pct_tl_nvr_dlq                    0.048490
# pct_tl_nvr_dlq                  mort_acc                          0.048490
# inq_last_6mths                  mths_since_recent_revol_delinq    0.047287
# mths_since_recent_revol_delinq  inq_last_6mths                    0.047287
# tot_coll_amt                    collections_12_mths_ex_med        0.046012
# collections_12_mths_ex_med      tot_coll_amt                      0.046012
# mo_sin_old_il_acct              pub_rec                           0.044982
# pub_rec                         mo_sin_old_il_acct                0.044982
# chargeoff_within_12_mths        mths_since_last_record            0.043150
# mths_since_last_record          chargeoff_within_12_mths          0.043150
# pct_tl_nvr_dlq                  num_bc_tl                         0.042177
# num_bc_tl                       pct_tl_nvr_dlq                    0.042177
# chargeoff_within_12_mths        collections_12_mths_ex_med        0.042027
# collections_12_mths_ex_med      chargeoff_within_12_mths          0.042027
# pct_tl_nvr_dlq                  dti                               0.042020
# dti                             pct_tl_nvr_dlq                    0.042020
# mo_sin_rcnt_tl                  loan_amnt                         0.041686
# loan_amnt                       mo_sin_rcnt_tl                    0.041686
# num_tl_90g_dpd_24m              delinq_amnt                       0.040582
# delinq_amnt                     num_tl_90g_dpd_24m                0.040582
# total_cu_tl                     pct_tl_nvr_dlq                    0.040010
# pct_tl_nvr_dlq                  total_cu_tl                       0.040010
# recoveries                      inq_last_6mths                    0.039129
# inq_last_6mths                  recoveries                        0.039129
#                                 loan_amnt                         0.039040
# loan_amnt                       inq_last_6mths                    0.039040
# mths_since_recent_revol_delinq  mths_since_last_record            0.038435
# mths_since_last_record          mths_since_recent_revol_delinq    0.038435
# chargeoff_within_12_mths        num_tl_120dpd_2m                  0.037937
# num_tl_120dpd_2m                chargeoff_within_12_mths          0.037937
# mo_sin_rcnt_tl                  dti                               0.037806
# dti                             mo_sin_rcnt_tl                    0.037806
# num_bc_tl                       mths_since_recent_revol_delinq    0.037502
# mths_since_recent_revol_delinq  num_bc_tl                         0.037502
# id                              mths_since_last_record            0.037319
# mths_since_last_record          id                                0.037319
# num_tl_120dpd_2m                mths_since_recent_revol_delinq    0.036336
# mths_since_recent_revol_delinq  num_tl_120dpd_2m                  0.036336
# num_tl_90g_dpd_24m              mort_acc                          0.036336
# mort_acc                        num_tl_90g_dpd_24m                0.036336
# pub_rec                         tot_coll_amt                      0.035377
# tot_coll_amt                    pub_rec                           0.035377
# il_util                         mths_since_last_record            0.033809
# mths_since_last_record          il_util                           0.033809
# chargeoff_within_12_mths        mort_acc                          0.033692
# mort_acc                        chargeoff_within_12_mths          0.033692
# dti_joint                       inq_fi                            0.032828
# inq_fi                          dti_joint                         0.032828
# total_cu_tl                     inq_last_6mths                    0.032530
# inq_last_6mths                  total_cu_tl                       0.032530
# num_bc_tl                       chargeoff_within_12_mths          0.032293
# chargeoff_within_12_mths        num_bc_tl                         0.032293
# total_rec_late_fee              mths_since_recent_revol_delinq    0.031637
# mths_since_recent_revol_delinq  total_rec_late_fee                0.031637
# num_tl_90g_dpd_24m              int_rate                          0.031344
# int_rate                        num_tl_90g_dpd_24m                0.031344
# num_tl_90g_dpd_24m              loan_amnt                         0.031334
# loan_amnt                       num_tl_90g_dpd_24m                0.031334
# inq_fi                          mths_since_last_record            0.030853
# mths_since_last_record          inq_fi                            0.030853
# inq_fi                          num_bc_tl                         0.030827
# num_bc_tl                       inq_fi                            0.030827
# mo_sin_old_il_acct              il_util                           0.028591
# il_util                         mo_sin_old_il_acct                0.028591
# num_bc_tl                       id                                0.028205
# id                              num_bc_tl                         0.028205
# num_bc_tl                       dti                               0.028171
# dti                             num_bc_tl                         0.028171
# dti_joint                       delinq_amnt                       0.027877
# delinq_amnt                     dti_joint                         0.027877
# recoveries                      inq_fi                            0.027693
# inq_fi                          recoveries                        0.027693
# collections_12_mths_ex_med      loan_amnt                         0.027454
# loan_amnt                       collections_12_mths_ex_med        0.027454
# inq_fi                          pct_tl_nvr_dlq                    0.026616
# pct_tl_nvr_dlq                  inq_fi                            0.026616
#                                 total_rec_late_fee                0.026287
# total_rec_late_fee              pct_tl_nvr_dlq                    0.026287
# collections_12_mths_ex_med      inq_last_6mths                    0.025801
# inq_last_6mths                  collections_12_mths_ex_med        0.025801
# tot_coll_amt                    inq_fi                            0.024884
# inq_fi                          tot_coll_amt                      0.024884
# mo_sin_rcnt_tl                  recoveries                        0.024589
# recoveries                      mo_sin_rcnt_tl                    0.024589
# num_bc_tl                       tot_coll_amt                      0.023352
# tot_coll_amt                    num_bc_tl                         0.023352
# pub_rec                         dti                               0.023200
# dti                             pub_rec                           0.023200
# il_util                         num_tl_90g_dpd_24m                0.022781
# num_tl_90g_dpd_24m              il_util                           0.022781
# total_cu_tl                     mths_since_last_record            0.021990
# mths_since_last_record          total_cu_tl                       0.021990
# mort_acc                        inq_last_6mths                    0.021717
# inq_last_6mths                  mort_acc                          0.021717
# tot_coll_amt                    loan_amnt                         0.021437
# loan_amnt                       tot_coll_amt                      0.021437
# il_util                         pub_rec                           0.021355
# pub_rec                         il_util                           0.021355
# mths_since_last_record          total_rec_late_fee                0.021311
# total_rec_late_fee              mths_since_last_record            0.021311
# chargeoff_within_12_mths        dti_joint                         0.021140
# dti_joint                       chargeoff_within_12_mths          0.021140
# num_tl_120dpd_2m                pct_tl_nvr_dlq                    0.021027
# pct_tl_nvr_dlq                  num_tl_120dpd_2m                  0.021027
# num_bc_tl                       num_tl_90g_dpd_24m                0.020871
# num_tl_90g_dpd_24m              num_bc_tl                         0.020871
# inq_last_6mths                  tot_coll_amt                      0.020749
# tot_coll_amt                    inq_last_6mths                    0.020749
# total_cu_tl                     int_rate                          0.020685
# int_rate                        total_cu_tl                       0.020685
# chargeoff_within_12_mths        inq_last_6mths                    0.020136
# inq_last_6mths                  chargeoff_within_12_mths          0.020136
# dti                             mort_acc                          0.020044
# mort_acc                        dti                               0.020044
# mths_since_recent_revol_delinq  inq_fi                            0.019561
# inq_fi                          mths_since_recent_revol_delinq    0.019561
# chargeoff_within_12_mths        mo_sin_old_il_acct                0.019460
# mo_sin_old_il_acct              chargeoff_within_12_mths          0.019460
# tot_coll_amt                    il_util                           0.019390
# il_util                         tot_coll_amt                      0.019390
# total_rec_late_fee              inq_last_6mths                    0.019330
# inq_last_6mths                  total_rec_late_fee                0.019330
# int_rate                        collections_12_mths_ex_med        0.019234
# collections_12_mths_ex_med      int_rate                          0.019234
# chargeoff_within_12_mths        il_util                           0.019124
# il_util                         chargeoff_within_12_mths          0.019124
# dti_joint                       loan_amnt                         0.018769
# loan_amnt                       dti_joint                         0.018769
# mort_acc                        mths_since_recent_revol_delinq    0.018656
# mths_since_recent_revol_delinq  mort_acc                          0.018656
# tot_coll_amt                    mo_sin_old_il_acct                0.018129
# mo_sin_old_il_acct              tot_coll_amt                      0.018129
# mo_sin_rcnt_tl                  mo_sin_old_il_acct                0.017177
# mo_sin_old_il_acct              mo_sin_rcnt_tl                    0.017177
# pub_rec                         collections_12_mths_ex_med        0.016719
# collections_12_mths_ex_med      pub_rec                           0.016719
# inq_last_6mths                  dti_joint                         0.016370
# dti_joint                       inq_last_6mths                    0.016370
# il_util                         delinq_amnt                       0.016289
# delinq_amnt                     il_util                           0.016289
# mort_acc                        tot_coll_amt                      0.016086
# tot_coll_amt                    mort_acc                          0.016086
# pct_tl_nvr_dlq                  delinq_amnt                       0.016077
# delinq_amnt                     pct_tl_nvr_dlq                    0.016077
# dti_joint                       collections_12_mths_ex_med        0.015914
# collections_12_mths_ex_med      dti_joint                         0.015914
# total_rec_late_fee              id                                0.015779
# id                              total_rec_late_fee                0.015779
# mort_acc                        delinq_amnt                       0.015543
# delinq_amnt                     mort_acc                          0.015543
# mths_since_recent_revol_delinq  dti_joint                         0.015510
# dti_joint                       mths_since_recent_revol_delinq    0.015510
# mths_since_last_record          collections_12_mths_ex_med        0.015383
# collections_12_mths_ex_med      mths_since_last_record            0.015383
# total_cu_tl                     collections_12_mths_ex_med        0.014588
# collections_12_mths_ex_med      total_cu_tl                       0.014588
# mo_sin_rcnt_tl                  pct_tl_nvr_dlq                    0.014469
# pct_tl_nvr_dlq                  mo_sin_rcnt_tl                    0.014469
# inq_fi                          num_tl_90g_dpd_24m                0.014341
# num_tl_90g_dpd_24m              inq_fi                            0.014341
# mths_since_last_record          loan_amnt                         0.014108
# loan_amnt                       mths_since_last_record            0.014108
# inq_last_6mths                  mo_sin_old_il_acct                0.014022
# mo_sin_old_il_acct              inq_last_6mths                    0.014022
# il_util                         pct_tl_nvr_dlq                    0.013843
# pct_tl_nvr_dlq                  il_util                           0.013843
# int_rate                        mths_since_recent_revol_delinq    0.013657
# mths_since_recent_revol_delinq  int_rate                          0.013657
# inq_fi                          id                                0.013579
# id                              inq_fi                            0.013579
# total_cu_tl                     total_rec_late_fee                0.013268
# total_rec_late_fee              total_cu_tl                       0.013268
# tot_coll_amt                    chargeoff_within_12_mths          0.013216
# chargeoff_within_12_mths        tot_coll_amt                      0.013216
# id                              mort_acc                          0.013036
# mort_acc                        id                                0.013036
# dti                             mo_sin_old_il_acct                0.012866
# mo_sin_old_il_acct              dti                               0.012866
# num_tl_120dpd_2m                inq_fi                            0.012796
# inq_fi                          num_tl_120dpd_2m                  0.012796
# tot_coll_amt                    mo_sin_rcnt_tl                    0.012672
# mo_sin_rcnt_tl                  tot_coll_amt                      0.012672
# recoveries                      total_cu_tl                       0.012112
# total_cu_tl                     recoveries                        0.012112
# pub_rec                         num_tl_90g_dpd_24m                0.011977
# num_tl_90g_dpd_24m              pub_rec                           0.011977
# id                              collections_12_mths_ex_med        0.011953
# collections_12_mths_ex_med      id                                0.011953
# int_rate                        chargeoff_within_12_mths          0.011913
# chargeoff_within_12_mths        int_rate                          0.011913
# dti                             total_cu_tl                       0.011851
# total_cu_tl                     dti                               0.011851
# num_bc_tl                       recoveries                        0.011549
# recoveries                      num_bc_tl                         0.011549
# mort_acc                        num_tl_120dpd_2m                  0.011498
# num_tl_120dpd_2m                mort_acc                          0.011498
# total_rec_late_fee              num_bc_tl                         0.011243
# num_bc_tl                       total_rec_late_fee                0.011243
# pub_rec                         num_bc_tl                         0.011189
# num_bc_tl                       pub_rec                           0.011189
#                                 collections_12_mths_ex_med        0.011185
# collections_12_mths_ex_med      num_bc_tl                         0.011185
# inq_fi                          dti                               0.011065
# dti                             inq_fi                            0.011065
# collections_12_mths_ex_med      mo_sin_rcnt_tl                    0.010853
# mo_sin_rcnt_tl                  collections_12_mths_ex_med        0.010853
# total_rec_late_fee              inq_fi                            0.010681
# inq_fi                          total_rec_late_fee                0.010681
#                                 collections_12_mths_ex_med        0.010622
# collections_12_mths_ex_med      inq_fi                            0.010622
# id                              pct_tl_nvr_dlq                    0.010366
# pct_tl_nvr_dlq                  id                                0.010366
# recoveries                      il_util                           0.010266
# il_util                         recoveries                        0.010266
# collections_12_mths_ex_med      mo_sin_old_il_acct                0.010227
# mo_sin_old_il_acct              collections_12_mths_ex_med        0.010227
# mort_acc                        collections_12_mths_ex_med        0.010133
# collections_12_mths_ex_med      mort_acc                          0.010133
# num_tl_120dpd_2m                int_rate                          0.010100
# int_rate                        num_tl_120dpd_2m                  0.010100
# collections_12_mths_ex_med      mths_since_recent_revol_delinq    0.010015
# mths_since_recent_revol_delinq  collections_12_mths_ex_med        0.010015
# total_rec_late_fee              mo_sin_rcnt_tl                    0.009785
# mo_sin_rcnt_tl                  total_rec_late_fee                0.009785
# tot_coll_amt                    int_rate                          0.009697
# int_rate                        tot_coll_amt                      0.009697
# delinq_amnt                     int_rate                          0.009647
# int_rate                        delinq_amnt                       0.009647
# total_cu_tl                     il_util                           0.009640
# il_util                         total_cu_tl                       0.009640
# loan_amnt                       inq_fi                            0.009638
# inq_fi                          loan_amnt                         0.009638
# dti_joint                       mths_since_last_record            0.009629
# mths_since_last_record          dti_joint                         0.009629
# il_util                         id                                0.009614
# id                              il_util                           0.009614
# dti                             recoveries                        0.009553
# recoveries                      dti                               0.009553
# total_rec_late_fee              num_tl_90g_dpd_24m                0.009493
# num_tl_90g_dpd_24m              total_rec_late_fee                0.009493
# int_rate                        mths_since_last_record            0.009398
# mths_since_last_record          int_rate                          0.009398
#                                 num_tl_120dpd_2m                  0.009131
# num_tl_120dpd_2m                mths_since_last_record            0.009131
# delinq_amnt                     inq_last_6mths                    0.008457
# inq_last_6mths                  delinq_amnt                       0.008457
# id                              loan_amnt                         0.008288
# loan_amnt                       id                                0.008288
# delinq_amnt                     collections_12_mths_ex_med        0.008177
# collections_12_mths_ex_med      delinq_amnt                       0.008177
# pct_tl_nvr_dlq                  recoveries                        0.007896
# recoveries                      pct_tl_nvr_dlq                    0.007896
# dti                             tot_coll_amt                      0.007619
# tot_coll_amt                    dti                               0.007619
# mort_acc                        pub_rec                           0.007400
# pub_rec                         mort_acc                          0.007400
# delinq_amnt                     chargeoff_within_12_mths          0.007182
# chargeoff_within_12_mths        delinq_amnt                       0.007182
# mo_sin_old_il_acct              recoveries                        0.007012
# recoveries                      mo_sin_old_il_acct                0.007012
# num_tl_90g_dpd_24m              tot_coll_amt                      0.006871
# tot_coll_amt                    num_tl_90g_dpd_24m                0.006871
# num_tl_120dpd_2m                mo_sin_old_il_acct                0.006614
# mo_sin_old_il_acct              num_tl_120dpd_2m                  0.006614
# total_cu_tl                     num_tl_90g_dpd_24m                0.006465
# num_tl_90g_dpd_24m              total_cu_tl                       0.006465
# delinq_amnt                     total_cu_tl                       0.006448
# total_cu_tl                     delinq_amnt                       0.006448
# dti_joint                       dti                               0.006211
# dti                             dti_joint                         0.006211
#                                 loan_amnt                         0.006103
# loan_amnt                       dti                               0.006103
# dti                             id                                0.005692
# id                              dti                               0.005692
# total_cu_tl                     tot_coll_amt                      0.005526
# tot_coll_amt                    total_cu_tl                       0.005526
# num_tl_90g_dpd_24m              dti                               0.005476
# dti                             num_tl_90g_dpd_24m                0.005476
# il_util                         total_rec_late_fee                0.005470
# total_rec_late_fee              il_util                           0.005470
# chargeoff_within_12_mths        loan_amnt                         0.005382
# loan_amnt                       chargeoff_within_12_mths          0.005382
# mo_sin_rcnt_tl                  id                                0.005305
# id                              mo_sin_rcnt_tl                    0.005305
# num_tl_120dpd_2m                id                                0.005254
# id                              num_tl_120dpd_2m                  0.005254
# mo_sin_rcnt_tl                  chargeoff_within_12_mths          0.005090
# chargeoff_within_12_mths        mo_sin_rcnt_tl                    0.005090
# inq_fi                          mo_sin_old_il_acct                0.004910
# mo_sin_old_il_acct              inq_fi                            0.004910
# tot_coll_amt                    num_tl_120dpd_2m                  0.004812
# num_tl_120dpd_2m                tot_coll_amt                      0.004812
# num_bc_tl                       num_tl_120dpd_2m                  0.004754
# num_tl_120dpd_2m                num_bc_tl                         0.004754
# num_tl_90g_dpd_24m              mo_sin_rcnt_tl                    0.004534
# mo_sin_rcnt_tl                  num_tl_90g_dpd_24m                0.004534
# recoveries                      collections_12_mths_ex_med        0.004269
# collections_12_mths_ex_med      recoveries                        0.004269
# dti                             il_util                           0.004219
# il_util                         dti                               0.004219
# total_rec_late_fee              chargeoff_within_12_mths          0.004216
# chargeoff_within_12_mths        total_rec_late_fee                0.004216
# total_rec_late_fee              collections_12_mths_ex_med        0.004134
# collections_12_mths_ex_med      total_rec_late_fee                0.004134
# recoveries                      mths_since_last_record            0.004039
# mths_since_last_record          recoveries                        0.004039
# inq_fi                          chargeoff_within_12_mths          0.003950
# chargeoff_within_12_mths        inq_fi                            0.003950
# mths_since_recent_revol_delinq  mo_sin_old_il_acct                0.003847
# mo_sin_old_il_acct              mths_since_recent_revol_delinq    0.003847
# inq_fi                          delinq_amnt                       0.003818
# delinq_amnt                     inq_fi                            0.003818
# mo_sin_old_il_acct              delinq_amnt                       0.003759
# delinq_amnt                     mo_sin_old_il_acct                0.003759
# dti_joint                       mort_acc                          0.003638
# mort_acc                        dti_joint                         0.003638
# collections_12_mths_ex_med      dti                               0.003588
# dti                             collections_12_mths_ex_med        0.003588
# pub_rec                         id                                0.003501
# id                              pub_rec                           0.003501
# mths_since_last_record          delinq_amnt                       0.003392
# delinq_amnt                     mths_since_last_record            0.003392
# dti                             mths_since_recent_revol_delinq    0.003353
# mths_since_recent_revol_delinq  dti                               0.003353
# total_cu_tl                     pub_rec                           0.003349
# pub_rec                         total_cu_tl                       0.003349
# mo_sin_rcnt_tl                  num_tl_120dpd_2m                  0.003288
# num_tl_120dpd_2m                mo_sin_rcnt_tl                    0.003288
# dti                             inq_last_6mths                    0.003277
# inq_last_6mths                  dti                               0.003277
# pub_rec                         delinq_amnt                       0.003200
# delinq_amnt                     pub_rec                           0.003200
# chargeoff_within_12_mths        recoveries                        0.002795
# recoveries                      chargeoff_within_12_mths          0.002795
# num_tl_120dpd_2m                recoveries                        0.002738
# recoveries                      num_tl_120dpd_2m                  0.002738
# dti                             delinq_amnt                       0.002667
# delinq_amnt                     dti                               0.002667
# recoveries                      mort_acc                          0.002563
# mort_acc                        recoveries                        0.002563
# num_bc_tl                       total_cu_tl                       0.002413
# total_cu_tl                     num_bc_tl                         0.002413
# total_rec_late_fee              mo_sin_old_il_acct                0.002383
# mo_sin_old_il_acct              total_rec_late_fee                0.002383
# chargeoff_within_12_mths        dti                               0.002340
# dti                             chargeoff_within_12_mths          0.002340
# id                              tot_coll_amt                      0.002312
# tot_coll_amt                    id                                0.002312
# num_tl_120dpd_2m                dti                               0.002251
# dti                             num_tl_120dpd_2m                  0.002251
# delinq_amnt                     mo_sin_rcnt_tl                    0.002235
# mo_sin_rcnt_tl                  delinq_amnt                       0.002235
# collections_12_mths_ex_med      il_util                           0.002178
# il_util                         collections_12_mths_ex_med        0.002178
# tot_coll_amt                    delinq_amnt                       0.002142
# delinq_amnt                     tot_coll_amt                      0.002142
#                                 loan_amnt                         0.002096
# loan_amnt                       delinq_amnt                       0.002096
# mths_since_last_record          mo_sin_rcnt_tl                    0.002069
# mo_sin_rcnt_tl                  mths_since_last_record            0.002069
# recoveries                      mths_since_recent_revol_delinq    0.002057
# mths_since_recent_revol_delinq  recoveries                        0.002057
# total_cu_tl                     num_tl_120dpd_2m                  0.002029
# num_tl_120dpd_2m                total_cu_tl                       0.002029
# chargeoff_within_12_mths        pub_rec                           0.001974
# pub_rec                         chargeoff_within_12_mths          0.001974
# delinq_amnt                     id                                0.001961
# id                              delinq_amnt                       0.001961
# pub_rec                         recoveries                        0.001952
# recoveries                      pub_rec                           0.001952
# delinq_amnt                     num_bc_tl                         0.001911
# num_bc_tl                       delinq_amnt                       0.001911
# num_tl_120dpd_2m                inq_last_6mths                    0.001884
# inq_last_6mths                  num_tl_120dpd_2m                  0.001884
# il_util                         num_tl_120dpd_2m                  0.001763
# num_tl_120dpd_2m                il_util                           0.001763
# num_tl_90g_dpd_24m              recoveries                        0.001556
# recoveries                      num_tl_90g_dpd_24m                0.001556
# num_tl_90g_dpd_24m              dti_joint                         0.001323
# dti_joint                       num_tl_90g_dpd_24m                0.001323
# mths_since_recent_revol_delinq  id                                0.001272
# id                              mths_since_recent_revol_delinq    0.001272
# dti                             total_rec_late_fee                0.001150
# total_rec_late_fee              dti                               0.001150
# recoveries                      delinq_amnt                       0.001075
# delinq_amnt                     recoveries                        0.001075
# chargeoff_within_12_mths        id                                0.001075
# id                              chargeoff_within_12_mths          0.001075
# pub_rec                         num_tl_120dpd_2m                  0.001069
# num_tl_120dpd_2m                pub_rec                           0.001069
# mths_since_recent_revol_delinq  delinq_amnt                       0.001022
# delinq_amnt                     mths_since_recent_revol_delinq    0.001022
# total_cu_tl                     id                                0.000914
# id                              total_cu_tl                       0.000914
# loan_amnt                       num_tl_120dpd_2m                  0.000905
# num_tl_120dpd_2m                loan_amnt                         0.000905
#                                 collections_12_mths_ex_med        0.000860
# collections_12_mths_ex_med      num_tl_120dpd_2m                  0.000860
# mths_since_recent_revol_delinq  total_cu_tl                       0.000860
# total_cu_tl                     mths_since_recent_revol_delinq    0.000860
# total_rec_late_fee              delinq_amnt                       0.000787
# delinq_amnt                     total_rec_late_fee                0.000787
# inq_last_6mths                  id                                0.000660
# id                              inq_last_6mths                    0.000660
#                                 num_tl_90g_dpd_24m                0.000612
# num_tl_90g_dpd_24m              id                                0.000612
# chargeoff_within_12_mths        total_cu_tl                       0.000372
# total_cu_tl                     chargeoff_within_12_mths          0.000372
# tot_coll_amt                    recoveries                        0.000342
# recoveries                      tot_coll_amt                      0.000342
# total_rec_late_fee              tot_coll_amt                      0.000320
# tot_coll_amt                    total_rec_late_fee                0.000320
# total_rec_late_fee              mort_acc                          0.000210
# mort_acc                        total_rec_late_fee                0.000210
# total_rec_late_fee              pub_rec                           0.000146
# pub_rec                         total_rec_late_fee                0.000146
# num_tl_120dpd_2m                total_rec_late_fee                0.000098
# total_rec_late_fee              num_tl_120dpd_2m                  0.000098
# id                              mo_sin_old_il_acct                0.000088
# mo_sin_old_il_acct              id                                0.000088
# id                              policy_code                            NaN
# loan_amnt                       policy_code                            NaN
# int_rate                        policy_code                            NaN
# dti                             policy_code                            NaN
# inq_last_6mths                  policy_code                            NaN
# mths_since_last_record          policy_code                            NaN
# pub_rec                         policy_code                            NaN
# total_rec_late_fee              policy_code                            NaN
# recoveries                      policy_code                            NaN
# collections_12_mths_ex_med      policy_code                            NaN
# policy_code                     id                                     NaN
#                                 loan_amnt                              NaN
#                                 int_rate                               NaN
#                                 dti                                    NaN
#                                 inq_last_6mths                         NaN
#                                 mths_since_last_record                 NaN
#                                 pub_rec                                NaN
#                                 total_rec_late_fee                     NaN
#                                 recoveries                             NaN
#                                 collections_12_mths_ex_med             NaN
#                                 policy_code                            NaN
#                                 dti_joint                              NaN
#                                 tot_coll_amt                           NaN
#                                 il_util                                NaN
#                                 inq_fi                                 NaN
#                                 total_cu_tl                            NaN
#                                 chargeoff_within_12_mths               NaN
#                                 delinq_amnt                            NaN
#                                 mo_sin_old_il_acct                     NaN
#                                 mo_sin_rcnt_tl                         NaN
#                                 mort_acc                               NaN
#                                 mths_since_recent_revol_delinq         NaN
#                                 num_bc_tl                              NaN
#                                 num_tl_120dpd_2m                       NaN
#                                 num_tl_90g_dpd_24m                     NaN
#                                 pct_tl_nvr_dlq                         NaN
# dti_joint                       policy_code                            NaN
#                                 num_tl_120dpd_2m                       NaN
# tot_coll_amt                    policy_code                            NaN
# il_util                         policy_code                            NaN
# inq_fi                          policy_code                            NaN
# total_cu_tl                     policy_code                            NaN
# chargeoff_within_12_mths        policy_code                            NaN
# delinq_amnt                     policy_code                            NaN
# mo_sin_old_il_acct              policy_code                            NaN
# mo_sin_rcnt_tl                  policy_code                            NaN
# mort_acc                        policy_code                            NaN
# mths_since_recent_revol_delinq  policy_code                            NaN
# num_bc_tl                       policy_code                            NaN
# num_tl_120dpd_2m                policy_code                            NaN
#                                 dti_joint                              NaN
# num_tl_90g_dpd_24m              policy_code                            NaN
# pct_tl_nvr_dlq                  policy_code                            NaN
# dtype: float64

# %%
y2015 = y2015.drop(columns = ['int_rate', 'pct_tl_nvr_dlq', 'pub_rec', 'num_tl_120dpd_2m', 'inq_last_6mths'])

# %%
## Run Random Forest with cleaned data
rfc5 = ensemble.RandomForestClassifier()
X5 = y2015.drop('loan_status', 1)
Y5 = y2015['loan_status']
X5 = pd.get_dummies(X5)
X5 = X5.dropna(axis=1)

cross_val_score(rfc5, X5, Y5, cv=10)
# Out:
# c:\users\nstow\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# c:\users\nstow\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# c:\users\nstow\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# c:\users\nstow\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# c:\users\nstow\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# c:\users\nstow\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# c:\users\nstow\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# c:\users\nstow\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# c:\users\nstow\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# c:\users\nstow\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# array([0.92830852, 0.92560139, 0.93215549, 0.92089953, 0.90774163,
#        0.9217763 , 0.90163623, 0.93808924, 0.93419146, 0.94606469])

# %%
## recreate sorted correlation matrix
c7 = y2015.corr().abs()

s7 = c7.unstack()
so7 = s7.sort_values(kind="quicksort", ascending=False)

print(so7)
# Out:
# num_tl_90g_dpd_24m              num_tl_90g_dpd_24m                1.000000
# il_util                         il_util                           1.000000
# mort_acc                        mort_acc                          1.000000
# mo_sin_rcnt_tl                  mo_sin_rcnt_tl                    1.000000
# mo_sin_old_il_acct              mo_sin_old_il_acct                1.000000
# delinq_amnt                     delinq_amnt                       1.000000
# chargeoff_within_12_mths        chargeoff_within_12_mths          1.000000
# total_cu_tl                     total_cu_tl                       1.000000
# inq_fi                          inq_fi                            1.000000
# tot_coll_amt                    tot_coll_amt                      1.000000
# num_bc_tl                       num_bc_tl                         1.000000
# dti_joint                       dti_joint                         1.000000
# collections_12_mths_ex_med      collections_12_mths_ex_med        1.000000
# recoveries                      recoveries                        1.000000
# total_rec_late_fee              total_rec_late_fee                1.000000
# mths_since_last_record          mths_since_last_record            1.000000
# dti                             dti                               1.000000
# loan_amnt                       loan_amnt                         1.000000
# mths_since_recent_revol_delinq  mths_since_recent_revol_delinq    1.000000
# id                              id                                1.000000
# mort_acc                        loan_amnt                         0.231574
# loan_amnt                       mort_acc                          0.231574
# num_tl_90g_dpd_24m              chargeoff_within_12_mths          0.219341
# chargeoff_within_12_mths        num_tl_90g_dpd_24m                0.219341
# il_util                         mo_sin_rcnt_tl                    0.206114
# mo_sin_rcnt_tl                  il_util                           0.206114
# loan_amnt                       num_bc_tl                         0.203509
# num_bc_tl                       loan_amnt                         0.203509
# mort_acc                        num_bc_tl                         0.188328
# num_bc_tl                       mort_acc                          0.188328
# mo_sin_old_il_acct              mort_acc                          0.185704
# mort_acc                        mo_sin_old_il_acct                0.185704
#                                 total_cu_tl                       0.169887
# total_cu_tl                     mort_acc                          0.169887
# mths_since_last_record          num_bc_tl                         0.157830
# num_bc_tl                       mths_since_last_record            0.157830
# il_util                         inq_fi                            0.145342
# inq_fi                          il_util                           0.145342
# num_tl_90g_dpd_24m              mths_since_recent_revol_delinq    0.141736
# mths_since_recent_revol_delinq  num_tl_90g_dpd_24m                0.141736
# loan_amnt                       mo_sin_old_il_acct                0.137114
# mo_sin_old_il_acct              loan_amnt                         0.137114
# inq_fi                          mo_sin_rcnt_tl                    0.135433
# mo_sin_rcnt_tl                  inq_fi                            0.135433
#                                 num_bc_tl                         0.129605
# num_bc_tl                       mo_sin_rcnt_tl                    0.129605
# collections_12_mths_ex_med      num_tl_90g_dpd_24m                0.120101
# num_tl_90g_dpd_24m              collections_12_mths_ex_med        0.120101
# num_bc_tl                       mo_sin_old_il_acct                0.114920
# mo_sin_old_il_acct              num_bc_tl                         0.114920
# mths_since_last_record          mort_acc                          0.108039
# mort_acc                        mths_since_last_record            0.108039
# loan_amnt                       il_util                           0.107324
# il_util                         loan_amnt                         0.107324
# dti_joint                       total_cu_tl                       0.103740
# total_cu_tl                     dti_joint                         0.103740
# mo_sin_old_il_acct              total_cu_tl                       0.096620
# total_cu_tl                     mo_sin_old_il_acct                0.096620
# mo_sin_old_il_acct              dti_joint                         0.093306
# dti_joint                       mo_sin_old_il_acct                0.093306
# id                              dti_joint                         0.092846
# dti_joint                       id                                0.092846
# inq_fi                          total_cu_tl                       0.092703
# total_cu_tl                     inq_fi                            0.092703
# mths_since_last_record          num_tl_90g_dpd_24m                0.089774
# num_tl_90g_dpd_24m              mths_since_last_record            0.089774
# total_cu_tl                     mo_sin_rcnt_tl                    0.085295
# mo_sin_rcnt_tl                  total_cu_tl                       0.085295
# dti                             mths_since_last_record            0.083465
# mths_since_last_record          dti                               0.083465
# dti_joint                       il_util                           0.079700
# il_util                         dti_joint                         0.079700
# loan_amnt                       recoveries                        0.077870
# recoveries                      loan_amnt                         0.077870
# mths_since_recent_revol_delinq  mo_sin_rcnt_tl                    0.077252
# mo_sin_rcnt_tl                  mths_since_recent_revol_delinq    0.077252
# mort_acc                        inq_fi                            0.075278
# inq_fi                          mort_acc                          0.075278
# mort_acc                        il_util                           0.073663
# il_util                         mort_acc                          0.073663
# dti_joint                       tot_coll_amt                      0.071590
# tot_coll_amt                    dti_joint                         0.071590
# total_cu_tl                     loan_amnt                         0.071500
# loan_amnt                       total_cu_tl                       0.071500
# recoveries                      dti_joint                         0.070967
# dti_joint                       recoveries                        0.070967
# recoveries                      id                                0.070027
# id                              recoveries                        0.070027
# num_bc_tl                       dti_joint                         0.069130
# dti_joint                       num_bc_tl                         0.069130
# tot_coll_amt                    mths_since_recent_revol_delinq    0.069065
# mths_since_recent_revol_delinq  tot_coll_amt                      0.069065
# recoveries                      total_rec_late_fee                0.065903
# total_rec_late_fee              recoveries                        0.065903
# mths_since_recent_revol_delinq  il_util                           0.065826
# il_util                         mths_since_recent_revol_delinq    0.065826
# num_bc_tl                       il_util                           0.062322
# il_util                         num_bc_tl                         0.062322
# dti_joint                       mo_sin_rcnt_tl                    0.056705
# mo_sin_rcnt_tl                  dti_joint                         0.056705
# total_rec_late_fee              dti_joint                         0.054897
# dti_joint                       total_rec_late_fee                0.054897
# chargeoff_within_12_mths        mths_since_recent_revol_delinq    0.053455
# mths_since_recent_revol_delinq  chargeoff_within_12_mths          0.053455
# mo_sin_old_il_acct              mths_since_last_record            0.053113
# mths_since_last_record          mo_sin_old_il_acct                0.053113
# total_rec_late_fee              loan_amnt                         0.051888
# loan_amnt                       total_rec_late_fee                0.051888
# mo_sin_old_il_acct              num_tl_90g_dpd_24m                0.050211
# num_tl_90g_dpd_24m              mo_sin_old_il_acct                0.050211
# loan_amnt                       mths_since_recent_revol_delinq    0.049828
# mths_since_recent_revol_delinq  loan_amnt                         0.049828
# mort_acc                        mo_sin_rcnt_tl                    0.048839
# mo_sin_rcnt_tl                  mort_acc                          0.048839
# tot_coll_amt                    mths_since_last_record            0.048726
# mths_since_last_record          tot_coll_amt                      0.048726
# tot_coll_amt                    collections_12_mths_ex_med        0.046012
# collections_12_mths_ex_med      tot_coll_amt                      0.046012
# chargeoff_within_12_mths        mths_since_last_record            0.043150
# mths_since_last_record          chargeoff_within_12_mths          0.043150
# chargeoff_within_12_mths        collections_12_mths_ex_med        0.042027
# collections_12_mths_ex_med      chargeoff_within_12_mths          0.042027
# loan_amnt                       mo_sin_rcnt_tl                    0.041686
# mo_sin_rcnt_tl                  loan_amnt                         0.041686
# delinq_amnt                     num_tl_90g_dpd_24m                0.040582
# num_tl_90g_dpd_24m              delinq_amnt                       0.040582
# mths_since_last_record          mths_since_recent_revol_delinq    0.038435
# mths_since_recent_revol_delinq  mths_since_last_record            0.038435
# mo_sin_rcnt_tl                  dti                               0.037806
# dti                             mo_sin_rcnt_tl                    0.037806
# mths_since_recent_revol_delinq  num_bc_tl                         0.037502
# num_bc_tl                       mths_since_recent_revol_delinq    0.037502
# id                              mths_since_last_record            0.037319
# mths_since_last_record          id                                0.037319
# mort_acc                        num_tl_90g_dpd_24m                0.036336
# num_tl_90g_dpd_24m              mort_acc                          0.036336
# il_util                         mths_since_last_record            0.033809
# mths_since_last_record          il_util                           0.033809
# mort_acc                        chargeoff_within_12_mths          0.033692
# chargeoff_within_12_mths        mort_acc                          0.033692
# dti_joint                       inq_fi                            0.032828
# inq_fi                          dti_joint                         0.032828
# chargeoff_within_12_mths        num_bc_tl                         0.032293
# num_bc_tl                       chargeoff_within_12_mths          0.032293
# mths_since_recent_revol_delinq  total_rec_late_fee                0.031637
# total_rec_late_fee              mths_since_recent_revol_delinq    0.031637
# num_tl_90g_dpd_24m              loan_amnt                         0.031334
# loan_amnt                       num_tl_90g_dpd_24m                0.031334
# mths_since_last_record          inq_fi                            0.030853
# inq_fi                          mths_since_last_record            0.030853
# num_bc_tl                       inq_fi                            0.030827
# inq_fi                          num_bc_tl                         0.030827
# il_util                         mo_sin_old_il_acct                0.028591
# mo_sin_old_il_acct              il_util                           0.028591
# num_bc_tl                       id                                0.028205
# id                              num_bc_tl                         0.028205
# dti                             num_bc_tl                         0.028171
# num_bc_tl                       dti                               0.028171
# delinq_amnt                     dti_joint                         0.027877
# dti_joint                       delinq_amnt                       0.027877
# inq_fi                          recoveries                        0.027693
# recoveries                      inq_fi                            0.027693
# loan_amnt                       collections_12_mths_ex_med        0.027454
# collections_12_mths_ex_med      loan_amnt                         0.027454
# inq_fi                          tot_coll_amt                      0.024884
# tot_coll_amt                    inq_fi                            0.024884
# mo_sin_rcnt_tl                  recoveries                        0.024589
# recoveries                      mo_sin_rcnt_tl                    0.024589
# tot_coll_amt                    num_bc_tl                         0.023352
# num_bc_tl                       tot_coll_amt                      0.023352
# num_tl_90g_dpd_24m              il_util                           0.022781
# il_util                         num_tl_90g_dpd_24m                0.022781
# mths_since_last_record          total_cu_tl                       0.021990
# total_cu_tl                     mths_since_last_record            0.021990
# tot_coll_amt                    loan_amnt                         0.021437
# loan_amnt                       tot_coll_amt                      0.021437
# total_rec_late_fee              mths_since_last_record            0.021311
# mths_since_last_record          total_rec_late_fee                0.021311
# dti_joint                       chargeoff_within_12_mths          0.021140
# chargeoff_within_12_mths        dti_joint                         0.021140
# num_bc_tl                       num_tl_90g_dpd_24m                0.020871
# num_tl_90g_dpd_24m              num_bc_tl                         0.020871
# mort_acc                        dti                               0.020044
# dti                             mort_acc                          0.020044
# inq_fi                          mths_since_recent_revol_delinq    0.019561
# mths_since_recent_revol_delinq  inq_fi                            0.019561
# chargeoff_within_12_mths        mo_sin_old_il_acct                0.019460
# mo_sin_old_il_acct              chargeoff_within_12_mths          0.019460
# il_util                         tot_coll_amt                      0.019390
# tot_coll_amt                    il_util                           0.019390
# il_util                         chargeoff_within_12_mths          0.019124
# chargeoff_within_12_mths        il_util                           0.019124
# dti_joint                       loan_amnt                         0.018769
# loan_amnt                       dti_joint                         0.018769
# mths_since_recent_revol_delinq  mort_acc                          0.018656
# mort_acc                        mths_since_recent_revol_delinq    0.018656
# tot_coll_amt                    mo_sin_old_il_acct                0.018129
# mo_sin_old_il_acct              tot_coll_amt                      0.018129
# mo_sin_rcnt_tl                  mo_sin_old_il_acct                0.017177
# mo_sin_old_il_acct              mo_sin_rcnt_tl                    0.017177
# il_util                         delinq_amnt                       0.016289
# delinq_amnt                     il_util                           0.016289
# tot_coll_amt                    mort_acc                          0.016086
# mort_acc                        tot_coll_amt                      0.016086
# dti_joint                       collections_12_mths_ex_med        0.015914
# collections_12_mths_ex_med      dti_joint                         0.015914
# total_rec_late_fee              id                                0.015779
# id                              total_rec_late_fee                0.015779
# mort_acc                        delinq_amnt                       0.015543
# delinq_amnt                     mort_acc                          0.015543
# mths_since_recent_revol_delinq  dti_joint                         0.015510
# dti_joint                       mths_since_recent_revol_delinq    0.015510
# mths_since_last_record          collections_12_mths_ex_med        0.015383
# collections_12_mths_ex_med      mths_since_last_record            0.015383
#                                 total_cu_tl                       0.014588
# total_cu_tl                     collections_12_mths_ex_med        0.014588
# inq_fi                          num_tl_90g_dpd_24m                0.014341
# num_tl_90g_dpd_24m              inq_fi                            0.014341
# loan_amnt                       mths_since_last_record            0.014108
# mths_since_last_record          loan_amnt                         0.014108
# id                              inq_fi                            0.013579
# inq_fi                          id                                0.013579
# total_cu_tl                     total_rec_late_fee                0.013268
# total_rec_late_fee              total_cu_tl                       0.013268
# tot_coll_amt                    chargeoff_within_12_mths          0.013216
# chargeoff_within_12_mths        tot_coll_amt                      0.013216
# id                              mort_acc                          0.013036
# mort_acc                        id                                0.013036
# mo_sin_old_il_acct              dti                               0.012866
# dti                             mo_sin_old_il_acct                0.012866
# tot_coll_amt                    mo_sin_rcnt_tl                    0.012672
# mo_sin_rcnt_tl                  tot_coll_amt                      0.012672
# recoveries                      total_cu_tl                       0.012112
# total_cu_tl                     recoveries                        0.012112
# collections_12_mths_ex_med      id                                0.011953
# id                              collections_12_mths_ex_med        0.011953
# dti                             total_cu_tl                       0.011851
# total_cu_tl                     dti                               0.011851
# recoveries                      num_bc_tl                         0.011549
# num_bc_tl                       recoveries                        0.011549
# total_rec_late_fee              num_bc_tl                         0.011243
# num_bc_tl                       total_rec_late_fee                0.011243
#                                 collections_12_mths_ex_med        0.011185
# collections_12_mths_ex_med      num_bc_tl                         0.011185
# dti                             inq_fi                            0.011065
# inq_fi                          dti                               0.011065
# mo_sin_rcnt_tl                  collections_12_mths_ex_med        0.010853
# collections_12_mths_ex_med      mo_sin_rcnt_tl                    0.010853
# total_rec_late_fee              inq_fi                            0.010681
# inq_fi                          total_rec_late_fee                0.010681
# collections_12_mths_ex_med      inq_fi                            0.010622
# inq_fi                          collections_12_mths_ex_med        0.010622
# il_util                         recoveries                        0.010266
# recoveries                      il_util                           0.010266
# mo_sin_old_il_acct              collections_12_mths_ex_med        0.010227
# collections_12_mths_ex_med      mo_sin_old_il_acct                0.010227
# mort_acc                        collections_12_mths_ex_med        0.010133
# collections_12_mths_ex_med      mort_acc                          0.010133
#                                 mths_since_recent_revol_delinq    0.010015
# mths_since_recent_revol_delinq  collections_12_mths_ex_med        0.010015
# total_rec_late_fee              mo_sin_rcnt_tl                    0.009785
# mo_sin_rcnt_tl                  total_rec_late_fee                0.009785
# il_util                         total_cu_tl                       0.009640
# total_cu_tl                     il_util                           0.009640
# inq_fi                          loan_amnt                         0.009638
# loan_amnt                       inq_fi                            0.009638
# mths_since_last_record          dti_joint                         0.009629
# dti_joint                       mths_since_last_record            0.009629
# il_util                         id                                0.009614
# id                              il_util                           0.009614
# dti                             recoveries                        0.009553
# recoveries                      dti                               0.009553
# total_rec_late_fee              num_tl_90g_dpd_24m                0.009493
# num_tl_90g_dpd_24m              total_rec_late_fee                0.009493
# id                              loan_amnt                         0.008288
# loan_amnt                       id                                0.008288
# collections_12_mths_ex_med      delinq_amnt                       0.008177
# delinq_amnt                     collections_12_mths_ex_med        0.008177
# tot_coll_amt                    dti                               0.007619
# dti                             tot_coll_amt                      0.007619
# delinq_amnt                     chargeoff_within_12_mths          0.007182
# chargeoff_within_12_mths        delinq_amnt                       0.007182
# mo_sin_old_il_acct              recoveries                        0.007012
# recoveries                      mo_sin_old_il_acct                0.007012
# tot_coll_amt                    num_tl_90g_dpd_24m                0.006871
# num_tl_90g_dpd_24m              tot_coll_amt                      0.006871
# total_cu_tl                     num_tl_90g_dpd_24m                0.006465
# num_tl_90g_dpd_24m              total_cu_tl                       0.006465
# delinq_amnt                     total_cu_tl                       0.006448
# total_cu_tl                     delinq_amnt                       0.006448
# dti                             dti_joint                         0.006211
# dti_joint                       dti                               0.006211
# dti                             loan_amnt                         0.006103
# loan_amnt                       dti                               0.006103
# dti                             id                                0.005692
# id                              dti                               0.005692
# total_cu_tl                     tot_coll_amt                      0.005526
# tot_coll_amt                    total_cu_tl                       0.005526
# num_tl_90g_dpd_24m              dti                               0.005476
# dti                             num_tl_90g_dpd_24m                0.005476
# il_util                         total_rec_late_fee                0.005470
# total_rec_late_fee              il_util                           0.005470
# chargeoff_within_12_mths        loan_amnt                         0.005382
# loan_amnt                       chargeoff_within_12_mths          0.005382
# id                              mo_sin_rcnt_tl                    0.005305
# mo_sin_rcnt_tl                  id                                0.005305
# chargeoff_within_12_mths        mo_sin_rcnt_tl                    0.005090
# mo_sin_rcnt_tl                  chargeoff_within_12_mths          0.005090
# inq_fi                          mo_sin_old_il_acct                0.004910
# mo_sin_old_il_acct              inq_fi                            0.004910
# mo_sin_rcnt_tl                  num_tl_90g_dpd_24m                0.004534
# num_tl_90g_dpd_24m              mo_sin_rcnt_tl                    0.004534
# recoveries                      collections_12_mths_ex_med        0.004269
# collections_12_mths_ex_med      recoveries                        0.004269
# dti                             il_util                           0.004219
# il_util                         dti                               0.004219
# total_rec_late_fee              chargeoff_within_12_mths          0.004216
# chargeoff_within_12_mths        total_rec_late_fee                0.004216
# total_rec_late_fee              collections_12_mths_ex_med        0.004134
# collections_12_mths_ex_med      total_rec_late_fee                0.004134
# mths_since_last_record          recoveries                        0.004039
# recoveries                      mths_since_last_record            0.004039
# chargeoff_within_12_mths        inq_fi                            0.003950
# inq_fi                          chargeoff_within_12_mths          0.003950
# mths_since_recent_revol_delinq  mo_sin_old_il_acct                0.003847
# mo_sin_old_il_acct              mths_since_recent_revol_delinq    0.003847
# delinq_amnt                     inq_fi                            0.003818
# inq_fi                          delinq_amnt                       0.003818
# delinq_amnt                     mo_sin_old_il_acct                0.003759
# mo_sin_old_il_acct              delinq_amnt                       0.003759
# dti_joint                       mort_acc                          0.003638
# mort_acc                        dti_joint                         0.003638
# collections_12_mths_ex_med      dti                               0.003588
# dti                             collections_12_mths_ex_med        0.003588
# delinq_amnt                     mths_since_last_record            0.003392
# mths_since_last_record          delinq_amnt                       0.003392
# dti                             mths_since_recent_revol_delinq    0.003353
# mths_since_recent_revol_delinq  dti                               0.003353
# recoveries                      chargeoff_within_12_mths          0.002795
# chargeoff_within_12_mths        recoveries                        0.002795
# dti                             delinq_amnt                       0.002667
# delinq_amnt                     dti                               0.002667
# mort_acc                        recoveries                        0.002563
# recoveries                      mort_acc                          0.002563
# total_cu_tl                     num_bc_tl                         0.002413
# num_bc_tl                       total_cu_tl                       0.002413
# mo_sin_old_il_acct              total_rec_late_fee                0.002383
# total_rec_late_fee              mo_sin_old_il_acct                0.002383
# dti                             chargeoff_within_12_mths          0.002340
# chargeoff_within_12_mths        dti                               0.002340
# tot_coll_amt                    id                                0.002312
# id                              tot_coll_amt                      0.002312
# mo_sin_rcnt_tl                  delinq_amnt                       0.002235
# delinq_amnt                     mo_sin_rcnt_tl                    0.002235
# collections_12_mths_ex_med      il_util                           0.002178
# il_util                         collections_12_mths_ex_med        0.002178
# delinq_amnt                     tot_coll_amt                      0.002142
# tot_coll_amt                    delinq_amnt                       0.002142
# delinq_amnt                     loan_amnt                         0.002096
# loan_amnt                       delinq_amnt                       0.002096
# mths_since_last_record          mo_sin_rcnt_tl                    0.002069
# mo_sin_rcnt_tl                  mths_since_last_record            0.002069
# mths_since_recent_revol_delinq  recoveries                        0.002057
# recoveries                      mths_since_recent_revol_delinq    0.002057
# delinq_amnt                     id                                0.001961
# id                              delinq_amnt                       0.001961
# num_bc_tl                       delinq_amnt                       0.001911
# delinq_amnt                     num_bc_tl                         0.001911
# recoveries                      num_tl_90g_dpd_24m                0.001556
# num_tl_90g_dpd_24m              recoveries                        0.001556
# dti_joint                       num_tl_90g_dpd_24m                0.001323
# num_tl_90g_dpd_24m              dti_joint                         0.001323
# mths_since_recent_revol_delinq  id                                0.001272
# id                              mths_since_recent_revol_delinq    0.001272
# dti                             total_rec_late_fee                0.001150
# total_rec_late_fee              dti                               0.001150
# recoveries                      delinq_amnt                       0.001075
# delinq_amnt                     recoveries                        0.001075
# chargeoff_within_12_mths        id                                0.001075
# id                              chargeoff_within_12_mths          0.001075
# mths_since_recent_revol_delinq  delinq_amnt                       0.001022
# delinq_amnt                     mths_since_recent_revol_delinq    0.001022
# total_cu_tl                     id                                0.000914
# id                              total_cu_tl                       0.000914
# mths_since_recent_revol_delinq  total_cu_tl                       0.000860
# total_cu_tl                     mths_since_recent_revol_delinq    0.000860
# total_rec_late_fee              delinq_amnt                       0.000787
# delinq_amnt                     total_rec_late_fee                0.000787
# num_tl_90g_dpd_24m              id                                0.000612
# id                              num_tl_90g_dpd_24m                0.000612
# total_cu_tl                     chargeoff_within_12_mths          0.000372
# chargeoff_within_12_mths        total_cu_tl                       0.000372
# tot_coll_amt                    recoveries                        0.000342
# recoveries                      tot_coll_amt                      0.000342
# tot_coll_amt                    total_rec_late_fee                0.000320
# total_rec_late_fee              tot_coll_amt                      0.000320
# mort_acc                        total_rec_late_fee                0.000210
# total_rec_late_fee              mort_acc                          0.000210
# id                              mo_sin_old_il_acct                0.000088
# mo_sin_old_il_acct              id                                0.000088
# id                              policy_code                            NaN
# loan_amnt                       policy_code                            NaN
# dti                             policy_code                            NaN
# mths_since_last_record          policy_code                            NaN
# total_rec_late_fee              policy_code                            NaN
# recoveries                      policy_code                            NaN
# collections_12_mths_ex_med      policy_code                            NaN
# policy_code                     id                                     NaN
#                                 loan_amnt                              NaN
#                                 dti                                    NaN
#                                 mths_since_last_record                 NaN
#                                 total_rec_late_fee                     NaN
#                                 recoveries                             NaN
#                                 collections_12_mths_ex_med             NaN
#                                 policy_code                            NaN
#                                 dti_joint                              NaN
#                                 tot_coll_amt                           NaN
#                                 il_util                                NaN
#                                 inq_fi                                 NaN
#                                 total_cu_tl                            NaN
#                                 chargeoff_within_12_mths               NaN
#                                 delinq_amnt                            NaN
#                                 mo_sin_old_il_acct                     NaN
#                                 mo_sin_rcnt_tl                         NaN
#                                 mort_acc                               NaN
#                                 mths_since_recent_revol_delinq         NaN
#                                 num_bc_tl                              NaN
#                                 num_tl_90g_dpd_24m                     NaN
# dti_joint                       policy_code                            NaN
# tot_coll_amt                    policy_code                            NaN
# il_util                         policy_code                            NaN
# inq_fi                          policy_code                            NaN
# total_cu_tl                     policy_code                            NaN
# chargeoff_within_12_mths        policy_code                            NaN
# delinq_amnt                     policy_code                            NaN
# mo_sin_old_il_acct              policy_code                            NaN
# mo_sin_rcnt_tl                  policy_code                            NaN
# mort_acc                        policy_code                            NaN
# mths_since_recent_revol_delinq  policy_code                            NaN
# num_bc_tl                       policy_code                            NaN
# num_tl_90g_dpd_24m              policy_code                            NaN
# dtype: float64

# %%
y2015 = y2015.drop(columns = ['loan_amnt', 'chargeoff_within_12_mths', 'mo_sin_rcnt_tl'])

# %%
## Run Random Forest with cleaned data
rfc6 = ensemble.RandomForestClassifier()
X6 = y2015.drop('loan_status', 1)
Y6 = y2015['loan_status']
X6 = pd.get_dummies(X6)
X6 = X6.dropna(axis=1)

cross_val_score(rfc6, X6, Y6, cv=10)
# Out:
# c:\users\nstow\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# c:\users\nstow\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# c:\users\nstow\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# c:\users\nstow\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# c:\users\nstow\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# c:\users\nstow\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# c:\users\nstow\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# c:\users\nstow\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# c:\users\nstow\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# c:\users\nstow\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# array([0.92659875, 0.93094441, 0.91987842, 0.92213436, 0.87102826,
#        0.91847542, 0.75162079, 0.92569284, 0.93412022, 0.93537738])

# %%
## recreate sorted correlation matrix
c8 = y2015.corr().abs()

s8 = c8.unstack()
so8 = s8.sort_values(kind="quicksort", ascending=False)

print(so8)
# Out:
# num_tl_90g_dpd_24m              num_tl_90g_dpd_24m                1.000000
# num_bc_tl                       num_bc_tl                         1.000000
# dti                             dti                               1.000000
# mths_since_last_record          mths_since_last_record            1.000000
# total_rec_late_fee              total_rec_late_fee                1.000000
# recoveries                      recoveries                        1.000000
# collections_12_mths_ex_med      collections_12_mths_ex_med        1.000000
# dti_joint                       dti_joint                         1.000000
# tot_coll_amt                    tot_coll_amt                      1.000000
# inq_fi                          inq_fi                            1.000000
# total_cu_tl                     total_cu_tl                       1.000000
# delinq_amnt                     delinq_amnt                       1.000000
# mo_sin_old_il_acct              mo_sin_old_il_acct                1.000000
# mort_acc                        mort_acc                          1.000000
# mths_since_recent_revol_delinq  mths_since_recent_revol_delinq    1.000000
# il_util                         il_util                           1.000000
# id                              id                                1.000000
# mort_acc                        num_bc_tl                         0.188328
# num_bc_tl                       mort_acc                          0.188328
# mo_sin_old_il_acct              mort_acc                          0.185704
# mort_acc                        mo_sin_old_il_acct                0.185704
#                                 total_cu_tl                       0.169887
# total_cu_tl                     mort_acc                          0.169887
# mths_since_last_record          num_bc_tl                         0.157830
# num_bc_tl                       mths_since_last_record            0.157830
# il_util                         inq_fi                            0.145342
# inq_fi                          il_util                           0.145342
# num_tl_90g_dpd_24m              mths_since_recent_revol_delinq    0.141736
# mths_since_recent_revol_delinq  num_tl_90g_dpd_24m                0.141736
# num_tl_90g_dpd_24m              collections_12_mths_ex_med        0.120101
# collections_12_mths_ex_med      num_tl_90g_dpd_24m                0.120101
# mo_sin_old_il_acct              num_bc_tl                         0.114920
# num_bc_tl                       mo_sin_old_il_acct                0.114920
# mths_since_last_record          mort_acc                          0.108039
# mort_acc                        mths_since_last_record            0.108039
# dti_joint                       total_cu_tl                       0.103740
# total_cu_tl                     dti_joint                         0.103740
#                                 mo_sin_old_il_acct                0.096620
# mo_sin_old_il_acct              total_cu_tl                       0.096620
# dti_joint                       mo_sin_old_il_acct                0.093306
# mo_sin_old_il_acct              dti_joint                         0.093306
# dti_joint                       id                                0.092846
# id                              dti_joint                         0.092846
# total_cu_tl                     inq_fi                            0.092703
# inq_fi                          total_cu_tl                       0.092703
# mths_since_last_record          num_tl_90g_dpd_24m                0.089774
# num_tl_90g_dpd_24m              mths_since_last_record            0.089774
# mths_since_last_record          dti                               0.083465
# dti                             mths_since_last_record            0.083465
# dti_joint                       il_util                           0.079700
# il_util                         dti_joint                         0.079700
# mort_acc                        inq_fi                            0.075278
# inq_fi                          mort_acc                          0.075278
# mort_acc                        il_util                           0.073663
# il_util                         mort_acc                          0.073663
# tot_coll_amt                    dti_joint                         0.071590
# dti_joint                       tot_coll_amt                      0.071590
#                                 recoveries                        0.070967
# recoveries                      dti_joint                         0.070967
# id                              recoveries                        0.070027
# recoveries                      id                                0.070027
# dti_joint                       num_bc_tl                         0.069130
# num_bc_tl                       dti_joint                         0.069130
# mths_since_recent_revol_delinq  tot_coll_amt                      0.069065
# tot_coll_amt                    mths_since_recent_revol_delinq    0.069065
# total_rec_late_fee              recoveries                        0.065903
# recoveries                      total_rec_late_fee                0.065903
# il_util                         mths_since_recent_revol_delinq    0.065826
# mths_since_recent_revol_delinq  il_util                           0.065826
# num_bc_tl                       il_util                           0.062322
# il_util                         num_bc_tl                         0.062322
# total_rec_late_fee              dti_joint                         0.054897
# dti_joint                       total_rec_late_fee                0.054897
# mths_since_last_record          mo_sin_old_il_acct                0.053113
# mo_sin_old_il_acct              mths_since_last_record            0.053113
# num_tl_90g_dpd_24m              mo_sin_old_il_acct                0.050211
# mo_sin_old_il_acct              num_tl_90g_dpd_24m                0.050211
# mths_since_last_record          tot_coll_amt                      0.048726
# tot_coll_amt                    mths_since_last_record            0.048726
#                                 collections_12_mths_ex_med        0.046012
# collections_12_mths_ex_med      tot_coll_amt                      0.046012
# num_tl_90g_dpd_24m              delinq_amnt                       0.040582
# delinq_amnt                     num_tl_90g_dpd_24m                0.040582
# mths_since_recent_revol_delinq  mths_since_last_record            0.038435
# mths_since_last_record          mths_since_recent_revol_delinq    0.038435
# num_bc_tl                       mths_since_recent_revol_delinq    0.037502
# mths_since_recent_revol_delinq  num_bc_tl                         0.037502
# id                              mths_since_last_record            0.037319
# mths_since_last_record          id                                0.037319
# mort_acc                        num_tl_90g_dpd_24m                0.036336
# num_tl_90g_dpd_24m              mort_acc                          0.036336
# il_util                         mths_since_last_record            0.033809
# mths_since_last_record          il_util                           0.033809
# dti_joint                       inq_fi                            0.032828
# inq_fi                          dti_joint                         0.032828
# mths_since_recent_revol_delinq  total_rec_late_fee                0.031637
# total_rec_late_fee              mths_since_recent_revol_delinq    0.031637
# mths_since_last_record          inq_fi                            0.030853
# inq_fi                          mths_since_last_record            0.030853
# num_bc_tl                       inq_fi                            0.030827
# inq_fi                          num_bc_tl                         0.030827
# il_util                         mo_sin_old_il_acct                0.028591
# mo_sin_old_il_acct              il_util                           0.028591
# id                              num_bc_tl                         0.028205
# num_bc_tl                       id                                0.028205
# dti                             num_bc_tl                         0.028171
# num_bc_tl                       dti                               0.028171
# dti_joint                       delinq_amnt                       0.027877
# delinq_amnt                     dti_joint                         0.027877
# inq_fi                          recoveries                        0.027693
# recoveries                      inq_fi                            0.027693
# inq_fi                          tot_coll_amt                      0.024884
# tot_coll_amt                    inq_fi                            0.024884
#                                 num_bc_tl                         0.023352
# num_bc_tl                       tot_coll_amt                      0.023352
# num_tl_90g_dpd_24m              il_util                           0.022781
# il_util                         num_tl_90g_dpd_24m                0.022781
# mths_since_last_record          total_cu_tl                       0.021990
# total_cu_tl                     mths_since_last_record            0.021990
# total_rec_late_fee              mths_since_last_record            0.021311
# mths_since_last_record          total_rec_late_fee                0.021311
# num_bc_tl                       num_tl_90g_dpd_24m                0.020871
# num_tl_90g_dpd_24m              num_bc_tl                         0.020871
# dti                             mort_acc                          0.020044
# mort_acc                        dti                               0.020044
# mths_since_recent_revol_delinq  inq_fi                            0.019561
# inq_fi                          mths_since_recent_revol_delinq    0.019561
# tot_coll_amt                    il_util                           0.019390
# il_util                         tot_coll_amt                      0.019390
# mths_since_recent_revol_delinq  mort_acc                          0.018656
# mort_acc                        mths_since_recent_revol_delinq    0.018656
# tot_coll_amt                    mo_sin_old_il_acct                0.018129
# mo_sin_old_il_acct              tot_coll_amt                      0.018129
# il_util                         delinq_amnt                       0.016289
# delinq_amnt                     il_util                           0.016289
# tot_coll_amt                    mort_acc                          0.016086
# mort_acc                        tot_coll_amt                      0.016086
# dti_joint                       collections_12_mths_ex_med        0.015914
# collections_12_mths_ex_med      dti_joint                         0.015914
# total_rec_late_fee              id                                0.015779
# id                              total_rec_late_fee                0.015779
# mort_acc                        delinq_amnt                       0.015543
# delinq_amnt                     mort_acc                          0.015543
# mths_since_recent_revol_delinq  dti_joint                         0.015510
# dti_joint                       mths_since_recent_revol_delinq    0.015510
# mths_since_last_record          collections_12_mths_ex_med        0.015383
# collections_12_mths_ex_med      mths_since_last_record            0.015383
# total_cu_tl                     collections_12_mths_ex_med        0.014588
# collections_12_mths_ex_med      total_cu_tl                       0.014588
# num_tl_90g_dpd_24m              inq_fi                            0.014341
# inq_fi                          num_tl_90g_dpd_24m                0.014341
#                                 id                                0.013579
# id                              inq_fi                            0.013579
# total_cu_tl                     total_rec_late_fee                0.013268
# total_rec_late_fee              total_cu_tl                       0.013268
# id                              mort_acc                          0.013036
# mort_acc                        id                                0.013036
# mo_sin_old_il_acct              dti                               0.012866
# dti                             mo_sin_old_il_acct                0.012866
# total_cu_tl                     recoveries                        0.012112
# recoveries                      total_cu_tl                       0.012112
# collections_12_mths_ex_med      id                                0.011953
# id                              collections_12_mths_ex_med        0.011953
# dti                             total_cu_tl                       0.011851
# total_cu_tl                     dti                               0.011851
# num_bc_tl                       recoveries                        0.011549
# recoveries                      num_bc_tl                         0.011549
# total_rec_late_fee              num_bc_tl                         0.011243
# num_bc_tl                       total_rec_late_fee                0.011243
#                                 collections_12_mths_ex_med        0.011185
# collections_12_mths_ex_med      num_bc_tl                         0.011185
# inq_fi                          dti                               0.011065
# dti                             inq_fi                            0.011065
# inq_fi                          total_rec_late_fee                0.010681
# total_rec_late_fee              inq_fi                            0.010681
# inq_fi                          collections_12_mths_ex_med        0.010622
# collections_12_mths_ex_med      inq_fi                            0.010622
# recoveries                      il_util                           0.010266
# il_util                         recoveries                        0.010266
# mo_sin_old_il_acct              collections_12_mths_ex_med        0.010227
# collections_12_mths_ex_med      mo_sin_old_il_acct                0.010227
#                                 mort_acc                          0.010133
# mort_acc                        collections_12_mths_ex_med        0.010133
# mths_since_recent_revol_delinq  collections_12_mths_ex_med        0.010015
# collections_12_mths_ex_med      mths_since_recent_revol_delinq    0.010015
# il_util                         total_cu_tl                       0.009640
# total_cu_tl                     il_util                           0.009640
# mths_since_last_record          dti_joint                         0.009629
# dti_joint                       mths_since_last_record            0.009629
# id                              il_util                           0.009614
# il_util                         id                                0.009614
# dti                             recoveries                        0.009553
# recoveries                      dti                               0.009553
# num_tl_90g_dpd_24m              total_rec_late_fee                0.009493
# total_rec_late_fee              num_tl_90g_dpd_24m                0.009493
# delinq_amnt                     collections_12_mths_ex_med        0.008177
# collections_12_mths_ex_med      delinq_amnt                       0.008177
# tot_coll_amt                    dti                               0.007619
# dti                             tot_coll_amt                      0.007619
# mo_sin_old_il_acct              recoveries                        0.007012
# recoveries                      mo_sin_old_il_acct                0.007012
# tot_coll_amt                    num_tl_90g_dpd_24m                0.006871
# num_tl_90g_dpd_24m              tot_coll_amt                      0.006871
# total_cu_tl                     num_tl_90g_dpd_24m                0.006465
# num_tl_90g_dpd_24m              total_cu_tl                       0.006465
# delinq_amnt                     total_cu_tl                       0.006448
# total_cu_tl                     delinq_amnt                       0.006448
# dti                             dti_joint                         0.006211
# dti_joint                       dti                               0.006211
# dti                             id                                0.005692
# id                              dti                               0.005692
# total_cu_tl                     tot_coll_amt                      0.005526
# tot_coll_amt                    total_cu_tl                       0.005526
# dti                             num_tl_90g_dpd_24m                0.005476
# num_tl_90g_dpd_24m              dti                               0.005476
# total_rec_late_fee              il_util                           0.005470
# il_util                         total_rec_late_fee                0.005470
# mo_sin_old_il_acct              inq_fi                            0.004910
# inq_fi                          mo_sin_old_il_acct                0.004910
# recoveries                      collections_12_mths_ex_med        0.004269
# collections_12_mths_ex_med      recoveries                        0.004269
# dti                             il_util                           0.004219
# il_util                         dti                               0.004219
# total_rec_late_fee              collections_12_mths_ex_med        0.004134
# collections_12_mths_ex_med      total_rec_late_fee                0.004134
# mths_since_last_record          recoveries                        0.004039
# recoveries                      mths_since_last_record            0.004039
# mths_since_recent_revol_delinq  mo_sin_old_il_acct                0.003847
# mo_sin_old_il_acct              mths_since_recent_revol_delinq    0.003847
# delinq_amnt                     inq_fi                            0.003818
# inq_fi                          delinq_amnt                       0.003818
# mo_sin_old_il_acct              delinq_amnt                       0.003759
# delinq_amnt                     mo_sin_old_il_acct                0.003759
# mort_acc                        dti_joint                         0.003638
# dti_joint                       mort_acc                          0.003638
# dti                             collections_12_mths_ex_med        0.003588
# collections_12_mths_ex_med      dti                               0.003588
# delinq_amnt                     mths_since_last_record            0.003392
# mths_since_last_record          delinq_amnt                       0.003392
# dti                             mths_since_recent_revol_delinq    0.003353
# mths_since_recent_revol_delinq  dti                               0.003353
# delinq_amnt                     dti                               0.002667
# dti                             delinq_amnt                       0.002667
# mort_acc                        recoveries                        0.002563
# recoveries                      mort_acc                          0.002563
# total_cu_tl                     num_bc_tl                         0.002413
# num_bc_tl                       total_cu_tl                       0.002413
# total_rec_late_fee              mo_sin_old_il_acct                0.002383
# mo_sin_old_il_acct              total_rec_late_fee                0.002383
# tot_coll_amt                    id                                0.002312
# id                              tot_coll_amt                      0.002312
# collections_12_mths_ex_med      il_util                           0.002178
# il_util                         collections_12_mths_ex_med        0.002178
# tot_coll_amt                    delinq_amnt                       0.002142
# delinq_amnt                     tot_coll_amt                      0.002142
# mths_since_recent_revol_delinq  recoveries                        0.002057
# recoveries                      mths_since_recent_revol_delinq    0.002057
# id                              delinq_amnt                       0.001961
# delinq_amnt                     id                                0.001961
#                                 num_bc_tl                         0.001911
# num_bc_tl                       delinq_amnt                       0.001911
# num_tl_90g_dpd_24m              recoveries                        0.001556
# recoveries                      num_tl_90g_dpd_24m                0.001556
# num_tl_90g_dpd_24m              dti_joint                         0.001323
# dti_joint                       num_tl_90g_dpd_24m                0.001323
# id                              mths_since_recent_revol_delinq    0.001272
# mths_since_recent_revol_delinq  id                                0.001272
# total_rec_late_fee              dti                               0.001150
# dti                             total_rec_late_fee                0.001150
# delinq_amnt                     recoveries                        0.001075
# recoveries                      delinq_amnt                       0.001075
# mths_since_recent_revol_delinq  delinq_amnt                       0.001022
# delinq_amnt                     mths_since_recent_revol_delinq    0.001022
# id                              total_cu_tl                       0.000914
# total_cu_tl                     id                                0.000914
#                                 mths_since_recent_revol_delinq    0.000860
# mths_since_recent_revol_delinq  total_cu_tl                       0.000860
# delinq_amnt                     total_rec_late_fee                0.000787
# total_rec_late_fee              delinq_amnt                       0.000787
# id                              num_tl_90g_dpd_24m                0.000612
# num_tl_90g_dpd_24m              id                                0.000612
# recoveries                      tot_coll_amt                      0.000342
# tot_coll_amt                    recoveries                        0.000342
# total_rec_late_fee              tot_coll_amt                      0.000320
# tot_coll_amt                    total_rec_late_fee                0.000320
# mort_acc                        total_rec_late_fee                0.000210
# total_rec_late_fee              mort_acc                          0.000210
# id                              mo_sin_old_il_acct                0.000088
# mo_sin_old_il_acct              id                                0.000088
# id                              policy_code                            NaN
# dti                             policy_code                            NaN
# mths_since_last_record          policy_code                            NaN
# total_rec_late_fee              policy_code                            NaN
# recoveries                      policy_code                            NaN
# collections_12_mths_ex_med      policy_code                            NaN
# policy_code                     id                                     NaN
#                                 dti                                    NaN
#                                 mths_since_last_record                 NaN
#                                 total_rec_late_fee                     NaN
#                                 recoveries                             NaN
#                                 collections_12_mths_ex_med             NaN
#                                 policy_code                            NaN
#                                 dti_joint                              NaN
#                                 tot_coll_amt                           NaN
#                                 il_util                                NaN
#                                 inq_fi                                 NaN
#                                 total_cu_tl                            NaN
#                                 delinq_amnt                            NaN
#                                 mo_sin_old_il_acct                     NaN
#                                 mort_acc                               NaN
#                                 mths_since_recent_revol_delinq         NaN
#                                 num_bc_tl                              NaN
#                                 num_tl_90g_dpd_24m                     NaN
# dti_joint                       policy_code                            NaN
# tot_coll_amt                    policy_code                            NaN
# il_util                         policy_code                            NaN
# inq_fi                          policy_code                            NaN
# total_cu_tl                     policy_code                            NaN
# delinq_amnt                     policy_code                            NaN
# mo_sin_old_il_acct              policy_code                            NaN
# mort_acc                        policy_code                            NaN
# mths_since_recent_revol_delinq  policy_code                            NaN
# num_bc_tl                       policy_code                            NaN
# num_tl_90g_dpd_24m              policy_code                            NaN
# dtype: float64

# %%
y2015 = y2015.drop(columns = ['num_bc_tl', 'mo_sin_old_il_acct', 'mort_acc'])

# %%
## Run Random Forest with cleaned data
rfc7 = ensemble.RandomForestClassifier()
X7 = y2015.drop('loan_status', 1)
Y7 = df['loan_status']
X7 = pd.get_dummies(X7)
X7 = X7.dropna(axis=1)

cross_val_score(rfc7, X7, Y7, cv=10)
# Out:
# c:\users\nstow\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# c:\users\nstow\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# c:\users\nstow\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# c:\users\nstow\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# c:\users\nstow\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# c:\users\nstow\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# c:\users\nstow\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# c:\users\nstow\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# c:\users\nstow\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# c:\users\nstow\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# array([0.91137707, 0.9269787 , 0.90959607, 0.9229655 , 0.87316552,
#        0.91263358, 0.84217151, 0.93725807, 0.91925333, 0.92727877])

# %% [markdown]
# ### This is still averaging at 90%. We will try one more data clean.

# %%
df = y2015

# %%
## recreate sorted correlation matrix
c9 = df.corr().abs()

s9 = c9.unstack()
so9 = s9.sort_values(kind="quicksort", ascending=False)

print(so9)
# Out:
# num_tl_90g_dpd_24m              num_tl_90g_dpd_24m                1.000000
# mths_since_recent_revol_delinq  mths_since_recent_revol_delinq    1.000000
# dti                             dti                               1.000000
# mths_since_last_record          mths_since_last_record            1.000000
# total_rec_late_fee              total_rec_late_fee                1.000000
# recoveries                      recoveries                        1.000000
# collections_12_mths_ex_med      collections_12_mths_ex_med        1.000000
# dti_joint                       dti_joint                         1.000000
# tot_coll_amt                    tot_coll_amt                      1.000000
# il_util                         il_util                           1.000000
# inq_fi                          inq_fi                            1.000000
# total_cu_tl                     total_cu_tl                       1.000000
# delinq_amnt                     delinq_amnt                       1.000000
# id                              id                                1.000000
# inq_fi                          il_util                           0.145342
# il_util                         inq_fi                            0.145342
# num_tl_90g_dpd_24m              mths_since_recent_revol_delinq    0.141736
# mths_since_recent_revol_delinq  num_tl_90g_dpd_24m                0.141736
# num_tl_90g_dpd_24m              collections_12_mths_ex_med        0.120101
# collections_12_mths_ex_med      num_tl_90g_dpd_24m                0.120101
# dti_joint                       total_cu_tl                       0.103740
# total_cu_tl                     dti_joint                         0.103740
# id                              dti_joint                         0.092846
# dti_joint                       id                                0.092846
# inq_fi                          total_cu_tl                       0.092703
# total_cu_tl                     inq_fi                            0.092703
# num_tl_90g_dpd_24m              mths_since_last_record            0.089774
# mths_since_last_record          num_tl_90g_dpd_24m                0.089774
# dti                             mths_since_last_record            0.083465
# mths_since_last_record          dti                               0.083465
# il_util                         dti_joint                         0.079700
# dti_joint                       il_util                           0.079700
# tot_coll_amt                    dti_joint                         0.071590
# dti_joint                       tot_coll_amt                      0.071590
#                                 recoveries                        0.070967
# recoveries                      dti_joint                         0.070967
# id                              recoveries                        0.070027
# recoveries                      id                                0.070027
# tot_coll_amt                    mths_since_recent_revol_delinq    0.069065
# mths_since_recent_revol_delinq  tot_coll_amt                      0.069065
# total_rec_late_fee              recoveries                        0.065903
# recoveries                      total_rec_late_fee                0.065903
# mths_since_recent_revol_delinq  il_util                           0.065826
# il_util                         mths_since_recent_revol_delinq    0.065826
# total_rec_late_fee              dti_joint                         0.054897
# dti_joint                       total_rec_late_fee                0.054897
# tot_coll_amt                    mths_since_last_record            0.048726
# mths_since_last_record          tot_coll_amt                      0.048726
# collections_12_mths_ex_med      tot_coll_amt                      0.046012
# tot_coll_amt                    collections_12_mths_ex_med        0.046012
# num_tl_90g_dpd_24m              delinq_amnt                       0.040582
# delinq_amnt                     num_tl_90g_dpd_24m                0.040582
# mths_since_recent_revol_delinq  mths_since_last_record            0.038435
# mths_since_last_record          mths_since_recent_revol_delinq    0.038435
# id                              mths_since_last_record            0.037319
# mths_since_last_record          id                                0.037319
# il_util                         mths_since_last_record            0.033809
# mths_since_last_record          il_util                           0.033809
# dti_joint                       inq_fi                            0.032828
# inq_fi                          dti_joint                         0.032828
# total_rec_late_fee              mths_since_recent_revol_delinq    0.031637
# mths_since_recent_revol_delinq  total_rec_late_fee                0.031637
# inq_fi                          mths_since_last_record            0.030853
# mths_since_last_record          inq_fi                            0.030853
# delinq_amnt                     dti_joint                         0.027877
# dti_joint                       delinq_amnt                       0.027877
# inq_fi                          recoveries                        0.027693
# recoveries                      inq_fi                            0.027693
# inq_fi                          tot_coll_amt                      0.024884
# tot_coll_amt                    inq_fi                            0.024884
# il_util                         num_tl_90g_dpd_24m                0.022781
# num_tl_90g_dpd_24m              il_util                           0.022781
# mths_since_last_record          total_cu_tl                       0.021990
# total_cu_tl                     mths_since_last_record            0.021990
# total_rec_late_fee              mths_since_last_record            0.021311
# mths_since_last_record          total_rec_late_fee                0.021311
# inq_fi                          mths_since_recent_revol_delinq    0.019561
# mths_since_recent_revol_delinq  inq_fi                            0.019561
# il_util                         tot_coll_amt                      0.019390
# tot_coll_amt                    il_util                           0.019390
# il_util                         delinq_amnt                       0.016289
# delinq_amnt                     il_util                           0.016289
# collections_12_mths_ex_med      dti_joint                         0.015914
# dti_joint                       collections_12_mths_ex_med        0.015914
# id                              total_rec_late_fee                0.015779
# total_rec_late_fee              id                                0.015779
# dti_joint                       mths_since_recent_revol_delinq    0.015510
# mths_since_recent_revol_delinq  dti_joint                         0.015510
# collections_12_mths_ex_med      mths_since_last_record            0.015383
# mths_since_last_record          collections_12_mths_ex_med        0.015383
# collections_12_mths_ex_med      total_cu_tl                       0.014588
# total_cu_tl                     collections_12_mths_ex_med        0.014588
# inq_fi                          num_tl_90g_dpd_24m                0.014341
# num_tl_90g_dpd_24m              inq_fi                            0.014341
# inq_fi                          id                                0.013579
# id                              inq_fi                            0.013579
# total_rec_late_fee              total_cu_tl                       0.013268
# total_cu_tl                     total_rec_late_fee                0.013268
# recoveries                      total_cu_tl                       0.012112
# total_cu_tl                     recoveries                        0.012112
# id                              collections_12_mths_ex_med        0.011953
# collections_12_mths_ex_med      id                                0.011953
# dti                             total_cu_tl                       0.011851
# total_cu_tl                     dti                               0.011851
# inq_fi                          dti                               0.011065
# dti                             inq_fi                            0.011065
# total_rec_late_fee              inq_fi                            0.010681
# inq_fi                          total_rec_late_fee                0.010681
#                                 collections_12_mths_ex_med        0.010622
# collections_12_mths_ex_med      inq_fi                            0.010622
# il_util                         recoveries                        0.010266
# recoveries                      il_util                           0.010266
# mths_since_recent_revol_delinq  collections_12_mths_ex_med        0.010015
# collections_12_mths_ex_med      mths_since_recent_revol_delinq    0.010015
# total_cu_tl                     il_util                           0.009640
# il_util                         total_cu_tl                       0.009640
# dti_joint                       mths_since_last_record            0.009629
# mths_since_last_record          dti_joint                         0.009629
# il_util                         id                                0.009614
# id                              il_util                           0.009614
# recoveries                      dti                               0.009553
# dti                             recoveries                        0.009553
# total_rec_late_fee              num_tl_90g_dpd_24m                0.009493
# num_tl_90g_dpd_24m              total_rec_late_fee                0.009493
# delinq_amnt                     collections_12_mths_ex_med        0.008177
# collections_12_mths_ex_med      delinq_amnt                       0.008177
# tot_coll_amt                    dti                               0.007619
# dti                             tot_coll_amt                      0.007619
# num_tl_90g_dpd_24m              tot_coll_amt                      0.006871
# tot_coll_amt                    num_tl_90g_dpd_24m                0.006871
# num_tl_90g_dpd_24m              total_cu_tl                       0.006465
# total_cu_tl                     num_tl_90g_dpd_24m                0.006465
# delinq_amnt                     total_cu_tl                       0.006448
# total_cu_tl                     delinq_amnt                       0.006448
# dti_joint                       dti                               0.006211
# dti                             dti_joint                         0.006211
#                                 id                                0.005692
# id                              dti                               0.005692
# total_cu_tl                     tot_coll_amt                      0.005526
# tot_coll_amt                    total_cu_tl                       0.005526
# num_tl_90g_dpd_24m              dti                               0.005476
# dti                             num_tl_90g_dpd_24m                0.005476
# il_util                         total_rec_late_fee                0.005470
# total_rec_late_fee              il_util                           0.005470
# recoveries                      collections_12_mths_ex_med        0.004269
# collections_12_mths_ex_med      recoveries                        0.004269
# dti                             il_util                           0.004219
# il_util                         dti                               0.004219
# total_rec_late_fee              collections_12_mths_ex_med        0.004134
# collections_12_mths_ex_med      total_rec_late_fee                0.004134
# recoveries                      mths_since_last_record            0.004039
# mths_since_last_record          recoveries                        0.004039
# delinq_amnt                     inq_fi                            0.003818
# inq_fi                          delinq_amnt                       0.003818
# dti                             collections_12_mths_ex_med        0.003588
# collections_12_mths_ex_med      dti                               0.003588
# mths_since_last_record          delinq_amnt                       0.003392
# delinq_amnt                     mths_since_last_record            0.003392
# mths_since_recent_revol_delinq  dti                               0.003353
# dti                             mths_since_recent_revol_delinq    0.003353
#                                 delinq_amnt                       0.002667
# delinq_amnt                     dti                               0.002667
# tot_coll_amt                    id                                0.002312
# id                              tot_coll_amt                      0.002312
# il_util                         collections_12_mths_ex_med        0.002178
# collections_12_mths_ex_med      il_util                           0.002178
# tot_coll_amt                    delinq_amnt                       0.002142
# delinq_amnt                     tot_coll_amt                      0.002142
# mths_since_recent_revol_delinq  recoveries                        0.002057
# recoveries                      mths_since_recent_revol_delinq    0.002057
# id                              delinq_amnt                       0.001961
# delinq_amnt                     id                                0.001961
# recoveries                      num_tl_90g_dpd_24m                0.001556
# num_tl_90g_dpd_24m              recoveries                        0.001556
#                                 dti_joint                         0.001323
# dti_joint                       num_tl_90g_dpd_24m                0.001323
# id                              mths_since_recent_revol_delinq    0.001272
# mths_since_recent_revol_delinq  id                                0.001272
# total_rec_late_fee              dti                               0.001150
# dti                             total_rec_late_fee                0.001150
# recoveries                      delinq_amnt                       0.001075
# delinq_amnt                     recoveries                        0.001075
# mths_since_recent_revol_delinq  delinq_amnt                       0.001022
# delinq_amnt                     mths_since_recent_revol_delinq    0.001022
# total_cu_tl                     id                                0.000914
# id                              total_cu_tl                       0.000914
# total_cu_tl                     mths_since_recent_revol_delinq    0.000860
# mths_since_recent_revol_delinq  total_cu_tl                       0.000860
# delinq_amnt                     total_rec_late_fee                0.000787
# total_rec_late_fee              delinq_amnt                       0.000787
# id                              num_tl_90g_dpd_24m                0.000612
# num_tl_90g_dpd_24m              id                                0.000612
# tot_coll_amt                    recoveries                        0.000342
# recoveries                      tot_coll_amt                      0.000342
# total_rec_late_fee              tot_coll_amt                      0.000320
# tot_coll_amt                    total_rec_late_fee                0.000320
# id                              policy_code                            NaN
# dti                             policy_code                            NaN
# mths_since_last_record          policy_code                            NaN
# total_rec_late_fee              policy_code                            NaN
# recoveries                      policy_code                            NaN
# collections_12_mths_ex_med      policy_code                            NaN
# policy_code                     id                                     NaN
#                                 dti                                    NaN
#                                 mths_since_last_record                 NaN
#                                 total_rec_late_fee                     NaN
#                                 recoveries                             NaN
#                                 collections_12_mths_ex_med             NaN
#                                 policy_code                            NaN
#                                 dti_joint                              NaN
#                                 tot_coll_amt                           NaN
#                                 il_util                                NaN
#                                 inq_fi                                 NaN
#                                 total_cu_tl                            NaN
#                                 delinq_amnt                            NaN
#                                 mths_since_recent_revol_delinq         NaN
#                                 num_tl_90g_dpd_24m                     NaN
# dti_joint                       policy_code                            NaN
# tot_coll_amt                    policy_code                            NaN
# il_util                         policy_code                            NaN
# inq_fi                          policy_code                            NaN
# total_cu_tl                     policy_code                            NaN
# delinq_amnt                     policy_code                            NaN
# mths_since_recent_revol_delinq  policy_code                            NaN
# num_tl_90g_dpd_24m              policy_code                            NaN
# dtype: float64

# %%
df = df.drop(columns = ['il_util', 'mths_since_recent_revol_delinq', 'collections_12_mths_ex_med'])

# %%
## Run Random Forest with cleaned data
rfc8 = ensemble.RandomForestClassifier()
X8 = y2015.drop('loan_status', 1)
Y8 = df['loan_status']
X8 = pd.get_dummies(X8)
X8 = X8.dropna(axis=1)

cross_val_score(rfc8, X8, Y8, cv=10)
# Out:
# c:\users\nstow\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# c:\users\nstow\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# c:\users\nstow\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# c:\users\nstow\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# c:\users\nstow\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# c:\users\nstow\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# c:\users\nstow\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# c:\users\nstow\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# c:\users\nstow\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# c:\users\nstow\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# array([0.88193109, 0.92942462, 0.91888105, 0.92329795, 0.87463785,
#        0.91688435, 0.76537082, 0.93863545, 0.85852709, 0.87614592])

# %% [markdown]
# ### We are now below 90% accuracy, so we will use the data before this last cleaning cycle. We will look at that data to determine if it is possible to make these conclusions without information on payment or principle information.

# %%
y2015.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 421095 entries, 0 to 421094
# Data columns (total 31 columns):
# id                                421095 non-null float64
# term                              421095 non-null object
# grade                             421095 non-null object
# emp_length                        397278 non-null object
# home_ownership                    421095 non-null object
# verification_status               421095 non-null object
# issue_d                           421095 non-null object
# loan_status                       421095 non-null object
# pymnt_plan                        421095 non-null object
# purpose                           421095 non-null object
# title                             420963 non-null object
# dti                               421095 non-null float64
# mths_since_last_record            74415 non-null float64
# initial_list_status               421095 non-null object
# total_rec_late_fee                421095 non-null float64
# recoveries                        421095 non-null float64
# last_pymnt_d                      420801 non-null object
# next_pymnt_d                      303928 non-null object
# last_credit_pull_d                421087 non-null object
# collections_12_mths_ex_med        421095 non-null float64
# policy_code                       421095 non-null float64
# application_type                  421095 non-null object
# dti_joint                         509 non-null float64
# verification_status_joint         511 non-null object
# tot_coll_amt                      421095 non-null float64
# il_util                           18617 non-null float64
# inq_fi                            21372 non-null float64
# total_cu_tl                       21372 non-null float64
# delinq_amnt                       421095 non-null float64
# mths_since_recent_revol_delinq    151737 non-null float64
# num_tl_90g_dpd_24m                421095 non-null float64
# dtypes: float64(15), object(16)
# memory usage: 99.6+ MB

# %% [markdown]
# ### It may be possible to perform the Random Forest method without information on payment or principle as there is not a lot of data remaining that relates to those two features. You would probably have to have more features than we have now (31) and the algorithm would not run as efficiently.
